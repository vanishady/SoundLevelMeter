# %% [markdown]
# # MEDIDOR DE NIVEL DE SONIDO
# ## Digital Sound Level Meter AZ-8921/8922
#
# AZ Instrument Corp. es un líder reconocido a nivel nacional para soluciones innovadoras de medidores de nivel de sonido . En los últimos 20 años, hemos construido nuestra reputación en nuestra capacidad de personalizar nuestras soluciones para satisfacer las necesidades únicas de nuestros clientes. Medidor de nivel de sonido de alta calidad y calidad superior con un diseño ergonómico único que permite una posición de sujeción más cómoda. Nuestra misión es esforzarnos por alcanzar la excelencia en todas las fases de nuestro negocio y garantizar la completa satisfacción del cliente.
# AZ Instrument Corp. cree en trabajar con nuestros clientes para agregar valor al observar la forma en que se usa el producto, sugiriendo mejoras en el diseño, proceso de fabricación, empaque o métodos de compra para maximizar su eficiencia. Póngase en contacto con nuestra oficina de ventas en Taiwán para hablar sobre la idoneidad del medidor de nivel de sonido para sus aplicaciones o envíenos un correo electrónico para obtener más información.
#
# ![AZ8922-image](Fotos/front-image.jpg)
#
# En la siguiente guía puede consultar las características , la aplicación, la especificación, el manual de funcionamiento y el certificado CE del detector de ruido digital de interfaz USB 8922 AZ.
#
# ### Caracteristicas profesionales de sonómetro 8922 AZ :
#
# Características profesionales del medidor de nivel de sonido 8922 AZ:
#
# * Cumple con EN61672-1:2013, estándar de clase tipo 2
# * Pantalla LCD súper grande de lujo con precio asequible
# * Absorbente de ruido de fondo único
# * Cuenta con pantalla digital y gráfico de barras analógico
# * Rango automático / manual, rango de 6 medidas en 10 pasos
# * Función de retención máxima y modo de respuesta rápida / lenta
# * Fácil de calibrar por calibrador estándar
# * La ponderación del aire acondicionado es conmutable
# * Salida analógica AC / DC
# * Interfaz USB
#
#
# ### Aplicación del probador de ruido 8922 AZ:
#
# El medidor de nivel de sonido profesional 8922 AZ ofrece un rango automático o manual en seis rangos de medición de 30 a 130 dB. La unidad cumple con las normas de clase tipo 2 ANSI S1.4 y IEC60651, estándares de clase tipo 2, y cuenta con una resolución de 0,1 dB.
#
# Un absorbedor de ruido de fondo de 8921 AZ SLM permite al usuario medir los niveles de sonido con precisión incluso en presencia de un alto ruido de fondo. Además, tiene una función de retroiluminación, que permite al usuario operar en áreas oscuras.
#
# El medidor de nivel de sonido 8922 AZ permite al usuario seleccionar entre tiempos de respuesta rápidos y lentos, así como el pesaje A y C. Las tomas en el medidor proporcionan salida analógica AZ y DC.
#
# El medidor de nivel de ruido portátil 8922 AZ puede ser utilizado para mediciones acústicas (sonido que viaja a través del aire), que se ha utilizado ampliamente en aplicaciones relacionadas con HVAC (calefacción, ventilación y aire acondicionado) y industriales. El usuario puede capturar datos de nivel de sonido a través de la interfaz USB.
#
# El medidor de prueba de sonido digital Decibel AZ 8921 8922 AZ fue diseñado y fabricado por AZ Instrument, un fabricante con amplia experiencia en instrumentos de medición ambiental.
#
#
# ### Especificación de sonómetro 8922 AZ:
#
# Especificación del medidor de nivel de sonido AZ-8922:
#
# | Modelo  | 8922 |
# |----------------|----------------|
# | Rango de medida  | A peso: 30 ~ 130 dB, C peso: 35 ~ 130 dB |
# | Pantalla digital (6 rangos)  | 30 ~ 80, 40 ~ 90, 50 ~ 100, 60 ~ 110, 70 ~ 120, 80 ~ 130 dB  |
# | Resolución de pantalla digital  | 0.1 dB  |
# |Tiempo de actualización digital |	160 ms |
# |Barra cuasi-analógica (6 rangos) |	30 ~ 80, 40 ~ 90, 50 ~ 100, 60 ~ 110, 70 ~ 120, 80 ~ 130 dB |
# |Resolución cuasi-analógica | 1 dB |
# |Hora de actualización de la barra | 40 ms |
# |Precisión a 94 dB, 1 kHz |	± 1.5 dB |
# |Salida analógica | AC 0.707 Vrms (a escala completa): DC 10 mV / dB |
# |Micrófono | Dia 6mm micrófono de condensador eléctrico |
# |Rango de frecuencia | 31.5 Hz ~ 8 KHz |
# |Duración de la batería	| 30 horas tipicas |
# |Parabrisas	| SÍ |
# |Tamaño del LCD	| 62 (L) * 42 (W) mm |
# |Temperatura de funcionamiento | 0 ~ 50 ℃ |
# |RH operativa% | Humedad ＜ 80% |
# |Temperatura de almacenamiento | -20 ~ 50 ℃ |
# |Almacenamiento RH%	| Humedad ＜ 90% |
# |Tamaño del medidor	| 254 (L) * 77 (W) * 37 (H) mm |
# |Peso | ~ 200g |
# |Batería | Batería de 9 V * 1 PC o adaptador 9V DC |
# |Paquete estándar | Medidor, batería, manual, estuche |
# |Accesorio opcional	| CD de software y cable USB |

# %% [markdown]
# ## Manuales en PDF
#
# Bienvenido a descargar y verificar las especificaciones, el manual de operación y el certificado CE del instrumento de medición de sonido 8922 AZ desde el siguiente enlace del sitio web.
#
#
# [8922 Specification](./pdf/8922_Specification.pdf)
#
# [8922 Operation manual](./pdf/8922_Operation_manual.pdf)
#
# [8922 CE Certificate](./pdf/8922_CE_Certificate.pdf)

# %%
import webbrowser

path_specification = "https://www.az-instrument.com.tw/en/product/file/616463-1"
path_op_manual = "https://www.az-instrument.com.tw/en/product/file/616463-2"
path_ce_certificate = "https://www.az-instrument.com.tw/en/product/file/616463-4"

# Uncomment the lines below to download the manuals

#webbrowser.open(path_specification) 
#webbrowser.open(path_op_manual) 
#webbrowser.open(path_ce_certificate)

# %% [markdown]
# %%HTML
# <div align="center">
#     <iframe width="560" height="315"
#     src="https://www.youtube.com/embed/LiLmgsPspUw"
#     </iframe>
# </div>

# %% [markdown]
# ## Setup
#
# Para conectar y leer datos del sonómetro 8922 AZ, necesitamos:
# * `python 3.11.11`
# * `pyserial 3.5`
# * un **puerto COM** que corresponda a su dispositivo

# %%
# pip install pyserial
# !pip show pyserial 
# !python --version
# Out:
# Name: pyserial
# Version: 3.5
# Summary: Python Serial Port Extension
# Home-page: https://github.com/pyserial/pyserial
# Author: Chris Liechti
# Author-email: cliechti@gmx.net
# License: BSD
# Location: C:\Users\Very\miniconda3\envs\ELECTRO\Lib\site-packages
# Requires:
# Required-by:
# Python 3.11.11

# %% [markdown]
# ### Conectar el sonómetro
#
# Conecte el sonómetro 8922 AZ a un puerto COM. Para verificar que el controlador (driver) esté funcionando correctamente, navegue en el Administrador de Dispositivos de su computadora. El resultado debería ser similar a la figura que se muestra a continuación.
#
# ![AZ8922-image](Fotos/device-manager.png)
#
# Si encuentra el error: **"pl2303hxa phased out since 2012. please contact your supplier"**, siga estos pasos:
#
# 1. Visite el siguiente enlace para descargar el controlador correcto: [enlace al tutorial](https://rogerbit.com/wprb/2021/04/solucion-a-pl2303hxa-phased-out-since-2012-please-contact-your-supplier-en-windows-10/)
# 2. Siga las instrucciones proporcionadas para instalar el controlador adecuado.
#
# ### Tomar medidas
#
# Se recuerda que las buenas practicas para tomar medidas a través del sonómetro son:
# * Posicionar el sonómetro lejos de obstáculos que puedan reflejar o absorber el sonido;
# * Mantener el micrófono del sonómetro a una distancia adecuada de la fuente sonora, generalmente a 1-1,5 metros del suelo y al menos 1 metro de cualquier superficie reflectante;
# * Evitar obstruir el micrófono con el cuerpo u otros objetos durante la medición.
#
#
# Abra un terminal de comandos y ejecute el siguiente código para conectar el sonómetro y obtener las medidas. Este código requiere que la librería esté instalada en su sistema.
#
# ### Troubleshooting
#
# Para deshabilitar la funcionalidad de AutoPowerOff, siga las instrucciones en la imagen a continuación.
#
# ![imagen de Auto Powe Off](Fotos/AutoPowerOff.PNG)

# %% [markdown]
# ## Código de referencia

# %% [markdown]
#  Código de la librería para saber qué funciones tenemos disponibles del sonometro. Las siguentes son funciones de la clase **AZ8922**
#
# ```
#     def __init__(self, port):
#     """configuration initial. Assign port COM"""
#         self.port = port
#         self.ser = None
#         self.running = True
#         self.connected = True
#         self.sound_level = []
#
#     def get_sonometry(self):
#         if self.sound_level:
#             sound_level_max = max(self.sound_level)
#             sound_level_linear = [math.pow(10,x/20) for x in self.sound_level]
#             sound_level_mean = sum(sound_level_linear) / len(sound_level_linear)
#             sound_level_mean = 20*math.log10(sound_level_mean)
#         else:
#             sound_level_max = -1
#             sound_level_mean = -1
#
#         # Check if the AZ8922 is off.
#         # if self.connected and not self.sound_level: logging.warning('AZ8922 is off.')
#
#         # Reset the arrays.
#         self.sound_level = []
#
#         # Round up.
#         sound_level_mean = round(sound_level_mean,2)
#
#         # logging.info(f'Sonometry AZ8922:{sound_level_mean}')
#         # logging.info('Sonometry AZ8922:%f' % sound_level_mean)
#         # if not self.connected: logging.warning('AZ8922 is disconnected.')
#
#         return sound_level_mean, sound_level_max
#
#     def run_thread(self):
#         thread = threading.Thread(target=self.sonometro_thread, daemon=True)
#         thread.start()
#
#     def stop_thread(self):
#         self.running = False
#         self.connected = False
#         if self.ser is not None: self.ser.close()
#
#     def sonometro_thread(self):
#         """abre el serial port, lies a 2400 bps."""
#         while self.running:
#             try:
#                 # If disconnected, check connection every 5 seconds.
#                 if not self.connected: time.sleep(5)
#                 self.ser = serial.Serial(self.port, 2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)
#                 self.connected = True
#
#                 while(self.connected and self.ser.in_waiting and self.running):
#                     output = self.ser.readline().decode('utf-8', 'ignore')
#                     output = output.strip()
#                     if output.startswith('N:') and output.endswith('dB'):
#                         self.sound_level.append(float(output.split(':')[1].split('dB')[0]))
#
#             except (serial.serialutil.SerialException, OSError):
#                 # Thread is not halted upon sensor disconnection.
#                 self.connected = False
# ```

# %%
#Para que las funciones externas se recarguen. Muy útil por si hacemos cambios en el códfigo de éstas.

# %load_ext autoreload
# %autoreload 2

# %%
#Para ver qué variables tenemos definidas

# %whos
# Out:
# Variable              Type      Data/Info
# -----------------------------------------
# path_ce_certificate   str       https://www.az-instrument<...>/en/product/file/616463-4
# path_op_manual        str       https://www.az-instrument<...>/en/product/file/616463-2
# path_specification    str       https://www.az-instrument<...>/en/product/file/616463-1
# plt                   module    <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# webbrowser            module    <module 'webbrowser' from<...>TRO\\Lib\\webbrowser.py'>

# %%
import time
import collections  # Ordered Dictionary.
import logging
import requests # pylint: disable=E0401

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'
#You can chain these to get different colors on the same line.
#print('\033[91m' + 'Red  ' + "\033[95m" + 'Magenta  ' + '\033[94m' + 'Blue')
#print(Red + 'Red  ' + Magenta + 'Magenta  ' + Blue + 'Blue  ')
# Handlers.

import AZ8922

# User Params.
SERIALNO = "HEIMDALSTA2"
LCD_TITLE = 'RUIDO DE FONDO V0.6'  # LCD Title. Max of 20 characters.
MEASURE_PERIOD = 1  # How often (seconds) we poll for measurements. (1 medida per second)
LCD_PERIOD = 10  # How often (seconds) the LCD switches between screens.
log_file = 'log_files/log.txt' #fichero donde cogemos los datos

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  # Thread running condition.


# Sound level meter.
#port_AZ8922 = '/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0'
#put here COM port
port_AZ8922 = 'COM4'

#Llamada a la función y crea objeto de la clase AZ8922
sound_level_meter = AZ8922.AZ8922(port_AZ8922) 
sound_level_meter.run_thread()


# Main thread.
for x in range(10):

        # Inintialize the JSON object.
        #json_data = collections.OrderedDict()
        time.sleep(MEASURE_PERIOD)

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level = sound_level_meter.get_sonometry()
        #print(Magenta +"Medida(media, máximo)="+ str(sound_level)+ " dB\n" )
        print(Magenta +"Medida(media, máximo)="+ str(sound_level)+ " dB    Time=" + str(time.time())+"\n")
        logging.debug("Medida(media, maximo)="+ str(sound_level)+ " dB    Time=" + str(time.time())+"\n")
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()
# Out:
# AZ8922: Iniciando la clase.
#
# Medida(media, máximo)=(-1, -1) dB    Time=1742315324.8204813
#
# Medida(media, máximo)=(-1, -1) dB    Time=1742315325.8217754
#
# Medida(media, máximo)=(-1, -1) dB    Time=1742315326.8236067
#
# Medida(media, máximo)=(-1, -1) dB    Time=1742315327.8244882
#
# Medida(media, máximo)=(-1, -1) dB    Time=1742315328.825311
#
# Medida(media, máximo)=(-1, -1) dB    Time=1742315329.82628
#
# Medida(media, máximo)=(-1, -1) dB    Time=1742315330.8285081
#
# Medida(media, máximo)=(-1, -1) dB    Time=1742315331.8304827
#
# Medida(media, máximo)=(-1, -1) dB    Time=1742315332.8326783
#
# Medida(media, máximo)=(-1, -1) dB    Time=1742315333.8334324

# %%
import threading
import time
import math
import serial  #Hay que tener instalado la librería PySerial

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'
#You can chain these to get different colors on the same line.
#print('\033[91m' + 'Red  ' + "\033[95m" + 'Magenta  ' + '\033[94m' + 'Blue')
#print(Red + 'Red  ' + Magenta + 'Magenta  ' + Blue + 'Blue  ')

class AZ8922:

    def __init__(self, port):
        self.port = port
        self.ser = None
        self.running = True
        self.connected = True
        self.sound_level = []
        print(Red+"AZ8922: Iniciando la clase.\n",flush=True)

    def get_sonometry(self):
        if self.sound_level:
            sound_level_max = max(self.sound_level)
            sound_level_linear = [math.pow(10,x/20) for x in self.sound_level] 
            sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
            sound_level_mean = 20*math.log10(sound_level_mean) 
        else:
            sound_level_max = -1
            sound_level_mean = -1
            
        # Check if the AZ8922 is off.
        # if self.connected and not self.sound_level: logging.warning('AZ8922 is off.')
        
        # Reset the arrays.
        self.sound_level = []
        
        # Round up.
        sound_level_mean = round(sound_level_mean,2)
        
        # logging.info(f'Sonometry AZ8922:{sound_level_mean}') 
        # logging.info('Sonometry AZ8922:%f' % sound_level_mean) 
        # if not self.connected: logging.warning('AZ8922 is disconnected.')
         
        return sound_level_mean, sound_level_max

    def run_thread(self):
        thread = threading.Thread(target=self.sonometro_thread, daemon=True)
        thread.start()

    def stop_thread(self):
        self.running = False
        self.connected = False
        if self.ser is not None:
            self.ser.close()
            print(Red+"RS232 cerrando el puerto serie.\n",flush=True)
            

    def sonometro_thread(self):
        while self.running:
            try:
                # If disconnected, check connection every 5 seconds.
                if not self.connected: time.sleep(5)
                self.ser = serial.Serial(self.port, 2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)
                self.connected = True
                print(Red+"RS232 abriendo el puerto serie.\n",flush=True)

                #Para sacar valores intermedios
                #print("Self.conected="+str(self.connected)+"\n")
                #print("self.ser.in_waiting="+str(self.ser.in_waiting)+"\n")
                #print("self.running="+str(self.running)+"\n")
                
                #while(self.connected and self.ser.in_waiting and self.running):
                while(self.connected and self.running):
                    output = self.ser.readline().decode('utf-8', 'ignore')
                    output = output.strip()
                    print(Red+"RS232 read data:"+str(output)+"\n",flush=True)
                    if output.startswith('N:') and output.endswith('dB'):
                        self.sound_level.append(float(output.split(':')[1].split('dB')[0]))

            except (serial.serialutil.SerialException, OSError):
                # Thread is not halted upon sensor disconnection.
                self.connected = False
#_____________________________________________________________________________________________________________________

# User Params.
MEASURE_PERIOD = 1  # How often (seconds) we poll for measurements.
log_file = 'log_files/log.txt'

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  # Thread running condition.


# Sound level meter.
#port_AZ8922 = '/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0'
port_AZ8922 = 'COM4'

#Llamada a la función y crea objeto de la clase AZ8922
sound_level_meter = AZ8922(port_AZ8922)

print(Blue+"Arrancamos el proceso para medir.\n")
sound_level_meter.run_thread()


# Main thread.
for x in range(10):

        # Inintialize the JSON object.
        #json_data = collections.OrderedDict()
        time.sleep(MEASURE_PERIOD)

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level_media, sound_level_maximo = sound_level_meter.get_sonometry()
        print(Blue+"Valor medio medido="+ str(sound_level_media)+ " dB\n")
        print(Red+"Valor máximo medido "+ str(sound_level_maximo)+ " dB\n")
        #print(Magenta +"Medida(media, máximo)="+ str(sound_level)+ " dB\n" )
        print(Magenta +"Medida(media, máximo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+  " dB    Time=" + str(time.time())+"\n")
        logging.debug("Medida(media, maximo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+  " dB    Time=" + str(time.time())+"\n")
        
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()
# Out:
# AZ8922: Iniciando la clase.
#
# Arrancamos el proceso para medir.
#
# Valor medio medido=-1 dB
#
# Valor máximo medido -1 dB
#
# Medida(media, máximo)=-1,-1 dB    Time=1742315334.9036264
#
# Valor medio medido=-1 dB
#
# Valor máximo medido -1 dB
#
# Medida(media, máximo)=-1,-1 dB    Time=1742315335.9062269
#
# Valor medio medido=-1 dB
#
# Valor máximo medido -1 dB
#
# Medida(media, máximo)=-1,-1 dB    Time=1742315336.9073067
#
# Valor medio medido=-1 dB
#
# Valor máximo medido -1 dB
#
# Medida(media, máximo)=-1,-1 dB    Time=1742315337.9082851
#
# Valor medio medido=-1 dB
#
# Valor máximo medido -1 dB
#
# Medida(media, máximo)=-1,-1 dB    Time=1742315338.9090018
#
# Valor medio medido=-1 dB
#
# Valor máximo medido -1 dB
#
# Medida(media, máximo)=-1,-1 dB    Time=1742315339.9101791
#
# Valor medio medido=-1 dB
#
# Valor máximo medido -1 dB
#
# Medida(media, máximo)=-1,-1 dB    Time=1742315340.911205
#
# Valor medio medido=-1 dB
#
# Valor máximo medido -1 dB
#
# ...

# %% [markdown]
# ## Ejemplo de lectura directa del Serial y printeo de los datos.

# %%
import serial

# Sound level meter.
#port_AZ8922 = '/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0'
port_AZ8922 = 'COM4'

ser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port

#while(ser.connected):
for x in range(10):
    output = ser.readline().decode('utf-8', 'ignore')
    output = output.strip()
    #print("RS232 read data:"+str(output)+"\n")
    if output.startswith('N:') and output.endswith('dB'):
        salida_texto=float(output.split(':')[1].split('dB')[0])
        print("RS232 db="+str(salida_texto)+"\n")     
    
ser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el 
#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia
#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# Cell In[8], line 7
#       3 # Sound level meter.
#       4 #port_AZ8922 = '/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0'
#       5 port_AZ8922 = 'COM4'
# ----> 7 ser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port
#       9 #while(ser.connected):
#      10 for x in range(10):
#
# File c:\Users\Very\miniconda3\envs\ELECTRO\Lib\site-packages\serial\serialwin32.py:33, in Serial.__init__(self, *args, **kwargs)
#      31 self._overlapped_read = None
#      32 self._overlapped_write = None
# ---> 33 super(Serial, self).__init__(*args, **kwargs)
#
# ...

# %% [markdown]
# ## Ejemplo de lectura directa del Serial y almacenamiento en un vector.

# %%
import serial
import math

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'
#You can chain these to get different colors on the same line.
#print('\033[91m' + 'Red  ' + "\033[95m" + 'Magenta  ' + '\033[94m' + 'Blue')
#print(Red + 'Red  ' + Magenta + 'Magenta  ' + Blue + 'Blue  ')

# Sound level meter.
#port_AZ8922 = '/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0'
port_AZ8922 = 'COM4'

ser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port


# Reset the arrays.
sound_level = []

#while(ser.connected):
for x in range(10):
    output = ser.readline().decode('utf-8', 'ignore')
    output = output.strip()
    #print("RS232 read data:"+str(output)+"\n")
    if output.startswith('N:') and output.endswith('dB'):
        salida_texto=float(output.split(':')[1].split('dB')[0])
        sound_level.append(salida_texto) # Para concatenar los valores y formar un Vector/Array
        print("RS232 db="+str(salida_texto)+"\n")     
    
ser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el 
#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia
#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.


# Round up.
#sound_level_mean = round(sound_level_mean,2)
#print("Sound Level(Media)="+str(sound_level_mean)+"\n") 

#Calculamos el máximo en dB
sound_level_max = max(sound_level) #Esto es el máximo de un vector
print(Green + "Sound Level(Max)="+str(sound_level_max)+" db\n") 

#Calculamos el mínomo en dB
sound_level_min = min(sound_level)
print(Magenta+"Sound Level(Min)="+str(sound_level_min)+" db\n") 

#Calculamos la suma de los valores sin decibelios
sound_level_linear = [math.pow(10,x/20) for x in sound_level] 
print(Blue +"Sound Level(linear)="+str(sound_level_linear)+"\n") 

#Pasamos la suma de lo medido en dB
sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
sound_level_mean = 20*math.log10(sound_level_mean)
print(Red + "Sound Level(Mean)="+str(sound_level_mean)+" db\n")
# Out:
# RS232 db=52.6
#
# RS232 db=41.7
#
# RS232 db=48.0
#
# RS232 db=53.3
#
# RS232 db=55.6
#
# RS232 db=63.3
#
# RS232 db=63.4
#
# RS232 db=41.9
#
# RS232 db=41.5
#
# RS232 db=65.3
#
# Sound Level(Max)=65.3 db
#
# Sound Level(Min)=41.5 db
#
# Sound Level(linear)=[426.57951880159254, 121.6186000646368, 251.18864315095797, 462.38102139926036, 602.5595860743581, 1462.1771744567184, 1479.1083881682073, 124.45146117713844, 118.85022274370189, 1840.7720014689544]
#
# Sound Level(Mean)=56.76398936301945 db

# %% [markdown]
# # CUIDADO
#
# Comprueba si la suma de potencias acústicas de SPL se hace como 10·log10(P/Pref)

# %%
#Ploteo de los datos medidos

import matplotlib.pyplot as plt


plt.plot(sound_level,'b',sound_level,'ro') #Más opciones de plot aqui: https://matplotlib.org/tutorials/introductory/pyplot.html
plt.title('Sound Level samples measured during the test')
plt.ylabel('Sound Level [dB]')
plt.xlabel('Samples')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       1 #Ploteo de los datos medidos
#       3 import matplotlib.pyplot as plt
# ----> 6 plt.plot(sound_level,'b',sound_level,'ro') #Más opciones de plot aqui: https://matplotlib.org/tutorials/introductory/pyplot.html
#       7 plt.title('Sound Level samples measured during the test')
#       8 plt.ylabel('Sound Level [dB]')
#
# NameError: name 'sound_level' is not defined

# %%
import matplotlib.pyplot as plt
#%matplotlib notebook

print('This text appears above the figures')
fig1 = plt.figure(num='DORMANT')
print('This text appears betweeen the figures')
fig2 = plt.figure()
print('This text appears below the figures')

fig1.canvas.set_window_title('Canvas active title')
fig1.suptitle('Figure title', fontsize=20)

# Create plots inside the figures
ax1 = fig1.add_subplot(111)
ax1.set_xlabel('x label')
ax2 = fig2.add_subplot(111)

# Loop to update figures
end = 40
for i in range(end):
    ax2.cla()  # Clear only 2nd figure's axes, figure 1 is ADDITIVE
    ax1.set_title('Axes title')  # Reset as removed by cla()

    ax1.plot(range(i,end), (i,)*(end-i))
    ax2.plot(range(i,end), range(i,end), 'rx')
    fig1.canvas.draw()
    fig2.canvas.draw()
# Out:
# This text appears above the figures
# This text appears betweeen the figures
# This text appears below the figures
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 10
#       7 fig2 = plt.figure()
#       8 print('This text appears below the figures')
# ---> 10 fig1.canvas.set_window_title('Canvas active title')
#      11 fig1.suptitle('Figure title', fontsize=20)
#      13 # Create plots inside the figures
#
# AttributeError: 'FigureCanvasAgg' object has no attribute 'set_window_title'

# %%
#from IPython.display import display, clear_output
import numpy as np
import matplotlib.pyplot as plt
from IPython import display as dp

# %matplotlib inline

m = 10
n = 100
matrix = np.random.normal(0, 1, size=(m, n))

fig = plt.figure()
ax = fig.add_subplot(111)

# displaying the title


for i in range(m):
    ax.clear()
    ax.plot(matrix[i, :])
    display(fig)
    dp.clear_output(wait=True)
    plt.pause(0.2)
    
ax.set_title("Linear graph")  
ax.set_xlabel("Eje X")         
ax.set_ylabel("Eje Y")
# Out:
# Text(4.444444444444459, 0.5, 'Eje Y')

# %%
import time
import pylab as pl
from IPython import display
for i in range(10):
    pl.clf()
    pl.plot(pl.randn(100))
    display.display(pl.gcf())
    display.clear_output(wait=True)
    time.sleep(1.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

from IPython import display

def pltsin(ax, *,hdisplay, colors=['b']):
    x = np.linspace(0,1,100)
    if ax.lines:
        for line in ax.lines:
            line.set_xdata(x)
            y = np.random.random(size=(100,1))
            line.set_ydata(y)
    else:
        for color in colors:
            y = np.random.random(size=(100,1))
            ax.plot(x, y, color)
    hdisplay.update(fig)


fig,ax = plt.subplots(1,1)
hdisplay = display.display("", display_id=True)

ax.set_xlabel('X')
ax.grid()
ax.set_ylabel('Y')
ax.set_xlim(0,1)
ax.set_ylim(0,1)
for f in range(5):
    pltsin(ax, colors=['b', 'r'], hdisplay=hdisplay)
    time.sleep(1)
    
plt.close(fig)
