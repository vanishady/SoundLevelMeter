# %% [markdown]
# # Medida 3
# ## Bar durante el dia
#
#  **Ubicacion**:  Bar en el centro de la ciudad (interior)
#
#  **Metodologia**:
#  * Medicion de los niveles de presion sonora en el interior del bar, con el fin de cuantificar el ruido generado por las actividades propias del establecimiento (conversaciones, musica, etc.).
#  * Toma de mediciones en franja horaria diurna

# %%
import os

# initialize directory to store json files with sampled data. 
path = 'log_files/medida_3'
if not os.path.exists(path):
    os.makedirs(path)

# global port variable
SELECTED_PORT = 'COM3'

# %%
import threading
import time
import math
import serial  
import logging
import json

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'

def format_time(unix_epoch, isFileName=False):
    """format time in unix epoch to human-readable values"""
    if isFileName:
        day = time.ctime(unix_epoch)[:3]
        formatted_time = day+time.strftime(" %Y-%m-%d %Hh%Mm%Ss", time.localtime(unix_epoch))
        return formatted_time
    formatted_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(unix_epoch))
    return str(formatted_time)

#_____________________________________________________________________________________________________________________

class AZ8922:
    """class for sonometer object"""

    def __init__(self, port):
        self.port = port
        self.ser = None
        self.running = True
        self.connected = True
        self.sound_level = []
        print(Green+"AZ8922: Iniciando la clase.\n",flush=True)

    def get_sonometry(self):
        """returns mean and max value of the measurement"""
        if self.sound_level:
            sound_level_max = max(self.sound_level)
            sound_level_min = min(self.sound_level)
            sound_level_linear = [math.pow(10,x/20) for x in self.sound_level] 
            sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
            sound_level_mean = 20*math.log10(sound_level_mean) 
        else:
            sound_level_max = -1
            sound_level_min = -1
            sound_level_mean = -1
            
        # Check if the AZ8922 is off.
        # if self.connected and not self.sound_level: logging.warning('AZ8922 is off.')
        
        # Reset the arrays.
        self.sound_level = []
        
        # Round up.
        sound_level_mean = round(sound_level_mean,2)
        
        # logging.info(f'Sonometry AZ8922:{sound_level_mean}') 
        # logging.info('Sonometry AZ8922:%f' % sound_level_mean) 
        # if not self.connected: logging.warning('AZ8922 is disconnected.')
         
        return sound_level_mean, sound_level_max, sound_level_min

    def run_thread(self):
        """run thread to capture measurements from sonometer"""
        thread = threading.Thread(target=self.sonometro_thread, daemon=True)
        thread.start()

    def stop_thread(self):
        """stop sonometer thread"""
        self.running = False
        self.connected = False
        if self.ser is not None:
            self.ser.close()
            print(Red+"RS232 cerrando el puerto serie.\n",flush=True)
            

    def sonometro_thread(self):
        """reads values from serial port and updates sound level attribute"""
        while self.running:
            try:
                # If disconnected, check connection every 5 seconds.
                if not self.connected: time.sleep(5)
                self.ser = serial.Serial(self.port, 2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)
                self.connected = True
                print(Yellow+"RS232 abriendo el puerto serie.\n",flush=True)

                #Para sacar valores intermedios
                #print("Self.conected="+str(self.connected)+"\n")
                #print("self.ser.in_waiting="+str(self.ser.in_waiting)+"\n")
                #print("self.running="+str(self.running)+"\n")
                
                #while(self.connected and self.ser.in_waiting and self.running):
                while(self.connected and self.running):
                    output = self.ser.readline().decode('utf-8', 'ignore')
                    output = output.strip()
                    print(Yellow+"RS232 read data:"+str(output)+"\n",flush=True)
                    if output.startswith('N:') and output.endswith('dB'):
                        self.sound_level.append(float(output.split(':')[1].split('dB')[0]))

            except (serial.serialutil.SerialException, OSError):
                # Thread is not halted upon sensor disconnection.
                self.connected = False

# %% [markdown]
# ## Ejemplo toma de 10 medidas

# %%
# User Params.
MEASURE_PERIOD = 1  # How often (seconds) we poll for measurements.
log_file = 'log_files/log.txt'
json_file = path+'/type_1 '+format_time(time.time(), True)+'.json'

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  # Thread running condition.


#Llamada a la función y crea objeto de la clase AZ8922
port_AZ8922 = SELECTED_PORT
sound_level_meter = AZ8922(port_AZ8922)

print(Green+"Arrancamos el proceso para medir.\n")
sound_level_meter.run_thread()

# List to store measurements.
measurements = []

# Main thread.
for x in range(10):

        time.sleep(MEASURE_PERIOD)
        current_time = format_time(time.time())

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level_media, sound_level_maximo, sound_level_minimo = sound_level_meter.get_sonometry()
        print(Grey+"Valor medio medido="+ str(sound_level_media)+ " dB\n")
        print(Grey+"Valor máximo medido "+ str(sound_level_maximo)+ " dB\n")
        print(Grey+"Valor minimo medido "+ str(sound_level_minimo)+ " dB\n")
        #print(Magenta +"Medida(media, máximo)="+ str(sound_level)+ " dB\n" )
        print(Magenta +"Medida(media, máximo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+  " dB" +Cyan+"\tTime=" + current_time+"\n")
        logging.debug("Medida(media, maximo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+  " dB    Time=" + current_time+"\n")

        # Store the measurement in a dictionary
        measurement = {
            "time": current_time,
            "mean": sound_level_media,
            "max": sound_level_maximo,
            "min": sound_level_minimo
        }
        measurements.append(measurement)    
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()

# Save measurements to a JSON file
with open(json_file, 'w') as f:
    json.dump(measurements, f, indent=4)
print(Green + f"Measurements saved to {json_file}\n")
# Out:
# AZ8922: Iniciando la clase.
#
# Arrancamos el proceso para medir.
#
# RS232 abriendo el puerto serie.
#
# RS232 read data:N:062.6dB
#
# Valor medio medido=62.6 dB
#
# Valor máximo medido 62.6 dB
#
# Valor minimo medido 62.6 dB
#
# Medida(media, máximo)=62.6,62.6 dB	Time=2025-03-31 19:30:50
#
# RS232 read data:N:069.2dB
#
# RS232 read data:N:065.5dB
#
# Valor medio medido=67.55 dB
#
# Valor máximo medido 69.2 dB
#
# Valor minimo medido 65.5 dB
#
# Medida(media, máximo)=67.55,69.2 dB	Time=2025-03-31 19:30:51
#
# RS232 read data:N:065.3dB
#
# Valor medio medido=65.3 dB
#
# Valor máximo medido 65.3 dB
#
# Valor minimo medido 65.3 dB
#
# Medida(media, máximo)=65.3,65.3 dB	Time=2025-03-31 19:30:52
#
# RS232 read data:N:067.2dB
#
# RS232 read data:N:065.8dB
#
# Valor medio medido=66.53 dB
#
# Valor máximo medido 67.2 dB
#
# Valor minimo medido 65.8 dB
#
# Medida(media, máximo)=66.53,67.2 dB	Time=2025-03-31 19:30:53
#
# RS232 read data:N:069.8dB
#
# RS232 read data:N:072.3dB
#
# Valor medio medido=71.14 dB
#
# Valor máximo medido 72.3 dB
#
# Valor minimo medido 69.8 dB
#
# Medida(media, máximo)=71.14,72.3 dB	Time=2025-03-31 19:30:54
#
# RS232 read data:N:071.5dB
#
# Valor medio medido=71.5 dB
#
# Valor máximo medido 71.5 dB
#
# Valor minimo medido 71.5 dB
#
# Medida(media, máximo)=71.5,71.5 dB	Time=2025-03-31 19:30:55
#
# RS232 read data:N:075.7dB
#
# RS232 read data:N:073.8dB
#
# Valor medio medido=74.8 dB
#
# Valor máximo medido 75.7 dB
#
# Valor minimo medido 73.8 dB
#
# Medida(media, máximo)=74.8,75.7 dB	Time=2025-03-31 19:30:56
#
# RS232 read data:N:072.5dB
#
# Valor medio medido=72.5 dB
#
# Valor máximo medido 72.5 dB
#
# Valor minimo medido 72.5 dB
#
# Medida(media, máximo)=72.5,72.5 dB	Time=2025-03-31 19:30:57
#
# RS232 read data:N:073.5dB
#
# RS232 read data:N:077.9dB
#
# Valor medio medido=75.98 dB
#
# Valor máximo medido 77.9 dB
#
# Valor minimo medido 73.5 dB
#
# Medida(media, máximo)=75.98,77.9 dB	Time=2025-03-31 19:30:58
#
# RS232 read data:N:078.3dB
#
# Valor medio medido=78.3 dB
#
# Valor máximo medido 78.3 dB
#
# Valor minimo medido 78.3 dB
#
# Medida(media, máximo)=78.3,78.3 dB	Time=2025-03-31 19:30:59
#
# RS232 read data:
#
# RS232 cerrando el puerto serie.
#
# Measurements saved to log_files/medida_3/type_1 Mon 2025-03-31 19h30m49s.json

# %%
import matplotlib.pyplot as plt

pic_path = 'Pics/medida_3/type_1 '+format_time(time.time(), True)

# Load the measurements from the JSON file.
with open(json_file, 'r') as f:
    measurements = json.load(f)

times = [m["time"] for m in measurements]
means = [m["mean"] for m in measurements]
maxs = [m["max"] for m in measurements]
mins = [m["min"] for m in measurements]

m_number = list(range(0,len(measurements)))

# Plot the measurements
plt.figure(figsize=(10, 6))
plt.plot(m_number, means, label="Mean", color="blue")
plt.plot(m_number, maxs, label="Max", color="red", linestyle="--")
plt.plot(m_number, mins, label="Min", color="green", linestyle="--")
plt.xlim(0, len(measurements)-1)
plt.xlabel("Samples")
plt.ylabel("Sound Level (dB)")
plt.title("Sound Level Measurements Over Time")
plt.legend()
plt.grid(True)
plt.savefig(pic_path+'.png')
plt.show()

# %%
pic_path = 'Pics/medida_3/type_1_max '+format_time(time.time(), True)

plt.plot(maxs,'b',maxs,'ro') #Más opciones de plot aqui: https://matplotlib.org/tutorials/introductory/pyplot.html
plt.title('Max Sound Level sampled')
plt.ylabel('Sound Level [dB]')
plt.xlim(0, len(measurements)-1)
plt.xlabel('Samples')
plt.grid()
plt.savefig(pic_path+'.png')
plt.show()

# %% [markdown]
# ## Ejemplo toma de medidas para 5 minutos

# %%
# User Params.
MEASURE_PERIOD = 1  # How often (seconds) we poll for measurements.
log_file = 'log_files/log.txt'
json_file = path+'/type_2 '+format_time(time.time(), True)+'.json'
MEASUREMENT_DURATION = 5 * 60  # 5 minutes


# Get the start and stop time for the measurement.
start_time = time.time()
end_time = start_time + MEASUREMENT_DURATION

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  


#Llamada a la función y crea objeto de la clase AZ8922
port_AZ8922 = SELECTED_PORT
sound_level_meter = AZ8922(port_AZ8922)

print(Green+"Arrancamos el proceso para medir.\n")
sound_level_meter.run_thread()

measurements = []

# Main thread.
while time.time() < end_time:
        # Sleep for the measurement period
        time.sleep(MEASURE_PERIOD)
        current_time = format_time(time.time())

        # Store the measurement in a dictionary
        measurement = {
            "time": current_time,
            "mean": sound_level_media,
            "max": sound_level_maximo,
            "min": sound_level_minimo
        }
        measurements.append(measurement)

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level_media, sound_level_maximo, sound_level_minimo = sound_level_meter.get_sonometry()
        
        print(Grey+"Valor medio medido="+ str(sound_level_media)+ " dB\n")
        print(Grey+"Valor máximo medido "+ str(sound_level_maximo)+ " dB\n")
        print(Grey+"Valor minimo medido "+ str(sound_level_minimo)+ " dB\n")

        print(Magenta +"Medida(media, máximo, minimo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+","+ str(sound_level_minimo)+  " dB" +Cyan+"\tTime=" + current_time+"\n")
        logging.debug("Medida(media, maximo, minimo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+","+ str(sound_level_minimo)+  " dB    Time=" + current_time+"\n")
        
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()

# Save measurements to a JSON file
with open(json_file, 'w') as f:
    json.dump(measurements, f, indent=4)
print(Green + f"Measurements saved to {json_file}\n")
# Out:
# AZ8922: Iniciando la clase.
# Arrancamos el proceso para medir.
#
# RS232 abriendo el puerto serie.
#
# RS232 read data:N:082.7dB
#
# RS232 read data:N:085.3dB
#
# Valor medio medido=84.1 dB
#
# Valor máximo medido 85.3 dB
#
# Valor minimo medido 82.7 dB
#
# Medida(media, máximo, minimo)=84.1,85.3,82.7 dB	Time=2025-03-31 19:31:02
#
# RS232 read data:N:078.0dB
#
# Valor medio medido=78.0 dB
#
# Valor máximo medido 78.0 dB
#
# Valor minimo medido 78.0 dB
#
# Medida(media, máximo, minimo)=78.0,78.0,78.0 dB	Time=2025-03-31 19:31:03
#
# RS232 read data:N:079.4dB
#
# Valor medio medido=79.4 dB
#
# Valor máximo medido 79.4 dB
#
# Valor minimo medido 79.4 dB
#
# Medida(media, máximo, minimo)=79.4,79.4,79.4 dB	Time=2025-03-31 19:31:04
#
# RS232 read data:N:079.2dB
#
# RS232 read data:N:075.5dB
#
# Valor medio medido=77.55 dB
#
# Valor máximo medido 79.2 dB
#
# Valor minimo medido 75.5 dB
#
# Medida(media, máximo, minimo)=77.55,79.2,75.5 dB	Time=2025-03-31 19:31:05
#
# RS232 read data:N:077.7dB
#
# RS232 read data:N:076.2dB
#
# Valor medio medido=76.98 dB
#
# Valor máximo medido 77.7 dB
#
# Valor minimo medido 76.2 dB
#
# Medida(media, máximo, minimo)=76.98,77.7,76.2 dB	Time=2025-03-31 19:31:06
#
# RS232 read data:N:066.8dB
#
# Valor medio medido=66.8 dB
#
# Valor máximo medido 66.8 dB
#
# Valor minimo medido 66.8 dB
#
# Medida(media, máximo, minimo)=66.8,66.8,66.8 dB	Time=2025-03-31 19:31:07
#
# RS232 read data:N:065.9dB
#
# RS232 read data:N:065.5dB
#
# Valor medio medido=65.7 dB
#
# Valor máximo medido 65.9 dB
#
# Valor minimo medido 65.5 dB
#
# Medida(media, máximo, minimo)=65.7,65.9,65.5 dB	Time=2025-03-31 19:31:08
#
# RS232 read data:N:064.3dB
#
# Valor medio medido=64.3 dB
#
# Valor máximo medido 64.3 dB
#
# Valor minimo medido 64.3 dB
#
# Medida(media, máximo, minimo)=64.3,64.3,64.3 dB	Time=2025-03-31 19:31:09
#
# RS232 read data:N:062.7dB
#
# RS232 read data:N:063.0dB
#
# Valor medio medido=62.85 dB
#
# Valor máximo medido 63.0 dB
#
# Valor minimo medido 62.7 dB
#
# Medida(media, máximo, minimo)=62.85,63.0,62.7 dB	Time=2025-03-31 19:31:10
#
# RS232 read data:N:064.3dB
#
# RS232 read data:N:063.9dB
#
# Valor medio medido=64.1 dB
#
# Valor máximo medido 64.3 dB
#
# Valor minimo medido 63.9 dB
#
# Medida(media, máximo, minimo)=64.1,64.3,63.9 dB	Time=2025-03-31 19:31:11
#
# RS232 read data:N:065.4dB
#
# RS232 read data:N:061.7dB
#
# Valor medio medido=63.75 dB
#
# Valor máximo medido 65.4 dB
#
# Valor minimo medido 61.7 dB
#
# Medida(media, máximo, minimo)=63.75,65.4,61.7 dB	Time=2025-03-31 19:31:12
#
# RS232 read data:N:063.8dB
#
# Valor medio medido=63.8 dB
#
# Valor máximo medido 63.8 dB
#
# Valor minimo medido 63.8 dB
#
# Medida(media, máximo, minimo)=63.8,63.8,63.8 dB	Time=2025-03-31 19:31:13
#
# RS232 read data:N:065.9dB
#
# RS232 read data:N:064.3dB
#
# Valor medio medido=65.14 dB
#
# Valor máximo medido 65.9 dB
#
# Valor minimo medido 64.3 dB
#
# Medida(media, máximo, minimo)=65.14,65.9,64.3 dB	Time=2025-03-31 19:31:14
#
# RS232 read data:N:064.7dB
#
# RS232 read data:N:063.2dB
#
# Valor medio medido=63.98 dB
#
# Valor máximo medido 64.7 dB
#
# Valor minimo medido 63.2 dB
#
# Medida(media, máximo, minimo)=63.98,64.7,63.2 dB	Time=2025-03-31 19:31:15
#
# RS232 read data:N:063.7dB
#
# RS232 read data:N:067.9dB
#
# Valor medio medido=66.05 dB
#
# Valor máximo medido 67.9 dB
#
# Valor minimo medido 63.7 dB
#
# Medida(media, máximo, minimo)=66.05,67.9,63.7 dB	Time=2025-03-31 19:31:16
#
# RS232 read data:N:063.9dB
#
# Valor medio medido=63.9 dB
#
# Valor máximo medido 63.9 dB
#
# Valor minimo medido 63.9 dB
#
# Medida(media, máximo, minimo)=63.9,63.9,63.9 dB	Time=2025-03-31 19:31:17
#
# RS232 read data:N:065.8dB
#
# RS232 read data:N:062.5dB
#
# Valor medio medido=64.31 dB
#
# Valor máximo medido 65.8 dB
#
# Valor minimo medido 62.5 dB
#
# Medida(media, máximo, minimo)=64.31,65.8,62.5 dB	Time=2025-03-31 19:31:18
#
# RS232 read data:N:061.7dB
#
# RS232 read data:N:063.2dB
#
# Valor medio medido=62.48 dB
#
# Valor máximo medido 63.2 dB
#
# Valor minimo medido 61.7 dB
#
# Medida(media, máximo, minimo)=62.48,63.2,61.7 dB	Time=2025-03-31 19:31:19
#
# RS232 read data:N:061.9dB
#
# RS232 read data:N:062.1dB
#
# Valor medio medido=62.0 dB
#
# Valor máximo medido 62.1 dB
#
# Valor minimo medido 61.9 dB
#
# Medida(media, máximo, minimo)=62.0,62.1,61.9 dB	Time=2025-03-31 19:31:20
#
# RS232 read data:N:063.4dB
#
# RS232 read data:N:063.6dB
#
# Valor medio medido=63.5 dB
#
# Valor máximo medido 63.6 dB
#
# Valor minimo medido 63.4 dB
#
# Medida(media, máximo, minimo)=63.5,63.6,63.4 dB	Time=2025-03-31 19:31:21
#
# RS232 read data:N:064.0dB
#
# Valor medio medido=64.0 dB
#
# Valor máximo medido 64.0 dB
#
# Valor minimo medido 64.0 dB
#
# Medida(media, máximo, minimo)=64.0,64.0,64.0 dB	Time=2025-03-31 19:31:22
#
# RS232 read data:N:060.5dB
#
# RS232 read data:N:063.0dB
#
# Valor medio medido=61.84 dB
#
# Valor máximo medido 63.0 dB
#
# Valor minimo medido 60.5 dB
#
# Medida(media, máximo, minimo)=61.84,63.0,60.5 dB	Time=2025-03-31 19:31:23
#
# RS232 read data:N:064.3dB
#
# RS232 read data:N:065.1dB
#
# Valor medio medido=64.71 dB
#
# Valor máximo medido 65.1 dB
#
# Valor minimo medido 64.3 dB
#
# Medida(media, máximo, minimo)=64.71,65.1,64.3 dB	Time=2025-03-31 19:31:24
#
# RS232 read data:N:059.4dB
#
# RS232 read data:N:060.9dB
#
# Valor medio medido=60.18 dB
#
# Valor máximo medido 60.9 dB
#
# Valor minimo medido 59.4 dB
#
# Medida(media, máximo, minimo)=60.18,60.9,59.4 dB	Time=2025-03-31 19:31:25
#
# RS232 read data:N:065.5dB
#
# Valor medio medido=65.5 dB
#
# Valor máximo medido 65.5 dB
#
# Valor minimo medido 65.5 dB
#
# Medida(media, máximo, minimo)=65.5,65.5,65.5 dB	Time=2025-03-31 19:31:27
#
# RS232 read data:N:061.2dB
#
# RS232 read data:N:061.9dB
#
# Valor medio medido=61.56 dB
#
# Valor máximo medido 61.9 dB
#
# Valor minimo medido 61.2 dB
#
# Medida(media, máximo, minimo)=61.56,61.9,61.2 dB	Time=2025-03-31 19:31:28
#
# RS232 read data:N:063.5dB
#
# RS232 read data:N:062.5dB
#
# Valor medio medido=63.01 dB
#
# Valor máximo medido 63.5 dB
#
# Valor minimo medido 62.5 dB
#
# Medida(media, máximo, minimo)=63.01,63.5,62.5 dB	Time=2025-03-31 19:31:29
#
# RS232 read data:N:061.2dB
#
# RS232 read data:N:065.7dB
#
# Valor medio medido=63.74 dB
#
# Valor máximo medido 65.7 dB
#
# Valor minimo medido 61.2 dB
#
# Medida(media, máximo, minimo)=63.74,65.7,61.2 dB	Time=2025-03-31 19:31:30
#
# RS232 read data:N:059.6dB
#
# RS232 read data:N:056.6dB
#
# Valor medio medido=58.23 dB
#
# Valor máximo medido 59.6 dB
#
# Valor minimo medido 56.6 dB
#
# Medida(media, máximo, minimo)=58.23,59.6,56.6 dB	Time=2025-03-31 19:31:31
#
# RS232 read data:N:062.1dB
#
# Valor medio medido=62.1 dB
#
# Valor máximo medido 62.1 dB
#
# Valor minimo medido 62.1 dB
#
# Medida(media, máximo, minimo)=62.1,62.1,62.1 dB	Time=2025-03-31 19:31:32
#
# RS232 read data:N:062.1dB
#
# RS232 read data:N:059.0dB
#
# Valor medio medido=60.69 dB
#
# Valor máximo medido 62.1 dB
#
# Valor minimo medido 59.0 dB
#
# Medida(media, máximo, minimo)=60.69,62.1,59.0 dB	Time=2025-03-31 19:31:33
#
# RS232 read data:N:056.1dB
#
# RS232 read data:N:056.9dB
#
# Valor medio medido=56.51 dB
#
# Valor máximo medido 56.9 dB
#
# Valor minimo medido 56.1 dB
#
# Medida(media, máximo, minimo)=56.51,56.9,56.1 dB	Time=2025-03-31 19:31:34
#
# RS232 read data:N:059.2dB
#
# RS232 read data:N:059.2dB
#
# Valor medio medido=59.2 dB
#
# Valor máximo medido 59.2 dB
#
# Valor minimo medido 59.2 dB
#
# Medida(media, máximo, minimo)=59.2,59.2,59.2 dB	Time=2025-03-31 19:31:35
#
# RS232 read data:N:058.9dB
#
# RS232 read data:N:061.0dB
#
# Valor medio medido=60.01 dB
#
# Valor máximo medido 61.0 dB
#
# Valor minimo medido 58.9 dB
#
# Medida(media, máximo, minimo)=60.01,61.0,58.9 dB	Time=2025-03-31 19:31:36
#
# RS232 read data:N:062.8dB
#
# Valor medio medido=62.8 dB
#
# Valor máximo medido 62.8 dB
#
# Valor minimo medido 62.8 dB
#
# Medida(media, máximo, minimo)=62.8,62.8,62.8 dB	Time=2025-03-31 19:31:37
#
# RS232 read data:N:064.4dB
#
# RS232 read data:N:060.5dB
#
# Valor medio medido=62.67 dB
#
# Valor máximo medido 64.4 dB
#
# Valor minimo medido 60.5 dB
#
# Medida(media, máximo, minimo)=62.67,64.4,60.5 dB	Time=2025-03-31 19:31:38
#
# RS232 read data:N:060.8dB
#
# RS232 read data:N:066.4dB
#
# Valor medio medido=64.04 dB
#
# Valor máximo medido 66.4 dB
#
# Valor minimo medido 60.8 dB
#
# Medida(media, máximo, minimo)=64.04,66.4,60.8 dB	Time=2025-03-31 19:31:39
#
# RS232 read data:N:060.0dB
#
# RS232 read data:N:058.6dB
#
# Valor medio medido=59.33 dB
#
# Valor máximo medido 60.0 dB
#
# Valor minimo medido 58.6 dB
#
# Medida(media, máximo, minimo)=59.33,60.0,58.6 dB	Time=2025-03-31 19:31:40
#
# RS232 read data:N:064.3dB
#
# RS232 read data:N:061.8dB
#
# Valor medio medido=63.14 dB
#
# Valor máximo medido 64.3 dB
#
# Valor minimo medido 61.8 dB
#
# Medida(media, máximo, minimo)=63.14,64.3,61.8 dB	Time=2025-03-31 19:31:41
#
# RS232 read data:N:059.7dB
#
# Valor medio medido=59.7 dB
#
# Valor máximo medido 59.7 dB
#
# Valor minimo medido 59.7 dB
#
# Medida(media, máximo, minimo)=59.7,59.7,59.7 dB	Time=2025-03-31 19:31:42
#
# RS232 read data:N:056.9dB
#
# RS232 read data:N:057.3dB
#
# Valor medio medido=57.1 dB
#
# Valor máximo medido 57.3 dB
#
# Valor minimo medido 56.9 dB
#
# Medida(media, máximo, minimo)=57.1,57.3,56.9 dB	Time=2025-03-31 19:31:43
#
# RS232 read data:N:059.1dB
#
# RS232 read data:N:060.7dB
#
# Valor medio medido=59.94 dB
#
# Valor máximo medido 60.7 dB
#
# Valor minimo medido 59.1 dB
#
# Medida(media, máximo, minimo)=59.94,60.7,59.1 dB	Time=2025-03-31 19:31:44
#
# RS232 read data:N:060.9dB
#
# RS232 read data:N:059.2dB
#
# Valor medio medido=60.09 dB
#
# Valor máximo medido 60.9 dB
#
# Valor minimo medido 59.2 dB
#
# Medida(media, máximo, minimo)=60.09,60.9,59.2 dB	Time=2025-03-31 19:31:45
#
# RS232 read data:N:058.2dB
#
# RS232 read data:N:060.1dB
#
# Valor medio medido=59.2 dB
#
# Valor máximo medido 60.1 dB
#
# Valor minimo medido 58.2 dB
#
# Medida(media, máximo, minimo)=59.2,60.1,58.2 dB	Time=2025-03-31 19:31:46
#
# RS232 read data:N:059.8dB
#
# RS232 read data:N:060.3dB
#
# Valor medio medido=60.05 dB
#
# Valor máximo medido 60.3 dB
#
# Valor minimo medido 59.8 dB
#
# Medida(media, máximo, minimo)=60.05,60.3,59.8 dB	Time=2025-03-31 19:31:47
#
# RS232 read data:N:060.1dB
#
# Valor medio medido=60.1 dB
#
# Valor máximo medido 60.1 dB
#
# Valor minimo medido 60.1 dB
#
# Medida(media, máximo, minimo)=60.1,60.1,60.1 dB	Time=2025-03-31 19:31:48
#
# RS232 read data:N:060.5dB
#
# RS232 read data:N:062.1dB
#
# Valor medio medido=61.34 dB
#
# Valor máximo medido 62.1 dB
#
# Valor minimo medido 60.5 dB
#
# Medida(media, máximo, minimo)=61.34,62.1,60.5 dB	Time=2025-03-31 19:31:49
#
# RS232 read data:N:062.3dB
#
# RS232 read data:N:060.9dB
#
# Valor medio medido=61.63 dB
#
# Valor máximo medido 62.3 dB
#
# Valor minimo medido 60.9 dB
#
# Medida(media, máximo, minimo)=61.63,62.3,60.9 dB	Time=2025-03-31 19:31:50
#
# RS232 read data:N:063.0dB
#
# RS232 read data:N:063.2dB
#
# Valor medio medido=63.1 dB
#
# Valor máximo medido 63.2 dB
#
# Valor minimo medido 63.0 dB
#
# Medida(media, máximo, minimo)=63.1,63.2,63.0 dB	Time=2025-03-31 19:31:51
#
# RS232 read data:N:062.1dB
#
# RS232 read data:N:060.8dB
#
# Valor medio medido=61.47 dB
#
# Valor máximo medido 62.1 dB
#
# Valor minimo medido 60.8 dB
#
# Medida(media, máximo, minimo)=61.47,62.1,60.8 dB	Time=2025-03-31 19:31:52
#
# RS232 read data:N:061.1dB
#
# Valor medio medido=61.1 dB
#
# Valor máximo medido 61.1 dB
#
# Valor minimo medido 61.1 dB
#
# Medida(media, máximo, minimo)=61.1,61.1,61.1 dB	Time=2025-03-31 19:31:53
#
# RS232 read data:N:064.4dB
#
# RS232 read data:N:063.0dB
#
# Valor medio medido=63.73 dB
#
# Valor máximo medido 64.4 dB
#
# Valor minimo medido 63.0 dB
#
# Medida(media, máximo, minimo)=63.73,64.4,63.0 dB	Time=2025-03-31 19:31:54
#
# RS232 read data:N:066.6dB
#
# RS232 read data:N:070.0dB
#
# Valor medio medido=68.47 dB
#
# Valor máximo medido 70.0 dB
#
# Valor minimo medido 66.6 dB
#
# Medida(media, máximo, minimo)=68.47,70.0,66.6 dB	Time=2025-03-31 19:31:55
#
# RS232 read data:N:072.4dB
#
# Valor medio medido=72.4 dB
#
# Valor máximo medido 72.4 dB
#
# Valor minimo medido 72.4 dB
#
# Medida(media, máximo, minimo)=72.4,72.4,72.4 dB	Time=2025-03-31 19:31:56
#
# RS232 read data:N:071.2dB
#
# RS232 read data:N:063.2dB
#
# Valor medio medido=68.09 dB
#
# Valor máximo medido 71.2 dB
#
# Valor minimo medido 63.2 dB
#
# Medida(media, máximo, minimo)=68.09,71.2,63.2 dB	Time=2025-03-31 19:31:57
#
# RS232 read data:N:062.0dB
#
# RS232 read data:N:059.3dB
#
# Valor medio medido=60.75 dB
#
# Valor máximo medido 62.0 dB
#
# Valor minimo medido 59.3 dB
#
# Medida(media, máximo, minimo)=60.75,62.0,59.3 dB	Time=2025-03-31 19:31:58
#
# RS232 read data:N:059.4dB
#
# RS232 read data:N:058.8dB
#
# Valor medio medido=59.11 dB
#
# Valor máximo medido 59.4 dB
#
# Valor minimo medido 58.8 dB
#
# Medida(media, máximo, minimo)=59.11,59.4,58.8 dB	Time=2025-03-31 19:31:59
#
# RS232 read data:N:058.4dB
#
# RS232 read data:N:058.1dB
#
# Valor medio medido=58.25 dB
#
# Valor máximo medido 58.4 dB
#
# Valor minimo medido 58.1 dB
#
# Medida(media, máximo, minimo)=58.25,58.4,58.1 dB	Time=2025-03-31 19:32:00
#
# RS232 read data:N:060.6dB
#
# Valor medio medido=60.6 dB
#
# Valor máximo medido 60.6 dB
#
# Valor minimo medido 60.6 dB
#
# Medida(media, máximo, minimo)=60.6,60.6,60.6 dB	Time=2025-03-31 19:32:01
#
# RS232 read data:N:058.6dB
#
# RS232 read data:N:059.5dB
#
# Valor medio medido=59.06 dB
#
# Valor máximo medido 59.5 dB
#
# Valor minimo medido 58.6 dB
#
# Medida(media, máximo, minimo)=59.06,59.5,58.6 dB	Time=2025-03-31 19:32:02
#
# RS232 read data:N:056.9dB
#
# RS232 read data:N:059.7dB
#
# Valor medio medido=58.41 dB
#
# Valor máximo medido 59.7 dB
#
# Valor minimo medido 56.9 dB
#
# Medida(media, máximo, minimo)=58.41,59.7,56.9 dB	Time=2025-03-31 19:32:03
#
# RS232 read data:N:055.1dB
#
# RS232 read data:N:055.5dB
#
# Valor medio medido=55.3 dB
#
# Valor máximo medido 55.5 dB
#
# Valor minimo medido 55.1 dB
#
# Medida(media, máximo, minimo)=55.3,55.5,55.1 dB	Time=2025-03-31 19:32:04
#
# RS232 read data:N:060.8dB
#
# RS232 read data:N:055.5dB
#
# Valor medio medido=58.55 dB
#
# Valor máximo medido 60.8 dB
#
# Valor minimo medido 55.5 dB
#
# Medida(media, máximo, minimo)=58.55,60.8,55.5 dB	Time=2025-03-31 19:32:05
#
# RS232 read data:N:057.5dB
#
# RS232 read data:N:057.8dB
#
# Valor medio medido=57.65 dB
#
# Valor máximo medido 57.8 dB
#
# Valor minimo medido 57.5 dB
#
# Medida(media, máximo, minimo)=57.65,57.8,57.5 dB	Time=2025-03-31 19:32:06
#
# RS232 read data:N:063.7dB
#
# Valor medio medido=63.7 dB
#
# Valor máximo medido 63.7 dB
#
# Valor minimo medido 63.7 dB
#
# Medida(media, máximo, minimo)=63.7,63.7,63.7 dB	Time=2025-03-31 19:32:07
#
# RS232 read data:N:060.6dB
#
# RS232 read data:N:057.8dB
#
# Valor medio medido=59.31 dB
#
# Valor máximo medido 60.6 dB
#
# Valor minimo medido 57.8 dB
#
# Medida(media, máximo, minimo)=59.31,60.6,57.8 dB	Time=2025-03-31 19:32:08
#
# RS232 read data:N:058.9dB
#
# RS232 read data:N:055.2dB
#
# Valor medio medido=57.25 dB
#
# Valor máximo medido 58.9 dB
#
# Valor minimo medido 55.2 dB
#
# Medida(media, máximo, minimo)=57.25,58.9,55.2 dB	Time=2025-03-31 19:32:09
#
# RS232 read data:N:056.9dB
#
# RS232 read data:N:056.2dB
#
# Valor medio medido=56.56 dB
#
# Valor máximo medido 56.9 dB
#
# Valor minimo medido 56.2 dB
#
# Medida(media, máximo, minimo)=56.56,56.9,56.2 dB	Time=2025-03-31 19:32:10
#
# RS232 read data:N:064.9dB
#
# RS232 read data:N:064.6dB
#
# Valor medio medido=64.75 dB
#
# Valor máximo medido 64.9 dB
#
# Valor minimo medido 64.6 dB
#
# Medida(media, máximo, minimo)=64.75,64.9,64.6 dB	Time=2025-03-31 19:32:11
#
# RS232 read data:N:065.4dB
#
# RS232 read data:N:059.1dB
#
# Valor medio medido=62.81 dB
#
# Valor máximo medido 65.4 dB
#
# Valor minimo medido 59.1 dB
#
# Medida(media, máximo, minimo)=62.81,65.4,59.1 dB	Time=2025-03-31 19:32:12
#
# RS232 read data:N:056.7dB
#
# Valor medio medido=56.7 dB
#
# Valor máximo medido 56.7 dB
#
# Valor minimo medido 56.7 dB
#
# Medida(media, máximo, minimo)=56.7,56.7,56.7 dB	Time=2025-03-31 19:32:13
#
# RS232 read data:N:064.2dB
#
# RS232 read data:N:061.3dB
#
# Valor medio medido=62.87 dB
#
# Valor máximo medido 64.2 dB
#
# Valor minimo medido 61.3 dB
#
# Medida(media, máximo, minimo)=62.87,64.2,61.3 dB	Time=2025-03-31 19:32:14
#
# RS232 read data:N:055.6dB
#
# RS232 read data:N:065.4dB
#
# Valor medio medido=61.81 dB
#
# Valor máximo medido 65.4 dB
#
# Valor minimo medido 55.6 dB
#
# Medida(media, máximo, minimo)=61.81,65.4,55.6 dB	Time=2025-03-31 19:32:15
#
# RS232 read data:N:058.4dB
#
# RS232 read data:N:064.7dB
#
# Valor medio medido=62.11 dB
#
# Valor máximo medido 64.7 dB
#
# Valor minimo medido 58.4 dB
#
# Medida(media, máximo, minimo)=62.11,64.7,58.4 dB	Time=2025-03-31 19:32:16
#
# RS232 read data:N:061.8dB
#
# RS232 read data:N:060.1dB
#
# Valor medio medido=60.99 dB
#
# Valor máximo medido 61.8 dB
#
# Valor minimo medido 60.1 dB
#
# Medida(media, máximo, minimo)=60.99,61.8,60.1 dB	Time=2025-03-31 19:32:17
#
# RS232 read data:N:061.5dB
#
# Valor medio medido=61.5 dB
#
# Valor máximo medido 61.5 dB
#
# Valor minimo medido 61.5 dB
#
# Medida(media, máximo, minimo)=61.5,61.5,61.5 dB	Time=2025-03-31 19:32:18
#
# RS232 read data:N:062.8dB
#
# RS232 read data:N:061.1dB
#
# Valor medio medido=61.99 dB
#
# Valor máximo medido 62.8 dB
#
# Valor minimo medido 61.1 dB
#
# Medida(media, máximo, minimo)=61.99,62.8,61.1 dB	Time=2025-03-31 19:32:19
#
# RS232 read data:N:065.3dB
#
# RS232 read data:N:062.5dB
#
# Valor medio medido=64.01 dB
#
# Valor máximo medido 65.3 dB
#
# Valor minimo medido 62.5 dB
#
# Medida(media, máximo, minimo)=64.01,65.3,62.5 dB	Time=2025-03-31 19:32:20
#
# RS232 read data:N:062.8dB
#
# RS232 read data:N:059.6dB
#
# Valor medio medido=61.35 dB
#
# Valor máximo medido 62.8 dB
#
# Valor minimo medido 59.6 dB
#
# Medida(media, máximo, minimo)=61.35,62.8,59.6 dB	Time=2025-03-31 19:32:21
#
# RS232 read data:N:059.0dB
#
# RS232 read data:N:062.9dB
#
# Valor medio medido=61.17 dB
#
# Valor máximo medido 62.9 dB
#
# Valor minimo medido 59.0 dB
#
# Medida(media, máximo, minimo)=61.17,62.9,59.0 dB	Time=2025-03-31 19:32:22
#
# RS232 read data:N:058.8dB
#
# Valor medio medido=58.8 dB
#
# Valor máximo medido 58.8 dB
#
# Valor minimo medido 58.8 dB
#
# Medida(media, máximo, minimo)=58.8,58.8,58.8 dB	Time=2025-03-31 19:32:23
#
# RS232 read data:N:059.3dB
#
# RS232 read data:N:063.3dB
#
# Valor medio medido=61.53 dB
#
# Valor máximo medido 63.3 dB
#
# Valor minimo medido 59.3 dB
#
# Medida(media, máximo, minimo)=61.53,63.3,59.3 dB	Time=2025-03-31 19:32:24
#
# RS232 read data:N:060.2dB
#
# RS232 read data:N:062.7dB
#
# Valor medio medido=61.54 dB
#
# Valor máximo medido 62.7 dB
#
# Valor minimo medido 60.2 dB
#
# Medida(media, máximo, minimo)=61.54,62.7,60.2 dB	Time=2025-03-31 19:32:25
#
# RS232 read data:N:063.6dB
#
# RS232 read data:N:061.6dB
#
# Valor medio medido=62.66 dB
#
# Valor máximo medido 63.6 dB
#
# Valor minimo medido 61.6 dB
#
# Medida(media, máximo, minimo)=62.66,63.6,61.6 dB	Time=2025-03-31 19:32:26
#
# RS232 read data:N:062.1dB
#
# Valor medio medido=62.1 dB
#
# Valor máximo medido 62.1 dB
#
# Valor minimo medido 62.1 dB
#
# Medida(media, máximo, minimo)=62.1,62.1,62.1 dB	Time=2025-03-31 19:32:27
#
# RS232 read data:N:067.7dB
#
# RS232 read data:N:066.3dB
#
# Valor medio medido=67.03 dB
#
# Valor máximo medido 67.7 dB
#
# Valor minimo medido 66.3 dB
#
# Medida(media, máximo, minimo)=67.03,67.7,66.3 dB	Time=2025-03-31 19:32:28
#
# RS232 read data:N:059.9dB
#
# RS232 read data:N:061.9dB
#
# Valor medio medido=60.96 dB
#
# Valor máximo medido 61.9 dB
#
# Valor minimo medido 59.9 dB
#
# Medida(media, máximo, minimo)=60.96,61.9,59.9 dB	Time=2025-03-31 19:32:29
#
# RS232 read data:N:071.4dB
#
# RS232 read data:N:061.7dB
#
# Valor medio medido=67.84 dB
#
# Valor máximo medido 71.4 dB
#
# Valor minimo medido 61.7 dB
#
# Medida(media, máximo, minimo)=67.84,71.4,61.7 dB	Time=2025-03-31 19:32:30
#
# RS232 read data:N:064.6dB
#
# Valor medio medido=64.6 dB
#
# Valor máximo medido 64.6 dB
#
# Valor minimo medido 64.6 dB
#
# Medida(media, máximo, minimo)=64.6,64.6,64.6 dB	Time=2025-03-31 19:32:31
#
# RS232 read data:N:060.5dB
#
# RS232 read data:N:059.9dB
#
# Valor medio medido=60.21 dB
#
# Valor máximo medido 60.5 dB
#
# Valor minimo medido 59.9 dB
#
# Medida(media, máximo, minimo)=60.21,60.5,59.9 dB	Time=2025-03-31 19:32:32
#
# RS232 read data:N:060.0dB
#
# RS232 read data:N:059.0dB
#
# Valor medio medido=59.51 dB
#
# Valor máximo medido 60.0 dB
#
# Valor minimo medido 59.0 dB
#
# Medida(media, máximo, minimo)=59.51,60.0,59.0 dB	Time=2025-03-31 19:32:33
#
# RS232 read data:N:061.4dB
#
# RS232 read data:N:062.9dB
#
# Valor medio medido=62.18 dB
#
# Valor máximo medido 62.9 dB
#
# Valor minimo medido 61.4 dB
#
# Medida(media, máximo, minimo)=62.18,62.9,61.4 dB	Time=2025-03-31 19:32:34
#
# RS232 read data:N:066.9dB
#
# RS232 read data:N:059.6dB
#
# Valor medio medido=64.0 dB
#
# Valor máximo medido 66.9 dB
#
# Valor minimo medido 59.6 dB
#
# Medida(media, máximo, minimo)=64.0,66.9,59.6 dB	Time=2025-03-31 19:32:35
#
# RS232 read data:N:061.6dB
#
# RS232 read data:N:060.7dB
#
# Valor medio medido=61.16 dB
#
# Valor máximo medido 61.6 dB
#
# Valor minimo medido 60.7 dB
#
# Medida(media, máximo, minimo)=61.16,61.6,60.7 dB	Time=2025-03-31 19:32:36
#
# RS232 read data:N:060.6dB
#
# Valor medio medido=60.6 dB
#
# Valor máximo medido 60.6 dB
#
# Valor minimo medido 60.6 dB
#
# Medida(media, máximo, minimo)=60.6,60.6,60.6 dB	Time=2025-03-31 19:32:37
#
# RS232 read data:N:063.5dB
#
# RS232 read data:N:062.9dB
#
# Valor medio medido=63.21 dB
#
# Valor máximo medido 63.5 dB
#
# Valor minimo medido 62.9 dB
#
# Medida(media, máximo, minimo)=63.21,63.5,62.9 dB	Time=2025-03-31 19:32:38
#
# RS232 read data:N:063.4dB
#
# RS232 read data:N:067.7dB
#
# Valor medio medido=65.81 dB
#
# Valor máximo medido 67.7 dB
#
# Valor minimo medido 63.4 dB
#
# Medida(media, máximo, minimo)=65.81,67.7,63.4 dB	Time=2025-03-31 19:32:39
#
# RS232 read data:N:065.3dB
#
# RS232 read data:N:065.0dB
#
# Valor medio medido=65.15 dB
#
# Valor máximo medido 65.3 dB
#
# Valor minimo medido 65.0 dB
#
# Medida(media, máximo, minimo)=65.15,65.3,65.0 dB	Time=2025-03-31 19:32:40
#
# RS232 read data:N:058.7dB
#
# Valor medio medido=58.7 dB
#
# Valor máximo medido 58.7 dB
#
# Valor minimo medido 58.7 dB
#
# Medida(media, máximo, minimo)=58.7,58.7,58.7 dB	Time=2025-03-31 19:32:41
#
# RS232 read data:N:060.5dB
#
# RS232 read data:N:062.0dB
#
# Valor medio medido=61.28 dB
#
# Valor máximo medido 62.0 dB
#
# Valor minimo medido 60.5 dB
#
# Medida(media, máximo, minimo)=61.28,62.0,60.5 dB	Time=2025-03-31 19:32:42
#
# RS232 read data:N:059.7dB
#
# RS232 read data:N:063.2dB
#
# Valor medio medido=61.63 dB
#
# Valor máximo medido 63.2 dB
#
# Valor minimo medido 59.7 dB
#
# Medida(media, máximo, minimo)=61.63,63.2,59.7 dB	Time=2025-03-31 19:32:43
#
# RS232 read data:N:065.3dB
#
# RS232 read data:N:065.4dB
#
# Valor medio medido=65.35 dB
#
# Valor máximo medido 65.4 dB
#
# Valor minimo medido 65.3 dB
#
# Medida(media, máximo, minimo)=65.35,65.4,65.3 dB	Time=2025-03-31 19:32:44
#
# RS232 read data:N:066.7dB
#
# RS232 read data:N:061.2dB
#
# Valor medio medido=64.38 dB
#
# Valor máximo medido 66.7 dB
#
# Valor minimo medido 61.2 dB
#
# Medida(media, máximo, minimo)=64.38,66.7,61.2 dB	Time=2025-03-31 19:32:45
#
# RS232 read data:N:063.8dB
#
# Valor medio medido=63.8 dB
#
# Valor máximo medido 63.8 dB
#
# Valor minimo medido 63.8 dB
#
# Medida(media, máximo, minimo)=63.8,63.8,63.8 dB	Time=2025-03-31 19:32:46
#
# RS232 read data:N:057.6dB
#
# RS232 read data:N:060.4dB
#
# Valor medio medido=59.11 dB
#
# Valor máximo medido 60.4 dB
#
# Valor minimo medido 57.6 dB
#
# Medida(media, máximo, minimo)=59.11,60.4,57.6 dB	Time=2025-03-31 19:32:47
#
# RS232 read data:N:064.7dB
#
# RS232 read data:N:063.9dB
#
# Valor medio medido=64.31 dB
#
# Valor máximo medido 64.7 dB
#
# Valor minimo medido 63.9 dB
#
# Medida(media, máximo, minimo)=64.31,64.7,63.9 dB	Time=2025-03-31 19:32:48
#
# RS232 read data:N:059.1dB
#
# RS232 read data:N:060.0dB
#
# Valor medio medido=59.56 dB
#
# Valor máximo medido 60.0 dB
#
# Valor minimo medido 59.1 dB
#
# Medida(media, máximo, minimo)=59.56,60.0,59.1 dB	Time=2025-03-31 19:32:49
#
# RS232 read data:N:067.4dB
#
# Valor medio medido=67.4 dB
#
# Valor máximo medido 67.4 dB
#
# Valor minimo medido 67.4 dB
#
# Medida(media, máximo, minimo)=67.4,67.4,67.4 dB	Time=2025-03-31 19:32:50
#
# RS232 read data:N:058.3dB
#
# RS232 read data:N:058.7dB
#
# Valor medio medido=58.5 dB
#
# Valor máximo medido 58.7 dB
#
# Valor minimo medido 58.3 dB
#
# Medida(media, máximo, minimo)=58.5,58.7,58.3 dB	Time=2025-03-31 19:32:51
#
# RS232 read data:N:058.6dB
#
# RS232 read data:N:059.7dB
#
# Valor medio medido=59.17 dB
#
# Valor máximo medido 59.7 dB
#
# Valor minimo medido 58.6 dB
#
# Medida(media, máximo, minimo)=59.17,59.7,58.6 dB	Time=2025-03-31 19:32:52
#
# RS232 read data:N:065.1dB
#
# RS232 read data:N:057.1dB
#
# Valor medio medido=61.99 dB
#
# Valor máximo medido 65.1 dB
#
# Valor minimo medido 57.1 dB
#
# Medida(media, máximo, minimo)=61.99,65.1,57.1 dB	Time=2025-03-31 19:32:53
#
# RS232 read data:N:062.3dB
#
# RS232 read data:N:058.5dB
#
# Valor medio medido=60.61 dB
#
# Valor máximo medido 62.3 dB
#
# Valor minimo medido 58.5 dB
#
# Medida(media, máximo, minimo)=60.61,62.3,58.5 dB	Time=2025-03-31 19:32:54
#
# RS232 read data:N:053.4dB
#
# RS232 read data:N:058.3dB
#
# Valor medio medido=56.19 dB
#
# Valor máximo medido 58.3 dB
#
# Valor minimo medido 53.4 dB
#
# Medida(media, máximo, minimo)=56.19,58.3,53.4 dB	Time=2025-03-31 19:32:55
#
# RS232 read data:N:061.6dB
#
# RS232 read data:N:061.3dB
#
# Valor medio medido=61.45 dB
#
# Valor máximo medido 61.6 dB
#
# Valor minimo medido 61.3 dB
#
# Medida(media, máximo, minimo)=61.45,61.6,61.3 dB	Time=2025-03-31 19:32:56
#
# RS232 read data:N:062.3dB
#
# Valor medio medido=62.3 dB
#
# Valor máximo medido 62.3 dB
#
# Valor minimo medido 62.3 dB
#
# Medida(media, máximo, minimo)=62.3,62.3,62.3 dB	Time=2025-03-31 19:32:57
#
# RS232 read data:N:057.9dB
#
# RS232 read data:N:058.9dB
#
# Valor medio medido=58.41 dB
#
# Valor máximo medido 58.9 dB
#
# Valor minimo medido 57.9 dB
#
# Medida(media, máximo, minimo)=58.41,58.9,57.9 dB	Time=2025-03-31 19:32:58
#
# RS232 read data:N:058.9dB
#
# RS232 read data:N:058.5dB
#
# Valor medio medido=58.7 dB
#
# Valor máximo medido 58.9 dB
#
# Valor minimo medido 58.5 dB
#
# Medida(media, máximo, minimo)=58.7,58.9,58.5 dB	Time=2025-03-31 19:32:59
#
# RS232 read data:N:057.8dB
#
# RS232 read data:N:056.7dB
#
# Valor medio medido=57.27 dB
#
# Valor máximo medido 57.8 dB
#
# Valor minimo medido 56.7 dB
#
# Medida(media, máximo, minimo)=57.27,57.8,56.7 dB	Time=2025-03-31 19:33:00
#
# RS232 read data:N:059.7dB
#
# RS232 read data:N:057.0dB
#
# Valor medio medido=58.45 dB
#
# Valor máximo medido 59.7 dB
#
# Valor minimo medido 57.0 dB
#
# Medida(media, máximo, minimo)=58.45,59.7,57.0 dB	Time=2025-03-31 19:33:01
#
# RS232 read data:N:060.7dB
#
# RS232 read data:N:061.0dB
#
# Valor medio medido=60.85 dB
#
# Valor máximo medido 61.0 dB
#
# Valor minimo medido 60.7 dB
#
# Medida(media, máximo, minimo)=60.85,61.0,60.7 dB	Time=2025-03-31 19:33:02
#
# RS232 read data:N:056.6dB
#
# RS232 read data:N:054.9dB
#
# Valor medio medido=55.79 dB
#
# Valor máximo medido 56.6 dB
#
# Valor minimo medido 54.9 dB
#
# Medida(media, máximo, minimo)=55.79,56.6,54.9 dB	Time=2025-03-31 19:33:03
#
# RS232 read data:N:063.6dB
#
# Valor medio medido=63.6 dB
#
# Valor máximo medido 63.6 dB
#
# Valor minimo medido 63.6 dB
#
# Medida(media, máximo, minimo)=63.6,63.6,63.6 dB	Time=2025-03-31 19:33:04
#
# RS232 read data:N:059.9dB
#
# RS232 read data:N:057.9dB
#
# Valor medio medido=58.96 dB
#
# Valor máximo medido 59.9 dB
#
# Valor minimo medido 57.9 dB
#
# Medida(media, máximo, minimo)=58.96,59.9,57.9 dB	Time=2025-03-31 19:33:05
#
# RS232 read data:N:061.6dB
#
# RS232 read data:N:059.0dB
#
# Valor medio medido=60.4 dB
#
# Valor máximo medido 61.6 dB
#
# Valor minimo medido 59.0 dB
#
# Medida(media, máximo, minimo)=60.4,61.6,59.0 dB	Time=2025-03-31 19:33:06
#
# RS232 read data:N:060.5dB
#
# RS232 read data:N:056.5dB
#
# Valor medio medido=58.73 dB
#
# Valor máximo medido 60.5 dB
#
# Valor minimo medido 56.5 dB
#
# Medida(media, máximo, minimo)=58.73,60.5,56.5 dB	Time=2025-03-31 19:33:07
#
# RS232 read data:N:056.6dB
#
# RS232 read data:N:059.7dB
#
# Valor medio medido=58.29 dB
#
# Valor máximo medido 59.7 dB
#
# Valor minimo medido 56.6 dB
#
# Medida(media, máximo, minimo)=58.29,59.7,56.6 dB	Time=2025-03-31 19:33:08
#
# RS232 read data:N:057.3dB
#
# RS232 read data:N:057.9dB
#
# Valor medio medido=57.61 dB
#
# Valor máximo medido 57.9 dB
#
# Valor minimo medido 57.3 dB
#
# Medida(media, máximo, minimo)=57.61,57.9,57.3 dB	Time=2025-03-31 19:33:09
#
# RS232 read data:N:059.3dB
#
# RS232 read data:N:075.6dB
#
# Valor medio medido=70.82 dB
#
# Valor máximo medido 75.6 dB
#
# Valor minimo medido 59.3 dB
#
# Medida(media, máximo, minimo)=70.82,75.6,59.3 dB	Time=2025-03-31 19:33:10
#
# RS232 read data:N:068.1dB
#
# Valor medio medido=68.1 dB
#
# Valor máximo medido 68.1 dB
#
# Valor minimo medido 68.1 dB
#
# Medida(media, máximo, minimo)=68.1,68.1,68.1 dB	Time=2025-03-31 19:33:11
#
# RS232 read data:N:063.9dB
#
# RS232 read data:N:059.7dB
#
# Valor medio medido=62.05 dB
#
# Valor máximo medido 63.9 dB
#
# Valor minimo medido 59.7 dB
#
# Medida(media, máximo, minimo)=62.05,63.9,59.7 dB	Time=2025-03-31 19:33:12
#
# RS232 read data:N:057.5dB
#
# RS232 read data:N:056.7dB
#
# Valor medio medido=57.11 dB
#
# Valor máximo medido 57.5 dB
#
# Valor minimo medido 56.7 dB
#
# Medida(media, máximo, minimo)=57.11,57.5,56.7 dB	Time=2025-03-31 19:33:13
#
# RS232 read data:N:057.0dB
#
# RS232 read data:N:062.0dB
#
# Valor medio medido=59.85 dB
#
# Valor máximo medido 62.0 dB
#
# Valor minimo medido 57.0 dB
#
# Medida(media, máximo, minimo)=59.85,62.0,57.0 dB	Time=2025-03-31 19:33:14
#
# RS232 read data:N:057.8dB
#
# RS232 read data:N:058.4dB
#
# Valor medio medido=58.11 dB
#
# Valor máximo medido 58.4 dB
#
# Valor minimo medido 57.8 dB
#
# Medida(media, máximo, minimo)=58.11,58.4,57.8 dB	Time=2025-03-31 19:33:15
#
# RS232 read data:N:059.4dB
#
# RS232 read data:N:062.1dB
#
# Valor medio medido=60.85 dB
#
# Valor máximo medido 62.1 dB
#
# Valor minimo medido 59.4 dB
#
# Medida(media, máximo, minimo)=60.85,62.1,59.4 dB	Time=2025-03-31 19:33:16
#
# RS232 read data:N:063.6dB
#
# Valor medio medido=63.6 dB
#
# Valor máximo medido 63.6 dB
#
# Valor minimo medido 63.6 dB
#
# Medida(media, máximo, minimo)=63.6,63.6,63.6 dB	Time=2025-03-31 19:33:17
#
# RS232 read data:N:060.7dB
#
# RS232 read data:N:058.6dB
#
# Valor medio medido=59.71 dB
#
# Valor máximo medido 60.7 dB
#
# Valor minimo medido 58.6 dB
#
# Medida(media, máximo, minimo)=59.71,60.7,58.6 dB	Time=2025-03-31 19:33:18
#
# RS232 read data:N:065.6dB
#
# RS232 read data:N:062.4dB
#
# Valor medio medido=64.15 dB
#
# Valor máximo medido 65.6 dB
#
# Valor minimo medido 62.4 dB
#
# Medida(media, máximo, minimo)=64.15,65.6,62.4 dB	Time=2025-03-31 19:33:19
#
# RS232 read data:N:065.9dB
#
# RS232 read data:N:062.7dB
#
# Valor medio medido=64.45 dB
#
# Valor máximo medido 65.9 dB
#
# Valor minimo medido 62.7 dB
#
# Medida(media, máximo, minimo)=64.45,65.9,62.7 dB	Time=2025-03-31 19:33:20
#
# RS232 read data:N:064.4dB
#
# Valor medio medido=64.4 dB
#
# Valor máximo medido 64.4 dB
#
# Valor minimo medido 64.4 dB
#
# Medida(media, máximo, minimo)=64.4,64.4,64.4 dB	Time=2025-03-31 19:33:21
#
# RS232 read data:N:062.7dB
#
# RS232 read data:N:059.8dB
#
# Valor medio medido=61.37 dB
#
# Valor máximo medido 62.7 dB
#
# Valor minimo medido 59.8 dB
#
# Medida(media, máximo, minimo)=61.37,62.7,59.8 dB	Time=2025-03-31 19:33:22
#
# RS232 read data:N:057.7dB
#
# RS232 read data:N:057.5dB
#
# Valor medio medido=57.6 dB
#
# Valor máximo medido 57.7 dB
#
# Valor minimo medido 57.5 dB
#
# Medida(media, máximo, minimo)=57.6,57.7,57.5 dB	Time=2025-03-31 19:33:23
#
# RS232 read data:N:063.2dB
#
# RS232 read data:N:060.7dB
#
# Valor medio medido=62.04 dB
#
# Valor máximo medido 63.2 dB
#
# Valor minimo medido 60.7 dB
#
# Medida(media, máximo, minimo)=62.04,63.2,60.7 dB	Time=2025-03-31 19:33:24
#
# RS232 read data:N:059.0dB
#
# RS232 read data:N:060.0dB
#
# Valor medio medido=59.51 dB
#
# Valor máximo medido 60.0 dB
#
# Valor minimo medido 59.0 dB
#
# Medida(media, máximo, minimo)=59.51,60.0,59.0 dB	Time=2025-03-31 19:33:25
#
# RS232 read data:N:058.4dB
#
# RS232 read data:N:058.6dB
#
# Valor medio medido=58.5 dB
#
# Valor máximo medido 58.6 dB
#
# Valor minimo medido 58.4 dB
#
# Medida(media, máximo, minimo)=58.5,58.6,58.4 dB	Time=2025-03-31 19:33:26
#
# RS232 read data:N:063.9dB
#
# Valor medio medido=63.9 dB
#
# Valor máximo medido 63.9 dB
#
# Valor minimo medido 63.9 dB
#
# Medida(media, máximo, minimo)=63.9,63.9,63.9 dB	Time=2025-03-31 19:33:27
#
# RS232 read data:N:059.9dB
#
# RS232 read data:N:058.7dB
#
# Valor medio medido=59.32 dB
#
# Valor máximo medido 59.9 dB
#
# Valor minimo medido 58.7 dB
#
# Medida(media, máximo, minimo)=59.32,59.9,58.7 dB	Time=2025-03-31 19:33:28
#
# RS232 read data:N:060.4dB
#
# RS232 read data:N:061.4dB
#
# Valor medio medido=60.91 dB
#
# Valor máximo medido 61.4 dB
#
# Valor minimo medido 60.4 dB
#
# Medida(media, máximo, minimo)=60.91,61.4,60.4 dB	Time=2025-03-31 19:33:29
#
# RS232 read data:N:057.9dB
#
# RS232 read data:N:057.8dB
#
# Valor medio medido=57.85 dB
#
# Valor máximo medido 57.9 dB
#
# Valor minimo medido 57.8 dB
#
# Medida(media, máximo, minimo)=57.85,57.9,57.8 dB	Time=2025-03-31 19:33:30
#
# RS232 read data:N:063.7dB
#
# RS232 read data:N:061.3dB
#
# Valor medio medido=62.58 dB
#
# Valor máximo medido 63.7 dB
#
# Valor minimo medido 61.3 dB
#
# Medida(media, máximo, minimo)=62.58,63.7,61.3 dB	Time=2025-03-31 19:33:31
#
# RS232 read data:N:061.2dB
#
# Valor medio medido=61.2 dB
#
# Valor máximo medido 61.2 dB
#
# Valor minimo medido 61.2 dB
#
# Medida(media, máximo, minimo)=61.2,61.2,61.2 dB	Time=2025-03-31 19:33:32
#
# RS232 read data:N:062.2dB
#
# RS232 read data:N:062.2dB
#
# Valor medio medido=62.2 dB
#
# Valor máximo medido 62.2 dB
#
# Valor minimo medido 62.2 dB
#
# Medida(media, máximo, minimo)=62.2,62.2,62.2 dB	Time=2025-03-31 19:33:33
#
# RS232 read data:N:058.8dB
#
# RS232 read data:N:057.5dB
#
# Valor medio medido=58.17 dB
#
# Valor máximo medido 58.8 dB
#
# Valor minimo medido 57.5 dB
#
# Medida(media, máximo, minimo)=58.17,58.8,57.5 dB	Time=2025-03-31 19:33:34
#
# RS232 read data:N:060.7dB
#
# RS232 read data:N:060.6dB
#
# Valor medio medido=60.65 dB
#
# Valor máximo medido 60.7 dB
#
# Valor minimo medido 60.6 dB
#
# Medida(media, máximo, minimo)=60.65,60.7,60.6 dB	Time=2025-03-31 19:33:35
#
# RS232 read data:N:061.9dB
#
# RS232 read data:N:060.3dB
#
# Valor medio medido=61.14 dB
#
# Valor máximo medido 61.9 dB
#
# Valor minimo medido 60.3 dB
#
# Medida(media, máximo, minimo)=61.14,61.9,60.3 dB	Time=2025-03-31 19:33:36
#
# RS232 read data:N:064.2dB
#
# Valor medio medido=64.2 dB
#
# Valor máximo medido 64.2 dB
#
# Valor minimo medido 64.2 dB
#
# Medida(media, máximo, minimo)=64.2,64.2,64.2 dB	Time=2025-03-31 19:33:37
#
# RS232 read data:N:060.2dB
#
# RS232 read data:N:058.9dB
#
# Valor medio medido=59.57 dB
#
# Valor máximo medido 60.2 dB
#
# Valor minimo medido 58.9 dB
#
# Medida(media, máximo, minimo)=59.57,60.2,58.9 dB	Time=2025-03-31 19:33:38
#
# RS232 read data:N:061.2dB
#
# RS232 read data:N:061.0dB
#
# Valor medio medido=61.1 dB
#
# Valor máximo medido 61.2 dB
#
# Valor minimo medido 61.0 dB
#
# Medida(media, máximo, minimo)=61.1,61.2,61.0 dB	Time=2025-03-31 19:33:39
#
# RS232 read data:N:061.7dB
#
# RS232 read data:N:063.5dB
#
# Valor medio medido=62.65 dB
#
# Valor máximo medido 63.5 dB
#
# Valor minimo medido 61.7 dB
#
# Medida(media, máximo, minimo)=62.65,63.5,61.7 dB	Time=2025-03-31 19:33:40
#
# RS232 read data:N:059.0dB
#
# RS232 read data:N:060.2dB
#
# Valor medio medido=59.62 dB
#
# Valor máximo medido 60.2 dB
#
# Valor minimo medido 59.0 dB
#
# Medida(media, máximo, minimo)=59.62,60.2,59.0 dB	Time=2025-03-31 19:33:41
#
# RS232 read data:N:063.6dB
#
# RS232 read data:N:058.6dB
#
# Valor medio medido=61.45 dB
#
# Valor máximo medido 63.6 dB
#
# Valor minimo medido 58.6 dB
#
# Medida(media, máximo, minimo)=61.45,63.6,58.6 dB	Time=2025-03-31 19:33:42
#
# RS232 read data:N:058.2dB
#
# Valor medio medido=58.2 dB
#
# Valor máximo medido 58.2 dB
#
# Valor minimo medido 58.2 dB
#
# Medida(media, máximo, minimo)=58.2,58.2,58.2 dB	Time=2025-03-31 19:33:43
#
# RS232 read data:N:060.9dB
#
# RS232 read data:N:061.4dB
#
# Valor medio medido=61.15 dB
#
# Valor máximo medido 61.4 dB
#
# Valor minimo medido 60.9 dB
#
# Medida(media, máximo, minimo)=61.15,61.4,60.9 dB	Time=2025-03-31 19:33:44
#
# RS232 read data:N:061.9dB
#
# RS232 read data:N:062.2dB
#
# Valor medio medido=62.05 dB
#
# Valor máximo medido 62.2 dB
#
# Valor minimo medido 61.9 dB
#
# Medida(media, máximo, minimo)=62.05,62.2,61.9 dB	Time=2025-03-31 19:33:45
#
# RS232 read data:N:061.2dB
#
# RS232 read data:N:062.6dB
#
# Valor medio medido=61.93 dB
#
# Valor máximo medido 62.6 dB
#
# Valor minimo medido 61.2 dB
#
# Medida(media, máximo, minimo)=61.93,62.6,61.2 dB	Time=2025-03-31 19:33:46
#
# RS232 read data:N:063.2dB
#
# Valor medio medido=63.2 dB
#
# Valor máximo medido 63.2 dB
#
# Valor minimo medido 63.2 dB
#
# Medida(media, máximo, minimo)=63.2,63.2,63.2 dB	Time=2025-03-31 19:33:47
#
# RS232 read data:N:061.8dB
#
# RS232 read data:N:060.1dB
#
# Valor medio medido=60.99 dB
#
# Valor máximo medido 61.8 dB
#
# Valor minimo medido 60.1 dB
#
# Medida(media, máximo, minimo)=60.99,61.8,60.1 dB	Time=2025-03-31 19:33:48
#
# RS232 read data:N:059.1dB
#
# RS232 read data:N:064.7dB
#
# Valor medio medido=62.34 dB
#
# Valor máximo medido 64.7 dB
#
# Valor minimo medido 59.1 dB
#
# Medida(media, máximo, minimo)=62.34,64.7,59.1 dB	Time=2025-03-31 19:33:49
#
# RS232 read data:N:061.5dB
#
# RS232 read data:N:060.5dB
#
# Valor medio medido=61.01 dB
#
# Valor máximo medido 61.5 dB
#
# Valor minimo medido 60.5 dB
#
# Medida(media, máximo, minimo)=61.01,61.5,60.5 dB	Time=2025-03-31 19:33:50
#
# RS232 read data:N:058.7dB
#
# RS232 read data:N:061.3dB
#
# Valor medio medido=60.1 dB
#
# Valor máximo medido 61.3 dB
#
# Valor minimo medido 58.7 dB
#
# Medida(media, máximo, minimo)=60.1,61.3,58.7 dB	Time=2025-03-31 19:33:51
#
# RS232 read data:N:062.5dB
#
# RS232 read data:N:061.4dB
#
# Valor medio medido=61.97 dB
#
# Valor máximo medido 62.5 dB
#
# Valor minimo medido 61.4 dB
#
# Medida(media, máximo, minimo)=61.97,62.5,61.4 dB	Time=2025-03-31 19:33:52
#
# RS232 read data:N:061.9dB
#
# Valor medio medido=61.9 dB
#
# Valor máximo medido 61.9 dB
#
# Valor minimo medido 61.9 dB
#
# Medida(media, máximo, minimo)=61.9,61.9,61.9 dB	Time=2025-03-31 19:33:53
#
# RS232 read data:N:060.4dB
#
# RS232 read data:N:061.8dB
#
# Valor medio medido=61.13 dB
#
# Valor máximo medido 61.8 dB
#
# Valor minimo medido 60.4 dB
#
# Medida(media, máximo, minimo)=61.13,61.8,60.4 dB	Time=2025-03-31 19:33:54
#
# RS232 read data:N:059.8dB
#
# RS232 read data:N:059.1dB
#
# Valor medio medido=59.46 dB
#
# Valor máximo medido 59.8 dB
#
# Valor minimo medido 59.1 dB
#
# Medida(media, máximo, minimo)=59.46,59.8,59.1 dB	Time=2025-03-31 19:33:55
#
# RS232 read data:N:060.7dB
#
# RS232 read data:N:060.0dB
#
# Valor medio medido=60.36 dB
#
# Valor máximo medido 60.7 dB
#
# Valor minimo medido 60.0 dB
#
# Medida(media, máximo, minimo)=60.36,60.7,60.0 dB	Time=2025-03-31 19:33:56
#
# RS232 read data:N:058.0dB
#
# RS232 read data:N:061.2dB
#
# Valor medio medido=59.75 dB
#
# Valor máximo medido 61.2 dB
#
# Valor minimo medido 58.0 dB
#
# Medida(media, máximo, minimo)=59.75,61.2,58.0 dB	Time=2025-03-31 19:33:57
#
# RS232 read data:N:061.4dB
#
# RS232 read data:N:059.3dB
#
# Valor medio medido=60.41 dB
#
# Valor máximo medido 61.4 dB
#
# Valor minimo medido 59.3 dB
#
# Medida(media, máximo, minimo)=60.41,61.4,59.3 dB	Time=2025-03-31 19:33:58
#
# RS232 read data:N:062.2dB
#
# Valor medio medido=62.2 dB
#
# Valor máximo medido 62.2 dB
#
# Valor minimo medido 62.2 dB
#
# Medida(media, máximo, minimo)=62.2,62.2,62.2 dB	Time=2025-03-31 19:33:59
#
# RS232 read data:N:064.1dB
#
# RS232 read data:N:066.6dB
#
# Valor medio medido=65.44 dB
#
# Valor máximo medido 66.6 dB
#
# Valor minimo medido 64.1 dB
#
# Medida(media, máximo, minimo)=65.44,66.6,64.1 dB	Time=2025-03-31 19:34:00
#
# RS232 read data:N:070.7dB
#
# RS232 read data:N:067.2dB
#
# Valor medio medido=69.13 dB
#
# Valor máximo medido 70.7 dB
#
# Valor minimo medido 67.2 dB
#
# Medida(media, máximo, minimo)=69.13,70.7,67.2 dB	Time=2025-03-31 19:34:01
#
# RS232 read data:N:068.3dB
#
# Valor medio medido=68.3 dB
#
# Valor máximo medido 68.3 dB
#
# Valor minimo medido 68.3 dB
#
# Medida(media, máximo, minimo)=68.3,68.3,68.3 dB	Time=2025-03-31 19:34:02
#
# RS232 read data:N:070.7dB
#
# RS232 read data:N:064.7dB
#
# Valor medio medido=68.21 dB
#
# Valor máximo medido 70.7 dB
#
# Valor minimo medido 64.7 dB
#
# Medida(media, máximo, minimo)=68.21,70.7,64.7 dB	Time=2025-03-31 19:34:03
#
# RS232 read data:N:062.8dB
#
# RS232 read data:N:063.6dB
#
# Valor medio medido=63.21 dB
#
# Valor máximo medido 63.6 dB
#
# Valor minimo medido 62.8 dB
#
# Medida(media, máximo, minimo)=63.21,63.6,62.8 dB	Time=2025-03-31 19:34:04
#
# RS232 read data:N:063.1dB
#
# RS232 read data:N:064.6dB
#
# Valor medio medido=63.88 dB
#
# Valor máximo medido 64.6 dB
#
# Valor minimo medido 63.1 dB
#
# Medida(media, máximo, minimo)=63.88,64.6,63.1 dB	Time=2025-03-31 19:34:05
#
# RS232 read data:N:059.0dB
#
# Valor medio medido=59.0 dB
#
# Valor máximo medido 59.0 dB
#
# Valor minimo medido 59.0 dB
#
# Medida(media, máximo, minimo)=59.0,59.0,59.0 dB	Time=2025-03-31 19:34:06
#
# RS232 read data:N:064.1dB
#
# RS232 read data:N:055.9dB
#
# Valor medio medido=60.93 dB
#
# Valor máximo medido 64.1 dB
#
# Valor minimo medido 55.9 dB
#
# Medida(media, máximo, minimo)=60.93,64.1,55.9 dB	Time=2025-03-31 19:34:07
#
# RS232 read data:N:062.7dB
#
# RS232 read data:N:057.4dB
#
# Valor medio medido=60.45 dB
#
# Valor máximo medido 62.7 dB
#
# Valor minimo medido 57.4 dB
#
# Medida(media, máximo, minimo)=60.45,62.7,57.4 dB	Time=2025-03-31 19:34:08
#
# RS232 read data:N:059.9dB
#
# RS232 read data:N:059.3dB
#
# Valor medio medido=59.61 dB
#
# Valor máximo medido 59.9 dB
#
# Valor minimo medido 59.3 dB
#
# Medida(media, máximo, minimo)=59.61,59.9,59.3 dB	Time=2025-03-31 19:34:09
#
# RS232 read data:N:058.5dB
#
# RS232 read data:N:056.8dB
#
# Valor medio medido=57.69 dB
#
# Valor máximo medido 58.5 dB
#
# Valor minimo medido 56.8 dB
#
# Medida(media, máximo, minimo)=57.69,58.5,56.8 dB	Time=2025-03-31 19:34:10
#
# RS232 read data:N:057.6dB
#
# RS232 read data:N:059.9dB
#
# Valor medio medido=58.83 dB
#
# Valor máximo medido 59.9 dB
#
# Valor minimo medido 57.6 dB
#
# Medida(media, máximo, minimo)=58.83,59.9,57.6 dB	Time=2025-03-31 19:34:11
#
# RS232 read data:N:060.6dB
#
# Valor medio medido=60.6 dB
#
# Valor máximo medido 60.6 dB
#
# Valor minimo medido 60.6 dB
#
# Medida(media, máximo, minimo)=60.6,60.6,60.6 dB	Time=2025-03-31 19:34:12
#
# RS232 read data:N:058.8dB
#
# RS232 read data:N:064.5dB
#
# Valor medio medido=62.11 dB
#
# Valor máximo medido 64.5 dB
#
# Valor minimo medido 58.8 dB
#
# Medida(media, máximo, minimo)=62.11,64.5,58.8 dB	Time=2025-03-31 19:34:13
#
# RS232 read data:N:060.4dB
#
# RS232 read data:N:068.8dB
#
# Valor medio medido=65.58 dB
#
# Valor máximo medido 68.8 dB
#
# Valor minimo medido 60.4 dB
#
# Medida(media, máximo, minimo)=65.58,68.8,60.4 dB	Time=2025-03-31 19:34:14
#
# RS232 read data:N:068.9dB
#
# RS232 read data:N:057.8dB
#
# Valor medio medido=65.01 dB
#
# Valor máximo medido 68.9 dB
#
# Valor minimo medido 57.8 dB
#
# Medida(media, máximo, minimo)=65.01,68.9,57.8 dB	Time=2025-03-31 19:34:15
#
# RS232 read data:N:061.7dB
#
# RS232 read data:N:057.9dB
#
# Valor medio medido=60.01 dB
#
# Valor máximo medido 61.7 dB
#
# Valor minimo medido 57.9 dB
#
# Medida(media, máximo, minimo)=60.01,61.7,57.9 dB	Time=2025-03-31 19:34:16
#
# RS232 read data:N:061.2dB
#
# Valor medio medido=61.2 dB
#
# Valor máximo medido 61.2 dB
#
# Valor minimo medido 61.2 dB
#
# Medida(media, máximo, minimo)=61.2,61.2,61.2 dB	Time=2025-03-31 19:34:17
#
# RS232 read data:N:060.0dB
#
# RS232 read data:N:060.1dB
#
# Valor medio medido=60.05 dB
#
# Valor máximo medido 60.1 dB
#
# Valor minimo medido 60.0 dB
#
# Medida(media, máximo, minimo)=60.05,60.1,60.0 dB	Time=2025-03-31 19:34:18
#
# RS232 read data:N:059.8dB
#
# RS232 read data:N:058.1dB
#
# Valor medio medido=58.99 dB
#
# Valor máximo medido 59.8 dB
#
# Valor minimo medido 58.1 dB
#
# Medida(media, máximo, minimo)=58.99,59.8,58.1 dB	Time=2025-03-31 19:34:19
#
# RS232 read data:N:061.3dB
#
# RS232 read data:N:060.8dB
#
# Valor medio medido=61.05 dB
#
# Valor máximo medido 61.3 dB
#
# Valor minimo medido 60.8 dB
#
# Medida(media, máximo, minimo)=61.05,61.3,60.8 dB	Time=2025-03-31 19:34:20
#
# RS232 read data:N:063.0dB
#
# RS232 read data:N:060.2dB
#
# Valor medio medido=61.71 dB
#
# Valor máximo medido 63.0 dB
#
# Valor minimo medido 60.2 dB
#
# Medida(media, máximo, minimo)=61.71,63.0,60.2 dB	Time=2025-03-31 19:34:21
#
# RS232 read data:N:060.6dB
#
# Valor medio medido=60.6 dB
#
# Valor máximo medido 60.6 dB
#
# Valor minimo medido 60.6 dB
#
# Medida(media, máximo, minimo)=60.6,60.6,60.6 dB	Time=2025-03-31 19:34:22
#
# RS232 read data:N:058.4dB
#
# RS232 read data:N:058.5dB
#
# Valor medio medido=58.45 dB
#
# Valor máximo medido 58.5 dB
#
# Valor minimo medido 58.4 dB
#
# Medida(media, máximo, minimo)=58.45,58.5,58.4 dB	Time=2025-03-31 19:34:23
#
# RS232 read data:N:056.8dB
#
# RS232 read data:N:057.4dB
#
# Valor medio medido=57.11 dB
#
# Valor máximo medido 57.4 dB
#
# Valor minimo medido 56.8 dB
#
# Medida(media, máximo, minimo)=57.11,57.4,56.8 dB	Time=2025-03-31 19:34:24
#
# RS232 read data:N:062.0dB
#
# RS232 read data:N:058.4dB
#
# Valor medio medido=60.39 dB
#
# Valor máximo medido 62.0 dB
#
# Valor minimo medido 58.4 dB
#
# Medida(media, máximo, minimo)=60.39,62.0,58.4 dB	Time=2025-03-31 19:34:25
#
# RS232 read data:N:061.1dB
#
# RS232 read data:N:058.1dB
#
# Valor medio medido=59.73 dB
#
# Valor máximo medido 61.1 dB
#
# Valor minimo medido 58.1 dB
#
# Medida(media, máximo, minimo)=59.73,61.1,58.1 dB	Time=2025-03-31 19:34:26
#
# RS232 read data:N:057.4dB
#
# RS232 read data:N:057.9dB
#
# Valor medio medido=57.65 dB
#
# Valor máximo medido 57.9 dB
#
# Valor minimo medido 57.4 dB
#
# Medida(media, máximo, minimo)=57.65,57.9,57.4 dB	Time=2025-03-31 19:34:27
#
# RS232 read data:N:057.9dB
#
# RS232 read data:N:062.8dB
#
# Valor medio medido=60.69 dB
#
# Valor máximo medido 62.8 dB
#
# Valor minimo medido 57.9 dB
#
# Medida(media, máximo, minimo)=60.69,62.8,57.9 dB	Time=2025-03-31 19:34:28
#
# RS232 read data:N:058.0dB
#
# Valor medio medido=58.0 dB
#
# Valor máximo medido 58.0 dB
#
# Valor minimo medido 58.0 dB
#
# Medida(media, máximo, minimo)=58.0,58.0,58.0 dB	Time=2025-03-31 19:34:29
#
# RS232 read data:N:057.2dB
#
# RS232 read data:N:059.2dB
#
# Valor medio medido=58.26 dB
#
# Valor máximo medido 59.2 dB
#
# Valor minimo medido 57.2 dB
#
# Medida(media, máximo, minimo)=58.26,59.2,57.2 dB	Time=2025-03-31 19:34:30
#
# RS232 read data:N:056.9dB
#
# RS232 read data:N:058.7dB
#
# Valor medio medido=57.85 dB
#
# Valor máximo medido 58.7 dB
#
# Valor minimo medido 56.9 dB
#
# Medida(media, máximo, minimo)=57.85,58.7,56.9 dB	Time=2025-03-31 19:34:31
#
# RS232 read data:N:058.0dB
#
# RS232 read data:N:068.5dB
#
# Valor medio medido=64.75 dB
#
# Valor máximo medido 68.5 dB
#
# Valor minimo medido 58.0 dB
#
# Medida(media, máximo, minimo)=64.75,68.5,58.0 dB	Time=2025-03-31 19:34:32
#
# RS232 read data:N:064.5dB
#
# RS232 read data:N:062.0dB
#
# Valor medio medido=63.34 dB
#
# Valor máximo medido 64.5 dB
#
# Valor minimo medido 62.0 dB
#
# Medida(media, máximo, minimo)=63.34,64.5,62.0 dB	Time=2025-03-31 19:34:33
#
# RS232 read data:N:063.5dB
#
# Valor medio medido=63.5 dB
#
# Valor máximo medido 63.5 dB
#
# Valor minimo medido 63.5 dB
#
# Medida(media, máximo, minimo)=63.5,63.5,63.5 dB	Time=2025-03-31 19:34:34
#
# RS232 read data:N:066.3dB
#
# RS232 read data:N:068.9dB
#
# Valor medio medido=67.7 dB
#
# Valor máximo medido 68.9 dB
#
# Valor minimo medido 66.3 dB
#
# Medida(media, máximo, minimo)=67.7,68.9,66.3 dB	Time=2025-03-31 19:34:35
#
# RS232 read data:N:069.9dB
#
# RS232 read data:N:069.1dB
#
# Valor medio medido=69.51 dB
#
# Valor máximo medido 69.9 dB
#
# Valor minimo medido 69.1 dB
#
# Medida(media, máximo, minimo)=69.51,69.9,69.1 dB	Time=2025-03-31 19:34:36
#
# RS232 read data:N:063.2dB
#
# RS232 read data:N:064.4dB
#
# Valor medio medido=63.82 dB
#
# Valor máximo medido 64.4 dB
#
# Valor minimo medido 63.2 dB
#
# Medida(media, máximo, minimo)=63.82,64.4,63.2 dB	Time=2025-03-31 19:34:37
#
# RS232 read data:N:062.4dB
#
# Valor medio medido=62.4 dB
#
# Valor máximo medido 62.4 dB
#
# Valor minimo medido 62.4 dB
#
# Medida(media, máximo, minimo)=62.4,62.4,62.4 dB	Time=2025-03-31 19:34:38
#
# RS232 read data:N:061.0dB
#
# RS232 read data:N:061.1dB
#
# Valor medio medido=61.05 dB
#
# Valor máximo medido 61.1 dB
#
# Valor minimo medido 61.0 dB
#
# Medida(media, máximo, minimo)=61.05,61.1,61.0 dB	Time=2025-03-31 19:34:39
#
# RS232 read data:N:061.3dB
#
# RS232 read data:N:061.7dB
#
# Valor medio medido=61.5 dB
#
# Valor máximo medido 61.7 dB
#
# Valor minimo medido 61.3 dB
#
# Medida(media, máximo, minimo)=61.5,61.7,61.3 dB	Time=2025-03-31 19:34:40
#
# RS232 read data:N:060.9dB
#
# RS232 read data:N:067.0dB
#
# Valor medio medido=64.47 dB
#
# Valor máximo medido 67.0 dB
#
# Valor minimo medido 60.9 dB
#
# Medida(media, máximo, minimo)=64.47,67.0,60.9 dB	Time=2025-03-31 19:34:41
#
# RS232 read data:N:060.8dB
#
# Valor medio medido=60.8 dB
#
# Valor máximo medido 60.8 dB
#
# Valor minimo medido 60.8 dB
#
# Medida(media, máximo, minimo)=60.8,60.8,60.8 dB	Time=2025-03-31 19:34:42
#
# RS232 read data:N:070.4dB
#
# RS232 read data:N:064.8dB
#
# Valor medio medido=68.04 dB
#
# Valor máximo medido 70.4 dB
#
# Valor minimo medido 64.8 dB
#
# Medida(media, máximo, minimo)=68.04,70.4,64.8 dB	Time=2025-03-31 19:34:43
#
# RS232 read data:N:061.9dB
#
# RS232 read data:N:060.3dB
#
# Valor medio medido=61.14 dB
#
# Valor máximo medido 61.9 dB
#
# Valor minimo medido 60.3 dB
#
# Medida(media, máximo, minimo)=61.14,61.9,60.3 dB	Time=2025-03-31 19:34:44
#
# RS232 read data:N:059.3dB
#
# RS232 read data:N:058.0dB
#
# Valor medio medido=58.67 dB
#
# Valor máximo medido 59.3 dB
#
# Valor minimo medido 58.0 dB
#
# Medida(media, máximo, minimo)=58.67,59.3,58.0 dB	Time=2025-03-31 19:34:45
#
# RS232 read data:N:061.2dB
#
# Valor medio medido=61.2 dB
#
# Valor máximo medido 61.2 dB
#
# Valor minimo medido 61.2 dB
#
# Medida(media, máximo, minimo)=61.2,61.2,61.2 dB	Time=2025-03-31 19:34:46
#
# RS232 read data:N:061.0dB
#
# RS232 read data:N:057.8dB
#
# Valor medio medido=59.55 dB
#
# Valor máximo medido 61.0 dB
#
# Valor minimo medido 57.8 dB
#
# Medida(media, máximo, minimo)=59.55,61.0,57.8 dB	Time=2025-03-31 19:34:47
#
# RS232 read data:N:061.4dB
#
# RS232 read data:N:058.1dB
#
# Valor medio medido=59.91 dB
#
# Valor máximo medido 61.4 dB
#
# Valor minimo medido 58.1 dB
#
# Medida(media, máximo, minimo)=59.91,61.4,58.1 dB	Time=2025-03-31 19:34:48
#
# RS232 read data:N:058.6dB
#
# RS232 read data:N:059.0dB
#
# Valor medio medido=58.8 dB
#
# Valor máximo medido 59.0 dB
#
# Valor minimo medido 58.6 dB
#
# Medida(media, máximo, minimo)=58.8,59.0,58.6 dB	Time=2025-03-31 19:34:49
#
# RS232 read data:N:060.3dB
#
# RS232 read data:N:059.0dB
#
# Valor medio medido=59.67 dB
#
# Valor máximo medido 60.3 dB
#
# Valor minimo medido 59.0 dB
#
# Medida(media, máximo, minimo)=59.67,60.3,59.0 dB	Time=2025-03-31 19:34:50
#
# RS232 read data:N:060.0dB
#
# Valor medio medido=60.0 dB
#
# Valor máximo medido 60.0 dB
#
# Valor minimo medido 60.0 dB
#
# Medida(media, máximo, minimo)=60.0,60.0,60.0 dB	Time=2025-03-31 19:34:51
#
# RS232 read data:N:060.5dB
#
# RS232 read data:N:059.9dB
#
# Valor medio medido=60.21 dB
#
# Valor máximo medido 60.5 dB
#
# Valor minimo medido 59.9 dB
#
# Medida(media, máximo, minimo)=60.21,60.5,59.9 dB	Time=2025-03-31 19:34:52
#
# RS232 read data:N:060.3dB
#
# RS232 read data:N:061.8dB
#
# Valor medio medido=61.08 dB
#
# Valor máximo medido 61.8 dB
#
# Valor minimo medido 60.3 dB
#
# Medida(media, máximo, minimo)=61.08,61.8,60.3 dB	Time=2025-03-31 19:34:53
#
# RS232 read data:N:059.7dB
#
# RS232 read data:N:061.4dB
#
# Valor medio medido=60.59 dB
#
# Valor máximo medido 61.4 dB
#
# Valor minimo medido 59.7 dB
#
# Medida(media, máximo, minimo)=60.59,61.4,59.7 dB	Time=2025-03-31 19:34:54
#
# RS232 read data:N:061.4dB
#
# RS232 read data:N:062.3dB
#
# Valor medio medido=61.86 dB
#
# Valor máximo medido 62.3 dB
#
# Valor minimo medido 61.4 dB
#
# Medida(media, máximo, minimo)=61.86,62.3,61.4 dB	Time=2025-03-31 19:34:55
#
# RS232 read data:N:066.5dB
#
# Valor medio medido=66.5 dB
#
# Valor máximo medido 66.5 dB
#
# Valor minimo medido 66.5 dB
#
# Medida(media, máximo, minimo)=66.5,66.5,66.5 dB	Time=2025-03-31 19:34:56
#
# RS232 read data:N:066.2dB
#
# RS232 read data:N:066.0dB
#
# Valor medio medido=66.1 dB
#
# Valor máximo medido 66.2 dB
#
# Valor minimo medido 66.0 dB
#
# Medida(media, máximo, minimo)=66.1,66.2,66.0 dB	Time=2025-03-31 19:34:57
#
# RS232 read data:N:064.0dB
#
# RS232 read data:N:062.0dB
#
# Valor medio medido=63.06 dB
#
# Valor máximo medido 64.0 dB
#
# Valor minimo medido 62.0 dB
#
# Medida(media, máximo, minimo)=63.06,64.0,62.0 dB	Time=2025-03-31 19:34:58
#
# RS232 read data:N:063.8dB
#
# Valor medio medido=63.8 dB
#
# Valor máximo medido 63.8 dB
#
# Valor minimo medido 63.8 dB
#
# Medida(media, máximo, minimo)=63.8,63.8,63.8 dB	Time=2025-03-31 19:34:59
#
# RS232 read data:N:066.5dB
#
# RS232 read data:N:069.8dB
#
# Valor medio medido=68.31 dB
#
# Valor máximo medido 69.8 dB
#
# Valor minimo medido 66.5 dB
#
# Medida(media, máximo, minimo)=68.31,69.8,66.5 dB	Time=2025-03-31 19:35:00
#
# RS232 read data:N:067.3dB
#
# RS232 read data:N:067.8dB
#
# Valor medio medido=67.55 dB
#
# Valor máximo medido 67.8 dB
#
# Valor minimo medido 67.3 dB
#
# Medida(media, máximo, minimo)=67.55,67.8,67.3 dB	Time=2025-03-31 19:35:01
#
# RS232 read data:N:063.5dB
#
# RS232 read data:N:061.3dB
#
# Valor medio medido=62.47 dB
#
# Valor máximo medido 63.5 dB
#
# Valor minimo medido 61.3 dB
#
# Medida(media, máximo, minimo)=62.47,63.5,61.3 dB	Time=2025-03-31 19:35:02
#
# RS232 read data:N:060.9dB
#
# Valor medio medido=60.9 dB
#
# Valor máximo medido 60.9 dB
#
# Valor minimo medido 60.9 dB
#
# Medida(media, máximo, minimo)=60.9,60.9,60.9 dB	Time=2025-03-31 19:35:03
#
# RS232 read data:N:069.9dB
#
# RS232 read data:N:057.0dB
#
# Valor medio medido=65.65 dB
#
# Valor máximo medido 69.9 dB
#
# Valor minimo medido 57.0 dB
#
# Medida(media, máximo, minimo)=65.65,69.9,57.0 dB	Time=2025-03-31 19:35:04
#
# RS232 read data:N:062.0dB
#
# RS232 read data:N:060.8dB
#
# Valor medio medido=61.42 dB
#
# Valor máximo medido 62.0 dB
#
# Valor minimo medido 60.8 dB
#
# Medida(media, máximo, minimo)=61.42,62.0,60.8 dB	Time=2025-03-31 19:35:05
#
# RS232 read data:N:065.0dB
#
# RS232 read data:N:060.5dB
#
# Valor medio medido=63.04 dB
#
# Valor máximo medido 65.0 dB
#
# Valor minimo medido 60.5 dB
#
# Medida(media, máximo, minimo)=63.04,65.0,60.5 dB	Time=2025-03-31 19:35:06
#
# RS232 read data:N:061.7dB
#
# Valor medio medido=61.7 dB
#
# Valor máximo medido 61.7 dB
#
# Valor minimo medido 61.7 dB
#
# Medida(media, máximo, minimo)=61.7,61.7,61.7 dB	Time=2025-03-31 19:35:07
#
# RS232 read data:N:061.7dB
#
# RS232 read data:N:063.0dB
#
# Valor medio medido=62.37 dB
#
# Valor máximo medido 63.0 dB
#
# Valor minimo medido 61.7 dB
#
# Medida(media, máximo, minimo)=62.37,63.0,61.7 dB	Time=2025-03-31 19:35:08
#
# RS232 read data:N:068.6dB
#
# RS232 read data:N:061.0dB
#
# Valor medio medido=65.61 dB
#
# Valor máximo medido 68.6 dB
#
# Valor minimo medido 61.0 dB
#
# Medida(media, máximo, minimo)=65.61,68.6,61.0 dB	Time=2025-03-31 19:35:09
#
# RS232 read data:N:060.9dB
#
# RS232 read data:N:060.4dB
#
# Valor medio medido=60.65 dB
#
# Valor máximo medido 60.9 dB
#
# Valor minimo medido 60.4 dB
#
# Medida(media, máximo, minimo)=60.65,60.9,60.4 dB	Time=2025-03-31 19:35:10
#
# RS232 read data:N:060.9dB
#
# Valor medio medido=60.9 dB
#
# Valor máximo medido 60.9 dB
#
# Valor minimo medido 60.9 dB
#
# Medida(media, máximo, minimo)=60.9,60.9,60.9 dB	Time=2025-03-31 19:35:11
#
# RS232 read data:N:059.5dB
#
# RS232 read data:N:060.8dB
#
# Valor medio medido=60.17 dB
#
# Valor máximo medido 60.8 dB
#
# Valor minimo medido 59.5 dB
#
# Medida(media, máximo, minimo)=60.17,60.8,59.5 dB	Time=2025-03-31 19:35:12
#
# RS232 read data:N:063.6dB
#
# RS232 read data:N:064.2dB
#
# Valor medio medido=63.91 dB
#
# Valor máximo medido 64.2 dB
#
# Valor minimo medido 63.6 dB
#
# Medida(media, máximo, minimo)=63.91,64.2,63.6 dB	Time=2025-03-31 19:35:13
#
# RS232 read data:N:061.9dB
#
# RS232 read data:N:065.6dB
#
# Valor medio medido=63.95 dB
#
# Valor máximo medido 65.6 dB
#
# Valor minimo medido 61.9 dB
#
# Medida(media, máximo, minimo)=63.95,65.6,61.9 dB	Time=2025-03-31 19:35:14
#
# RS232 read data:N:066.7dB
#
# RS232 read data:N:060.5dB
#
# Valor medio medido=64.14 dB
#
# Valor máximo medido 66.7 dB
#
# Valor minimo medido 60.5 dB
#
# Medida(media, máximo, minimo)=64.14,66.7,60.5 dB	Time=2025-03-31 19:35:15
#
# RS232 read data:N:061.4dB
#
# Valor medio medido=61.4 dB
#
# Valor máximo medido 61.4 dB
#
# Valor minimo medido 61.4 dB
#
# Medida(media, máximo, minimo)=61.4,61.4,61.4 dB	Time=2025-03-31 19:35:16
#
# RS232 read data:N:054.6dB
#
# RS232 read data:N:056.9dB
#
# Valor medio medido=55.83 dB
#
# Valor máximo medido 56.9 dB
#
# Valor minimo medido 54.6 dB
#
# Medida(media, máximo, minimo)=55.83,56.9,54.6 dB	Time=2025-03-31 19:35:17
#
# RS232 read data:N:058.5dB
#
# RS232 read data:N:065.6dB
#
# Valor medio medido=62.76 dB
#
# Valor máximo medido 65.6 dB
#
# Valor minimo medido 58.5 dB
#
# Medida(media, máximo, minimo)=62.76,65.6,58.5 dB	Time=2025-03-31 19:35:18
#
# RS232 read data:N:064.8dB
#
# RS232 read data:N:061.7dB
#
# Valor medio medido=63.39 dB
#
# Valor máximo medido 64.8 dB
#
# Valor minimo medido 61.7 dB
#
# Medida(media, máximo, minimo)=63.39,64.8,61.7 dB	Time=2025-03-31 19:35:19
#
# RS232 read data:N:062.0dB
#
# RS232 read data:N:061.8dB
#
# Valor medio medido=61.9 dB
#
# Valor máximo medido 62.0 dB
#
# Valor minimo medido 61.8 dB
#
# Medida(media, máximo, minimo)=61.9,62.0,61.8 dB	Time=2025-03-31 19:35:20
#
# RS232 read data:N:065.1dB
#
# Valor medio medido=65.1 dB
#
# Valor máximo medido 65.1 dB
#
# Valor minimo medido 65.1 dB
#
# Medida(media, máximo, minimo)=65.1,65.1,65.1 dB	Time=2025-03-31 19:35:21
#
# RS232 read data:N:065.5dB
#
# RS232 read data:N:063.2dB
#
# Valor medio medido=64.43 dB
#
# Valor máximo medido 65.5 dB
#
# Valor minimo medido 63.2 dB
#
# Medida(media, máximo, minimo)=64.43,65.5,63.2 dB	Time=2025-03-31 19:35:22
#
# RS232 read data:N:063.8dB
#
# RS232 read data:N:064.1dB
#
# Valor medio medido=63.95 dB
#
# Valor máximo medido 64.1 dB
#
# Valor minimo medido 63.8 dB
#
# Medida(media, máximo, minimo)=63.95,64.1,63.8 dB	Time=2025-03-31 19:35:23
#
# RS232 read data:N:061.1dB
#
# RS232 read data:N:062.0dB
#
# Valor medio medido=61.56 dB
#
# Valor máximo medido 62.0 dB
#
# Valor minimo medido 61.1 dB
#
# Medida(media, máximo, minimo)=61.56,62.0,61.1 dB	Time=2025-03-31 19:35:24
#
# RS232 read data:N:060.7dB
#
# Valor medio medido=60.7 dB
#
# Valor máximo medido 60.7 dB
#
# Valor minimo medido 60.7 dB
#
# Medida(media, máximo, minimo)=60.7,60.7,60.7 dB	Time=2025-03-31 19:35:25
#
# RS232 read data:N:063.3dB
#
# RS232 read data:N:062.9dB
#
# Valor medio medido=63.1 dB
#
# Valor máximo medido 63.3 dB
#
# Valor minimo medido 62.9 dB
#
# Medida(media, máximo, minimo)=63.1,63.3,62.9 dB	Time=2025-03-31 19:35:26
#
# RS232 read data:N:068.5dB
#
# RS232 read data:N:066.0dB
#
# Valor medio medido=67.34 dB
#
# Valor máximo medido 68.5 dB
#
# Valor minimo medido 66.0 dB
#
# Medida(media, máximo, minimo)=67.34,68.5,66.0 dB	Time=2025-03-31 19:35:27
#
# RS232 read data:N:062.7dB
#
# RS232 read data:N:065.2dB
#
# Valor medio medido=64.04 dB
#
# Valor máximo medido 65.2 dB
#
# Valor minimo medido 62.7 dB
#
# Medida(media, máximo, minimo)=64.04,65.2,62.7 dB	Time=2025-03-31 19:35:28
#
# RS232 read data:N:062.3dB
#
# Valor medio medido=62.3 dB
#
# Valor máximo medido 62.3 dB
#
# Valor minimo medido 62.3 dB
#
# Medida(media, máximo, minimo)=62.3,62.3,62.3 dB	Time=2025-03-31 19:35:29
#
# RS232 read data:N:065.9dB
#
# RS232 read data:N:063.9dB
#
# Valor medio medido=64.96 dB
#
# Valor máximo medido 65.9 dB
#
# Valor minimo medido 63.9 dB
#
# Medida(media, máximo, minimo)=64.96,65.9,63.9 dB	Time=2025-03-31 19:35:30
#
# RS232 read data:N:063.9dB
#
# RS232 read data:N:065.1dB
#
# Valor medio medido=64.52 dB
#
# Valor máximo medido 65.1 dB
#
# Valor minimo medido 63.9 dB
#
# Medida(media, máximo, minimo)=64.52,65.1,63.9 dB	Time=2025-03-31 19:35:31
#
# RS232 read data:N:067.9dB
#
# Valor medio medido=67.9 dB
#
# Valor máximo medido 67.9 dB
#
# Valor minimo medido 67.9 dB
#
# Medida(media, máximo, minimo)=67.9,67.9,67.9 dB	Time=2025-03-31 19:35:32
#
# RS232 read data:N:068.3dB
#
# RS232 read data:N:071.0dB
#
# Valor medio medido=69.75 dB
#
# Valor máximo medido 71.0 dB
#
# Valor minimo medido 68.3 dB
#
# Medida(media, máximo, minimo)=69.75,71.0,68.3 dB	Time=2025-03-31 19:35:33
#
# RS232 read data:N:069.2dB
#
# RS232 read data:N:069.4dB
#
# Valor medio medido=69.3 dB
#
# Valor máximo medido 69.4 dB
#
# Valor minimo medido 69.2 dB
#
# Medida(media, máximo, minimo)=69.3,69.4,69.2 dB	Time=2025-03-31 19:35:34
#
# RS232 read data:N:068.2dB
#
# Valor medio medido=68.2 dB
#
# Valor máximo medido 68.2 dB
#
# Valor minimo medido 68.2 dB
#
# Medida(media, máximo, minimo)=68.2,68.2,68.2 dB	Time=2025-03-31 19:35:35
#
# RS232 read data:N:066.8dB
#
# RS232 read data:N:067.2dB
#
# Valor medio medido=67.0 dB
#
# Valor máximo medido 67.2 dB
#
# Valor minimo medido 66.8 dB
#
# Medida(media, máximo, minimo)=67.0,67.2,66.8 dB	Time=2025-03-31 19:35:36
#
# RS232 read data:N:067.7dB
#
# RS232 read data:N:068.0dB
#
# Valor medio medido=67.85 dB
#
# Valor máximo medido 68.0 dB
#
# Valor minimo medido 67.7 dB
#
# Medida(media, máximo, minimo)=67.85,68.0,67.7 dB	Time=2025-03-31 19:35:37
#
# RS232 read data:N:068.4dB
#
# Valor medio medido=68.4 dB
#
# Valor máximo medido 68.4 dB
#
# Valor minimo medido 68.4 dB
#
# Medida(media, máximo, minimo)=68.4,68.4,68.4 dB	Time=2025-03-31 19:35:38
#
# RS232 read data:N:068.1dB
#
# RS232 read data:N:067.1dB
#
# Valor medio medido=67.61 dB
#
# Valor máximo medido 68.1 dB
#
# Valor minimo medido 67.1 dB
#
# Medida(media, máximo, minimo)=67.61,68.1,67.1 dB	Time=2025-03-31 19:35:39
#
# RS232 read data:N:071.8dB
#
# RS232 read data:N:061.4dB
#
# Valor medio medido=68.07 dB
#
# Valor máximo medido 71.8 dB
#
# Valor minimo medido 61.4 dB
#
# Medida(media, máximo, minimo)=68.07,71.8,61.4 dB	Time=2025-03-31 19:35:40
#
# RS232 read data:N:067.7dB
#
# RS232 read data:N:064.8dB
#
# Valor medio medido=66.37 dB
#
# Valor máximo medido 67.7 dB
#
# Valor minimo medido 64.8 dB
#
# Medida(media, máximo, minimo)=66.37,67.7,64.8 dB	Time=2025-03-31 19:35:41
#
# RS232 read data:N:069.1dB
#
# Valor medio medido=69.1 dB
#
# Valor máximo medido 69.1 dB
#
# Valor minimo medido 69.1 dB
#
# Medida(media, máximo, minimo)=69.1,69.1,69.1 dB	Time=2025-03-31 19:35:42
#
# RS232 read data:N:064.6dB
#
# RS232 read data:N:069.9dB
#
# Valor medio medido=67.65 dB
#
# Valor máximo medido 69.9 dB
#
# Valor minimo medido 64.6 dB
#
# Medida(media, máximo, minimo)=67.65,69.9,64.6 dB	Time=2025-03-31 19:35:43
#
# RS232 read data:N:065.4dB
#
# RS232 read data:N:062.0dB
#
# Valor medio medido=63.87 dB
#
# Valor máximo medido 65.4 dB
#
# Valor minimo medido 62.0 dB
#
# Medida(media, máximo, minimo)=63.87,65.4,62.0 dB	Time=2025-03-31 19:35:44
#
# RS232 read data:N:066.7dB
#
# Valor medio medido=66.7 dB
#
# Valor máximo medido 66.7 dB
#
# Valor minimo medido 66.7 dB
#
# Medida(media, máximo, minimo)=66.7,66.7,66.7 dB	Time=2025-03-31 19:35:45
#
# RS232 read data:N:065.8dB
#
# RS232 read data:N:060.5dB
#
# Valor medio medido=63.55 dB
#
# Valor máximo medido 65.8 dB
#
# Valor minimo medido 60.5 dB
#
# Medida(media, máximo, minimo)=63.55,65.8,60.5 dB	Time=2025-03-31 19:35:46
#
# RS232 read data:N:068.7dB
#
# RS232 read data:N:061.1dB
#
# Valor medio medido=65.71 dB
#
# Valor máximo medido 68.7 dB
#
# Valor minimo medido 61.1 dB
#
# Medida(media, máximo, minimo)=65.71,68.7,61.1 dB	Time=2025-03-31 19:35:47
#
# RS232 read data:N:062.3dB
#
# RS232 read data:N:062.2dB
#
# Valor medio medido=62.25 dB
#
# Valor máximo medido 62.3 dB
#
# Valor minimo medido 62.2 dB
#
# Medida(media, máximo, minimo)=62.25,62.3,62.2 dB	Time=2025-03-31 19:35:48
#
# RS232 read data:N:060.7dB
#
# Valor medio medido=60.7 dB
#
# Valor máximo medido 60.7 dB
#
# Valor minimo medido 60.7 dB
#
# Medida(media, máximo, minimo)=60.7,60.7,60.7 dB	Time=2025-03-31 19:35:49
#
# RS232 read data:N:065.1dB
#
# RS232 read data:N:059.7dB
#
# Valor medio medido=62.81 dB
#
# Valor máximo medido 65.1 dB
#
# Valor minimo medido 59.7 dB
#
# Medida(media, máximo, minimo)=62.81,65.1,59.7 dB	Time=2025-03-31 19:35:50
#
# RS232 read data:N:060.8dB
#
# RS232 read data:N:059.9dB
#
# Valor medio medido=60.36 dB
#
# Valor máximo medido 60.8 dB
#
# Valor minimo medido 59.9 dB
#
# Medida(media, máximo, minimo)=60.36,60.8,59.9 dB	Time=2025-03-31 19:35:51
#
# RS232 read data:N:060.7dB
#
# RS232 read data:N:064.2dB
#
# Valor medio medido=62.63 dB
#
# Valor máximo medido 64.2 dB
#
# Valor minimo medido 60.7 dB
#
# Medida(media, máximo, minimo)=62.63,64.2,60.7 dB	Time=2025-03-31 19:35:52
#
# RS232 read data:N:060.2dB
#
# Valor medio medido=60.2 dB
#
# Valor máximo medido 60.2 dB
#
# Valor minimo medido 60.2 dB
#
# Medida(media, máximo, minimo)=60.2,60.2,60.2 dB	Time=2025-03-31 19:35:53
#
# RS232 read data:N:056.5dB
#
# RS232 read data:N:065.4dB
#
# Valor medio medido=62.04 dB
#
# Valor máximo medido 65.4 dB
#
# Valor minimo medido 56.5 dB
#
# Medida(media, máximo, minimo)=62.04,65.4,56.5 dB	Time=2025-03-31 19:35:54
#
# RS232 read data:N:063.1dB
#
# RS232 read data:N:061.9dB
#
# Valor medio medido=62.52 dB
#
# Valor máximo medido 63.1 dB
#
# Valor minimo medido 61.9 dB
#
# Medida(media, máximo, minimo)=62.52,63.1,61.9 dB	Time=2025-03-31 19:35:55
#
# RS232 read data:N:055.8dB
#
# RS232 read data:N:067.1dB
#
# Valor medio medido=63.17 dB
#
# Valor máximo medido 67.1 dB
#
# Valor minimo medido 55.8 dB
#
# Medida(media, máximo, minimo)=63.17,67.1,55.8 dB	Time=2025-03-31 19:35:56
#
# RS232 read data:N:058.9dB
#
# RS232 read data:N:056.7dB
#
# Valor medio medido=57.87 dB
#
# Valor máximo medido 58.9 dB
#
# Valor minimo medido 56.7 dB
#
# Medida(media, máximo, minimo)=57.87,58.9,56.7 dB	Time=2025-03-31 19:35:57
#
# RS232 read data:N:057.1dB
#
# Valor medio medido=57.1 dB
#
# Valor máximo medido 57.1 dB
#
# Valor minimo medido 57.1 dB
#
# Medida(media, máximo, minimo)=57.1,57.1,57.1 dB	Time=2025-03-31 19:35:58
#
# RS232 read data:N:059.7dB
#
# RS232 read data:N:058.4dB
#
# Valor medio medido=59.07 dB
#
# Valor máximo medido 59.7 dB
#
# Valor minimo medido 58.4 dB
#
# Medida(media, máximo, minimo)=59.07,59.7,58.4 dB	Time=2025-03-31 19:35:59
#
# RS232 read data:N:057.7dB
#
# RS232 read data:N:071.8dB
#
# Valor medio medido=67.34 dB
#
# Valor máximo medido 71.8 dB
#
# Valor minimo medido 57.7 dB
#
# Medida(media, máximo, minimo)=67.34,71.8,57.7 dB	Time=2025-03-31 19:36:00
#
# RS232 read data:N:058.9dB
#
# RS232 read data:N:059.7dB
#
# Valor medio medido=59.31 dB
#
# Valor máximo medido 59.7 dB
#
# Valor minimo medido 58.9 dB
#
# Medida(media, máximo, minimo)=59.31,59.7,58.9 dB	Time=2025-03-31 19:36:01
#
# RS232 read data:N:055.7dB
#
# RS232 read data:N:056.5dB
#
# Valor medio medido=56.11 dB
#
# Valor máximo medido 56.5 dB
#
# Valor minimo medido 55.7 dB
#
# Medida(media, máximo, minimo)=56.11,56.5,55.7 dB	Time=2025-03-31 19:36:02
#
# RS232 read data:
#
# RS232 cerrando el puerto serie.
#
# Measurements saved to log_files/medida_3/type_2 Mon 2025-03-31 19h31m01s.json

# %%
import matplotlib.pyplot as plt

pic_path = 'Pics/medida_3/type_2 '+format_time(time.time(), True)

# Load the measurements from the JSON file.
with open(json_file, 'r') as f:
    measurements = json.load(f)

times = [m["time"] for m in measurements]
means = [m["mean"] for m in measurements]
maxs = [m["max"] for m in measurements]
mins = [m["min"] for m in measurements]

m_number = list(range(0,len(measurements)))

# Plot the measurements
plt.figure(figsize=(10, 6))
plt.plot(m_number, means, label="Mean", color="blue")
plt.plot(m_number, maxs, label="Max", color="red", linestyle="--")
plt.plot(m_number, mins, label="Min", color="green", linestyle="--")
plt.xlim(0, len(measurements)-1)
plt.xlabel("Sampling Time")
plt.ylabel("Sound Level (dB)")
plt.title("Sound Level Measurements Over Time")
plt.legend()
plt.grid(True)
plt.savefig(pic_path+'.png')
plt.show()

# %% [markdown]
# ## Ejemplo de lectura directa del Serial y almacenamiento en un vector.

# %%
import serial
import math

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'


# Sound level meter.
port_AZ8922 = SELECTED_PORT
ser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port


# Reset the arrays.
sound_level = []

#while(ser.connected):
for x in range(10):
    output = ser.readline().decode('utf-8', 'ignore')
    output = output.strip()
    #print("RS232 read data:"+str(output)+"\n")
    if output.startswith('N:') and output.endswith('dB'):
        salida_texto=float(output.split(':')[1].split('dB')[0])
        sound_level.append(salida_texto) # Para concatenar los valores y formar un Vector/Array
        print("RS232 db="+str(salida_texto)+"\n")     
    
ser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el 
#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia
#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.


# Round up.
#sound_level_mean = round(sound_level_mean,2)
#print("Sound Level(Media)="+str(sound_level_mean)+"\n") 

#Calculamos el máximo en dB
sound_level_max = max(sound_level) #Esto es el máximo de un vector
print(Green + "Sound Level(Max)="+str(sound_level_max)+" db\n") 

#Calculamos el mínomo en dB
sound_level_min = min(sound_level)
print(Magenta+"Sound Level(Min)="+str(sound_level_min)+" db\n") 

#Calculamos la suma de los valores sin decibelios
sound_level_linear = [math.pow(10,x/20) for x in sound_level] 
print(Blue +"Sound Level(linear)="+str(sound_level_linear)+"\n") 

#Pasamos la suma de lo medido en dB
sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
sound_level_mean = 20*math.log10(sound_level_mean)
print(Red + "Sound Level(Mean)="+str(sound_level_mean)+" db\n")
# Out:
# RS232 db=63.7
#
# RS232 db=63.0
#
# RS232 db=65.3
#
# RS232 db=57.0
#
# RS232 db=68.0
#
# RS232 db=60.6
#
# RS232 db=61.8
#
# RS232 db=59.4
#
# RS232 db=61.4
#
# RS232 db=60.1
#
# Sound Level(Max)=68.0 db
#
# Sound Level(Min)=57.0 db
#
# Sound Level(linear)=[1531.0874616820304, 1412.537544622754, 1840.7720014689544, 707.945784384138, 2511.88643150958, 1071.519305237607, 1230.268770812381, 933.2543007969905, 1174.897554939529, 1011.5794542598983]
#
# Sound Level(Mean)=62.55877021965312 db
