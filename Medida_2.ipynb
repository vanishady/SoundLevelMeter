# %% [markdown]
# # Medida 2
# ## Piso con ventana abierta
#
#  **Ubicacion**: Piso residencial (interior) con ventana abierta.
#
#  **Metodologia**:
#  * Medicion de los niveles de presion sonora en el interior del piso, con el fin de cuantificar la intrusion de ruido exterior (trafico, obras urbanas, vecindario etc.).
#  * Toma de mediciones en tres franjas horarias diurnas: mañana (10:00-13:00), siesta (14:00-17:00) y tarde (18:00-20:00).
#  * Toma de mediciones en dos franjas horarias nocturnas: tarde-noche (20:00-22:00) y noche (00:00-02:00).
#  * Toma de mediciones en diferentes dıas de la semana: fin de semana (sabado) y un dıa laboral.

# %%
import os

# initialize directory to store json files with sampled data. 
path = 'log_files/medida_2'
if not os.path.exists(path):
    os.makedirs(path)

# global port variable
SELECTED_PORT = 'COM3'

# %%
import threading
import time
import math
import serial  
import logging
import json

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'

def format_time(unix_epoch, isFileName=False):
    """format time in unix epoch to human-readable values"""
    if isFileName:
        day = time.ctime(unix_epoch)[:3]
        formatted_time = day+time.strftime(" %Y-%m-%d %Hh%Mm%Ss", time.localtime(unix_epoch))
        return formatted_time
    formatted_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(unix_epoch))
    return str(formatted_time)

#_____________________________________________________________________________________________________________________

class AZ8922:
    """class for sonometer object"""

    def __init__(self, port):
        self.port = port
        self.ser = None
        self.running = True
        self.connected = True
        self.sound_level = []
        print(Green+"AZ8922: Iniciando la clase.\n",flush=True)

    def get_sonometry(self):
        """returns mean and max value of the measurement"""
        if self.sound_level:
            sound_level_max = max(self.sound_level)
            sound_level_min = min(self.sound_level)
            sound_level_linear = [math.pow(10,x/20) for x in self.sound_level] 
            sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
            sound_level_mean = 20*math.log10(sound_level_mean) 
        else:
            sound_level_max = -1
            sound_level_min = -1
            sound_level_mean = -1
            
        # Check if the AZ8922 is off.
        # if self.connected and not self.sound_level: logging.warning('AZ8922 is off.')
        
        # Reset the arrays.
        self.sound_level = []
        
        # Round up.
        sound_level_mean = round(sound_level_mean,2)
        
        # logging.info(f'Sonometry AZ8922:{sound_level_mean}') 
        # logging.info('Sonometry AZ8922:%f' % sound_level_mean) 
        # if not self.connected: logging.warning('AZ8922 is disconnected.')
         
        return sound_level_mean, sound_level_max, sound_level_min

    def run_thread(self):
        """run thread to capture measurements from sonometer"""
        thread = threading.Thread(target=self.sonometro_thread, daemon=True)
        thread.start()

    def stop_thread(self):
        """stop sonometer thread"""
        self.running = False
        self.connected = False
        if self.ser is not None:
            self.ser.close()
            print(Red+"RS232 cerrando el puerto serie.\n",flush=True)
            

    def sonometro_thread(self):
        """reads values from serial port and updates sound level attribute"""
        while self.running:
            try:
                # If disconnected, check connection every 5 seconds.
                if not self.connected: time.sleep(5)
                self.ser = serial.Serial(self.port, 2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)
                self.connected = True
                print(Yellow+"RS232 abriendo el puerto serie.\n",flush=True)

                #Para sacar valores intermedios
                #print("Self.conected="+str(self.connected)+"\n")
                #print("self.ser.in_waiting="+str(self.ser.in_waiting)+"\n")
                #print("self.running="+str(self.running)+"\n")
                
                #while(self.connected and self.ser.in_waiting and self.running):
                while(self.connected and self.running):
                    output = self.ser.readline().decode('utf-8', 'ignore')
                    output = output.strip()
                    print(Yellow+"RS232 read data:"+str(output)+"\n",flush=True)
                    if output.startswith('N:') and output.endswith('dB'):
                        self.sound_level.append(float(output.split(':')[1].split('dB')[0]))

            except (serial.serialutil.SerialException, OSError):
                # Thread is not halted upon sensor disconnection.
                self.connected = False

# %% [markdown]
# ## Ejemplo toma de 10 medidas

# %%
# User Params.
MEASURE_PERIOD = 1  # How often (seconds) we poll for measurements.
log_file = 'log_files/log.txt'
json_file = path+'/type_1 '+format_time(time.time(), True)+'.json'

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  # Thread running condition.


#Llamada a la función y crea objeto de la clase AZ8922
port_AZ8922 = SELECTED_PORT
sound_level_meter = AZ8922(port_AZ8922)

print(Green+"Arrancamos el proceso para medir.\n")
sound_level_meter.run_thread()

# List to store measurements.
measurements = []

# Main thread.
for x in range(10):

        time.sleep(MEASURE_PERIOD)
        current_time = format_time(time.time())

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level_media, sound_level_maximo, sound_level_minimo = sound_level_meter.get_sonometry()
        print(Grey+"Valor medio medido="+ str(sound_level_media)+ " dB\n")
        print(Grey+"Valor máximo medido "+ str(sound_level_maximo)+ " dB\n")
        print(Grey+"Valor minimo medido "+ str(sound_level_minimo)+ " dB\n")
        #print(Magenta +"Medida(media, máximo)="+ str(sound_level)+ " dB\n" )
        print(Magenta +"Medida(media, máximo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+  " dB" +Cyan+"\tTime=" + current_time+"\n")
        logging.debug("Medida(media, maximo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+  " dB    Time=" + current_time+"\n")
        
        # Store the measurement in a dictionary
        measurement = {
            "time": current_time,
            "mean": sound_level_media,
            "max": sound_level_maximo,
            "min": sound_level_minimo
        }
        measurements.append(measurement)
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()

# Save measurements to a JSON file
with open(json_file, 'w') as f:
    json.dump(measurements, f, indent=4)
print(Green + f"Measurements saved to {json_file}\n")
# Out:
# AZ8922: Iniciando la clase.
#
# Arrancamos el proceso para medir.
#
# RS232 abriendo el puerto serie.
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:037.2dB
#
# Valor medio medido=38.15 dB
#
# Valor máximo medido 39.0 dB
#
# Valor minimo medido 37.2 dB
#
# Medida(media, máximo)=38.15,39.0 dB	Time=2025-03-27 01:08:42
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:037.2dB
#
# Valor medio medido=37.4 dB
#
# Valor máximo medido 37.6 dB
#
# Valor minimo medido 37.2 dB
#
# Medida(media, máximo)=37.4,37.6 dB	Time=2025-03-27 01:08:43
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:038.5dB
#
# Valor medio medido=38.47 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo)=38.47,38.6 dB	Time=2025-03-27 01:08:44
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:037.6dB
#
# Valor medio medido=37.8 dB
#
# Valor máximo medido 38.0 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo)=37.8,38.0 dB	Time=2025-03-27 01:08:45
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:038.1dB
#
# Valor medio medido=38.14 dB
#
# Valor máximo medido 38.5 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo)=38.14,38.5 dB	Time=2025-03-27 01:08:46
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:038.4dB
#
# Valor medio medido=38.3 dB
#
# Valor máximo medido 38.4 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo)=38.3,38.4 dB	Time=2025-03-27 01:08:47
#
# RS232 read data:N:037.4dB
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:037.7dB
#
# Valor medio medido=37.74 dB
#
# Valor máximo medido 38.1 dB
#
# Valor minimo medido 37.4 dB
#
# Medida(media, máximo)=37.74,38.1 dB	Time=2025-03-27 01:08:48
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:037.2dB
#
# Valor medio medido=37.84 dB
#
# Valor máximo medido 38.2 dB
#
# Valor minimo medido 37.2 dB
#
# Medida(media, máximo)=37.84,38.2 dB	Time=2025-03-27 01:08:49
#
# RS232 read data:N:037.3dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=37.81 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 37.3 dB
#
# Medida(media, máximo)=37.81,38.3 dB	Time=2025-03-27 01:08:50
#
# RS232 read data:N:037.5dB
#
# RS232 read data:N:037.9dB
#
# RS232 read data:N:037.6dB
#
# Valor medio medido=37.67 dB
#
# Valor máximo medido 37.9 dB
#
# Valor minimo medido 37.5 dB
#
# Medida(media, máximo)=37.67,37.9 dB	Time=2025-03-27 01:08:51
#
# RS232 read data:
#
# RS232 cerrando el puerto serie.
#
# Measurements saved to log_files/medida_2/type_1 Thu 2025-03-27 01h08m41s.json

# %%
import matplotlib.pyplot as plt

pic_path = 'Pics/medida_2/type_1 '+format_time(time.time(), True)

# Load the measurements from the JSON file.
with open(json_file, 'r') as f:
    measurements = json.load(f)

times = [m["time"] for m in measurements]
means = [m["mean"] for m in measurements]
maxs = [m["max"] for m in measurements]
mins = [m["min"] for m in measurements]

m_number = list(range(0,len(measurements)))

# Plot the measurements
plt.figure(figsize=(10, 6))
plt.plot(m_number, means, label="Mean", color="blue")
plt.plot(m_number, maxs, label="Max", color="red", linestyle="--")
plt.plot(m_number, mins, label="Min", color="green", linestyle="--")
plt.xlim(0, len(measurements)-1)
plt.xlabel("Samples")
plt.ylabel("Sound Level (dB)")
plt.title("Sound Level Measurements Over Time")
plt.legend()
plt.grid(True)
plt.savefig(pic_path+'.png')
plt.show()

# %%
pic_path = 'Pics/medida_2/type_1_max '+format_time(time.time(), True)

plt.plot(maxs,'b',maxs,'ro') #Más opciones de plot aqui: https://matplotlib.org/tutorials/introductory/pyplot.html
plt.title('Max Sound Level sampled')
plt.ylabel('Sound Level [dB]')
plt.xlim(0, len(measurements)-1)
plt.xlabel('Samples')
plt.grid()
plt.savefig(pic_path+'.png')
plt.show()

# %% [markdown]
# ## Ejemplo toma de medidas para 5 minutos

# %%
# User Params.
MEASURE_PERIOD = 1  # How often (seconds) we poll for measurements.
log_file = 'log_files/log.txt'
json_file = path+'/type_2 '+format_time(time.time(), True)+'.json'
MEASUREMENT_DURATION = 5 * 60  # 5 minutes


# Get the start and stop time for the measurement.
start_time = time.time()
end_time = start_time + MEASUREMENT_DURATION

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  


#Llamada a la función y crea objeto de la clase AZ8922
port_AZ8922 = SELECTED_PORT
sound_level_meter = AZ8922(port_AZ8922)

print(Green+"Arrancamos el proceso para medir.\n")
sound_level_meter.run_thread()

measurements = []

# Main thread.
while time.time() < end_time:
        # Sleep for the measurement period
        time.sleep(MEASURE_PERIOD)
        current_time = format_time(time.time())

        # Store the measurement in a dictionary
        measurement = {
            "time": current_time,
            "mean": sound_level_media,
            "max": sound_level_maximo,
            "min": sound_level_minimo
        }
        measurements.append(measurement)

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level_media, sound_level_maximo, sound_level_minimo = sound_level_meter.get_sonometry()
        
        print(Grey+"Valor medio medido="+ str(sound_level_media)+ " dB\n")
        print(Grey+"Valor máximo medido "+ str(sound_level_maximo)+ " dB\n")
        print(Grey+"Valor minimo medido "+ str(sound_level_minimo)+ " dB\n")

        print(Magenta +"Medida(media, máximo, minimo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+","+ str(sound_level_minimo)+  " dB" +Cyan+"\tTime=" + current_time+"\n")
        logging.debug("Medida(media, maximo, minimo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+","+ str(sound_level_minimo)+  " dB    Time=" + current_time+"\n")
        
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()

# Save measurements to a JSON file
with open(json_file, 'w') as f:
    json.dump(measurements, f, indent=4)
print(Green + f"Measurements saved to {json_file}\n")
# Out:
# AZ8922: Iniciando la clase.
#
# Arrancamos el proceso para medir.
#
# RS232 abriendo el puerto serie.
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:038.5dB
#
# Valor medio medido=38.16 dB
#
# Valor máximo medido 38.5 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=38.16,38.5,37.8 dB	Time=2025-03-27 01:08:53
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=38.88 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=38.88,39.4,38.3 dB	Time=2025-03-27 01:08:54
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:038.7dB
#
# Valor medio medido=37.94 dB
#
# Valor máximo medido 38.7 dB
#
# Valor minimo medido 37.1 dB
#
# Medida(media, máximo, minimo)=37.94,38.7,37.1 dB	Time=2025-03-27 01:08:55
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=39.24 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 38.9 dB
#
# Medida(media, máximo, minimo)=39.24,39.6,38.9 dB	Time=2025-03-27 01:08:56
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:038.0dB
#
# Valor medio medido=38.46 dB
#
# Valor máximo medido 38.9 dB
#
# Valor minimo medido 38.0 dB
#
# Medida(media, máximo, minimo)=38.46,38.9,38.0 dB	Time=2025-03-27 01:08:57
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=38.97 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 38.7 dB
#
# Medida(media, máximo, minimo)=38.97,39.5,38.7 dB	Time=2025-03-27 01:08:58
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=39.05 dB
#
# Valor máximo medido 39.3 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=39.05,39.3,38.8 dB	Time=2025-03-27 01:08:59
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=40.5 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 40.5 dB
#
# Medida(media, máximo, minimo)=40.5,40.5,40.5 dB	Time=2025-03-27 01:09:00
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=38.87 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=38.87,39.1,38.6 dB	Time=2025-03-27 01:09:01
#
# RS232 read data:N:045.3dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=42.58 dB
#
# Valor máximo medido 45.3 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=42.58,45.3,38.6 dB	Time=2025-03-27 01:09:02
#
# RS232 read data:N:037.3dB
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:037.7dB
#
# Valor medio medido=37.78 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 37.3 dB
#
# Medida(media, máximo, minimo)=37.78,38.3,37.3 dB	Time=2025-03-27 01:09:03
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:037.6dB
#
# Valor medio medido=37.7 dB
#
# Valor máximo medido 37.8 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo, minimo)=37.7,37.8,37.6 dB	Time=2025-03-27 01:09:04
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=38.62 dB
#
# Valor máximo medido 39.3 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=38.62,39.3,37.8 dB	Time=2025-03-27 01:09:05
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:037.4dB
#
# Valor medio medido=37.91 dB
#
# Valor máximo medido 38.4 dB
#
# Valor minimo medido 37.4 dB
#
# Medida(media, máximo, minimo)=37.91,38.4,37.4 dB	Time=2025-03-27 01:09:06
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:037.2dB
#
# Valor medio medido=37.68 dB
#
# Valor máximo medido 38.2 dB
#
# Valor minimo medido 37.2 dB
#
# Medida(media, máximo, minimo)=37.68,38.2,37.2 dB	Time=2025-03-27 01:09:07
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:036.8dB
#
# Valor medio medido=37.51 dB
#
# Valor máximo medido 38.0 dB
#
# Valor minimo medido 36.8 dB
#
# Medida(media, máximo, minimo)=37.51,38.0,36.8 dB	Time=2025-03-27 01:09:08
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:037.4dB
#
# Valor medio medido=37.76 dB
#
# Valor máximo medido 38.1 dB
#
# Valor minimo medido 37.4 dB
#
# Medida(media, máximo, minimo)=37.76,38.1,37.4 dB	Time=2025-03-27 01:09:09
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:037.2dB
#
# Valor medio medido=37.92 dB
#
# Valor máximo medido 38.7 dB
#
# Valor minimo medido 37.2 dB
#
# Medida(media, máximo, minimo)=37.92,38.7,37.2 dB	Time=2025-03-27 01:09:10
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:046.0dB
#
# Valor medio medido=42.83 dB
#
# Valor máximo medido 46.0 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=42.83,46.0,37.8 dB	Time=2025-03-27 01:09:11
#
# RS232 read data:N:037.0dB
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:039.0dB
#
# Valor medio medido=37.94 dB
#
# Valor máximo medido 39.0 dB
#
# Valor minimo medido 37.0 dB
#
# Medida(media, máximo, minimo)=37.94,39.0,37.0 dB	Time=2025-03-27 01:09:12
#
# RS232 read data:N:037.9dB
#
# RS232 read data:N:037.4dB
#
# Valor medio medido=37.65 dB
#
# Valor máximo medido 37.9 dB
#
# Valor minimo medido 37.4 dB
#
# Medida(media, máximo, minimo)=37.65,37.9,37.4 dB	Time=2025-03-27 01:09:13
#
# RS232 read data:N:037.4dB
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:037.9dB
#
# Valor medio medido=37.77 dB
#
# Valor máximo medido 38.0 dB
#
# Valor minimo medido 37.4 dB
#
# Medida(media, máximo, minimo)=37.77,38.0,37.4 dB	Time=2025-03-27 01:09:14
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=38.15 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 38.0 dB
#
# Medida(media, máximo, minimo)=38.15,38.3,38.0 dB	Time=2025-03-27 01:09:15
#
# RS232 read data:N:037.4dB
#
# RS232 read data:N:037.9dB
#
# RS232 read data:N:037.3dB
#
# Valor medio medido=37.54 dB
#
# Valor máximo medido 37.9 dB
#
# Valor minimo medido 37.3 dB
#
# Medida(media, máximo, minimo)=37.54,37.9,37.3 dB	Time=2025-03-27 01:09:16
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:038.7dB
#
# Valor medio medido=38.41 dB
#
# Valor máximo medido 38.7 dB
#
# Valor minimo medido 38.1 dB
#
# Medida(media, máximo, minimo)=38.41,38.7,38.1 dB	Time=2025-03-27 01:09:17
#
# RS232 read data:N:037.9dB
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:037.3dB
#
# Valor medio medido=37.6 dB
#
# Valor máximo medido 37.9 dB
#
# Valor minimo medido 37.3 dB
#
# Medida(media, máximo, minimo)=37.6,37.9,37.3 dB	Time=2025-03-27 01:09:18
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:039.0dB
#
# Valor medio medido=38.61 dB
#
# Valor máximo medido 39.0 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=38.61,39.0,38.2 dB	Time=2025-03-27 01:09:19
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:038.9dB
#
# Valor medio medido=38.81 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=38.81,39.2,38.3 dB	Time=2025-03-27 01:09:20
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:038.5dB
#
# Valor medio medido=38.6 dB
#
# Valor máximo medido 38.7 dB
#
# Valor minimo medido 38.5 dB
#
# Medida(media, máximo, minimo)=38.6,38.7,38.5 dB	Time=2025-03-27 01:09:21
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=38.34 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=38.34,38.6,37.8 dB	Time=2025-03-27 01:09:22
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:037.2dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=38.38 dB
#
# Valor máximo medido 39.3 dB
#
# Valor minimo medido 37.2 dB
#
# Medida(media, máximo, minimo)=38.38,39.3,37.2 dB	Time=2025-03-27 01:09:23
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:038.7dB
#
# Valor medio medido=38.95 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 38.7 dB
#
# Medida(media, máximo, minimo)=38.95,39.2,38.7 dB	Time=2025-03-27 01:09:24
#
# RS232 read data:N:037.9dB
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:037.6dB
#
# Valor medio medido=37.7 dB
#
# Valor máximo medido 37.9 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo, minimo)=37.7,37.9,37.6 dB	Time=2025-03-27 01:09:25
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=39.35 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=39.35,39.6,39.1 dB	Time=2025-03-27 01:09:26
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=38.91 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 38.4 dB
#
# Medida(media, máximo, minimo)=38.91,39.5,38.4 dB	Time=2025-03-27 01:09:27
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=38.97 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=38.97,39.6,38.3 dB	Time=2025-03-27 01:09:28
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:039.1dB
#
# Valor medio medido=39.51 dB
#
# Valor máximo medido 39.9 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=39.51,39.9,39.1 dB	Time=2025-03-27 01:09:29
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:038.1dB
#
# Valor medio medido=38.83 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 38.1 dB
#
# Medida(media, máximo, minimo)=38.83,39.5,38.1 dB	Time=2025-03-27 01:09:30
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:037.5dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=38.57 dB
#
# Valor máximo medido 39.3 dB
#
# Valor minimo medido 37.5 dB
#
# Medida(media, máximo, minimo)=38.57,39.3,37.5 dB	Time=2025-03-27 01:09:31
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=39.51 dB
#
# Valor máximo medido 39.8 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.51,39.8,39.2 dB	Time=2025-03-27 01:09:32
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:038.7dB
#
# Valor medio medido=38.67 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo, minimo)=38.67,39.6,37.6 dB	Time=2025-03-27 01:09:33
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:040.3dB
#
# Valor medio medido=39.49 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=39.49,40.3,38.6 dB	Time=2025-03-27 01:09:34
#
# RS232 read data:N:041.8dB
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:043.2dB
#
# Valor medio medido=41.88 dB
#
# Valor máximo medido 43.2 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo, minimo)=41.88,43.2,40.4 dB	Time=2025-03-27 01:09:35
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:047.1dB
#
# Valor medio medido=44.68 dB
#
# Valor máximo medido 47.1 dB
#
# Valor minimo medido 41.3 dB
#
# Medida(media, máximo, minimo)=44.68,47.1,41.3 dB	Time=2025-03-27 01:09:36
#
# RS232 read data:N:042.9dB
#
# RS232 read data:N:042.9dB
#
# Valor medio medido=42.9 dB
#
# Valor máximo medido 42.9 dB
#
# Valor minimo medido 42.9 dB
#
# Medida(media, máximo, minimo)=42.9,42.9,42.9 dB	Time=2025-03-27 01:09:37
#
# RS232 read data:N:041.7dB
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:039.1dB
#
# Valor medio medido=40.37 dB
#
# Valor máximo medido 41.7 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=40.37,41.7,39.1 dB	Time=2025-03-27 01:09:38
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=38.4 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=38.4,38.6,38.2 dB	Time=2025-03-27 01:09:39
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=38.72 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=38.72,39.5,38.2 dB	Time=2025-03-27 01:09:40
#
# RS232 read data:N:043.7dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=41.78 dB
#
# Valor máximo medido 43.7 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=41.78,43.7,39.3 dB	Time=2025-03-27 01:09:41
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:038.1dB
#
# Valor medio medido=38.88 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 38.1 dB
#
# Medida(media, máximo, minimo)=38.88,40.1,38.1 dB	Time=2025-03-27 01:09:42
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=38.6 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=38.6,38.6,38.6 dB	Time=2025-03-27 01:09:43
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=38.04 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 37.7 dB
#
# Medida(media, máximo, minimo)=38.04,38.3,37.7 dB	Time=2025-03-27 01:09:44
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:038.4dB
#
# Valor medio medido=38.6 dB
#
# Valor máximo medido 38.8 dB
#
# Valor minimo medido 38.4 dB
#
# Medida(media, máximo, minimo)=38.6,38.8,38.4 dB	Time=2025-03-27 01:09:45
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=38.43 dB
#
# Valor máximo medido 39.3 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo, minimo)=38.43,39.3,37.6 dB	Time=2025-03-27 01:09:46
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=38.65 dB
#
# Valor máximo medido 38.8 dB
#
# Valor minimo medido 38.5 dB
#
# Medida(media, máximo, minimo)=38.65,38.8,38.5 dB	Time=2025-03-27 01:09:47
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:038.0dB
#
# Valor medio medido=38.62 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 38.0 dB
#
# Medida(media, máximo, minimo)=38.62,39.4,38.0 dB	Time=2025-03-27 01:09:48
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:038.0dB
#
# Valor medio medido=38.57 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 38.0 dB
#
# Medida(media, máximo, minimo)=38.57,39.1,38.0 dB	Time=2025-03-27 01:09:49
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=37.62 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 36.8 dB
#
# Medida(media, máximo, minimo)=37.62,38.3,36.8 dB	Time=2025-03-27 01:09:50
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:037.9dB
#
# Valor medio medido=38.41 dB
#
# Valor máximo medido 38.9 dB
#
# Valor minimo medido 37.9 dB
#
# Medida(media, máximo, minimo)=38.41,38.9,37.9 dB	Time=2025-03-27 01:09:51
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=38.19 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 37.1 dB
#
# Medida(media, máximo, minimo)=38.19,39.5,37.1 dB	Time=2025-03-27 01:09:52
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:038.2dB
#
# Valor medio medido=38.25 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=38.25,38.3,38.2 dB	Time=2025-03-27 01:09:53
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:043.3dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=41.15 dB
#
# Valor máximo medido 43.3 dB
#
# Valor minimo medido 38.5 dB
#
# Medida(media, máximo, minimo)=41.15,43.3,38.5 dB	Time=2025-03-27 01:09:54
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=39.5 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=39.5,39.5,39.5 dB	Time=2025-03-27 01:09:55
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=39.5 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=39.5,39.6,39.3 dB	Time=2025-03-27 01:09:56
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=39.11 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=39.11,39.6,38.6 dB	Time=2025-03-27 01:09:57
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:040.7dB
#
# Valor medio medido=40.28 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=40.28,41.0,39.0 dB	Time=2025-03-27 01:09:58
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:041.9dB
#
# Valor medio medido=40.65 dB
#
# Valor máximo medido 41.9 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=40.65,41.9,39.2 dB	Time=2025-03-27 01:09:59
#
# RS232 read data:N:042.1dB
#
# RS232 read data:N:041.9dB
#
# Valor medio medido=42.0 dB
#
# Valor máximo medido 42.1 dB
#
# Valor minimo medido 41.9 dB
#
# Medida(media, máximo, minimo)=42.0,42.1,41.9 dB	Time=2025-03-27 01:10:00
#
# RS232 read data:N:042.2dB
#
# RS232 read data:N:042.3dB
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=41.71 dB
#
# Valor máximo medido 42.3 dB
#
# Valor minimo medido 40.5 dB
#
# Medida(media, máximo, minimo)=41.71,42.3,40.5 dB	Time=2025-03-27 01:10:01
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=39.47 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=39.47,40.1,38.8 dB	Time=2025-03-27 01:10:02
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=39.07 dB
#
# Valor máximo medido 39.3 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=39.07,39.3,38.6 dB	Time=2025-03-27 01:10:03
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:041.8dB
#
# Valor medio medido=41.27 dB
#
# Valor máximo medido 41.8 dB
#
# Valor minimo medido 40.7 dB
#
# Medida(media, máximo, minimo)=41.27,41.8,40.7 dB	Time=2025-03-27 01:10:04
#
# RS232 read data:N:041.9dB
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:041.2dB
#
# Valor medio medido=41.41 dB
#
# Valor máximo medido 41.9 dB
#
# Valor minimo medido 41.1 dB
#
# Medida(media, máximo, minimo)=41.41,41.9,41.1 dB	Time=2025-03-27 01:10:05
#
# RS232 read data:N:043.5dB
#
# RS232 read data:N:045.8dB
#
# Valor medio medido=44.73 dB
#
# Valor máximo medido 45.8 dB
#
# Valor minimo medido 43.5 dB
#
# Medida(media, máximo, minimo)=44.73,45.8,43.5 dB	Time=2025-03-27 01:10:06
#
# RS232 read data:N:045.8dB
#
# RS232 read data:N:045.3dB
#
# Valor medio medido=45.55 dB
#
# Valor máximo medido 45.8 dB
#
# Valor minimo medido 45.3 dB
#
# Medida(media, máximo, minimo)=45.55,45.8,45.3 dB	Time=2025-03-27 01:10:07
#
# RS232 read data:N:043.7dB
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:041.9dB
#
# Valor medio medido=42.36 dB
#
# Valor máximo medido 43.7 dB
#
# Valor minimo medido 41.3 dB
#
# Medida(media, máximo, minimo)=42.36,43.7,41.3 dB	Time=2025-03-27 01:10:08
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=40.34 dB
#
# Valor máximo medido 41.1 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.34,41.1,39.5 dB	Time=2025-03-27 01:10:09
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=40.11 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 39.6 dB
#
# Medida(media, máximo, minimo)=40.11,40.6,39.6 dB	Time=2025-03-27 01:10:10
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:041.5dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=40.19 dB
#
# Valor máximo medido 41.5 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=40.19,41.5,39.2 dB	Time=2025-03-27 01:10:11
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:040.9dB
#
# Valor medio medido=40.23 dB
#
# Valor máximo medido 40.9 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.23,40.9,39.5 dB	Time=2025-03-27 01:10:12
#
# RS232 read data:N:041.9dB
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:041.3dB
#
# Valor medio medido=41.44 dB
#
# Valor máximo medido 41.9 dB
#
# Valor minimo medido 41.1 dB
#
# Medida(media, máximo, minimo)=41.44,41.9,41.1 dB	Time=2025-03-27 01:10:13
#
# RS232 read data:N:040.9dB
#
# RS232 read data:N:041.8dB
#
# Valor medio medido=41.36 dB
#
# Valor máximo medido 41.8 dB
#
# Valor minimo medido 40.9 dB
#
# Medida(media, máximo, minimo)=41.36,41.8,40.9 dB	Time=2025-03-27 01:10:14
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:041.7dB
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=41.11 dB
#
# Valor máximo medido 41.7 dB
#
# Valor minimo medido 40.5 dB
#
# Medida(media, máximo, minimo)=41.11,41.7,40.5 dB	Time=2025-03-27 01:10:15
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=40.11 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=40.11,40.5,39.7 dB	Time=2025-03-27 01:10:16
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:040.6dB
#
# Valor medio medido=40.35 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=40.35,40.6,40.1 dB	Time=2025-03-27 01:10:17
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:049.4dB
#
# RS232 read data:N:040.3dB
#
# Valor medio medido=44.45 dB
#
# Valor máximo medido 49.4 dB
#
# Valor minimo medido 40.2 dB
#
# Medida(media, máximo, minimo)=44.45,49.4,40.2 dB	Time=2025-03-27 01:10:18
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:039.1dB
#
# Valor medio medido=39.1 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=39.1,39.1,39.1 dB	Time=2025-03-27 01:10:19
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:040.8dB
#
# Valor medio medido=40.06 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=40.06,40.8,39.2 dB	Time=2025-03-27 01:10:20
#
# RS232 read data:N:040.9dB
#
# RS232 read data:N:039.0dB
#
# Valor medio medido=40.0 dB
#
# Valor máximo medido 40.9 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=40.0,40.9,39.0 dB	Time=2025-03-27 01:10:21
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:040.0dB
#
# Valor medio medido=38.87 dB
#
# Valor máximo medido 40.0 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=38.87,40.0,38.2 dB	Time=2025-03-27 01:10:22
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:037.7dB
#
# Valor medio medido=38.01 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 37.7 dB
#
# Medida(media, máximo, minimo)=38.01,38.3,37.7 dB	Time=2025-03-27 01:10:23
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:043.1dB
#
# Valor medio medido=40.26 dB
#
# Valor máximo medido 43.1 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=40.26,43.1,38.2 dB	Time=2025-03-27 01:10:24
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=39.95 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=39.95,40.1,39.8 dB	Time=2025-03-27 01:10:25
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=39.43 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=39.43,40.1,38.3 dB	Time=2025-03-27 01:10:26
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:037.8dB
#
# Valor medio medido=38.21 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=38.21,38.6,37.8 dB	Time=2025-03-27 01:10:27
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:041.6dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=40.36 dB
#
# Valor máximo medido 41.6 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=40.36,41.6,39.2 dB	Time=2025-03-27 01:10:28
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:038.5dB
#
# Valor medio medido=39.45 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 38.5 dB
#
# Medida(media, máximo, minimo)=39.45,40.3,38.5 dB	Time=2025-03-27 01:10:29
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:038.2dB
#
# Valor medio medido=39.67 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=39.67,40.8,38.2 dB	Time=2025-03-27 01:10:30
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:042.4dB
#
# Valor medio medido=41.59 dB
#
# Valor máximo medido 42.4 dB
#
# Valor minimo medido 40.7 dB
#
# Medida(media, máximo, minimo)=41.59,42.4,40.7 dB	Time=2025-03-27 01:10:31
#
# RS232 read data:N:042.3dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=41.18 dB
#
# Valor máximo medido 42.3 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=41.18,42.3,39.9 dB	Time=2025-03-27 01:10:32
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:041.8dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=40.49 dB
#
# Valor máximo medido 41.8 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=40.49,41.8,38.8 dB	Time=2025-03-27 01:10:33
#
# RS232 read data:N:042.2dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=41.62 dB
#
# Valor máximo medido 42.2 dB
#
# Valor minimo medido 41.0 dB
#
# Medida(media, máximo, minimo)=41.62,42.2,41.0 dB	Time=2025-03-27 01:10:34
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=40.41 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=40.41,40.8,40.1 dB	Time=2025-03-27 01:10:35
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:041.6dB
#
# Valor medio medido=40.61 dB
#
# Valor máximo medido 41.6 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.61,41.6,39.5 dB	Time=2025-03-27 01:10:36
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:040.3dB
#
# Valor medio medido=40.55 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 40.3 dB
#
# Medida(media, máximo, minimo)=40.55,40.8,40.3 dB	Time=2025-03-27 01:10:37
#
# RS232 read data:N:041.6dB
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:042.1dB
#
# Valor medio medido=41.49 dB
#
# Valor máximo medido 42.1 dB
#
# Valor minimo medido 40.7 dB
#
# Medida(media, máximo, minimo)=41.49,42.1,40.7 dB	Time=2025-03-27 01:10:38
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:040.3dB
#
# Valor medio medido=39.72 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=39.72,40.3,39.1 dB	Time=2025-03-27 01:10:39
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=39.88 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=39.88,40.4,39.5 dB	Time=2025-03-27 01:10:40
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=40.15 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.15,40.4,39.9 dB	Time=2025-03-27 01:10:41
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:042.2dB
#
# Valor medio medido=40.98 dB
#
# Valor máximo medido 42.2 dB
#
# Valor minimo medido 40.0 dB
#
# Medida(media, máximo, minimo)=40.98,42.2,40.0 dB	Time=2025-03-27 01:10:42
#
# RS232 read data:N:042.0dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=41.01 dB
#
# Valor máximo medido 42.0 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=41.01,42.0,39.9 dB	Time=2025-03-27 01:10:43
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:040.3dB
#
# Valor medio medido=40.81 dB
#
# Valor máximo medido 41.3 dB
#
# Valor minimo medido 40.3 dB
#
# Medida(media, máximo, minimo)=40.81,41.3,40.3 dB	Time=2025-03-27 01:10:44
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:040.9dB
#
# RS232 read data:N:042.2dB
#
# Valor medio medido=41.45 dB
#
# Valor máximo medido 42.2 dB
#
# Valor minimo medido 40.9 dB
#
# Medida(media, máximo, minimo)=41.45,42.2,40.9 dB	Time=2025-03-27 01:10:45
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:044.9dB
#
# Valor medio medido=42.98 dB
#
# Valor máximo medido 44.9 dB
#
# Valor minimo medido 40.5 dB
#
# Medida(media, máximo, minimo)=42.98,44.9,40.5 dB	Time=2025-03-27 01:10:46
#
# RS232 read data:N:042.7dB
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=41.15 dB
#
# Valor máximo medido 42.7 dB
#
# Valor minimo medido 40.0 dB
#
# Medida(media, máximo, minimo)=41.15,42.7,40.0 dB	Time=2025-03-27 01:10:47
#
# RS232 read data:N:041.8dB
#
# RS232 read data:N:041.7dB
#
# Valor medio medido=41.75 dB
#
# Valor máximo medido 41.8 dB
#
# Valor minimo medido 41.7 dB
#
# Medida(media, máximo, minimo)=41.75,41.8,41.7 dB	Time=2025-03-27 01:10:48
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=40.6 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo, minimo)=40.6,40.8,40.4 dB	Time=2025-03-27 01:10:49
#
# RS232 read data:N:041.8dB
#
# RS232 read data:N:041.5dB
#
# RS232 read data:N:042.0dB
#
# Valor medio medido=41.77 dB
#
# Valor máximo medido 42.0 dB
#
# Valor minimo medido 41.5 dB
#
# Medida(media, máximo, minimo)=41.77,42.0,41.5 dB	Time=2025-03-27 01:10:50
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:040.9dB
#
# Valor medio medido=40.85 dB
#
# Valor máximo medido 40.9 dB
#
# Valor minimo medido 40.8 dB
#
# Medida(media, máximo, minimo)=40.85,40.9,40.8 dB	Time=2025-03-27 01:10:51
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=40.52 dB
#
# Valor máximo medido 41.2 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.52,41.2,39.9 dB	Time=2025-03-27 01:10:52
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:039.1dB
#
# Valor medio medido=39.72 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=39.72,40.3,39.1 dB	Time=2025-03-27 01:10:53
#
# RS232 read data:N:041.5dB
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=40.34 dB
#
# Valor máximo medido 41.5 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.34,41.5,39.5 dB	Time=2025-03-27 01:10:54
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=39.96 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=39.96,40.4,39.5 dB	Time=2025-03-27 01:10:55
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=40.07 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=40.07,40.4,39.7 dB	Time=2025-03-27 01:10:56
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=40.25 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 40.0 dB
#
# Medida(media, máximo, minimo)=40.25,40.5,40.0 dB	Time=2025-03-27 01:10:57
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:040.0dB
#
# Valor medio medido=39.95 dB
#
# Valor máximo medido 40.0 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=39.95,40.0,39.9 dB	Time=2025-03-27 01:10:58
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=40.03 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.03,40.1,39.9 dB	Time=2025-03-27 01:10:59
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=39.25 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=39.25,39.5,39.0 dB	Time=2025-03-27 01:11:00
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:041.4dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=40.62 dB
#
# Valor máximo medido 41.4 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=40.62,41.4,40.1 dB	Time=2025-03-27 01:11:01
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=40.28 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.28,41.0,39.5 dB	Time=2025-03-27 01:11:02
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:042.3dB
#
# Valor medio medido=41.15 dB
#
# Valor máximo medido 42.3 dB
#
# Valor minimo medido 40.0 dB
#
# Medida(media, máximo, minimo)=41.15,42.3,40.0 dB	Time=2025-03-27 01:11:03
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=39.65 dB
#
# Valor máximo medido 39.8 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=39.65,39.8,39.5 dB	Time=2025-03-27 01:11:04
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=39.17 dB
#
# Valor máximo medido 39.8 dB
#
# Valor minimo medido 38.5 dB
#
# Medida(media, máximo, minimo)=39.17,39.8,38.5 dB	Time=2025-03-27 01:11:05
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:040.0dB
#
# Valor medio medido=39.7 dB
#
# Valor máximo medido 40.0 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=39.7,40.0,39.3 dB	Time=2025-03-27 01:11:06
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=39.85 dB
#
# Valor máximo medido 39.9 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=39.85,39.9,39.8 dB	Time=2025-03-27 01:11:07
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:039.1dB
#
# Valor medio medido=39.44 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=39.44,39.6,39.1 dB	Time=2025-03-27 01:11:08
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:042.2dB
#
# Valor medio medido=41.67 dB
#
# Valor máximo medido 42.2 dB
#
# Valor minimo medido 41.1 dB
#
# Medida(media, máximo, minimo)=41.67,42.2,41.1 dB	Time=2025-03-27 01:11:09
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=40.1 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.1,40.3,39.9 dB	Time=2025-03-27 01:11:10
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=39.95 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=39.95,40.2,39.7 dB	Time=2025-03-27 01:11:11
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:040.9dB
#
# Valor medio medido=40.02 dB
#
# Valor máximo medido 40.9 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=40.02,40.9,39.4 dB	Time=2025-03-27 01:11:12
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=39.95 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=39.95,40.1,39.8 dB	Time=2025-03-27 01:11:13
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=40.34 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=40.34,40.7,39.7 dB	Time=2025-03-27 01:11:14
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=40.06 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=40.06,40.4,39.7 dB	Time=2025-03-27 01:11:15
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=40.16 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=40.16,40.5,39.8 dB	Time=2025-03-27 01:11:16
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:040.9dB
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=40.87 dB
#
# Valor máximo medido 41.2 dB
#
# Valor minimo medido 40.5 dB
#
# Medida(media, máximo, minimo)=40.87,41.2,40.5 dB	Time=2025-03-27 01:11:17
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=39.61 dB
#
# Valor máximo medido 39.9 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=39.61,39.9,39.3 dB	Time=2025-03-27 01:11:18
#
# RS232 read data:N:041.7dB
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=40.55 dB
#
# Valor máximo medido 41.7 dB
#
# Valor minimo medido 39.6 dB
#
# Medida(media, máximo, minimo)=40.55,41.7,39.6 dB	Time=2025-03-27 01:11:19
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=40.15 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=40.15,40.2,40.1 dB	Time=2025-03-27 01:11:20
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:037.5dB
#
# Valor medio medido=38.68 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 37.5 dB
#
# Medida(media, máximo, minimo)=38.68,40.2,37.5 dB	Time=2025-03-27 01:11:21
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=39.26 dB
#
# Valor máximo medido 39.7 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=39.26,39.7,38.8 dB	Time=2025-03-27 01:11:22
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:037.5dB
#
# Valor medio medido=37.97 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 37.5 dB
#
# Medida(media, máximo, minimo)=37.97,38.3,37.5 dB	Time=2025-03-27 01:11:23
#
# RS232 read data:N:037.3dB
#
# RS232 read data:N:038.0dB
#
# Valor medio medido=37.66 dB
#
# Valor máximo medido 38.0 dB
#
# Valor minimo medido 37.3 dB
#
# Medida(media, máximo, minimo)=37.66,38.0,37.3 dB	Time=2025-03-27 01:11:24
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:037.0dB
#
# RS232 read data:N:037.9dB
#
# Valor medio medido=37.58 dB
#
# Valor máximo medido 37.9 dB
#
# Valor minimo medido 37.0 dB
#
# Medida(media, máximo, minimo)=37.58,37.9,37.0 dB	Time=2025-03-27 01:11:25
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:037.6dB
#
# Valor medio medido=38.01 dB
#
# Valor máximo medido 38.4 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo, minimo)=38.01,38.4,37.6 dB	Time=2025-03-27 01:11:26
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=38.98 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=38.98,39.5,38.6 dB	Time=2025-03-27 01:11:27
#
# RS232 read data:N:037.5dB
#
# RS232 read data:N:038.1dB
#
# Valor medio medido=37.81 dB
#
# Valor máximo medido 38.1 dB
#
# Valor minimo medido 37.5 dB
#
# Medida(media, máximo, minimo)=37.81,38.1,37.5 dB	Time=2025-03-27 01:11:28
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:038.0dB
#
# Valor medio medido=38.2 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 38.0 dB
#
# Medida(media, máximo, minimo)=38.2,38.6,38.0 dB	Time=2025-03-27 01:11:29
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:037.3dB
#
# Valor medio medido=37.37 dB
#
# Valor máximo medido 37.7 dB
#
# Valor minimo medido 37.1 dB
#
# Medida(media, máximo, minimo)=37.37,37.7,37.1 dB	Time=2025-03-27 01:11:30
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:038.4dB
#
# Valor medio medido=38.25 dB
#
# Valor máximo medido 38.4 dB
#
# Valor minimo medido 38.1 dB
#
# Medida(media, máximo, minimo)=38.25,38.4,38.1 dB	Time=2025-03-27 01:11:31
#
# RS232 read data:N:037.4dB
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=39.33 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 37.4 dB
#
# Medida(media, máximo, minimo)=39.33,40.2,37.4 dB	Time=2025-03-27 01:11:32
#
# RS232 read data:N:044.1dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=42.25 dB
#
# Valor máximo medido 44.1 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=42.25,44.1,39.9 dB	Time=2025-03-27 01:11:33
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:038.9dB
#
# Valor medio medido=39.63 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 38.9 dB
#
# Medida(media, máximo, minimo)=39.63,40.3,38.9 dB	Time=2025-03-27 01:11:34
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:043.3dB
#
# Valor medio medido=41.07 dB
#
# Valor máximo medido 43.3 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=41.07,43.3,39.5 dB	Time=2025-03-27 01:11:35
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=39.81 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=39.81,40.1,39.5 dB	Time=2025-03-27 01:11:36
#
# RS232 read data:N:043.9dB
#
# RS232 read data:N:042.8dB
#
# RS232 read data:N:040.3dB
#
# Valor medio medido=42.46 dB
#
# Valor máximo medido 43.9 dB
#
# Valor minimo medido 40.3 dB
#
# Medida(media, máximo, minimo)=42.46,43.9,40.3 dB	Time=2025-03-27 01:11:37
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:038.9dB
#
# Valor medio medido=40.07 dB
#
# Valor máximo medido 41.1 dB
#
# Valor minimo medido 38.9 dB
#
# Medida(media, máximo, minimo)=40.07,41.1,38.9 dB	Time=2025-03-27 01:11:38
#
# RS232 read data:N:043.1dB
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:041.4dB
#
# Valor medio medido=41.97 dB
#
# Valor máximo medido 43.1 dB
#
# Valor minimo medido 41.3 dB
#
# Medida(media, máximo, minimo)=41.97,43.1,41.3 dB	Time=2025-03-27 01:11:39
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=40.15 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.15,40.4,39.9 dB	Time=2025-03-27 01:11:40
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.3 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.3,39.4,39.2 dB	Time=2025-03-27 01:11:41
#
# RS232 read data:N:042.8dB
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=40.93 dB
#
# Valor máximo medido 42.8 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=40.93,42.8,39.2 dB	Time=2025-03-27 01:11:42
#
# RS232 read data:N:042.2dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=41.08 dB
#
# Valor máximo medido 42.2 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=41.08,42.2,39.8 dB	Time=2025-03-27 01:11:43
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=39.24 dB
#
# Valor máximo medido 39.7 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=39.24,39.7,38.8 dB	Time=2025-03-27 01:11:44
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:040.8dB
#
# Valor medio medido=40.51 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 40.2 dB
#
# Medida(media, máximo, minimo)=40.51,40.8,40.2 dB	Time=2025-03-27 01:11:45
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=39.15 dB
#
# Valor máximo medido 39.8 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=39.15,39.8,38.6 dB	Time=2025-03-27 01:11:46
#
# RS232 read data:N:043.2dB
#
# RS232 read data:N:039.1dB
#
# Valor medio medido=41.39 dB
#
# Valor máximo medido 43.2 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=41.39,43.2,39.1 dB	Time=2025-03-27 01:11:47
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:036.6dB
#
# Valor medio medido=37.96 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 36.6 dB
#
# Medida(media, máximo, minimo)=37.96,39.1,36.6 dB	Time=2025-03-27 01:11:48
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=38.4 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=38.4,38.6,38.2 dB	Time=2025-03-27 01:11:49
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:039.0dB
#
# Valor medio medido=38.82 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 38.0 dB
#
# Medida(media, máximo, minimo)=38.82,39.4,38.0 dB	Time=2025-03-27 01:11:50
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=38.75 dB
#
# Valor máximo medido 38.8 dB
#
# Valor minimo medido 38.7 dB
#
# Medida(media, máximo, minimo)=38.75,38.8,38.7 dB	Time=2025-03-27 01:11:51
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=39.0 dB
#
# Valor máximo medido 39.3 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=39.0,39.3,38.8 dB	Time=2025-03-27 01:11:52
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=39.76 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=39.76,40.1,39.4 dB	Time=2025-03-27 01:11:53
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:043.5dB
#
# Valor medio medido=40.83 dB
#
# Valor máximo medido 43.5 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=40.83,43.5,38.8 dB	Time=2025-03-27 01:11:54
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=39.71 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=39.71,40.1,39.3 dB	Time=2025-03-27 01:11:55
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=39.56 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=39.56,40.7,38.2 dB	Time=2025-03-27 01:11:56
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=40.03 dB
#
# Valor máximo medido 41.1 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=40.03,41.1,38.8 dB	Time=2025-03-27 01:11:57
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:037.8dB
#
# Valor medio medido=38.64 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=38.64,39.4,37.8 dB	Time=2025-03-27 01:11:58
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:041.5dB
#
# Valor medio medido=40.28 dB
#
# Valor máximo medido 41.5 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=40.28,41.5,39.3 dB	Time=2025-03-27 01:11:59
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=39.17 dB
#
# Valor máximo medido 39.7 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=39.17,39.7,38.6 dB	Time=2025-03-27 01:12:00
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.04 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 38.7 dB
#
# Medida(media, máximo, minimo)=39.04,39.4,38.7 dB	Time=2025-03-27 01:12:01
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:039.1dB
#
# Valor medio medido=39.72 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=39.72,40.3,39.1 dB	Time=2025-03-27 01:12:02
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=39.1 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 38.9 dB
#
# Medida(media, máximo, minimo)=39.1,39.2,38.9 dB	Time=2025-03-27 01:12:03
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=39.82 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.82,40.4,39.2 dB	Time=2025-03-27 01:12:04
#
# RS232 read data:N:043.5dB
#
# RS232 read data:N:042.1dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=42.09 dB
#
# Valor máximo medido 43.5 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo, minimo)=42.09,43.5,40.4 dB	Time=2025-03-27 01:12:05
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=39.4 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.4,39.6,39.2 dB	Time=2025-03-27 01:12:06
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=39.94 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=39.94,40.2,39.5 dB	Time=2025-03-27 01:12:07
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:039.0dB
#
# Valor medio medido=39.05 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=39.05,39.1,39.0 dB	Time=2025-03-27 01:12:08
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:039.0dB
#
# Valor medio medido=38.92 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 38.1 dB
#
# Medida(media, máximo, minimo)=38.92,39.6,38.1 dB	Time=2025-03-27 01:12:09
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:037.8dB
#
# Valor medio medido=38.53 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=38.53,39.2,37.8 dB	Time=2025-03-27 01:12:10
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=38.87 dB
#
# Valor máximo medido 38.9 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=38.87,38.9,38.8 dB	Time=2025-03-27 01:12:11
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:037.3dB
#
# Valor medio medido=37.92 dB
#
# Valor máximo medido 38.5 dB
#
# Valor minimo medido 37.3 dB
#
# Medida(media, máximo, minimo)=37.92,38.5,37.3 dB	Time=2025-03-27 01:12:12
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:038.2dB
#
# Valor medio medido=38.57 dB
#
# Valor máximo medido 38.9 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=38.57,38.9,38.2 dB	Time=2025-03-27 01:12:13
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=38.8 dB
#
# Valor máximo medido 38.8 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=38.8,38.8,38.8 dB	Time=2025-03-27 01:12:14
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:039.1dB
#
# Valor medio medido=38.42 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo, minimo)=38.42,39.1,37.6 dB	Time=2025-03-27 01:12:15
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:038.2dB
#
# Valor medio medido=38.35 dB
#
# Valor máximo medido 38.5 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=38.35,38.5,38.2 dB	Time=2025-03-27 01:12:16
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:037.8dB
#
# Valor medio medido=38.0 dB
#
# Valor máximo medido 38.4 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=38.0,38.4,37.8 dB	Time=2025-03-27 01:12:17
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:039.0dB
#
# Valor medio medido=38.71 dB
#
# Valor máximo medido 39.0 dB
#
# Valor minimo medido 38.4 dB
#
# Medida(media, máximo, minimo)=38.71,39.0,38.4 dB	Time=2025-03-27 01:12:18
#
# RS232 read data:N:037.3dB
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=38.47 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 37.3 dB
#
# Medida(media, máximo, minimo)=38.47,39.2,37.3 dB	Time=2025-03-27 01:12:19
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:038.1dB
#
# Valor medio medido=38.15 dB
#
# Valor máximo medido 38.2 dB
#
# Valor minimo medido 38.1 dB
#
# Medida(media, máximo, minimo)=38.15,38.2,38.1 dB	Time=2025-03-27 01:12:20
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:038.0dB
#
# Valor medio medido=38.44 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo, minimo)=38.44,39.6,37.6 dB	Time=2025-03-27 01:12:21
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=39.1 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 39.0 dB
#
# ...
#
# Medida(media, máximo, minimo)=38.99,40.2,37.7 dB	Time=2025-03-27 01:12:43
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:038.4dB
#
# Valor medio medido=38.97 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 38.4 dB
#
# Medida(media, máximo, minimo)=38.97,39.5,38.4 dB	Time=2025-03-27 01:12:44
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=38.81 dB
#
# Valor máximo medido 39.8 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=38.81,39.8,37.8 dB	Time=2025-03-27 01:12:45
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:038.9dB
#
# Valor medio medido=38.85 dB
#
# Valor máximo medido 38.9 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=38.85,38.9,38.8 dB	Time=2025-03-27 01:12:46
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=39.31 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 38.7 dB
#
# Medida(media, máximo, minimo)=39.31,39.6,38.7 dB	Time=2025-03-27 01:12:47
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=40.05 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.05,40.2,39.9 dB	Time=2025-03-27 01:12:48
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=39.64 dB
#
# Valor máximo medido 40.0 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.64,40.0,39.2 dB	Time=2025-03-27 01:12:49
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:040.0dB
#
# Valor medio medido=39.66 dB
#
# Valor máximo medido 40.0 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=39.66,40.0,39.3 dB	Time=2025-03-27 01:12:50
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:039.1dB
#
# Valor medio medido=39.66 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=39.66,40.5,39.1 dB	Time=2025-03-27 01:12:51
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.3 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.3,39.4,39.2 dB	Time=2025-03-27 01:12:52
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=40.14 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=40.14,40.4,39.8 dB	Time=2025-03-27 01:12:53
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=39.45 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=39.45,39.6,39.3 dB	Time=2025-03-27 01:12:54
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=39.21 dB
#
# Valor máximo medido 39.9 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=39.21,39.9,38.8 dB	Time=2025-03-27 01:12:55
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:040.0dB
#
# Valor medio medido=39.95 dB
#
# Valor máximo medido 40.0 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=39.95,40.0,39.9 dB	Time=2025-03-27 01:12:56
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.4 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 38.4 dB
#
# Medida(media, máximo, minimo)=39.4,40.3,38.4 dB	Time=2025-03-27 01:12:57
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:040.3dB
#
# Valor medio medido=40.45 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 40.3 dB
#
# Medida(media, máximo, minimo)=40.45,40.6,40.3 dB	Time=2025-03-27 01:12:58
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=39.57 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 38.9 dB
#
# Medida(media, máximo, minimo)=39.57,40.2,38.9 dB	Time=2025-03-27 01:12:59
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=39.97 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 39.6 dB
#
# Medida(media, máximo, minimo)=39.97,40.3,39.6 dB	Time=2025-03-27 01:13:00
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.11 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=39.11,39.4,38.8 dB	Time=2025-03-27 01:13:01
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:044.3dB
#
# Valor medio medido=41.58 dB
#
# Valor máximo medido 44.3 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=41.58,44.3,39.4 dB	Time=2025-03-27 01:13:02
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=39.8 dB
#
# Valor máximo medido 39.9 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=39.8,39.9,39.7 dB	Time=2025-03-27 01:13:03
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=40.57 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo, minimo)=40.57,40.8,40.4 dB	Time=2025-03-27 01:13:04
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=39.45 dB
#
# Valor máximo medido 39.7 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.45,39.7,39.2 dB	Time=2025-03-27 01:13:05
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=40.06 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=40.06,41.0,39.4 dB	Time=2025-03-27 01:13:06
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:040.7dB
#
# Valor medio medido=40.36 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 40.0 dB
#
# Medida(media, máximo, minimo)=40.36,40.7,40.0 dB	Time=2025-03-27 01:13:07
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=40.45 dB
# RS232 read data:N:038.6dB
#
#
# Valor máximo medido 41.3 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.45,41.3,39.5 dB	Time=2025-03-27 01:13:08
#
# RS232 read data:N:040.9dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=39.78 dB
#
# Valor máximo medido 40.9 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=39.78,40.9,38.6 dB	Time=2025-03-27 01:13:09
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:038.5dB
#
# Valor medio medido=38.5 dB
#
# Valor máximo medido 38.5 dB
#
# Valor minimo medido 38.5 dB
#
# Medida(media, máximo, minimo)=38.5,38.5,38.5 dB	Time=2025-03-27 01:13:10
#
# RS232 read data:N:042.5dB
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:037.8dB
#
# Valor medio medido=39.66 dB
#
# Valor máximo medido 42.5 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=39.66,42.5,37.8 dB	Time=2025-03-27 01:13:11
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=38.45 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=38.45,38.6,38.3 dB	Time=2025-03-27 01:13:12
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:039.0dB
#
# Valor medio medido=39.57 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=39.57,40.6,39.0 dB	Time=2025-03-27 01:13:13
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=39.68 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 38.9 dB
#
# Medida(media, máximo, minimo)=39.68,40.4,38.9 dB	Time=2025-03-27 01:13:14
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:037.9dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=39.3 dB
#
# Valor máximo medido 41.3 dB
#
# Valor minimo medido 37.9 dB
#
# Medida(media, máximo, minimo)=39.3,41.3,37.9 dB	Time=2025-03-27 01:13:15
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.15 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 38.9 dB
#
# Medida(media, máximo, minimo)=39.15,39.4,38.9 dB	Time=2025-03-27 01:13:16
#
# RS232 read data:N:042.0dB
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=40.36 dB
#
# Valor máximo medido 42.0 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=40.36,42.0,39.3 dB	Time=2025-03-27 01:13:17
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=40.67 dB
#
# Valor máximo medido 41.2 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=40.67,41.2,40.1 dB	Time=2025-03-27 01:13:18
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:038.7dB
#
# Valor medio medido=38.94 dB
#
# Valor máximo medido 39.3 dB
#
# Valor minimo medido 38.7 dB
#
# Medida(media, máximo, minimo)=38.94,39.3,38.7 dB	Time=2025-03-27 01:13:19
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:041.5dB
#
# Valor medio medido=40.01 dB
#
# Valor máximo medido 41.5 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=40.01,41.5,38.2 dB	Time=2025-03-27 01:13:20
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=39.1 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 38.7 dB
#
# Medida(media, máximo, minimo)=39.1,39.4,38.7 dB	Time=2025-03-27 01:13:21
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=39.6 dB
#
# Valor máximo medido 39.7 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=39.6,39.7,39.5 dB	Time=2025-03-27 01:13:22
#
# RS232 read data:N:037.5dB
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:038.9dB
#
# Valor medio medido=38.32 dB
#
# Valor máximo medido 38.9 dB
#
# Valor minimo medido 37.5 dB
#
# Medida(media, máximo, minimo)=38.32,38.9,37.5 dB	Time=2025-03-27 01:13:23
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=38.76 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=38.76,39.2,38.3 dB	Time=2025-03-27 01:13:24
#
# RS232 read data:N:042.5dB
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=39.99 dB
#
# Valor máximo medido 42.5 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=39.99,42.5,38.3 dB	Time=2025-03-27 01:13:25
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:039.1dB
#
# Valor medio medido=38.95 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=38.95,39.1,38.8 dB	Time=2025-03-27 01:13:26
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=38.88 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 38.4 dB
#
# Medida(media, máximo, minimo)=38.88,39.6,38.4 dB	Time=2025-03-27 01:13:27
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=39.25 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=39.25,40.1,38.3 dB	Time=2025-03-27 01:13:28
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=38.77 dB
#
# Valor máximo medido 39.8 dB
#
# Valor minimo medido 38.1 dB
#
# Medida(media, máximo, minimo)=38.77,39.8,38.1 dB	Time=2025-03-27 01:13:29
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:038.5dB
#
# Valor medio medido=38.65 dB
#
# Valor máximo medido 38.8 dB
#
# Valor minimo medido 38.5 dB
#
# Medida(media, máximo, minimo)=38.65,38.8,38.5 dB	Time=2025-03-27 01:13:30
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=39.26 dB
#
# Valor máximo medido 39.9 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=39.26,39.9,38.3 dB	Time=2025-03-27 01:13:31
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:037.8dB
#
# Valor medio medido=38.53 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=38.53,39.2,37.8 dB	Time=2025-03-27 01:13:32
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=38.33 dB
#
# Valor máximo medido 38.4 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=38.33,38.4,38.3 dB	Time=2025-03-27 01:13:33
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:037.4dB
#
# Valor medio medido=37.97 dB
#
# Valor máximo medido 38.5 dB
#
# Valor minimo medido 37.4 dB
#
# Medida(media, máximo, minimo)=37.97,38.5,37.4 dB	Time=2025-03-27 01:13:34
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:037.7dB
#
# Valor medio medido=38.66 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 37.7 dB
#
# Medida(media, máximo, minimo)=38.66,39.2,37.7 dB	Time=2025-03-27 01:13:35
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:039.1dB
#
# Valor medio medido=38.95 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=38.95,39.1,38.8 dB	Time=2025-03-27 01:13:36
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=38.35 dB
#
# Valor máximo medido 38.8 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo, minimo)=38.35,38.8,37.6 dB	Time=2025-03-27 01:13:37
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:038.4dB
#
# Valor medio medido=38.25 dB
#
# Valor máximo medido 38.4 dB
#
# Valor minimo medido 38.1 dB
#
# Medida(media, máximo, minimo)=38.25,38.4,38.1 dB	Time=2025-03-27 01:13:38
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:037.8dB
#
# Valor medio medido=38.22 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 37.7 dB
#
# Medida(media, máximo, minimo)=38.22,39.1,37.7 dB	Time=2025-03-27 01:13:39
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:038.4dB
#
# Valor medio medido=38.76 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 38.4 dB
#
# Medida(media, máximo, minimo)=38.76,39.1,38.4 dB	Time=2025-03-27 01:13:40
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=39.49 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 38.4 dB
#
# Medida(media, máximo, minimo)=39.49,40.7,38.4 dB	Time=2025-03-27 01:13:41
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:037.7dB
#
# Valor medio medido=38.11 dB
#
# Valor máximo medido 38.5 dB
#
# Valor minimo medido 37.7 dB
#
# Medida(media, máximo, minimo)=38.11,38.5,37.7 dB	Time=2025-03-27 01:13:42
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:037.2dB
#
# Valor medio medido=38.05 dB
#
# Valor máximo medido 38.5 dB
#
# Valor minimo medido 37.2 dB
#
# Medida(media, máximo, minimo)=38.05,38.5,37.2 dB	Time=2025-03-27 01:13:43
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:038.4dB
#
# Valor medio medido=38.06 dB
#
# Valor máximo medido 38.4 dB
#
# Valor minimo medido 37.7 dB
#
# Medida(media, máximo, minimo)=38.06,38.4,37.7 dB	Time=2025-03-27 01:13:44
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=38.33 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo, minimo)=38.33,39.2,37.6 dB	Time=2025-03-27 01:13:45
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:038.0dB
#
# Valor medio medido=38.46 dB
#
# Valor máximo medido 38.9 dB
#
# Valor minimo medido 38.0 dB
#
# Medida(media, máximo, minimo)=38.46,38.9,38.0 dB	Time=2025-03-27 01:13:46
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=38.44 dB
#
# Valor máximo medido 38.8 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=38.44,38.8,37.8 dB	Time=2025-03-27 01:13:47
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=39.25 dB
#
# Valor máximo medido 39.3 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.25,39.3,39.2 dB	Time=2025-03-27 01:13:48
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=38.54 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=38.54,39.1,38.2 dB	Time=2025-03-27 01:13:49
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=39.85 dB
#
# Valor máximo medido 40.0 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=39.85,40.0,39.7 dB	Time=2025-03-27 01:13:50
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:038.7dB
#
# Valor medio medido=38.18 dB
#
# Valor máximo medido 38.7 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=38.18,38.7,37.8 dB	Time=2025-03-27 01:13:51
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:038.5dB
#
# Valor medio medido=38.5 dB
#
# Valor máximo medido 38.5 dB
#
# Valor minimo medido 38.5 dB
#
# Medida(media, máximo, minimo)=38.5,38.5,38.5 dB	Time=2025-03-27 01:13:52
#
# RS232 cerrando el puerto serie.
#
# RS232 read data:
#
# Measurements saved to log_files/medida_2/type_2 Thu 2025-03-27 01h08m52s.json

# %%
import matplotlib.pyplot as plt

pic_path = 'Pics/medida_2/type_2 '+format_time(time.time(), True)

# Load the measurements from the JSON file.
with open(json_file, 'r') as f:
    measurements = json.load(f)

times = [m["time"] for m in measurements]
means = [m["mean"] for m in measurements]
maxs = [m["max"] for m in measurements]
mins = [m["min"] for m in measurements]

m_number = list(range(0,len(measurements)))

# Plot the measurements
plt.figure(figsize=(10, 6))
plt.plot(m_number, means, label="Mean", color="blue")
plt.plot(m_number, maxs, label="Max", color="red", linestyle="--")
plt.plot(m_number, mins, label="Min", color="green", linestyle="--")
plt.xlim(0, len(measurements)-1)
plt.ylim(30, 60)
plt.xlabel("Samples")
plt.ylabel("Sound Level (dB)")
plt.title("Sound Level Measurements Over Time")
plt.legend()
plt.grid(True)
plt.savefig(pic_path+'.png')
plt.show()

# %% [markdown]
# ## Ejemplo de lectura directa del Serial y almacenamiento en un vector.

# %%
import serial
import math

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'


# Sound level meter.
port_AZ8922 = SELECTED_PORT
ser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port


# Reset the arrays.
sound_level = []

#while(ser.connected):
for x in range(10):
    output = ser.readline().decode('utf-8', 'ignore')
    output = output.strip()
    #print("RS232 read data:"+str(output)+"\n")
    if output.startswith('N:') and output.endswith('dB'):
        salida_texto=float(output.split(':')[1].split('dB')[0])
        sound_level.append(salida_texto) # Para concatenar los valores y formar un Vector/Array
        print("RS232 db="+str(salida_texto)+"\n")     
    
ser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el 
#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia
#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.


# Round up.
#sound_level_mean = round(sound_level_mean,2)
#print("Sound Level(Media)="+str(sound_level_mean)+"\n") 

#Calculamos el máximo en dB
sound_level_max = max(sound_level) #Esto es el máximo de un vector
print(Green + "Sound Level(Max)="+str(sound_level_max)+" db\n") 

#Calculamos el mínomo en dB
sound_level_min = min(sound_level)
print(Magenta+"Sound Level(Min)="+str(sound_level_min)+" db\n") 

#Calculamos la suma de los valores sin decibelios
sound_level_linear = [math.pow(10,x/20) for x in sound_level] 
print(Blue +"Sound Level(linear)="+str(sound_level_linear)+"\n") 

#Pasamos la suma de lo medido en dB
sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
sound_level_mean = 20*math.log10(sound_level_mean)
print(Red + "Sound Level(Mean)="+str(sound_level_mean)+" db\n")
# Out:
# RS232 db=38.8
#
# RS232 db=38.3
#
# RS232 db=38.9
#
# RS232 db=38.6
#
# RS232 db=37.4
#
# RS232 db=38.0
#
# RS232 db=39.5
#
# RS232 db=37.4
#
# RS232 db=37.9
#
# RS232 db=38.0
#
# Sound Level(Max)=39.5 db
#
# Sound Level(Min)=37.4 db
#
# Sound Level(linear)=[87.09635899560806, 82.22426499470708, 88.10488730080138, 85.11380382023768, 74.13102413009173, 79.43282347242814, 94.40608762859236, 74.13102413009173, 78.52356346100719, 79.43282347242814]
#
# Sound Level(Mean)=38.30373885094922 db
