# %% [markdown]
# # Medida 2
# ## Piso con ventana abierta
#
#  **Ubicacion**: Piso residencial (interior) con ventana abierta.
#
#  **Metodologia**:
#  * Medicion de los niveles de presion sonora en el interior del piso, con el fin de cuantificar la intrusion de ruido exterior (trafico, obras urbanas, vecindario etc.).
#  * Toma de mediciones en tres franjas horarias diurnas: mañana (10:00-13:00), siesta (14:00-17:00) y tarde (18:00-20:00).
#  * Toma de mediciones en dos franjas horarias nocturnas: tarde-noche (20:00-22:00) y noche (00:00-02:00).
#  * Toma de mediciones en diferentes dıas de la semana: fin de semana (sabado) y un dıa laboral.

# %%
import os

# initialize directory to store json files with sampled data. 
path = 'log_files/medida_2'
if not os.path.exists(path):
    os.makedirs(path)

# global port variable
SELECTED_PORT = 'COM3'

# %%
import threading
import time
import math
import serial  
import logging
import json

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'

def format_time(unix_epoch, isFileName=False):
    """format time in unix epoch to human-readable values"""
    if isFileName:
        day = time.ctime(unix_epoch)[:3]
        formatted_time = day+time.strftime(" %Y-%m-%d %Hh%Mm%Ss", time.localtime(unix_epoch))
        return formatted_time
    formatted_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(unix_epoch))
    return str(formatted_time)

#_____________________________________________________________________________________________________________________

class AZ8922:
    """class for sonometer object"""

    def __init__(self, port):
        self.port = port
        self.ser = None
        self.running = True
        self.connected = True
        self.sound_level = []
        print(Green+"AZ8922: Iniciando la clase.\n",flush=True)

    def get_sonometry(self):
        """returns mean and max value of the measurement"""
        if self.sound_level:
            sound_level_max = max(self.sound_level)
            sound_level_min = min(self.sound_level)
            sound_level_linear = [math.pow(10,x/20) for x in self.sound_level] 
            sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
            sound_level_mean = 20*math.log10(sound_level_mean) 
        else:
            sound_level_max = -1
            sound_level_min = -1
            sound_level_mean = -1
            
        # Check if the AZ8922 is off.
        # if self.connected and not self.sound_level: logging.warning('AZ8922 is off.')
        
        # Reset the arrays.
        self.sound_level = []
        
        # Round up.
        sound_level_mean = round(sound_level_mean,2)
        
        # logging.info(f'Sonometry AZ8922:{sound_level_mean}') 
        # logging.info('Sonometry AZ8922:%f' % sound_level_mean) 
        # if not self.connected: logging.warning('AZ8922 is disconnected.')
         
        return sound_level_mean, sound_level_max, sound_level_min

    def run_thread(self):
        """run thread to capture measurements from sonometer"""
        thread = threading.Thread(target=self.sonometro_thread, daemon=True)
        thread.start()

    def stop_thread(self):
        """stop sonometer thread"""
        self.running = False
        self.connected = False
        if self.ser is not None:
            self.ser.close()
            print(Red+"RS232 cerrando el puerto serie.\n",flush=True)
            

    def sonometro_thread(self):
        """reads values from serial port and updates sound level attribute"""
        while self.running:
            try:
                # If disconnected, check connection every 5 seconds.
                if not self.connected: time.sleep(5)
                self.ser = serial.Serial(self.port, 2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)
                self.connected = True
                print(Yellow+"RS232 abriendo el puerto serie.\n",flush=True)

                #Para sacar valores intermedios
                #print("Self.conected="+str(self.connected)+"\n")
                #print("self.ser.in_waiting="+str(self.ser.in_waiting)+"\n")
                #print("self.running="+str(self.running)+"\n")
                
                #while(self.connected and self.ser.in_waiting and self.running):
                while(self.connected and self.running):
                    output = self.ser.readline().decode('utf-8', 'ignore')
                    output = output.strip()
                    print(Yellow+"RS232 read data:"+str(output)+"\n",flush=True)
                    if output.startswith('N:') and output.endswith('dB'):
                        self.sound_level.append(float(output.split(':')[1].split('dB')[0]))

            except (serial.serialutil.SerialException, OSError):
                # Thread is not halted upon sensor disconnection.
                self.connected = False

# %% [markdown]
# ## Ejemplo toma de 10 medidas

# %%
# User Params.
MEASURE_PERIOD = 1  # How often (seconds) we poll for measurements.
log_file = 'log_files/log.txt'
json_file = path+'/type_1 '+format_time(time.time(), True)+'.json'

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  # Thread running condition.


#Llamada a la función y crea objeto de la clase AZ8922
port_AZ8922 = SELECTED_PORT
sound_level_meter = AZ8922(port_AZ8922)

print(Green+"Arrancamos el proceso para medir.\n")
sound_level_meter.run_thread()

# List to store measurements.
measurements = []

# Main thread.
for x in range(10):

        time.sleep(MEASURE_PERIOD)
        current_time = format_time(time.time())

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level_media, sound_level_maximo, sound_level_minimo = sound_level_meter.get_sonometry()
        print(Grey+"Valor medio medido="+ str(sound_level_media)+ " dB\n")
        print(Grey+"Valor máximo medido "+ str(sound_level_maximo)+ " dB\n")
        print(Grey+"Valor minimo medido "+ str(sound_level_minimo)+ " dB\n")
        #print(Magenta +"Medida(media, máximo)="+ str(sound_level)+ " dB\n" )
        print(Magenta +"Medida(media, máximo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+  " dB" +Cyan+"\tTime=" + current_time+"\n")
        logging.debug("Medida(media, maximo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+  " dB    Time=" + current_time+"\n")
        
        # Store the measurement in a dictionary
        measurement = {
            "time": current_time,
            "mean": sound_level_media,
            "max": sound_level_maximo,
            "min": sound_level_minimo
        }
        measurements.append(measurement)
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()

# Save measurements to a JSON file
with open(json_file, 'w') as f:
    json.dump(measurements, f, indent=4)
print(Green + f"Measurements saved to {json_file}\n")
# Out:
# AZ8922: Iniciando la clase.
#
# Arrancamos el proceso para medir.
#
# RS232 abriendo el puerto serie.
#
# RS232 read data:N:035.4dB
#
# RS232 read data:N:037.7dB
#
# Valor medio medido=36.63 dB
#
# Valor máximo medido 37.7 dB
#
# Valor minimo medido 35.4 dB
#
# Medida(media, máximo)=36.63,37.7 dB	Time=2025-04-02 19:49:09
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:036.6dB
#
# Valor medio medido=37.17 dB
#
# Valor máximo medido 37.7 dB
#
# Valor minimo medido 36.6 dB
#
# Medida(media, máximo)=37.17,37.7 dB	Time=2025-04-02 19:49:10
#
# RS232 read data:N:037.5dB
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:038.4dB
#
# Valor medio medido=38.43 dB
#
# Valor máximo medido 39.3 dB
#
# Valor minimo medido 37.5 dB
#
# Medida(media, máximo)=38.43,39.3 dB	Time=2025-04-02 19:49:11
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=39.11 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo)=39.11,40.4 dB	Time=2025-04-02 19:49:12
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.6 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo)=39.6,40.5 dB	Time=2025-04-02 19:49:13
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=38.55 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 38.5 dB
#
# Medida(media, máximo)=38.55,38.6 dB	Time=2025-04-02 19:49:14
#
# RS232 read data:N:037.3dB
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:036.0dB
#
# Valor medio medido=36.82 dB
#
# Valor máximo medido 37.3 dB
#
# Valor minimo medido 36.0 dB
#
# Medida(media, máximo)=36.82,37.3 dB	Time=2025-04-02 19:49:15
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:036.1dB
#
# Valor medio medido=35.8 dB
#
# Valor máximo medido 36.1 dB
#
# Valor minimo medido 35.5 dB
#
# Medida(media, máximo)=35.8,36.1 dB	Time=2025-04-02 19:49:16
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:036.0dB
#
# Valor medio medido=35.85 dB
#
# Valor máximo medido 36.0 dB
#
# Valor minimo medido 35.7 dB
#
# Medida(media, máximo)=35.85,36.0 dB	Time=2025-04-02 19:49:17
#
# RS232 read data:N:036.4dB
#
# RS232 read data:N:036.2dB
#
# RS232 read data:N:037.7dB
#
# Valor medio medido=36.79 dB
#
# Valor máximo medido 37.7 dB
#
# Valor minimo medido 36.2 dB
#
# Medida(media, máximo)=36.79,37.7 dB	Time=2025-04-02 19:49:18
#
# RS232 read data:
#
# RS232 cerrando el puerto serie.
#
# Measurements saved to log_files/medida_2/type_1 Wed 2025-04-02 19h49m08s.json

# %%
import matplotlib.pyplot as plt

pic_path = 'Pics/medida_2/type_1 '+format_time(time.time(), True)

# Load the measurements from the JSON file.
with open(json_file, 'r') as f:
    measurements = json.load(f)

times = [m["time"] for m in measurements]
means = [m["mean"] for m in measurements]
maxs = [m["max"] for m in measurements]
mins = [m["min"] for m in measurements]

m_number = list(range(0,len(measurements)))

# Plot the measurements
plt.figure(figsize=(10, 6))
plt.plot(m_number, means, label="Mean", color="blue")
plt.plot(m_number, maxs, label="Max", color="red", linestyle="--")
plt.plot(m_number, mins, label="Min", color="green", linestyle="--")
plt.xlim(0, len(measurements)-1)
plt.xlabel("Samples")
plt.ylabel("Sound Level (dB)")
plt.title("Sound Level Measurements Over Time")
plt.legend()
plt.grid(True)
plt.savefig(pic_path+'.png')
plt.show()

# %%
pic_path = 'Pics/medida_2/type_1_max '+format_time(time.time(), True)

plt.plot(maxs,'b',maxs,'ro') #Más opciones de plot aqui: https://matplotlib.org/tutorials/introductory/pyplot.html
plt.title('Max Sound Level sampled')
plt.ylabel('Sound Level [dB]')
plt.xlim(0, len(measurements)-1)
plt.xlabel('Samples')
plt.grid()
plt.savefig(pic_path+'.png')
plt.show()

# %% [markdown]
# ## Ejemplo toma de medidas para 5 minutos

# %%
# User Params.
MEASURE_PERIOD = 1  # How often (seconds) we poll for measurements.
log_file = 'log_files/log.txt'
json_file = path+'/type_2 '+format_time(time.time(), True)+'.json'
MEASUREMENT_DURATION = 5 * 60  # 5 minutes


# Get the start and stop time for the measurement.
start_time = time.time()
end_time = start_time + MEASUREMENT_DURATION

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  


#Llamada a la función y crea objeto de la clase AZ8922
port_AZ8922 = SELECTED_PORT
sound_level_meter = AZ8922(port_AZ8922)

print(Green+"Arrancamos el proceso para medir.\n")
sound_level_meter.run_thread()

measurements = []

# Main thread.
while time.time() < end_time:
        # Sleep for the measurement period
        time.sleep(MEASURE_PERIOD)
        current_time = format_time(time.time())

        # Store the measurement in a dictionary
        measurement = {
            "time": current_time,
            "mean": sound_level_media,
            "max": sound_level_maximo,
            "min": sound_level_minimo
        }
        measurements.append(measurement)

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level_media, sound_level_maximo, sound_level_minimo = sound_level_meter.get_sonometry()
        
        print(Grey+"Valor medio medido="+ str(sound_level_media)+ " dB\n")
        print(Grey+"Valor máximo medido "+ str(sound_level_maximo)+ " dB\n")
        print(Grey+"Valor minimo medido "+ str(sound_level_minimo)+ " dB\n")

        print(Magenta +"Medida(media, máximo, minimo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+","+ str(sound_level_minimo)+  " dB" +Cyan+"\tTime=" + current_time+"\n")
        logging.debug("Medida(media, maximo, minimo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+","+ str(sound_level_minimo)+  " dB    Time=" + current_time+"\n")
        
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()

# Save measurements to a JSON file
with open(json_file, 'w') as f:
    json.dump(measurements, f, indent=4)
print(Green + f"Measurements saved to {json_file}\n")
# Out:
# AZ8922: Iniciando la clase.
#
# Arrancamos el proceso para medir.
#
# RS232 abriendo el puerto serie.
#
# RS232 read data:N:037.2dB
#
# RS232 read data:N:037.7dB
#
# Valor medio medido=37.45 dB
#
# Valor máximo medido 37.7 dB
#
# Valor minimo medido 37.2 dB
#
# Medida(media, máximo, minimo)=37.45,37.7,37.2 dB	Time=2025-04-02 19:49:20
#
# RS232 read data:N:037.3dB
#
# RS232 read data:N:036.9dB
#
# RS232 read data:N:037.3dB
#
# Valor medio medido=37.17 dB
#
# Valor máximo medido 37.3 dB
#
# Valor minimo medido 36.9 dB
#
# Medida(media, máximo, minimo)=37.17,37.3,36.9 dB	Time=2025-04-02 19:49:21
#
# RS232 read data:N:037.9dB
#
# RS232 read data:N:037.1dB
#
# Valor medio medido=37.51 dB
#
# Valor máximo medido 37.9 dB
#
# Valor minimo medido 37.1 dB
#
# Medida(media, máximo, minimo)=37.51,37.9,37.1 dB	Time=2025-04-02 19:49:22
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:038.1dB
#
# Valor medio medido=38.58 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 38.1 dB
#
# Medida(media, máximo, minimo)=38.58,39.1,38.1 dB	Time=2025-04-02 19:49:23
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:036.0dB
#
# Valor medio medido=36.89 dB
#
# Valor máximo medido 37.7 dB
#
# Valor minimo medido 36.0 dB
#
# Medida(media, máximo, minimo)=36.89,37.7,36.0 dB	Time=2025-04-02 19:49:24
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:037.7dB
#
# Valor medio medido=38.04 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 37.7 dB
#
# Medida(media, máximo, minimo)=38.04,38.3,37.7 dB	Time=2025-04-02 19:49:25
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:036.1dB
#
# Valor medio medido=36.61 dB
#
# Valor máximo medido 37.1 dB
#
# Valor minimo medido 36.1 dB
#
# Medida(media, máximo, minimo)=36.61,37.1,36.1 dB	Time=2025-04-02 19:49:26
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:037.1dB
#
# Valor medio medido=37.72 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 37.1 dB
#
# Medida(media, máximo, minimo)=37.72,38.3,37.1 dB	Time=2025-04-02 19:49:27
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:037.5dB
#
# RS232 read data:N:036.2dB
#
# Valor medio medido=37.27 dB
#
# Valor máximo medido 38.0 dB
#
# Valor minimo medido 36.2 dB
#
# Medida(media, máximo, minimo)=37.27,38.0,36.2 dB	Time=2025-04-02 19:49:28
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:036.2dB
#
# Valor medio medido=36.0 dB
#
# Valor máximo medido 36.2 dB
#
# Valor minimo medido 35.8 dB
#
# Medida(media, máximo, minimo)=36.0,36.2,35.8 dB	Time=2025-04-02 19:49:29
#
# RS232 read data:N:036.3dB
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:036.5dB
#
# Valor medio medido=36.17 dB
#
# Valor máximo medido 36.5 dB
#
# Valor minimo medido 35.7 dB
#
# Medida(media, máximo, minimo)=36.17,36.5,35.7 dB	Time=2025-04-02 19:49:30
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:036.5dB
#
# Valor medio medido=35.98 dB
#
# Valor máximo medido 36.5 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=35.98,36.5,35.6 dB	Time=2025-04-02 19:49:31
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:036.3dB
#
# Valor medio medido=36.45 dB
#
# Valor máximo medido 36.6 dB
#
# Valor minimo medido 36.3 dB
#
# Medida(media, máximo, minimo)=36.45,36.6,36.3 dB	Time=2025-04-02 19:49:32
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:035.0dB
#
# Valor medio medido=35.1 dB
#
# Valor máximo medido 35.3 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo, minimo)=35.1,35.3,35.0 dB	Time=2025-04-02 19:49:33
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:035.9dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=35.27 dB
#
# Valor máximo medido 35.9 dB
#
# Valor minimo medido 34.1 dB
#
# Medida(media, máximo, minimo)=35.27,35.9,34.1 dB	Time=2025-04-02 19:49:34
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:035.4dB
#
# Valor medio medido=35.11 dB
#
# Valor máximo medido 35.4 dB
#
# Valor minimo medido 34.8 dB
#
# Medida(media, máximo, minimo)=35.11,35.4,34.8 dB	Time=2025-04-02 19:49:35
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:036.4dB
#
# RS232 read data:N:037.4dB
#
# Valor medio medido=36.56 dB
#
# Valor máximo medido 37.4 dB
#
# Valor minimo medido 35.8 dB
#
# Medida(media, máximo, minimo)=36.56,37.4,35.8 dB	Time=2025-04-02 19:49:36
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:041.1dB
#
# Valor medio medido=38.81 dB
#
# Valor máximo medido 41.1 dB
#
# Valor minimo medido 35.7 dB
#
# Medida(media, máximo, minimo)=38.81,41.1,35.7 dB	Time=2025-04-02 19:49:37
#
# RS232 read data:N:035.4dB
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:034.9dB
#
# Valor medio medido=35.2 dB
#
# Valor máximo medido 35.4 dB
#
# Valor minimo medido 34.9 dB
#
# Medida(media, máximo, minimo)=35.2,35.4,34.9 dB	Time=2025-04-02 19:49:38
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:035.4dB
#
# Valor medio medido=35.3 dB
#
# Valor máximo medido 35.5 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo, minimo)=35.3,35.5,35.0 dB	Time=2025-04-02 19:49:39
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=35.05 dB
#
# Valor máximo medido 35.3 dB
#
# Valor minimo medido 34.8 dB
#
# Medida(media, máximo, minimo)=35.05,35.3,34.8 dB	Time=2025-04-02 19:49:40
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:034.7dB
#
# Valor medio medido=35.08 dB
#
# Valor máximo medido 35.6 dB
#
# Valor minimo medido 34.7 dB
#
# Medida(media, máximo, minimo)=35.08,35.6,34.7 dB	Time=2025-04-02 19:49:41
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:035.6dB
#
# Valor medio medido=35.37 dB
#
# Valor máximo medido 35.6 dB
#
# Valor minimo medido 35.2 dB
#
# Medida(media, máximo, minimo)=35.37,35.6,35.2 dB	Time=2025-04-02 19:49:42
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:035.6dB
#
# Valor medio medido=35.31 dB
#
# Valor máximo medido 35.6 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo, minimo)=35.31,35.6,35.0 dB	Time=2025-04-02 19:49:43
#
# RS232 read data:N:036.2dB
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:038.4dB
#
# Valor medio medido=37.48 dB
#
# Valor máximo medido 38.4 dB
#
# Valor minimo medido 36.2 dB
#
# Medida(media, máximo, minimo)=37.48,38.4,36.2 dB	Time=2025-04-02 19:49:44
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:038.0dB
#
# Valor medio medido=37.65 dB
#
# Valor máximo medido 38.1 dB
#
# Valor minimo medido 36.8 dB
#
# Medida(media, máximo, minimo)=37.65,38.1,36.8 dB	Time=2025-04-02 19:49:45
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:036.9dB
#
# Valor medio medido=37.47 dB
#
# Valor máximo medido 38.0 dB
#
# Valor minimo medido 36.9 dB
#
# Medida(media, máximo, minimo)=37.47,38.0,36.9 dB	Time=2025-04-02 19:49:46
#
# RS232 read data:N:036.7dB
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=38.22 dB
#
# Valor máximo medido 39.7 dB
#
# Valor minimo medido 36.7 dB
#
# Medida(media, máximo, minimo)=38.22,39.7,36.7 dB	Time=2025-04-02 19:49:47
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=38.21 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=38.21,38.6,37.8 dB	Time=2025-04-02 19:49:48
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:037.3dB
#
# RS232 read data:N:036.7dB
#
# Valor medio medido=37.68 dB
#
# Valor máximo medido 38.9 dB
#
# Valor minimo medido 36.7 dB
#
# Medida(media, máximo, minimo)=37.68,38.9,36.7 dB	Time=2025-04-02 19:49:49
#
# RS232 read data:N:036.2dB
#
# RS232 read data:N:036.2dB
#
# Valor medio medido=36.2 dB
#
# Valor máximo medido 36.2 dB
#
# Valor minimo medido 36.2 dB
#
# Medida(media, máximo, minimo)=36.2,36.2,36.2 dB	Time=2025-04-02 19:49:50
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:036.3dB
#
# Valor medio medido=36.5 dB
#
# Valor máximo medido 36.6 dB
#
# Valor minimo medido 36.3 dB
#
# Medida(media, máximo, minimo)=36.5,36.6,36.3 dB	Time=2025-04-02 19:49:51
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:037.4dB
#
# RS232 read data:N:035.9dB
#
# Valor medio medido=36.65 dB
#
# Valor máximo medido 37.4 dB
#
# Valor minimo medido 35.9 dB
#
# Medida(media, máximo, minimo)=36.65,37.4,35.9 dB	Time=2025-04-02 19:49:52
#
# RS232 read data:N:036.5dB
#
# RS232 read data:N:036.5dB
#
# Valor medio medido=36.5 dB
#
# Valor máximo medido 36.5 dB
#
# Valor minimo medido 36.5 dB
#
# Medida(media, máximo, minimo)=36.5,36.5,36.5 dB	Time=2025-04-02 19:49:53
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:037.8dB
#
# Valor medio medido=38.24 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=38.24,38.6,37.8 dB	Time=2025-04-02 19:49:54
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:036.7dB
#
# Valor medio medido=37.37 dB
#
# Valor máximo medido 38.0 dB
#
# Valor minimo medido 36.7 dB
#
# Medida(media, máximo, minimo)=37.37,38.0,36.7 dB	Time=2025-04-02 19:49:55
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=38.75 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=38.75,39.4,38.3 dB	Time=2025-04-02 19:49:56
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=40.49 dB
#
# Valor máximo medido 41.3 dB
#
# Valor minimo medido 39.6 dB
#
# Medida(media, máximo, minimo)=40.49,41.3,39.6 dB	Time=2025-04-02 19:49:57
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:040.0dB
#
# Valor medio medido=38.66 dB
#
# Valor máximo medido 40.0 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=38.66,40.0,37.8 dB	Time=2025-04-02 19:49:58
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=39.95 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=39.95,40.1,39.8 dB	Time=2025-04-02 19:49:59
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:036.6dB
#
# Valor medio medido=38.13 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 36.6 dB
#
# Medida(media, máximo, minimo)=38.13,39.1,36.6 dB	Time=2025-04-02 19:50:00
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:036.1dB
#
# Valor medio medido=36.46 dB
#
# Valor máximo medido 36.8 dB
#
# Valor minimo medido 36.1 dB
#
# Medida(media, máximo, minimo)=36.46,36.8,36.1 dB	Time=2025-04-02 19:50:01
#
# RS232 read data:N:036.2dB
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:036.9dB
#
# Valor medio medido=36.57 dB
#
# Valor máximo medido 36.9 dB
#
# Valor minimo medido 36.2 dB
#
# Medida(media, máximo, minimo)=36.57,36.9,36.2 dB	Time=2025-04-02 19:50:02
#
# RS232 read data:N:037.0dB
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:038.2dB
#
# Valor medio medido=37.31 dB
#
# Valor máximo medido 37.6 dB
#
# Valor minimo medido 37.0 dB
#
# Medida(media, máximo, minimo)=37.31,37.6,37.0 dB	Time=2025-04-02 19:50:03
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=39.19 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=39.19,40.5,38.2 dB	Time=2025-04-02 19:50:04
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:040.3dB
#
# Valor medio medido=40.1 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.1,40.3,39.9 dB	Time=2025-04-02 19:50:05
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:038.5dB
#
# Valor medio medido=39.93 dB
#
# Valor máximo medido 41.1 dB
#
# Valor minimo medido 38.5 dB
#
# Medida(media, máximo, minimo)=39.93,41.1,38.5 dB	Time=2025-04-02 19:50:06
#
# RS232 read data:N:037.3dB
#
# RS232 read data:N:037.9dB
#
# Valor medio medido=37.61 dB
#
# Valor máximo medido 37.9 dB
#
# Valor minimo medido 37.3 dB
#
# Medida(media, máximo, minimo)=37.61,37.9,37.3 dB	Time=2025-04-02 19:50:07
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:037.8dB
#
# Valor medio medido=38.01 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo, minimo)=38.01,38.6,37.6 dB	Time=2025-04-02 19:50:08
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:037.7dB
#
# Valor medio medido=37.9 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 37.7 dB
#
# Medida(media, máximo, minimo)=37.9,38.3,37.7 dB	Time=2025-04-02 19:50:09
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:035.9dB
#
# Valor medio medido=35.61 dB
#
# Valor máximo medido 35.9 dB
#
# Valor minimo medido 35.3 dB
#
# Medida(media, máximo, minimo)=35.61,35.9,35.3 dB	Time=2025-04-02 19:50:10
#
# RS232 read data:N:036.0dB
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:036.0dB
#
# Valor medio medido=35.93 dB
#
# Valor máximo medido 36.0 dB
#
# Valor minimo medido 35.8 dB
#
# Medida(media, máximo, minimo)=35.93,36.0,35.8 dB	Time=2025-04-02 19:50:11
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:036.4dB
#
# Valor medio medido=36.76 dB
#
# Valor máximo medido 37.1 dB
#
# Valor minimo medido 36.4 dB
#
# Medida(media, máximo, minimo)=36.76,37.1,36.4 dB	Time=2025-04-02 19:50:12
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:035.2dB
#
# Valor medio medido=35.27 dB
#
# Valor máximo medido 35.3 dB
#
# Valor minimo medido 35.2 dB
#
# Medida(media, máximo, minimo)=35.27,35.3,35.2 dB	Time=2025-04-02 19:50:13
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:036.4dB
#
# Valor medio medido=35.49 dB
#
# Valor máximo medido 36.4 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo, minimo)=35.49,36.4,35.0 dB	Time=2025-04-02 19:50:14
#
# RS232 read data:N:036.5dB
#
# RS232 read data:N:036.2dB
#
# Valor medio medido=36.35 dB
#
# Valor máximo medido 36.5 dB
#
# Valor minimo medido 36.2 dB
#
# Medida(media, máximo, minimo)=36.35,36.5,36.2 dB	Time=2025-04-02 19:50:15
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:036.1dB
#
# Valor medio medido=35.77 dB
#
# Valor máximo medido 36.1 dB
#
# Valor minimo medido 35.5 dB
#
# Medida(media, máximo, minimo)=35.77,36.1,35.5 dB	Time=2025-04-02 19:50:16
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:035.8dB
#
# Valor medio medido=35.35 dB
#
# Valor máximo medido 35.8 dB
#
# Valor minimo medido 34.6 dB
#
# Medida(media, máximo, minimo)=35.35,35.8,34.6 dB	Time=2025-04-02 19:50:17
#
# RS232 read data:N:036.3dB
#
# RS232 read data:N:037.8dB
#
# Valor medio medido=37.08 dB
#
# Valor máximo medido 37.8 dB
#
# Valor minimo medido 36.3 dB
#
# Medida(media, máximo, minimo)=37.08,37.8,36.3 dB	Time=2025-04-02 19:50:18
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:036.3dB
#
# Valor medio medido=36.69 dB
#
# Valor máximo medido 38.0 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=36.69,38.0,35.6 dB	Time=2025-04-02 19:50:19
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:037.2dB
#
# Valor medio medido=37.4 dB
#
# Valor máximo medido 37.6 dB
#
# Valor minimo medido 37.2 dB
#
# Medida(media, máximo, minimo)=37.4,37.6,37.2 dB	Time=2025-04-02 19:50:20
#
# RS232 read data:N:037.4dB
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:037.4dB
#
# Valor medio medido=37.5 dB
#
# Valor máximo medido 37.7 dB
#
# Valor minimo medido 37.4 dB
#
# Medida(media, máximo, minimo)=37.5,37.7,37.4 dB	Time=2025-04-02 19:50:21
#
# RS232 read data:N:036.9dB
#
# RS232 read data:N:036.7dB
#
# RS232 read data:N:037.1dB
#
# Valor medio medido=36.9 dB
#
# Valor máximo medido 37.1 dB
#
# Valor minimo medido 36.7 dB
#
# Medida(media, máximo, minimo)=36.9,37.1,36.7 dB	Time=2025-04-02 19:50:22
#
# RS232 read data:N:037.4dB
#
# RS232 read data:N:035.4dB
#
# Valor medio medido=36.46 dB
#
# Valor máximo medido 37.4 dB
#
# Valor minimo medido 35.4 dB
#
# Medida(media, máximo, minimo)=36.46,37.4,35.4 dB	Time=2025-04-02 19:50:23
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:036.9dB
#
# Valor medio medido=36.83 dB
#
# Valor máximo medido 36.9 dB
#
# Valor minimo medido 36.8 dB
#
# Medida(media, máximo, minimo)=36.83,36.9,36.8 dB	Time=2025-04-02 19:50:24
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:037.4dB
#
# Valor medio medido=37.11 dB
#
# Valor máximo medido 37.4 dB
#
# Valor minimo medido 36.8 dB
#
# Medida(media, máximo, minimo)=37.11,37.4,36.8 dB	Time=2025-04-02 19:50:25
#
# RS232 read data:N:037.3dB
#
# RS232 read data:N:037.3dB
#
# RS232 read data:N:037.7dB
#
# Valor medio medido=37.44 dB
#
# Valor máximo medido 37.7 dB
#
# Valor minimo medido 37.3 dB
#
# Medida(media, máximo, minimo)=37.44,37.7,37.3 dB	Time=2025-04-02 19:50:26
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=38.15 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 38.0 dB
#
# Medida(media, máximo, minimo)=38.15,38.3,38.0 dB	Time=2025-04-02 19:50:27
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:037.0dB
#
# RS232 read data:N:036.2dB
#
# Valor medio medido=38.2 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 36.2 dB
#
# Medida(media, máximo, minimo)=38.2,40.7,36.2 dB	Time=2025-04-02 19:50:28
#
# RS232 read data:N:036.4dB
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:036.9dB
#
# Valor medio medido=37.24 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 36.4 dB
#
# Medida(media, máximo, minimo)=37.24,38.3,36.4 dB	Time=2025-04-02 19:50:29
#
# RS232 read data:N:036.3dB
#
# RS232 read data:N:035.6dB
#
# Valor medio medido=35.96 dB
#
# Valor máximo medido 36.3 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=35.96,36.3,35.6 dB	Time=2025-04-02 19:50:30
#
# RS232 read data:N:036.7dB
#
# RS232 read data:N:036.5dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=35.96 dB
#
# Valor máximo medido 36.7 dB
#
# Valor minimo medido 34.5 dB
#
# Medida(media, máximo, minimo)=35.96,36.7,34.5 dB	Time=2025-04-02 19:50:31
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:036.1dB
#
# RS232 read data:N:035.6dB
#
# Valor medio medido=35.58 dB
#
# Valor máximo medido 36.1 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo, minimo)=35.58,36.1,35.0 dB	Time=2025-04-02 19:50:32
#
# RS232 read data:N:036.4dB
#
# RS232 read data:N:036.2dB
#
# Valor medio medido=36.3 dB
#
# Valor máximo medido 36.4 dB
#
# Valor minimo medido 36.2 dB
#
# Medida(media, máximo, minimo)=36.3,36.4,36.2 dB	Time=2025-04-02 19:50:33
#
# RS232 read data:N:036.5dB
#
# RS232 read data:N:036.0dB
#
# RS232 read data:N:037.3dB
#
# Valor medio medido=36.62 dB
#
# Valor máximo medido 37.3 dB
#
# Valor minimo medido 36.0 dB
#
# Medida(media, máximo, minimo)=36.62,37.3,36.0 dB	Time=2025-04-02 19:50:34
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:035.6dB
#
# Valor medio medido=35.6 dB
#
# Valor máximo medido 35.6 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=35.6,35.6,35.6 dB	Time=2025-04-02 19:50:35
#
# RS232 read data:N:035.9dB
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:035.5dB
#
# Valor medio medido=35.54 dB
#
# Valor máximo medido 35.9 dB
#
# Valor minimo medido 35.2 dB
#
# Medida(media, máximo, minimo)=35.54,35.9,35.2 dB	Time=2025-04-02 19:50:36
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:035.0dB
#
# Valor medio medido=35.0 dB
#
# Valor máximo medido 35.0 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo, minimo)=35.0,35.0,35.0 dB	Time=2025-04-02 19:50:37
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:035.6dB
#
# Valor medio medido=35.26 dB
#
# Valor máximo medido 35.6 dB
#
# Valor minimo medido 34.9 dB
#
# Medida(media, máximo, minimo)=35.26,35.6,34.9 dB	Time=2025-04-02 19:50:38
#
# RS232 read data:N:035.9dB
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:035.9dB
#
# Valor medio medido=35.8 dB
#
# Valor máximo medido 35.9 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=35.8,35.9,35.6 dB	Time=2025-04-02 19:50:39
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:037.0dB
#
# RS232 read data:N:036.1dB
#
# Valor medio medido=36.64 dB
#
# Valor máximo medido 37.0 dB
#
# Valor minimo medido 36.1 dB
#
# Medida(media, máximo, minimo)=36.64,37.0,36.1 dB	Time=2025-04-02 19:50:40
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:036.3dB
#
# Valor medio medido=36.45 dB
#
# Valor máximo medido 36.6 dB
#
# Valor minimo medido 36.3 dB
#
# Medida(media, máximo, minimo)=36.45,36.6,36.3 dB	Time=2025-04-02 19:50:41
#
# RS232 read data:N:037.2dB
#
# RS232 read data:N:036.9dB
#
# RS232 read data:N:036.5dB
#
# Valor medio medido=36.87 dB
#
# Valor máximo medido 37.2 dB
#
# Valor minimo medido 36.5 dB
#
# Medida(media, máximo, minimo)=36.87,37.2,36.5 dB	Time=2025-04-02 19:50:42
#
# RS232 read data:N:036.0dB
#
# RS232 read data:N:036.1dB
#
# RS232 read data:N:036.6dB
# Valor medio medido=36.05 dB
#
# Valor máximo medido 36.1 dB
#
# Valor minimo medido 36.0 dB
#
# Medida(media, máximo, minimo)=36.05,36.1,36.0 dB	Time=2025-04-02 19:50:43
#
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:038.9dB
#
# Valor medio medido=37.44 dB
#
# Valor máximo medido 38.9 dB
#
# Valor minimo medido 36.6 dB
#
# Medida(media, máximo, minimo)=37.44,38.9,36.6 dB	Time=2025-04-02 19:50:44
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:036.7dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=37.39 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 36.7 dB
#
# Medida(media, máximo, minimo)=37.39,38.3,36.7 dB	Time=2025-04-02 19:50:45
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:037.4dB
#
# Valor medio medido=37.81 dB
#
# Valor máximo medido 38.2 dB
#
# Valor minimo medido 37.4 dB
#
# Medida(media, máximo, minimo)=37.81,38.2,37.4 dB	Time=2025-04-02 19:50:46
#
# RS232 read data:N:037.0dB
#
# RS232 read data:N:036.3dB
#
# RS232 read data:N:036.5dB
#
# Valor medio medido=36.61 dB
#
# Valor máximo medido 37.0 dB
#
# Valor minimo medido 36.3 dB
#
# Medida(media, máximo, minimo)=36.61,37.0,36.3 dB	Time=2025-04-02 19:50:47
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:036.6dB
#
# Valor medio medido=37.44 dB
#
# Valor máximo medido 38.2 dB
#
# Valor minimo medido 36.6 dB
#
# Medida(media, máximo, minimo)=37.44,38.2,36.6 dB	Time=2025-04-02 19:50:48
#
# RS232 read data:N:037.4dB
#
# RS232 read data:N:037.2dB
#
# RS232 read data:N:037.5dB
#
# Valor medio medido=37.37 dB
#
# Valor máximo medido 37.5 dB
#
# Valor minimo medido 37.2 dB
#
# Medida(media, máximo, minimo)=37.37,37.5,37.2 dB	Time=2025-04-02 19:50:49
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=38.66 dB
#
# Valor máximo medido 39.0 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=38.66,39.0,38.3 dB	Time=2025-04-02 19:50:50
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:037.7dB
#
# Valor medio medido=37.67 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 36.6 dB
#
# Medida(media, máximo, minimo)=37.67,38.6,36.6 dB	Time=2025-04-02 19:50:51
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:036.5dB
#
# Valor medio medido=37.56 dB
#
# Valor máximo medido 38.9 dB
#
# Valor minimo medido 36.5 dB
#
# Medida(media, máximo, minimo)=37.56,38.9,36.5 dB	Time=2025-04-02 19:50:52
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:035.6dB
#
# Valor medio medido=35.45 dB
#
# Valor máximo medido 35.6 dB
#
# Valor minimo medido 35.3 dB
#
# Medida(media, máximo, minimo)=35.45,35.6,35.3 dB	Time=2025-04-02 19:50:53
#
# RS232 read data:N:036.3dB
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:036.6dB
#
# Valor medio medido=36.67 dB
#
# Valor máximo medido 37.1 dB
#
# Valor minimo medido 36.3 dB
#
# Medida(media, máximo, minimo)=36.67,37.1,36.3 dB	Time=2025-04-02 19:50:54
#
# RS232 read data:N:037.5dB
#
# RS232 read data:N:036.6dB
#
# Valor medio medido=37.06 dB
#
# Valor máximo medido 37.5 dB
#
# Valor minimo medido 36.6 dB
#
# Medida(media, máximo, minimo)=37.06,37.5,36.6 dB	Time=2025-04-02 19:50:55
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:037.5dB
#
# RS232 read data:N:038.4dB
#
# Valor medio medido=37.59 dB
#
# Valor máximo medido 38.4 dB
#
# Valor minimo medido 36.8 dB
#
# Medida(media, máximo, minimo)=37.59,38.4,36.8 dB	Time=2025-04-02 19:50:56
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:038.1dB
#
# Valor medio medido=38.46 dB
#
# Valor máximo medido 38.8 dB
#
# Valor minimo medido 38.1 dB
#
# Medida(media, máximo, minimo)=38.46,38.8,38.1 dB	Time=2025-04-02 19:50:57
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:038.0dB
#
# Valor medio medido=37.92 dB
#
# Valor máximo medido 39.0 dB
#
# Valor minimo medido 36.6 dB
#
# Medida(media, máximo, minimo)=37.92,39.0,36.6 dB	Time=2025-04-02 19:50:58
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:037.0dB
#
# Valor medio medido=37.18 dB
#
# Valor máximo medido 37.7 dB
#
# Valor minimo medido 36.8 dB
#
# Medida(media, máximo, minimo)=37.18,37.7,36.8 dB	Time=2025-04-02 19:50:59
#
# RS232 read data:N:037.4dB
#
# RS232 read data:N:037.5dB
#
# Valor medio medido=37.45 dB
#
# Valor máximo medido 37.5 dB
#
# Valor minimo medido 37.4 dB
#
# Medida(media, máximo, minimo)=37.45,37.5,37.4 dB	Time=2025-04-02 19:51:00
#
# RS232 read data:N:036.4dB
#
# RS232 read data:N:036.3dB
#
# RS232 read data:N:036.9dB
#
# Valor medio medido=36.54 dB
#
# Valor máximo medido 36.9 dB
#
# Valor minimo medido 36.3 dB
#
# Medida(media, máximo, minimo)=36.54,36.9,36.3 dB	Time=2025-04-02 19:51:01
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:038.0dB
#
# Valor medio medido=38.0 dB
#
# Valor máximo medido 38.0 dB
#
# Valor minimo medido 38.0 dB
#
# Medida(media, máximo, minimo)=38.0,38.0,38.0 dB	Time=2025-04-02 19:51:02
#
# RS232 read data:N:036.7dB
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=38.23 dB
#
# Valor máximo medido 39.0 dB
#
# Valor minimo medido 36.7 dB
#
# Medida(media, máximo, minimo)=38.23,39.0,36.7 dB	Time=2025-04-02 19:51:03
#
# RS232 read data:N:037.5dB
#
# RS232 read data:N:038.4dB
#
# Valor medio medido=37.96 dB
#
# Valor máximo medido 38.4 dB
#
# Valor minimo medido 37.5 dB
#
# Medida(media, máximo, minimo)=37.96,38.4,37.5 dB	Time=2025-04-02 19:51:04
#
# RS232 read data:N:037.3dB
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:036.4dB
#
# Valor medio medido=37.37 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 36.4 dB
#
# Medida(media, máximo, minimo)=37.37,38.3,36.4 dB	Time=2025-04-02 19:51:05
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:035.1dB
#
# Valor medio medido=35.85 dB
#
# Valor máximo medido 36.6 dB
#
# Valor minimo medido 35.1 dB
#
# Medida(media, máximo, minimo)=35.85,36.6,35.1 dB	Time=2025-04-02 19:51:06
#
# RS232 read data:N:036.0dB
#
# RS232 read data:N:036.2dB
#
# Valor medio medido=36.1 dB
#
# Valor máximo medido 36.2 dB
#
# Valor minimo medido 36.0 dB
#
# Medida(media, máximo, minimo)=36.1,36.2,36.0 dB	Time=2025-04-02 19:51:07
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:036.4dB
#
# RS232 read data:N:036.4dB
#
# Valor medio medido=36.17 dB
#
# Valor máximo medido 36.4 dB
#
# Valor minimo medido 35.7 dB
#
# Medida(media, máximo, minimo)=36.17,36.4,35.7 dB	Time=2025-04-02 19:51:08
#
# RS232 read data:N:035.4dB
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:035.7dB
#
# Valor medio medido=35.47 dB
#
# Valor máximo medido 35.7 dB
#
# Valor minimo medido 35.3 dB
#
# Medida(media, máximo, minimo)=35.47,35.7,35.3 dB	Time=2025-04-02 19:51:09
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:035.3dB
#
# Valor medio medido=35.05 dB
#
# Valor máximo medido 35.3 dB
#
# Valor minimo medido 34.8 dB
#
# Medida(media, máximo, minimo)=35.05,35.3,34.8 dB	Time=2025-04-02 19:51:10
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:036.2dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=35.36 dB
#
# Valor máximo medido 36.2 dB
#
# Valor minimo medido 34.8 dB
#
# Medida(media, máximo, minimo)=35.36,36.2,34.8 dB	Time=2025-04-02 19:51:11
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:035.1dB
#
# Valor medio medido=37.76 dB
#
# Valor máximo medido 39.8 dB
#
# Valor minimo medido 35.1 dB
#
# Medida(media, máximo, minimo)=37.76,39.8,35.1 dB	Time=2025-04-02 19:51:12
#
# RS232 read data:N:036.1dB
#
# RS232 read data:N:036.2dB
#
# RS232 read data:N:035.6dB
#
# Valor medio medido=35.97 dB
#
# Valor máximo medido 36.2 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=35.97,36.2,35.6 dB	Time=2025-04-02 19:51:13
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:036.5dB
#
# Valor medio medido=35.91 dB
#
# Valor máximo medido 36.5 dB
#
# Valor minimo medido 35.5 dB
#
# Medida(media, máximo, minimo)=35.91,36.5,35.5 dB	Time=2025-04-02 19:51:14
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:037.4dB
#
# Valor medio medido=36.5 dB
#
# Valor máximo medido 37.4 dB
#
# Valor minimo medido 35.5 dB
#
# Medida(media, máximo, minimo)=36.5,37.4,35.5 dB	Time=2025-04-02 19:51:15
#
# RS232 read data:N:043.7dB
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:037.1dB
#
# Valor medio medido=40.72 dB
#
# Valor máximo medido 43.7 dB
#
# Valor minimo medido 37.1 dB
#
# Medida(media, máximo, minimo)=40.72,43.7,37.1 dB	Time=2025-04-02 19:51:16
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:035.4dB
#
# Valor medio medido=36.57 dB
#
# Valor máximo medido 37.6 dB
#
# Valor minimo medido 35.4 dB
#
# Medida(media, máximo, minimo)=36.57,37.6,35.4 dB	Time=2025-04-02 19:51:17
#
# RS232 read data:N:036.2dB
#
# RS232 read data:N:036.2dB
#
# RS232 read data:N:041.1dB
#
# Valor medio medido=38.16 dB
#
# Valor máximo medido 41.1 dB
#
# Valor minimo medido 36.2 dB
#
# Medida(media, máximo, minimo)=38.16,41.1,36.2 dB	Time=2025-04-02 19:51:18
#
# RS232 read data:N:036.7dB
#
# RS232 read data:N:036.9dB
#
# Valor medio medido=36.8 dB
#
# Valor máximo medido 36.9 dB
#
# Valor minimo medido 36.7 dB
#
# Medida(media, máximo, minimo)=36.8,36.9,36.7 dB	Time=2025-04-02 19:51:19
#
# RS232 read data:N:036.7dB
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:035.7dB
#
# Valor medio medido=36.52 dB
#
# Valor máximo medido 37.1 dB
#
# Valor minimo medido 35.7 dB
#
# Medida(media, máximo, minimo)=36.52,37.1,35.7 dB	Time=2025-04-02 19:51:20
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:038.1dB
#
# Valor medio medido=36.95 dB
#
# Valor máximo medido 38.1 dB
#
# Valor minimo medido 35.8 dB
#
# Medida(media, máximo, minimo)=36.95,38.1,35.8 dB	Time=2025-04-02 19:51:21
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:037.6dB
#
# Valor medio medido=38.11 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo, minimo)=38.11,38.6,37.6 dB	Time=2025-04-02 19:51:22
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:035.3dB
#
# Valor medio medido=36.26 dB
#
# Valor máximo medido 36.8 dB
#
# Valor minimo medido 35.3 dB
#
# Medida(media, máximo, minimo)=36.26,36.8,35.3 dB	Time=2025-04-02 19:51:23
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=34.9 dB
#
# Valor máximo medido 35.0 dB
#
# Valor minimo medido 34.8 dB
#
# Medida(media, máximo, minimo)=34.9,35.0,34.8 dB	Time=2025-04-02 19:51:24
#
# RS232 read data:N:035.9dB
#
# RS232 read data:N:035.4dB
#
# RS232 read data:N:035.1dB
#
# Valor medio medido=35.47 dB
#
# Valor máximo medido 35.9 dB
#
# Valor minimo medido 35.1 dB
#
# Medida(media, máximo, minimo)=35.47,35.9,35.1 dB	Time=2025-04-02 19:51:25
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:035.7dB
#
# Valor medio medido=36.04 dB
#
# Valor máximo medido 37.1 dB
#
# Valor minimo medido 35.2 dB
#
# Medida(media, máximo, minimo)=36.04,37.1,35.2 dB	Time=2025-04-02 19:51:26
#
# RS232 read data:N:036.7dB
#
# RS232 read data:N:036.1dB
#
# Valor medio medido=36.41 dB
#
# Valor máximo medido 36.7 dB
#
# Valor minimo medido 36.1 dB
#
# Medida(media, máximo, minimo)=36.41,36.7,36.1 dB	Time=2025-04-02 19:51:27
#
# RS232 read data:N:036.5dB
#
# RS232 read data:N:036.7dB
#
# RS232 read data:N:035.5dB
#
# Valor medio medido=36.25 dB
#
# Valor máximo medido 36.7 dB
#
# Valor minimo medido 35.5 dB
#
# Medida(media, máximo, minimo)=36.25,36.7,35.5 dB	Time=2025-04-02 19:51:28
#
# RS232 read data:N:036.7dB
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:037.9dB
#
# Valor medio medido=37.45 dB
#
# Valor máximo medido 37.9 dB
#
# Valor minimo medido 36.7 dB
#
# Medida(media, máximo, minimo)=37.45,37.9,36.7 dB	Time=2025-04-02 19:51:29
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:036.2dB
#
# Valor medio medido=36.66 dB
#
# Valor máximo medido 37.1 dB
#
# Valor minimo medido 36.2 dB
#
# Medida(media, máximo, minimo)=36.66,37.1,36.2 dB	Time=2025-04-02 19:51:30
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=38.59 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 37.1 dB
#
# Medida(media, máximo, minimo)=38.59,39.5,37.1 dB	Time=2025-04-02 19:51:31
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:040.9dB
#
# Valor medio medido=40.46 dB
#
# Valor máximo medido 40.9 dB
#
# Valor minimo medido 40.0 dB
#
# Medida(media, máximo, minimo)=40.46,40.9,40.0 dB	Time=2025-04-02 19:51:32
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=39.44 dB
#
# Valor máximo medido 40.0 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=39.44,40.0,39.0 dB	Time=2025-04-02 19:51:33
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:037.4dB
#
# Valor medio medido=37.86 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 37.4 dB
#
# Medida(media, máximo, minimo)=37.86,38.3,37.4 dB	Time=2025-04-02 19:51:34
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:038.9dB
#
# Valor medio medido=38.71 dB
#
# Valor máximo medido 39.0 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=38.71,39.0,38.2 dB	Time=2025-04-02 19:51:35
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:038.2dB
#
# Valor medio medido=38.1 dB
#
# Valor máximo medido 38.2 dB
#
# Valor minimo medido 38.0 dB
#
# Medida(media, máximo, minimo)=38.1,38.2,38.0 dB	Time=2025-04-02 19:51:36
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:038.7dB
#
# Valor medio medido=38.94 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=38.94,39.5,38.6 dB	Time=2025-04-02 19:51:37
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:038.4dB
#
# Valor medio medido=38.5 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 38.4 dB
#
# Medida(media, máximo, minimo)=38.5,38.6,38.4 dB	Time=2025-04-02 19:51:38
#
# RS232 read data:N:037.3dB
#
# RS232 read data:N:037.2dB
#
# RS232 read data:N:037.1dB
#
# Valor medio medido=37.2 dB
#
# Valor máximo medido 37.3 dB
#
# Valor minimo medido 37.1 dB
#
# Medida(media, máximo, minimo)=37.2,37.3,37.1 dB	Time=2025-04-02 19:51:39
#
# RS232 read data:N:036.0dB
#
# RS232 read data:N:047.8dB
#
# Valor medio medido=43.77 dB
#
# Valor máximo medido 47.8 dB
#
# Valor minimo medido 36.0 dB
#
# Medida(media, máximo, minimo)=43.77,47.8,36.0 dB	Time=2025-04-02 19:51:40
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:036.7dB
#
# RS232 read data:N:035.9dB
#
# Valor medio medido=37.55 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 35.9 dB
#
# Medida(media, máximo, minimo)=37.55,39.6,35.9 dB	Time=2025-04-02 19:51:41
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:035.8dB
#
# Valor medio medido=35.73 dB
#
# Valor máximo medido 35.8 dB
#
# Valor minimo medido 35.7 dB
#
# Medida(media, máximo, minimo)=35.73,35.8,35.7 dB	Time=2025-04-02 19:51:42
#
# RS232 read data:N:037.3dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=38.3 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 37.3 dB
#
# Medida(media, máximo, minimo)=38.3,39.2,37.3 dB	Time=2025-04-02 19:51:43
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:036.0dB
#
# Valor medio medido=36.18 dB
#
# Valor máximo medido 36.8 dB
#
# Valor minimo medido 35.7 dB
#
# Medida(media, máximo, minimo)=36.18,36.8,35.7 dB	Time=2025-04-02 19:51:44
#
# RS232 read data:N:036.0dB
#
# RS232 read data:N:035.0dB
#
# Valor medio medido=35.51 dB
#
# Valor máximo medido 36.0 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo, minimo)=35.51,36.0,35.0 dB	Time=2025-04-02 19:51:45
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:035.9dB
#
# Valor medio medido=35.25 dB
#
# Valor máximo medido 35.9 dB
#
# Valor minimo medido 34.5 dB
#
# Medida(media, máximo, minimo)=35.25,35.9,34.5 dB	Time=2025-04-02 19:51:46
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:042.7dB
#
# RS232 read data:N:038.5dB
#
# Valor medio medido=39.45 dB
#
# Valor máximo medido 42.7 dB
#
# Valor minimo medido 35.7 dB
#
# Medida(media, máximo, minimo)=39.45,42.7,35.7 dB	Time=2025-04-02 19:51:47
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:035.9dB
#
# Valor medio medido=35.75 dB
#
# Valor máximo medido 35.9 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=35.75,35.9,35.6 dB	Time=2025-04-02 19:51:48
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:035.2dB
#
# Valor medio medido=34.9 dB
#
# Valor máximo medido 35.2 dB
#
# Valor minimo medido 34.5 dB
#
# Medida(media, máximo, minimo)=34.9,35.2,34.5 dB	Time=2025-04-02 19:51:49
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=34.44 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 34.1 dB
#
# Medida(media, máximo, minimo)=34.44,34.6,34.1 dB	Time=2025-04-02 19:51:50
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:034.7dB
#
# Valor medio medido=34.8 dB
#
# Valor máximo medido 34.9 dB
#
# Valor minimo medido 34.7 dB
#
# Medida(media, máximo, minimo)=34.8,34.9,34.7 dB	Time=2025-04-02 19:51:51
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:035.2dB
#
# Valor medio medido=34.98 dB
#
# Valor máximo medido 35.5 dB
#
# Valor minimo medido 34.2 dB
#
# Medida(media, máximo, minimo)=34.98,35.5,34.2 dB	Time=2025-04-02 19:51:52
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:035.1dB
#
# Valor medio medido=35.0 dB
#
# Valor máximo medido 35.1 dB
#
# Valor minimo medido 34.9 dB
#
# Medida(media, máximo, minimo)=35.0,35.1,34.9 dB	Time=2025-04-02 19:51:53
#
# RS232 read data:N:035.9dB
#
# RS232 read data:N:035.3dB
#
# Valor medio medido=35.61 dB
#
# Valor máximo medido 35.9 dB
#
# Valor minimo medido 35.3 dB
#
# Medida(media, máximo, minimo)=35.61,35.9,35.3 dB	Time=2025-04-02 19:51:54
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:037.2dB
#
# RS232 read data:N:036.8dB
#
# Valor medio medido=36.87 dB
#
# Valor máximo medido 37.2 dB
#
# Valor minimo medido 36.6 dB
#
# Medida(media, máximo, minimo)=36.87,37.2,36.6 dB	Time=2025-04-02 19:51:55
#
# RS232 read data:N:036.3dB
#
# RS232 read data:N:037.3dB
#
# Valor medio medido=36.81 dB
#
# Valor máximo medido 37.3 dB
#
# Valor minimo medido 36.3 dB
#
# Medida(media, máximo, minimo)=36.81,37.3,36.3 dB	Time=2025-04-02 19:51:56
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=37.97 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo, minimo)=37.97,38.3,37.6 dB	Time=2025-04-02 19:51:57
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:036.7dB
#
# RS232 read data:N:036.6dB
#
# Valor medio medido=37.24 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 36.6 dB
#
# Medida(media, máximo, minimo)=37.24,38.3,36.6 dB	Time=2025-04-02 19:51:58
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:036.9dB
#
# Valor medio medido=37.0 dB
#
# Valor máximo medido 37.1 dB
#
# Valor minimo medido 36.9 dB
#
# Medida(media, máximo, minimo)=37.0,37.1,36.9 dB	Time=2025-04-02 19:51:59
#
# RS232 read data:N:036.3dB
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:036.9dB
#
# Valor medio medido=36.28 dB
#
# Valor máximo medido 36.9 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=36.28,36.9,35.6 dB	Time=2025-04-02 19:52:00
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:036.6dB
#
# Valor medio medido=36.7 dB
#
# Valor máximo medido 36.8 dB
#
# Valor minimo medido 36.6 dB
#
# Medida(media, máximo, minimo)=36.7,36.8,36.6 dB	Time=2025-04-02 19:52:01
#
# RS232 read data:N:036.7dB
#
# RS232 read data:N:037.9dB
#
# RS232 read data:N:036.3dB
#
# Valor medio medido=36.99 dB
#
# Valor máximo medido 37.9 dB
#
# Valor minimo medido 36.3 dB
#
# Medida(media, máximo, minimo)=36.99,37.9,36.3 dB	Time=2025-04-02 19:52:02
#
# RS232 read data:N:037.5dB
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:036.5dB
#
# Valor medio medido=36.88 dB
#
# Valor máximo medido 37.5 dB
#
# Valor minimo medido 36.5 dB
#
# Medida(media, máximo, minimo)=36.88,37.5,36.5 dB	Time=2025-04-02 19:52:03
#
# RS232 read data:N:037.0dB
#
# RS232 read data:N:037.4dB
#
# Valor medio medido=37.2 dB
#
# Valor máximo medido 37.4 dB
#
# Valor minimo medido 37.0 dB
#
# Medida(media, máximo, minimo)=37.2,37.4,37.0 dB	Time=2025-04-02 19:52:04
#
# RS232 read data:N:036.1dB
#
# RS232 read data:N:037.4dB
#
# RS232 read data:N:037.6dB
#
# Valor medio medido=37.06 dB
#
# Valor máximo medido 37.6 dB
#
# Valor minimo medido 36.1 dB
#
# Medida(media, máximo, minimo)=37.06,37.6,36.1 dB	Time=2025-04-02 19:52:05
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=39.31 dB
#
# Valor máximo medido 39.7 dB
#
# Valor minimo medido 38.9 dB
#
# Medida(media, máximo, minimo)=39.31,39.7,38.9 dB	Time=2025-04-02 19:52:06
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:038.1dB
#
# Valor medio medido=38.41 dB
#
# Valor máximo medido 38.8 dB
#
# Valor minimo medido 38.1 dB
#
# Medida(media, máximo, minimo)=38.41,38.8,38.1 dB	Time=2025-04-02 19:52:07
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:037.5dB
#
# Valor medio medido=38.01 dB
#
# Valor máximo medido 38.5 dB
#
# Valor minimo medido 37.5 dB
#
# Medida(media, máximo, minimo)=38.01,38.5,37.5 dB	Time=2025-04-02 19:52:08
#
# RS232 read data:N:037.4dB
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:037.7dB
#
# Valor medio medido=37.84 dB
#
# Valor máximo medido 38.4 dB
#
# Valor minimo medido 37.4 dB
#
# Medida(media, máximo, minimo)=37.84,38.4,37.4 dB	Time=2025-04-02 19:52:09
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:037.0dB
#
# Valor medio medido=37.31 dB
#
# Valor máximo medido 37.6 dB
#
# Valor minimo medido 37.0 dB
#
# Medida(media, máximo, minimo)=37.31,37.6,37.0 dB	Time=2025-04-02 19:52:10
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:036.3dB
#
# RS232 read data:N:036.7dB
#
# Valor medio medido=36.18 dB
#
# Valor máximo medido 36.7 dB
#
# Valor minimo medido 35.5 dB
#
# Medida(media, máximo, minimo)=36.18,36.7,35.5 dB	Time=2025-04-02 19:52:11
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:035.1dB
#
# RS232 read data:N:035.7dB
#
# Valor medio medido=35.44 dB
#
# Valor máximo medido 35.7 dB
#
# Valor minimo medido 35.1 dB
#
# Medida(media, máximo, minimo)=35.44,35.7,35.1 dB	Time=2025-04-02 19:52:12
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:034.9dB
#
# Valor medio medido=35.05 dB
#
# Valor máximo medido 35.2 dB
#
# Valor minimo medido 34.9 dB
#
# Medida(media, máximo, minimo)=35.05,35.2,34.9 dB	Time=2025-04-02 19:52:13
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:036.1dB
#
# Valor medio medido=35.58 dB
#
# Valor máximo medido 36.1 dB
#
# Valor minimo medido 34.9 dB
#
# Medida(media, máximo, minimo)=35.58,36.1,34.9 dB	Time=2025-04-02 19:52:14
#
# RS232 read data:N:035.1dB
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:035.4dB
#
# Valor medio medido=35.4 dB
#
# Valor máximo medido 35.7 dB
#
# Valor minimo medido 35.1 dB
#
# Medida(media, máximo, minimo)=35.4,35.7,35.1 dB	Time=2025-04-02 19:52:15
#
# RS232 read data:N:036.0dB
#
# RS232 read data:N:036.6dB
#
# Valor medio medido=36.31 dB
#
# Valor máximo medido 36.6 dB
#
# Valor minimo medido 36.0 dB
#
# Medida(media, máximo, minimo)=36.31,36.6,36.0 dB	Time=2025-04-02 19:52:16
#
# RS232 read data:N:037.0dB
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:038.0dB
#
# Valor medio medido=36.89 dB
#
# Valor máximo medido 38.0 dB
#
# Valor minimo medido 35.5 dB
#
# Medida(media, máximo, minimo)=36.89,38.0,35.5 dB	Time=2025-04-02 19:52:17
#
# RS232 read data:N:036.5dB
#
# RS232 read data:N:037.5dB
#
# Valor medio medido=37.01 dB
#
# Valor máximo medido 37.5 dB
#
# Valor minimo medido 36.5 dB
#
# Medida(media, máximo, minimo)=37.01,37.5,36.5 dB	Time=2025-04-02 19:52:18
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:038.2dB
#
# Valor medio medido=38.31 dB
#
# Valor máximo medido 38.7 dB
#
# Valor minimo medido 38.0 dB
#
# Medida(media, máximo, minimo)=38.31,38.7,38.0 dB	Time=2025-04-02 19:52:19
#
# RS232 read data:N:037.4dB
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:038.7dB
#
# Valor medio medido=38.61 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 37.4 dB
#
# Medida(media, máximo, minimo)=38.61,39.6,37.4 dB	Time=2025-04-02 19:52:20
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=39.6 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=39.6,40.5,38.6 dB	Time=2025-04-02 19:52:21
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=39.55 dB
#
# Valor máximo medido 39.8 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=39.55,39.8,39.3 dB	Time=2025-04-02 19:52:22
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:036.5dB
#
# RS232 read data:N:036.3dB
#
# Valor medio medido=36.97 dB
#
# Valor máximo medido 38.0 dB
#
# Valor minimo medido 36.3 dB
#
# Medida(media, máximo, minimo)=36.97,38.0,36.3 dB	Time=2025-04-02 19:52:23
#
# RS232 read data:N:037.0dB
#
# RS232 read data:N:036.5dB
#
# RS232 read data:N:035.5dB
#
# Valor medio medido=36.36 dB
#
# Valor máximo medido 37.0 dB
#
# Valor minimo medido 35.5 dB
#
# Medida(media, máximo, minimo)=36.36,37.0,35.5 dB	Time=2025-04-02 19:52:24
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:035.8dB
#
# Valor medio medido=37.85 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 35.8 dB
#
# Medida(media, máximo, minimo)=37.85,39.5,35.8 dB	Time=2025-04-02 19:52:25
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:036.1dB
#
# Valor medio medido=35.84 dB
#
# Valor máximo medido 36.1 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=35.84,36.1,35.6 dB	Time=2025-04-02 19:52:26
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:035.9dB
#
# RS232 read data:N:035.1dB
#
# Valor medio medido=35.61 dB
#
# Valor máximo medido 35.9 dB
#
# Valor minimo medido 35.1 dB
#
# Medida(media, máximo, minimo)=35.61,35.9,35.1 dB	Time=2025-04-02 19:52:27
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:036.4dB
#
# Valor medio medido=35.68 dB
#
# Valor máximo medido 36.4 dB
#
# Valor minimo medido 34.9 dB
#
# Medida(media, máximo, minimo)=35.68,36.4,34.9 dB	Time=2025-04-02 19:52:28
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:035.5dB
#
# Valor medio medido=35.27 dB
#
# Valor máximo medido 35.5 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo, minimo)=35.27,35.5,35.0 dB	Time=2025-04-02 19:52:29
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.74 dB
#
# Valor máximo medido 35.0 dB
#
# Valor minimo medido 34.4 dB
#
# Medida(media, máximo, minimo)=34.74,35.0,34.4 dB	Time=2025-04-02 19:52:30
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:035.8dB
#
# Valor medio medido=35.41 dB
#
# Valor máximo medido 35.8 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo, minimo)=35.41,35.8,35.0 dB	Time=2025-04-02 19:52:31
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:035.0dB
#
# Valor medio medido=35.14 dB
#
# Valor máximo medido 35.6 dB
#
# Valor minimo medido 34.8 dB
#
# Medida(media, máximo, minimo)=35.14,35.6,34.8 dB	Time=2025-04-02 19:52:32
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:035.8dB
#
# Valor medio medido=37.97 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 35.8 dB
#
# Medida(media, máximo, minimo)=37.97,39.6,35.8 dB	Time=2025-04-02 19:52:33
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:035.0dB
#
# Valor medio medido=35.0 dB
#
# Valor máximo medido 35.0 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo, minimo)=35.0,35.0,35.0 dB	Time=2025-04-02 19:52:34
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:035.2dB
#
# Valor medio medido=35.07 dB
#
# Valor máximo medido 35.3 dB
#
# Valor minimo medido 34.7 dB
#
# Medida(media, máximo, minimo)=35.07,35.3,34.7 dB	Time=2025-04-02 19:52:35
#
# RS232 read data:N:036.1dB
#
# RS232 read data:N:035.5dB
#
# Valor medio medido=35.81 dB
#
# Valor máximo medido 36.1 dB
#
# Valor minimo medido 35.5 dB
#
# Medida(media, máximo, minimo)=35.81,36.1,35.5 dB	Time=2025-04-02 19:52:36
#
# RS232 read data:N:037.3dB
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:035.2dB
#
# Valor medio medido=36.08 dB
#
# Valor máximo medido 37.3 dB
#
# Valor minimo medido 35.2 dB
#
# Medida(media, máximo, minimo)=36.08,37.3,35.2 dB	Time=2025-04-02 19:52:37
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:035.5dB
#
# Valor medio medido=35.24 dB
#
# Valor máximo medido 35.6 dB
#
# Valor minimo medido 34.6 dB
#
# Medida(media, máximo, minimo)=35.24,35.6,34.6 dB	Time=2025-04-02 19:52:38
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:036.8dB
#
# Valor medio medido=36.8 dB
#
# Valor máximo medido 36.8 dB
#
# Valor minimo medido 36.8 dB
#
# Medida(media, máximo, minimo)=36.8,36.8,36.8 dB	Time=2025-04-02 19:52:39
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:036.0dB
#
# Valor medio medido=35.77 dB
#
# Valor máximo medido 36.0 dB
#
# Valor minimo medido 35.5 dB
#
# Medida(media, máximo, minimo)=35.77,36.0,35.5 dB	Time=2025-04-02 19:52:40
#
# RS232 read data:N:036.9dB
#
# RS232 read data:N:040.7dB
#
# Valor medio medido=39.01 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 36.9 dB
#
# Medida(media, máximo, minimo)=39.01,40.7,36.9 dB	Time=2025-04-02 19:52:41
#
# RS232 read data:N:040.9dB
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=39.53 dB
#
# Valor máximo medido 40.9 dB
#
# Valor minimo medido 38.7 dB
#
# Medida(media, máximo, minimo)=39.53,40.9,38.7 dB	Time=2025-04-02 19:52:42
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.06 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 38.7 dB
#
# Medida(media, máximo, minimo)=39.06,39.4,38.7 dB	Time=2025-04-02 19:52:43
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:037.4dB
#
# Valor medio medido=37.84 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 37.4 dB
#
# Medida(media, máximo, minimo)=37.84,38.3,37.4 dB	Time=2025-04-02 19:52:44
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:035.6dB
#
# Valor medio medido=35.41 dB
#
# Valor máximo medido 35.8 dB
#
# Valor minimo medido 34.8 dB
#
# Medida(media, máximo, minimo)=35.41,35.8,34.8 dB	Time=2025-04-02 19:52:45
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:035.4dB
#
# Valor medio medido=35.5 dB
#
# Valor máximo medido 35.6 dB
#
# Valor minimo medido 35.4 dB
#
# ...
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:036.8dB
#
# Valor medio medido=35.73 dB
#
# Valor máximo medido 36.8 dB
#
# Valor minimo medido 34.5 dB
#
# Medida(media, máximo, minimo)=35.73,36.8,34.5 dB	Time=2025-04-02 19:53:12
#
# RS232 read data:N:036.7dB
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:036.5dB
#
# Valor medio medido=36.28 dB
#
# Valor máximo medido 36.7 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=36.28,36.7,35.6 dB	Time=2025-04-02 19:53:13
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=37.36 dB
#
# Valor máximo medido 39.9 dB
#
# Valor minimo medido 35.7 dB
#
# Medida(media, máximo, minimo)=37.36,39.9,35.7 dB	Time=2025-04-02 19:53:14
#
# RS232 read data:N:036.4dB
#
# RS232 read data:N:035.3dB
#
# Valor medio medido=35.87 dB
#
# Valor máximo medido 36.4 dB
#
# Valor minimo medido 35.3 dB
#
# Medida(media, máximo, minimo)=35.87,36.4,35.3 dB	Time=2025-04-02 19:53:15
#
# RS232 read data:N:037.2dB
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:034.7dB
#
# Valor medio medido=35.68 dB
#
# Valor máximo medido 37.2 dB
#
# Valor minimo medido 34.7 dB
#
# Medida(media, máximo, minimo)=35.68,37.2,34.7 dB	Time=2025-04-02 19:53:16
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=35.84 dB
#
# Valor máximo medido 37.6 dB
#
# Valor minimo medido 34.8 dB
#
# Medida(media, máximo, minimo)=35.84,37.6,34.8 dB	Time=2025-04-02 19:53:17
#
# RS232 read data:N:037.3dB
#
# RS232 read data:N:037.1dB
#
# Valor medio medido=37.2 dB
#
# Valor máximo medido 37.3 dB
#
# Valor minimo medido 37.1 dB
#
# Medida(media, máximo, minimo)=37.2,37.3,37.1 dB	Time=2025-04-02 19:53:18
#
# RS232 read data:N:035.1dB
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:034.9dB
#
# Valor medio medido=36.73 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 34.9 dB
#
# Medida(media, máximo, minimo)=36.73,39.4,34.9 dB	Time=2025-04-02 19:53:19
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=34.14 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=34.14,34.4,33.7 dB	Time=2025-04-02 19:53:20
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=34.2 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 34.2 dB
#
# Medida(media, máximo, minimo)=34.2,34.2,34.2 dB	Time=2025-04-02 19:53:21
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.7dB
#
# Valor medio medido=34.11 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.11,34.7,33.6 dB	Time=2025-04-02 19:53:22
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=34.57 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 34.1 dB
#
# Medida(media, máximo, minimo)=34.57,34.8,34.1 dB	Time=2025-04-02 19:53:23
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=34.41 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=34.41,34.8,34.0 dB	Time=2025-04-02 19:53:24
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:038.2dB
#
# Valor medio medido=36.01 dB
#
# Valor máximo medido 38.2 dB
#
# Valor minimo medido 34.3 dB
#
# Medida(media, máximo, minimo)=36.01,38.2,34.3 dB	Time=2025-04-02 19:53:25
#
# RS232 read data:N:035.1dB
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=35.03 dB
#
# Valor máximo medido 35.2 dB
#
# Valor minimo medido 34.8 dB
#
# Medida(media, máximo, minimo)=35.03,35.2,34.8 dB	Time=2025-04-02 19:53:26
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=34.9 dB
#
# Valor máximo medido 35.0 dB
#
# Valor minimo medido 34.8 dB
#
# Medida(media, máximo, minimo)=34.9,35.0,34.8 dB	Time=2025-04-02 19:53:27
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=34.1 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=34.1,34.3,33.7 dB	Time=2025-04-02 19:53:28
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:035.0dB
#
# Valor medio medido=34.45 dB
#
# Valor máximo medido 35.0 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.45,35.0,33.6 dB	Time=2025-04-02 19:53:29
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:037.8dB
#
# Valor medio medido=38.42 dB
#
# Valor máximo medido 39.0 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=38.42,39.0,37.8 dB	Time=2025-04-02 19:53:30
#
# RS232 read data:N:035.4dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.6dB
#
# Valor medio medido=34.78 dB
#
# Valor máximo medido 35.4 dB
#
# Valor minimo medido 34.3 dB
#
# Medida(media, máximo, minimo)=34.78,35.4,34.3 dB	Time=2025-04-02 19:53:31
#
# RS232 read data:N:036.2dB
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:035.6dB
#
# Valor medio medido=37.11 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=37.11,39.1,35.6 dB	Time=2025-04-02 19:53:32
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=38.11 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 36.6 dB
#
# Medida(media, máximo, minimo)=38.11,39.4,36.6 dB	Time=2025-04-02 19:53:33
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:035.9dB
#
# Valor medio medido=35.31 dB
#
# Valor máximo medido 35.9 dB
#
# Valor minimo medido 34.7 dB
#
# Medida(media, máximo, minimo)=35.31,35.9,34.7 dB	Time=2025-04-02 19:53:34
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:036.7dB
#
# Valor medio medido=36.22 dB
#
# Valor máximo medido 36.7 dB
#
# Valor minimo medido 35.3 dB
#
# Medida(media, máximo, minimo)=36.22,36.7,35.3 dB	Time=2025-04-02 19:53:35
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=34.56 dB
#
# Valor máximo medido 34.9 dB
#
# Valor minimo medido 34.2 dB
#
# Medida(media, máximo, minimo)=34.56,34.9,34.2 dB	Time=2025-04-02 19:53:36
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:034.6dB
#
# Valor medio medido=34.8 dB
#
# Valor máximo medido 35.0 dB
#
# Valor minimo medido 34.6 dB
#
# Medida(media, máximo, minimo)=34.8,35.0,34.6 dB	Time=2025-04-02 19:53:37
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.24 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.24,34.5,33.9 dB	Time=2025-04-02 19:53:38
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:037.1dB
#
# Valor medio medido=35.9 dB
#
# Valor máximo medido 37.1 dB
#
# Valor minimo medido 34.5 dB
#
# Medida(media, máximo, minimo)=35.9,37.1,34.5 dB	Time=2025-04-02 19:53:39
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=34.61 dB
#
# Valor máximo medido 35.2 dB
#
# Valor minimo medido 34.3 dB
#
# Medida(media, máximo, minimo)=34.61,35.2,34.3 dB	Time=2025-04-02 19:53:40
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:036.0dB
#
# Valor medio medido=35.35 dB
#
# Valor máximo medido 36.0 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo, minimo)=35.35,36.0,35.0 dB	Time=2025-04-02 19:53:41
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:034.7dB
#
# Valor medio medido=34.95 dB
#
# Valor máximo medido 35.2 dB
#
# Valor minimo medido 34.7 dB
#
# Medida(media, máximo, minimo)=34.95,35.2,34.7 dB	Time=2025-04-02 19:53:42
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:036.5dB
#
# RS232 read data:N:045.7dB
#
# Valor medio medido=40.41 dB
#
# Valor máximo medido 45.7 dB
#
# Valor minimo medido 34.8 dB
#
# Medida(media, máximo, minimo)=40.41,45.7,34.8 dB	Time=2025-04-02 19:53:43
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:035.4dB
#
# Valor medio medido=37.51 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 35.4 dB
#
# Medida(media, máximo, minimo)=37.51,39.2,35.4 dB	Time=2025-04-02 19:53:44
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=39.82 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=39.82,41.0,38.6 dB	Time=2025-04-02 19:53:45
#
# RS232 read data:N:036.5dB
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:040.8dB
#
# Valor medio medido=39.22 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 36.5 dB
#
# Medida(media, máximo, minimo)=39.22,40.8,36.5 dB	Time=2025-04-02 19:53:46
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=38.08 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 36.8 dB
#
# Medida(media, máximo, minimo)=38.08,39.2,36.8 dB	Time=2025-04-02 19:53:47
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:043.1dB
#
# Valor medio medido=40.3 dB
#
# Valor máximo medido 43.1 dB
#
# Valor minimo medido 38.0 dB
#
# Medida(media, máximo, minimo)=40.3,43.1,38.0 dB	Time=2025-04-02 19:53:48
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=39.71 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.71,40.2,39.2 dB	Time=2025-04-02 19:53:49
#
# RS232 read data:N:037.0dB
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=38.03 dB
#
# Valor máximo medido 38.6 dB
#
# Valor minimo medido 37.0 dB
#
# Medida(media, máximo, minimo)=38.03,38.6,37.0 dB	Time=2025-04-02 19:53:50
#
# RS232 read data:N:041.6dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=40.48 dB
#
# Valor máximo medido 41.6 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=40.48,41.6,39.2 dB	Time=2025-04-02 19:53:51
#
# RS232 read data:N:037.5dB
#
# RS232 read data:N:037.9dB
#
# RS232 read data:N:036.4dB
#
# Valor medio medido=37.29 dB
#
# Valor máximo medido 37.9 dB
#
# Valor minimo medido 36.4 dB
#
# Medida(media, máximo, minimo)=37.29,37.9,36.4 dB	Time=2025-04-02 19:53:52
#
# RS232 read data:N:036.2dB
#
# RS232 read data:N:035.4dB
#
# Valor medio medido=35.81 dB
#
# Valor máximo medido 36.2 dB
#
# Valor minimo medido 35.4 dB
#
# Medida(media, máximo, minimo)=35.81,36.2,35.4 dB	Time=2025-04-02 19:53:53
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=36.09 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=36.09,38.3,33.9 dB	Time=2025-04-02 19:53:54
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:035.9dB
#
# Valor medio medido=36.36 dB
#
# Valor máximo medido 36.8 dB
#
# Valor minimo medido 35.9 dB
#
# Medida(media, máximo, minimo)=36.36,36.8,35.9 dB	Time=2025-04-02 19:53:55
#
# RS232 read data:N:036.2dB
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:035.8dB
#
# Valor medio medido=36.38 dB
#
# Valor máximo medido 37.1 dB
#
# Valor minimo medido 35.8 dB
#
# Medida(media, máximo, minimo)=36.38,37.1,35.8 dB	Time=2025-04-02 19:53:56
#
# RS232 read data:N:036.0dB
#
# RS232 read data:N:036.9dB
#
# RS232 read data:N:036.1dB
#
# Valor medio medido=36.34 dB
#
# Valor máximo medido 36.9 dB
#
# Valor minimo medido 36.0 dB
#
# Medida(media, máximo, minimo)=36.34,36.9,36.0 dB	Time=2025-04-02 19:53:57
#
# RS232 read data:N:035.9dB
#
# RS232 read data:N:037.1dB
#
# Valor medio medido=36.52 dB
#
# Valor máximo medido 37.1 dB
#
# Valor minimo medido 35.9 dB
#
# Medida(media, máximo, minimo)=36.52,37.1,35.9 dB	Time=2025-04-02 19:53:58
#
# RS232 read data:N:036.5dB
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:037.1dB
#
# Valor medio medido=37.3 dB
#
# Valor máximo medido 38.2 dB
#
# Valor minimo medido 36.5 dB
#
# Medida(media, máximo, minimo)=37.3,38.2,36.5 dB	Time=2025-04-02 19:53:59
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:036.6dB
#
# Valor medio medido=36.11 dB
#
# Valor máximo medido 36.6 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=36.11,36.6,35.6 dB	Time=2025-04-02 19:54:00
#
# RS232 read data:N:035.4dB
#
# RS232 read data:N:035.9dB
#
# RS232 read data:N:035.1dB
#
# Valor medio medido=35.47 dB
#
# Valor máximo medido 35.9 dB
#
# Valor minimo medido 35.1 dB
#
# Medida(media, máximo, minimo)=35.47,35.9,35.1 dB	Time=2025-04-02 19:54:01
#
# RS232 read data:N:036.0dB
#
# RS232 read data:N:035.4dB
#
# RS232 read data:N:035.3dB
#
# Valor medio medido=35.57 dB
#
# Valor máximo medido 36.0 dB
#
# Valor minimo medido 35.3 dB
#
# Medida(media, máximo, minimo)=35.57,36.0,35.3 dB	Time=2025-04-02 19:54:02
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:034.9dB
#
# Valor medio medido=34.85 dB
#
# Valor máximo medido 34.9 dB
#
# Valor minimo medido 34.8 dB
#
# Medida(media, máximo, minimo)=34.85,34.9,34.8 dB	Time=2025-04-02 19:54:03
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:035.1dB
#
# RS232 read data:N:035.6dB
#
# Valor medio medido=35.44 dB
#
# Valor máximo medido 35.6 dB
#
# Valor minimo medido 35.1 dB
#
# Medida(media, máximo, minimo)=35.44,35.6,35.1 dB	Time=2025-04-02 19:54:04
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=35.02 dB
#
# Valor máximo medido 35.7 dB
#
# Valor minimo medido 34.3 dB
#
# Medida(media, máximo, minimo)=35.02,35.7,34.3 dB	Time=2025-04-02 19:54:05
#
# RS232 read data:N:036.3dB
#
# RS232 read data:N:035.0dB
#
# Valor medio medido=35.67 dB
#
# Valor máximo medido 36.3 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo, minimo)=35.67,36.3,35.0 dB	Time=2025-04-02 19:54:06
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:036.2dB
#
# RS232 read data:N:035.8dB
#
# Valor medio medido=35.77 dB
#
# Valor máximo medido 36.2 dB
#
# Valor minimo medido 35.3 dB
#
# Medida(media, máximo, minimo)=35.77,36.2,35.3 dB	Time=2025-04-02 19:54:07
#
# RS232 read data:N:035.9dB
#
# RS232 read data:N:035.4dB
#
# RS232 read data:N:036.7dB
#
# Valor medio medido=36.02 dB
#
# Valor máximo medido 36.7 dB
#
# Valor minimo medido 35.4 dB
#
# Medida(media, máximo, minimo)=36.02,36.7,35.4 dB	Time=2025-04-02 19:54:08
#
# RS232 read data:N:036.0dB
#
# RS232 read data:N:035.2dB
#
# Valor medio medido=35.61 dB
#
# Valor máximo medido 36.0 dB
#
# Valor minimo medido 35.2 dB
#
# Medida(media, máximo, minimo)=35.61,36.0,35.2 dB	Time=2025-04-02 19:54:09
#
# RS232 read data:N:035.1dB
#
# RS232 read data:N:035.1dB
#
# RS232 read data:N:035.1dB
#
# Valor medio medido=35.1 dB
#
# Valor máximo medido 35.1 dB
#
# Valor minimo medido 35.1 dB
#
# Medida(media, máximo, minimo)=35.1,35.1,35.1 dB	Time=2025-04-02 19:54:10
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:036.5dB
#
# RS232 read data:N:035.9dB
#
# Valor medio medido=35.98 dB
#
# Valor máximo medido 36.5 dB
#
# Valor minimo medido 35.5 dB
#
# Medida(media, máximo, minimo)=35.98,36.5,35.5 dB	Time=2025-04-02 19:54:11
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:035.6dB
#
# Valor medio medido=35.55 dB
#
# Valor máximo medido 35.6 dB
#
# Valor minimo medido 35.5 dB
#
# Medida(media, máximo, minimo)=35.55,35.6,35.5 dB	Time=2025-04-02 19:54:12
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:035.8dB
#
# Valor medio medido=35.7 dB
#
# Valor máximo medido 35.8 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=35.7,35.8,35.6 dB	Time=2025-04-02 19:54:13
#
# RS232 read data:N:037.5dB
#
# RS232 read data:N:035.7dB
#
# Valor medio medido=36.65 dB
#
# Valor máximo medido 37.5 dB
#
# Valor minimo medido 35.7 dB
#
# Medida(media, máximo, minimo)=36.65,37.5,35.7 dB	Time=2025-04-02 19:54:14
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:037.0dB
#
# Valor medio medido=36.55 dB
#
# Valor máximo medido 37.0 dB
#
# Valor minimo medido 35.8 dB
#
# Medida(media, máximo, minimo)=36.55,37.0,35.8 dB	Time=2025-04-02 19:54:15
#
# RS232 read data:N:036.3dB
#
# RS232 read data:N:036.8dB
#
# RS232 read data:N:037.5dB
#
# Valor medio medido=36.88 dB
#
# Valor máximo medido 37.5 dB
#
# Valor minimo medido 36.3 dB
#
# Medida(media, máximo, minimo)=36.88,37.5,36.3 dB	Time=2025-04-02 19:54:16
#
# RS232 read data:N:037.0dB
#
# RS232 read data:N:038.1dB
#
# Valor medio medido=37.57 dB
#
# Valor máximo medido 38.1 dB
#
# Valor minimo medido 37.0 dB
#
# Medida(media, máximo, minimo)=37.57,38.1,37.0 dB	Time=2025-04-02 19:54:17
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:038.4dB
#
# Valor medio medido=38.54 dB
#
# Valor máximo medido 39.0 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=38.54,39.0,38.2 dB	Time=2025-04-02 19:54:18
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=39.49 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=39.49,40.3,38.6 dB	Time=2025-04-02 19:54:19
#
# RS232 cerrando el puerto serie.
#
# RS232 read data:
#
# Measurements saved to log_files/medida_2/type_2 Wed 2025-04-02 19h49m19s.json

# %%
import matplotlib.pyplot as plt

pic_path = 'Pics/medida_2/type_2 '+format_time(time.time(), True)

# Load the measurements from the JSON file.
with open(json_file, 'r') as f:
    measurements = json.load(f)

times = [m["time"] for m in measurements]
means = [m["mean"] for m in measurements]
maxs = [m["max"] for m in measurements]
mins = [m["min"] for m in measurements]

m_number = list(range(0,len(measurements)))

# Plot the measurements
plt.figure(figsize=(10, 6))
plt.plot(m_number, means, label="Mean", color="blue")
plt.plot(m_number, maxs, label="Max", color="red", linestyle="--")
plt.plot(m_number, mins, label="Min", color="green", linestyle="--")
plt.xlim(0, len(measurements)-1)
plt.ylim(30, 60)
plt.xlabel("Samples")
plt.ylabel("Sound Level (dB)")
plt.title("Sound Level Measurements Over Time")
plt.legend()
plt.grid(True)
plt.savefig(pic_path+'.png')
plt.show()

# %% [markdown]
# ## Ejemplo de lectura directa del Serial y almacenamiento en un vector.

# %%
import serial
import math

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'


# Sound level meter.
port_AZ8922 = SELECTED_PORT
ser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port


# Reset the arrays.
sound_level = []

#while(ser.connected):
for x in range(10):
    output = ser.readline().decode('utf-8', 'ignore')
    output = output.strip()
    #print("RS232 read data:"+str(output)+"\n")
    if output.startswith('N:') and output.endswith('dB'):
        salida_texto=float(output.split(':')[1].split('dB')[0])
        sound_level.append(salida_texto) # Para concatenar los valores y formar un Vector/Array
        print("RS232 db="+str(salida_texto)+"\n")     
    
ser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el 
#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia
#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.


# Round up.
#sound_level_mean = round(sound_level_mean,2)
#print("Sound Level(Media)="+str(sound_level_mean)+"\n") 

#Calculamos el máximo en dB
sound_level_max = max(sound_level) #Esto es el máximo de un vector
print(Green + "Sound Level(Max)="+str(sound_level_max)+" db\n") 

#Calculamos el mínomo en dB
sound_level_min = min(sound_level)
print(Magenta+"Sound Level(Min)="+str(sound_level_min)+" db\n") 

#Calculamos la suma de los valores sin decibelios
sound_level_linear = [math.pow(10,x/20) for x in sound_level] 
print(Blue +"Sound Level(linear)="+str(sound_level_linear)+"\n") 

#Pasamos la suma de lo medido en dB
sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
sound_level_mean = 20*math.log10(sound_level_mean)
print(Red + "Sound Level(Mean)="+str(sound_level_mean)+" db\n")
# Out:
# RS232 db=37.7
#
# RS232 db=37.1
#
# RS232 db=37.9
#
# RS232 db=39.2
#
# RS232 db=36.9
#
# RS232 db=37.4
#
# RS232 db=36.4
#
# RS232 db=36.9
#
# RS232 db=37.0
#
# RS232 db=36.5
#
# Sound Level(Max)=39.2 db
#
# Sound Level(Min)=36.4 db
#
# Sound Level(linear)=[76.73614893618193, 71.6143410212902, 78.52356346100719, 91.20108393559102, 69.98419960022734, 74.13102413009173, 66.06934480075958, 69.98419960022734, 70.79457843841381, 66.83439175686145]
#
# Sound Level(Mean)=37.336055901996424 db
