# %% [markdown]
# # Medida 2
# ## Piso con ventana abierta
#
#  **Ubicacion**: Piso residencial (interior) con ventana abierta.
#
#  **Metodologia**:
#  * Medicion de los niveles de presion sonora en el interior del piso, con el fin de cuantificar la intrusion de ruido exterior (trafico, obras urbanas, vecindario etc.).
#  * Toma de mediciones en tres franjas horarias diurnas: mañana (10:00-13:00), siesta (14:00-17:00) y tarde (18:00-20:00).
#  * Toma de mediciones en dos franjas horarias nocturnas: tarde-noche (20:00-22:00) y noche (00:00-02:00).
#  * Toma de mediciones en diferentes dıas de la semana: fin de semana (sabado) y un dıa laboral.

# %%
import os

# initialize directory to store json files with sampled data. 
path = 'log_files/medida_2'
if not os.path.exists(path):
    os.makedirs(path)

# global port variable
SELECTED_PORT = 'COM3'

# %%
import threading
import time
import math
import serial  
import logging
import json

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'

def format_time(unix_epoch, isFileName=False):
    """format time in unix epoch to human-readable values"""
    if isFileName:
        day = time.ctime(unix_epoch)[:3]
        formatted_time = day+time.strftime(" %Y-%m-%d %Hh%Mm%Ss", time.localtime(unix_epoch))
        return formatted_time
    formatted_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(unix_epoch))
    return str(formatted_time)

#_____________________________________________________________________________________________________________________

class AZ8922:
    """class for sonometer object"""

    def __init__(self, port):
        self.port = port
        self.ser = None
        self.running = True
        self.connected = True
        self.sound_level = []
        print(Green+"AZ8922: Iniciando la clase.\n",flush=True)

    def get_sonometry(self):
        """returns mean and max value of the measurement"""
        if self.sound_level:
            sound_level_max = max(self.sound_level)
            sound_level_min = min(self.sound_level)
            sound_level_linear = [math.pow(10,x/20) for x in self.sound_level] 
            sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
            sound_level_mean = 20*math.log10(sound_level_mean) 
        else:
            sound_level_max = -1
            sound_level_min = -1
            sound_level_mean = -1
            
        # Check if the AZ8922 is off.
        # if self.connected and not self.sound_level: logging.warning('AZ8922 is off.')
        
        # Reset the arrays.
        self.sound_level = []
        
        # Round up.
        sound_level_mean = round(sound_level_mean,2)
        
        # logging.info(f'Sonometry AZ8922:{sound_level_mean}') 
        # logging.info('Sonometry AZ8922:%f' % sound_level_mean) 
        # if not self.connected: logging.warning('AZ8922 is disconnected.')
         
        return sound_level_mean, sound_level_max, sound_level_min

    def run_thread(self):
        """run thread to capture measurements from sonometer"""
        thread = threading.Thread(target=self.sonometro_thread, daemon=True)
        thread.start()

    def stop_thread(self):
        """stop sonometer thread"""
        self.running = False
        self.connected = False
        if self.ser is not None:
            self.ser.close()
            print(Red+"RS232 cerrando el puerto serie.\n",flush=True)
            

    def sonometro_thread(self):
        """reads values from serial port and updates sound level attribute"""
        while self.running:
            try:
                # If disconnected, check connection every 5 seconds.
                if not self.connected: time.sleep(5)
                self.ser = serial.Serial(self.port, 2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)
                self.connected = True
                print(Yellow+"RS232 abriendo el puerto serie.\n",flush=True)

                #Para sacar valores intermedios
                #print("Self.conected="+str(self.connected)+"\n")
                #print("self.ser.in_waiting="+str(self.ser.in_waiting)+"\n")
                #print("self.running="+str(self.running)+"\n")
                
                #while(self.connected and self.ser.in_waiting and self.running):
                while(self.connected and self.running):
                    output = self.ser.readline().decode('utf-8', 'ignore')
                    output = output.strip()
                    print(Yellow+"RS232 read data:"+str(output)+"\n",flush=True)
                    if output.startswith('N:') and output.endswith('dB'):
                        self.sound_level.append(float(output.split(':')[1].split('dB')[0]))

            except (serial.serialutil.SerialException, OSError):
                # Thread is not halted upon sensor disconnection.
                self.connected = False

# %% [markdown]
# ## Ejemplo toma de 10 medidas

# %%
# User Params.
MEASURE_PERIOD = 1  # How often (seconds) we poll for measurements.
log_file = 'log_files/log.txt'
json_file = path+'/type_1 '+format_time(time.time(), True)+'.json'

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  # Thread running condition.


#Llamada a la función y crea objeto de la clase AZ8922
port_AZ8922 = SELECTED_PORT
sound_level_meter = AZ8922(port_AZ8922)

print(Green+"Arrancamos el proceso para medir.\n")
sound_level_meter.run_thread()

# List to store measurements.
measurements = []

# Main thread.
for x in range(10):

        time.sleep(MEASURE_PERIOD)
        current_time = format_time(time.time())

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level_media, sound_level_maximo, sound_level_minimo = sound_level_meter.get_sonometry()
        print(Grey+"Valor medio medido="+ str(sound_level_media)+ " dB\n")
        print(Grey+"Valor máximo medido "+ str(sound_level_maximo)+ " dB\n")
        print(Grey+"Valor minimo medido "+ str(sound_level_minimo)+ " dB\n")
        #print(Magenta +"Medida(media, máximo)="+ str(sound_level)+ " dB\n" )
        print(Magenta +"Medida(media, máximo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+  " dB" +Cyan+"\tTime=" + current_time+"\n")
        logging.debug("Medida(media, maximo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+  " dB    Time=" + current_time+"\n")
        
        # Store the measurement in a dictionary
        measurement = {
            "time": current_time,
            "mean": sound_level_media,
            "max": sound_level_maximo,
            "min": sound_level_minimo
        }
        measurements.append(measurement)
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()

# Save measurements to a JSON file
with open(json_file, 'w') as f:
    json.dump(measurements, f, indent=4)
print(Green + f"Measurements saved to {json_file}\n")
# Out:
# AZ8922: Iniciando la clase.
#
# Arrancamos el proceso para medir.
#
# RS232 abriendo el puerto serie.
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:035.2dB
#
# Valor medio medido=34.57 dB
#
# Valor máximo medido 35.2 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo)=34.57,35.2 dB	Time=2025-03-30 03:02:58
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.14 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo)=34.14,34.4 dB	Time=2025-03-30 03:02:59
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.7dB
#
# Valor medio medido=34.18 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo)=34.18,34.7 dB	Time=2025-03-30 03:03:00
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:035.6dB
#
# Valor medio medido=34.93 dB
#
# Valor máximo medido 35.6 dB
#
# Valor minimo medido 34.2 dB
#
# Medida(media, máximo)=34.93,35.6 dB	Time=2025-03-30 03:03:01
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:035.0dB
#
# Valor medio medido=35.4 dB
#
# Valor máximo medido 35.7 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo)=35.4,35.7 dB	Time=2025-03-30 03:03:02
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:035.1dB
#
# Valor medio medido=35.07 dB
#
# Valor máximo medido 35.2 dB
#
# Valor minimo medido 34.9 dB
#
# Medida(media, máximo)=35.07,35.2 dB	Time=2025-03-30 03:03:03
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.6 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 34.5 dB
#
# Medida(media, máximo)=34.6,34.7 dB	Time=2025-03-30 03:03:04
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=34.17 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo)=34.17,34.6 dB	Time=2025-03-30 03:03:05
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=34.07 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo)=34.07,34.3 dB	Time=2025-03-30 03:03:06
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=33.84 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo)=33.84,34.0 dB	Time=2025-03-30 03:03:07
#
# RS232 read data:
#
# RS232 cerrando el puerto serie.
#
# Measurements saved to log_files/medida_2/type_1 Sun 2025-03-30 03h02m57s.json

# %%
import matplotlib.pyplot as plt

pic_path = 'Pics/medida_2/type_1 '+format_time(time.time(), True)

# Load the measurements from the JSON file.
with open(json_file, 'r') as f:
    measurements = json.load(f)

times = [m["time"] for m in measurements]
means = [m["mean"] for m in measurements]
maxs = [m["max"] for m in measurements]
mins = [m["min"] for m in measurements]

m_number = list(range(0,len(measurements)))

# Plot the measurements
plt.figure(figsize=(10, 6))
plt.plot(m_number, means, label="Mean", color="blue")
plt.plot(m_number, maxs, label="Max", color="red", linestyle="--")
plt.plot(m_number, mins, label="Min", color="green", linestyle="--")
plt.xlim(0, len(measurements)-1)
plt.xlabel("Samples")
plt.ylabel("Sound Level (dB)")
plt.title("Sound Level Measurements Over Time")
plt.legend()
plt.grid(True)
plt.savefig(pic_path+'.png')
plt.show()

# %%
pic_path = 'Pics/medida_2/type_1_max '+format_time(time.time(), True)

plt.plot(maxs,'b',maxs,'ro') #Más opciones de plot aqui: https://matplotlib.org/tutorials/introductory/pyplot.html
plt.title('Max Sound Level sampled')
plt.ylabel('Sound Level [dB]')
plt.xlim(0, len(measurements)-1)
plt.xlabel('Samples')
plt.grid()
plt.savefig(pic_path+'.png')
plt.show()

# %% [markdown]
# ## Ejemplo toma de medidas para 5 minutos

# %%
# User Params.
MEASURE_PERIOD = 1  # How often (seconds) we poll for measurements.
log_file = 'log_files/log.txt'
json_file = path+'/type_2 '+format_time(time.time(), True)+'.json'
MEASUREMENT_DURATION = 5 * 60  # 5 minutes


# Get the start and stop time for the measurement.
start_time = time.time()
end_time = start_time + MEASUREMENT_DURATION

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  


#Llamada a la función y crea objeto de la clase AZ8922
port_AZ8922 = SELECTED_PORT
sound_level_meter = AZ8922(port_AZ8922)

print(Green+"Arrancamos el proceso para medir.\n")
sound_level_meter.run_thread()

measurements = []

# Main thread.
while time.time() < end_time:
        # Sleep for the measurement period
        time.sleep(MEASURE_PERIOD)
        current_time = format_time(time.time())

        # Store the measurement in a dictionary
        measurement = {
            "time": current_time,
            "mean": sound_level_media,
            "max": sound_level_maximo,
            "min": sound_level_minimo
        }
        measurements.append(measurement)

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level_media, sound_level_maximo, sound_level_minimo = sound_level_meter.get_sonometry()
        
        print(Grey+"Valor medio medido="+ str(sound_level_media)+ " dB\n")
        print(Grey+"Valor máximo medido "+ str(sound_level_maximo)+ " dB\n")
        print(Grey+"Valor minimo medido "+ str(sound_level_minimo)+ " dB\n")

        print(Magenta +"Medida(media, máximo, minimo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+","+ str(sound_level_minimo)+  " dB" +Cyan+"\tTime=" + current_time+"\n")
        logging.debug("Medida(media, maximo, minimo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+","+ str(sound_level_minimo)+  " dB    Time=" + current_time+"\n")
        
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()

# Save measurements to a JSON file
with open(json_file, 'w') as f:
    json.dump(measurements, f, indent=4)
print(Green + f"Measurements saved to {json_file}\n")
# Out:
# AZ8922: Iniciando la clase.
#
# Arrancamos el proceso para medir.
#
# RS232 abriendo el puerto serie.
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:035.8dB
#
# Valor medio medido=35.65 dB
#
# Valor máximo medido 35.8 dB
#
# Valor minimo medido 35.5 dB
#
# Medida(media, máximo, minimo)=35.65,35.8,35.5 dB	Time=2025-03-30 03:03:09
#
# RS232 read data:N:036.3dB
#
# RS232 read data:N:038.0dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=37.99 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 36.3 dB
#
# Medida(media, máximo, minimo)=37.99,39.4,36.3 dB	Time=2025-03-30 03:03:10
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=39.98 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.98,40.7,39.2 dB	Time=2025-03-30 03:03:11
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.21 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=39.21,39.6,38.6 dB	Time=2025-03-30 03:03:12
#
# RS232 read data:N:036.2dB
#
# RS232 read data:N:036.5dB
#
# Valor medio medido=36.35 dB
#
# Valor máximo medido 36.5 dB
#
# Valor minimo medido 36.2 dB
#
# Medida(media, máximo, minimo)=36.35,36.5,36.2 dB	Time=2025-03-30 03:03:13
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:035.9dB
#
# Valor medio medido=35.83 dB
#
# Valor máximo medido 35.9 dB
#
# Valor minimo medido 35.8 dB
#
# Medida(media, máximo, minimo)=35.83,35.9,35.8 dB	Time=2025-03-30 03:03:14
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.43 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 34.3 dB
#
# Medida(media, máximo, minimo)=34.43,34.6,34.3 dB	Time=2025-03-30 03:03:15
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:034.7dB
#
# Valor medio medido=34.55 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 34.4 dB
#
# Medida(media, máximo, minimo)=34.55,34.7,34.4 dB	Time=2025-03-30 03:03:16
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=34.13 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=34.13,34.2,34.0 dB	Time=2025-03-30 03:03:17
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.6 dB
#
# Valor máximo medido 34.9 dB
#
# Valor minimo medido 34.4 dB
#
# Medida(media, máximo, minimo)=34.6,34.9,34.4 dB	Time=2025-03-30 03:03:18
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=34.81 dB
#
# Valor máximo medido 35.2 dB
#
# Valor minimo medido 34.4 dB
#
# Medida(media, máximo, minimo)=34.81,35.2,34.4 dB	Time=2025-03-30 03:03:19
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:034.6dB
#
# Valor medio medido=34.65 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 34.6 dB
#
# Medida(media, máximo, minimo)=34.65,34.7,34.6 dB	Time=2025-03-30 03:03:20
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=33.98 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.98,34.5,33.2 dB	Time=2025-03-30 03:03:21
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.87 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.87,34.0,33.8 dB	Time=2025-03-30 03:03:22
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.3 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 34.1 dB
#
# Medida(media, máximo, minimo)=34.3,34.5,34.1 dB	Time=2025-03-30 03:03:23
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=34.31 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.31,34.8,33.9 dB	Time=2025-03-30 03:03:24
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.47 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 34.4 dB
#
# Medida(media, máximo, minimo)=34.47,34.6,34.4 dB	Time=2025-03-30 03:03:25
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=33.97 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.97,34.2,33.6 dB	Time=2025-03-30 03:03:26
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=34.46 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 34.1 dB
#
# Medida(media, máximo, minimo)=34.46,34.8,34.1 dB	Time=2025-03-30 03:03:27
#
# RS232 read data:N:035.1dB
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:035.6dB
#
# Valor medio medido=35.47 dB
#
# Valor máximo medido 35.7 dB
#
# Valor minimo medido 35.1 dB
#
# Medida(media, máximo, minimo)=35.47,35.7,35.1 dB	Time=2025-03-30 03:03:28
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=38.59 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 37.7 dB
#
# Medida(media, máximo, minimo)=38.59,39.2,37.7 dB	Time=2025-03-30 03:03:29
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:043.3dB
#
# Valor medio medido=42.31 dB
#
# Valor máximo medido 43.3 dB
#
# Valor minimo medido 41.2 dB
#
# Medida(media, máximo, minimo)=42.31,43.3,41.2 dB	Time=2025-03-30 03:03:30
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:041.9dB
#
# Valor medio medido=41.51 dB
#
# Valor máximo medido 41.9 dB
#
# Valor minimo medido 41.1 dB
#
# Medida(media, máximo, minimo)=41.51,41.9,41.1 dB	Time=2025-03-30 03:03:31
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:037.4dB
#
# Valor medio medido=39.82 dB
#
# Valor máximo medido 41.3 dB
#
# Valor minimo medido 37.4 dB
#
# Medida(media, máximo, minimo)=39.82,41.3,37.4 dB	Time=2025-03-30 03:03:32
#
# RS232 read data:N:036.5dB
#
# RS232 read data:N:036.5dB
#
# Valor medio medido=36.5 dB
#
# Valor máximo medido 36.5 dB
#
# Valor minimo medido 36.5 dB
#
# Medida(media, máximo, minimo)=36.5,36.5,36.5 dB	Time=2025-03-30 03:03:33
#
# RS232 read data:N:035.4dB
#
# RS232 read data:N:036.2dB
#
# RS232 read data:N:035.4dB
#
# Valor medio medido=35.67 dB
#
# Valor máximo medido 36.2 dB
#
# Valor minimo medido 35.4 dB
#
# Medida(media, máximo, minimo)=35.67,36.2,35.4 dB	Time=2025-03-30 03:03:34
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:035.0dB
#
# Valor medio medido=34.87 dB
#
# Valor máximo medido 35.0 dB
#
# Valor minimo medido 34.7 dB
#
# Medida(media, máximo, minimo)=34.87,35.0,34.7 dB	Time=2025-03-30 03:03:35
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:035.0dB
#
# Valor medio medido=34.75 dB
#
# Valor máximo medido 35.0 dB
#
# Valor minimo medido 34.5 dB
#
# Medida(media, máximo, minimo)=34.75,35.0,34.5 dB	Time=2025-03-30 03:03:36
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.7dB
#
# Valor medio medido=34.41 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.41,34.7,33.9 dB	Time=2025-03-30 03:03:37
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:034.7dB
#
# Valor medio medido=34.44 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.44,34.8,33.8 dB	Time=2025-03-30 03:03:38
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.6 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.6,33.8,33.3 dB	Time=2025-03-30 03:03:39
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.35 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.35,33.5,33.2 dB	Time=2025-03-30 03:03:40
#
# RS232 read data:N:032.5dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.0dB
#
# Valor medio medido=32.9 dB
#
# Valor máximo medido 33.2 dB
#
# Valor minimo medido 32.5 dB
#
# Medida(media, máximo, minimo)=32.9,33.2,32.5 dB	Time=2025-03-30 03:03:41
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.57 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.57,33.8,33.3 dB	Time=2025-03-30 03:03:42
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.61 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.61,33.9,33.1 dB	Time=2025-03-30 03:03:43
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.9 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.9,34.0,33.8 dB	Time=2025-03-30 03:03:44
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.5 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.5,33.6,33.4 dB	Time=2025-03-30 03:03:45
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.67,33.7,33.6 dB	Time=2025-03-30 03:03:46
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.47 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.47,33.8,33.2 dB	Time=2025-03-30 03:03:47
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.8 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.8,33.8,33.8 dB	Time=2025-03-30 03:03:48
#
# RS232 read data:N:032.8dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.34 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 32.8 dB
#
# Medida(media, máximo, minimo)=33.34,33.8,32.8 dB	Time=2025-03-30 03:03:49
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.3 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.3,33.4,33.2 dB	Time=2025-03-30 03:03:50
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.6 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.6,33.8,33.5 dB	Time=2025-03-30 03:03:51
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.65 dB
# RS232 read data:N:032.7dB
#
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.65,33.9,33.4 dB	Time=2025-03-30 03:03:52
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.0 dB
#
# Valor máximo medido 33.2 dB
#
# Valor minimo medido 32.7 dB
#
# Medida(media, máximo, minimo)=33.0,33.2,32.7 dB	Time=2025-03-30 03:03:53
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.0dB
#
# Valor medio medido=33.1 dB
#
# Valor máximo medido 33.2 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.1,33.2,33.0 dB	Time=2025-03-30 03:03:54
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:032.5dB
#
# Valor medio medido=32.94 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 32.5 dB
#
# Medida(media, máximo, minimo)=32.94,33.4,32.5 dB	Time=2025-03-30 03:03:55
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.38 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.38,33.9,32.9 dB	Time=2025-03-30 03:03:56
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.25 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.25,33.4,33.1 dB	Time=2025-03-30 03:03:57
#
# RS232 read data:N:032.7dB
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.18 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 32.7 dB
#
# Medida(media, máximo, minimo)=33.18,33.9,32.7 dB	Time=2025-03-30 03:03:58
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.27 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.27,33.5,33.1 dB	Time=2025-03-30 03:03:59
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:032.7dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.1 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 32.7 dB
#
# Medida(media, máximo, minimo)=33.1,33.4,32.7 dB	Time=2025-03-30 03:04:00
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:032.8dB
#
# Valor medio medido=33.11 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 32.8 dB
#
# Medida(media, máximo, minimo)=33.11,33.4,32.8 dB	Time=2025-03-30 03:04:01
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.2 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.2,33.4,32.9 dB	Time=2025-03-30 03:04:02
#
# RS232 read data:N:032.7dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.1dB
#
# Valor medio medido=33.14 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 32.7 dB
#
# Medida(media, máximo, minimo)=33.14,33.6,32.7 dB	Time=2025-03-30 03:04:03
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:032.9dB
#
# Valor medio medido=33.24 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.24,33.4,32.9 dB	Time=2025-03-30 03:04:04
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.37 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.37,33.4,33.3 dB	Time=2025-03-30 03:04:05
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.51 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.51,33.9,33.1 dB	Time=2025-03-30 03:04:06
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.0dB
#
# RS232 read data:N:034.7dB
#
# Valor medio medido=33.8 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.8,34.7,33.0 dB	Time=2025-03-30 03:04:07
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.6 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.6,33.8,33.4 dB	Time=2025-03-30 03:04:08
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:032.8dB
#
# Valor medio medido=33.27 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 32.8 dB
#
# Medida(media, máximo, minimo)=33.27,33.5,32.8 dB	Time=2025-03-30 03:04:09
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.8 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.8,33.9,33.7 dB	Time=2025-03-30 03:04:10
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.27 dB
#
# Valor máximo medido 33.3 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.27,33.3,33.2 dB	Time=2025-03-30 03:04:11
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:032.8dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.41 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 32.8 dB
#
# Medida(media, máximo, minimo)=33.41,33.9,32.8 dB	Time=2025-03-30 03:04:12
#
# RS232 read data:N:032.8dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.2 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 32.8 dB
#
# Medida(media, máximo, minimo)=33.2,33.5,32.8 dB	Time=2025-03-30 03:04:13
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=34.15 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=34.15,34.8,33.5 dB	Time=2025-03-30 03:04:14
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.1dB
#
# Valor medio medido=33.72 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.72,34.3,33.1 dB	Time=2025-03-30 03:04:15
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.7 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.7,34.0,33.5 dB	Time=2025-03-30 03:04:16
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=33.99 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.99,34.8,33.3 dB	Time=2025-03-30 03:04:17
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:034.9dB
#
# Valor medio medido=34.32 dB
#
# Valor máximo medido 34.9 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=34.32,34.9,33.7 dB	Time=2025-03-30 03:04:18
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=34.68 dB
#
# Valor máximo medido 35.2 dB
#
# Valor minimo medido 34.2 dB
#
# Medida(media, máximo, minimo)=34.68,35.2,34.2 dB	Time=2025-03-30 03:04:19
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.8 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.8,34.0,33.5 dB	Time=2025-03-30 03:04:20
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.07 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.07,34.4,33.6 dB	Time=2025-03-30 03:04:21
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:035.7dB
#
# Valor medio medido=34.54 dB
#
# Valor máximo medido 35.7 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=34.54,35.7,33.2 dB	Time=2025-03-30 03:04:22
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=33.92 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.92,34.5,33.2 dB	Time=2025-03-30 03:04:23
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:037.1dB
#
# Valor medio medido=35.63 dB
#
# Valor máximo medido 37.1 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=35.63,37.1,33.9 dB	Time=2025-03-30 03:04:24
#
# RS232 read data:N:037.2dB
#
# RS232 read data:N:035.0dB
#
# Valor medio medido=36.17 dB
#
# Valor máximo medido 37.2 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo, minimo)=36.17,37.2,35.0 dB	Time=2025-03-30 03:04:25
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:035.3dB
#
# Valor medio medido=36.09 dB
#
# Valor máximo medido 37.7 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo, minimo)=36.09,37.7,35.0 dB	Time=2025-03-30 03:04:26
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.33 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 34.2 dB
#
# Medida(media, máximo, minimo)=34.33,34.4,34.2 dB	Time=2025-03-30 03:04:27
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.01 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.01,34.4,33.6 dB	Time=2025-03-30 03:04:28
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=34.01 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.01,34.5,33.6 dB	Time=2025-03-30 03:04:29
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=34.15 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=34.15,34.8,33.7 dB	Time=2025-03-30 03:04:30
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:034.6dB
#
# Valor medio medido=34.78 dB
#
# Valor máximo medido 35.3 dB
#
# Valor minimo medido 34.4 dB
#
# Medida(media, máximo, minimo)=34.78,35.3,34.4 dB	Time=2025-03-30 03:04:31
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:036.3dB
#
# Valor medio medido=35.96 dB
#
# Valor máximo medido 36.3 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=35.96,36.3,35.6 dB	Time=2025-03-30 03:04:32
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:036.1dB
#
# Valor medio medido=35.57 dB
#
# Valor máximo medido 36.1 dB
#
# Valor minimo medido 35.3 dB
#
# Medida(media, máximo, minimo)=35.57,36.1,35.3 dB	Time=2025-03-30 03:04:33
#
# RS232 read data:N:037.8dB
#
# RS232 read data:N:038.1dB
#
# Valor medio medido=37.95 dB
#
# Valor máximo medido 38.1 dB
#
# Valor minimo medido 37.8 dB
#
# Medida(media, máximo, minimo)=37.95,38.1,37.8 dB	Time=2025-03-30 03:04:34
#
# RS232 read data:N:037.0dB
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:037.8dB
#
# Valor medio medido=37.47 dB
#
# Valor máximo medido 37.8 dB
#
# Valor minimo medido 37.0 dB
#
# Medida(media, máximo, minimo)=37.47,37.8,37.0 dB	Time=2025-03-30 03:04:35
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:035.9dB
#
# RS232 read data:N:035.3dB
#
# Valor medio medido=36.32 dB
#
# Valor máximo medido 37.6 dB
#
# Valor minimo medido 35.3 dB
#
# Medida(media, máximo, minimo)=36.32,37.6,35.3 dB	Time=2025-03-30 03:04:36
#
# RS232 read data:N:035.8dB
#
# RS232 read data:N:035.6dB
#
# Valor medio medido=35.7 dB
#
# Valor máximo medido 35.8 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=35.7,35.8,35.6 dB	Time=2025-03-30 03:04:37
#
# RS232 read data:N:036.0dB
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=35.22 dB
#
# Valor máximo medido 36.0 dB
#
# Valor minimo medido 34.4 dB
#
# Medida(media, máximo, minimo)=35.22,36.0,34.4 dB	Time=2025-03-30 03:04:38
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:035.3dB
#
# Valor medio medido=34.94 dB
#
# Valor máximo medido 35.3 dB
#
# Valor minimo medido 34.7 dB
#
# Medida(media, máximo, minimo)=34.94,35.3,34.7 dB	Time=2025-03-30 03:04:39
#
# RS232 read data:N:035.4dB
#
# RS232 read data:N:036.5dB
#
# Valor medio medido=35.97 dB
#
# Valor máximo medido 36.5 dB
#
# Valor minimo medido 35.4 dB
#
# Medida(media, máximo, minimo)=35.97,36.5,35.4 dB	Time=2025-03-30 03:04:40
#
# RS232 read data:N:036.4dB
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=37.66 dB
#
# Valor máximo medido 38.8 dB
#
# Valor minimo medido 36.4 dB
#
# Medida(media, máximo, minimo)=37.66,38.8,36.4 dB	Time=2025-03-30 03:04:41
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:042.8dB
#
# Valor medio medido=42.04 dB
#
# Valor máximo medido 42.8 dB
#
# Valor minimo medido 41.2 dB
#
# Medida(media, máximo, minimo)=42.04,42.8,41.2 dB	Time=2025-03-30 03:04:42
#
# RS232 read data:N:043.0dB
#
# RS232 read data:N:043.2dB
#
# RS232 read data:N:041.7dB
#
# Valor medio medido=42.66 dB
#
# Valor máximo medido 43.2 dB
#
# Valor minimo medido 41.7 dB
#
# Medida(media, máximo, minimo)=42.66,43.2,41.7 dB	Time=2025-03-30 03:04:43
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:037.6dB
#
# Valor medio medido=38.17 dB
#
# Valor máximo medido 38.7 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo, minimo)=38.17,38.7,37.6 dB	Time=2025-03-30 03:04:44
#
# RS232 read data:N:037.1dB
#
# RS232 read data:N:038.1dB
#
# RS232 read data:N:037.5dB
#
# Valor medio medido=37.58 dB
#
# Valor máximo medido 38.1 dB
#
# Valor minimo medido 37.1 dB
#
# Medida(media, máximo, minimo)=37.58,38.1,37.1 dB	Time=2025-03-30 03:04:45
#
# RS232 read data:N:035.9dB
#
# RS232 read data:N:035.0dB
#
# Valor medio medido=35.46 dB
#
# Valor máximo medido 35.9 dB
#
# Valor minimo medido 35.0 dB
#
# Medida(media, máximo, minimo)=35.46,35.9,35.0 dB	Time=2025-03-30 03:04:46
#
# RS232 read data:N:036.3dB
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:035.7dB
#
# Valor medio medido=35.74 dB
#
# Valor máximo medido 36.3 dB
#
# Valor minimo medido 35.2 dB
#
# Medida(media, máximo, minimo)=35.74,36.3,35.2 dB	Time=2025-03-30 03:04:47
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:035.4dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=35.31 dB
#
# Valor máximo medido 35.7 dB
#
# Valor minimo medido 34.8 dB
#
# Medida(media, máximo, minimo)=35.31,35.7,34.8 dB	Time=2025-03-30 03:04:48
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:036.7dB
#
# Valor medio medido=36.17 dB
#
# Valor máximo medido 36.7 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=36.17,36.7,35.6 dB	Time=2025-03-30 03:04:49
#
# RS232 read data:N:036.6dB
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=35.29 dB
#
# Valor máximo medido 36.6 dB
#
# Valor minimo medido 34.4 dB
#
# Medida(media, máximo, minimo)=35.29,36.6,34.4 dB	Time=2025-03-30 03:04:50
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.0dB
#
# Valor medio medido=33.78 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.78,34.3,33.0 dB	Time=2025-03-30 03:04:51
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.05 dB
#
# Valor máximo medido 33.2 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.05,33.2,32.9 dB	Time=2025-03-30 03:04:52
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=34.0 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.0,34.2,33.6 dB	Time=2025-03-30 03:04:53
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.5 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.5,33.7,33.4 dB	Time=2025-03-30 03:04:54
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.93 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.93,34.1,33.8 dB	Time=2025-03-30 03:04:55
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.45 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.45,33.7,33.2 dB	Time=2025-03-30 03:04:56
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.68 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.68,34.2,33.3 dB	Time=2025-03-30 03:04:57
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.67,33.9,33.5 dB	Time=2025-03-30 03:04:58
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.8 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.8,34.1,33.6 dB	Time=2025-03-30 03:04:59
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.55 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.55,33.7,33.4 dB	Time=2025-03-30 03:05:00
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.0dB
#
# Valor medio medido=33.82 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.82,34.3,33.0 dB	Time=2025-03-30 03:05:01
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.0dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.54 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.54,33.9,33.0 dB	Time=2025-03-30 03:05:02
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.0dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.27 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.27,33.5,33.0 dB	Time=2025-03-30 03:05:03
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.75 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.75,33.8,33.7 dB	Time=2025-03-30 03:05:04
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.73 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.73,33.8,33.6 dB	Time=2025-03-30 03:05:05
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.97 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.97,34.4,33.7 dB	Time=2025-03-30 03:05:06
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=34.1 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.1,34.4,33.9 dB	Time=2025-03-30 03:05:07
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=34.47 dB
#
# Valor máximo medido 35.0 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.47,35.0,33.9 dB	Time=2025-03-30 03:05:08
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:035.1dB
#
# RS232 read data:N:035.9dB
#
# Valor medio medido=35.31 dB
#
# Valor máximo medido 35.9 dB
#
# Valor minimo medido 34.9 dB
#
# Medida(media, máximo, minimo)=35.31,35.9,34.9 dB	Time=2025-03-30 03:05:09
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=34.13 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=34.13,34.2,34.0 dB	Time=2025-03-30 03:05:10
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:035.4dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=34.66 dB
#
# Valor máximo medido 35.4 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=34.66,35.4,33.7 dB	Time=2025-03-30 03:05:11
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.6 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 34.4 dB
#
# Medida(media, máximo, minimo)=34.6,34.8,34.4 dB	Time=2025-03-30 03:05:12
#
# RS232 read data:N:035.1dB
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:036.6dB
#
# Valor medio medido=35.79 dB
#
# Valor máximo medido 36.6 dB
#
# Valor minimo medido 35.1 dB
#
# Medida(media, máximo, minimo)=35.79,36.6,35.1 dB	Time=2025-03-30 03:05:13
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:037.5dB
#
# Valor medio medido=38.5 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 37.5 dB
#
# Medida(media, máximo, minimo)=38.5,39.4,37.5 dB	Time=2025-03-30 03:05:14
#
# RS232 read data:N:037.4dB
#
# RS232 read data:N:036.9dB
#
# RS232 read data:N:035.1dB
#
# Valor medio medido=36.52 dB
#
# Valor máximo medido 37.4 dB
#
# Valor minimo medido 35.1 dB
#
# Medida(media, máximo, minimo)=36.52,37.4,35.1 dB	Time=2025-03-30 03:05:15
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=34.21 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.21,34.6,33.8 dB	Time=2025-03-30 03:05:16
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.6dB
#
# Valor medio medido=34.21 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.21,34.6,33.9 dB	Time=2025-03-30 03:05:17
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.9dB
#
# Valor medio medido=34.56 dB
#
# Valor máximo medido 34.9 dB
#
# Valor minimo medido 34.2 dB
#
# Medida(media, máximo, minimo)=34.56,34.9,34.2 dB	Time=2025-03-30 03:05:18
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=34.38 dB
#
# Valor máximo medido 34.9 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.38,34.9,33.6 dB	Time=2025-03-30 03:05:19
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:035.4dB
#
# Valor medio medido=34.62 dB
#
# Valor máximo medido 35.4 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=34.62,35.4,34.0 dB	Time=2025-03-30 03:05:20
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:035.1dB
#
# Valor medio medido=35.0 dB
#
# Valor máximo medido 35.1 dB
#
# Valor minimo medido 34.9 dB
#
# Medida(media, máximo, minimo)=35.0,35.1,34.9 dB	Time=2025-03-30 03:05:21
#
# RS232 read data:N:035.6dB
#
# RS232 read data:N:036.1dB
#
# RS232 read data:N:036.6dB
#
# Valor medio medido=36.11 dB
#
# Valor máximo medido 36.6 dB
#
# Valor minimo medido 35.6 dB
#
# Medida(media, máximo, minimo)=36.11,36.6,35.6 dB	Time=2025-03-30 03:05:22
#
# RS232 read data:N:036.0dB
#
# RS232 read data:N:036.5dB
#
# Valor medio medido=36.25 dB
#
# Valor máximo medido 36.5 dB
#
# Valor minimo medido 36.0 dB
#
# Medida(media, máximo, minimo)=36.25,36.5,36.0 dB	Time=2025-03-30 03:05:23
#
# RS232 read data:N:036.9dB
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=35.47 dB
#
# Valor máximo medido 36.9 dB
#
# Valor minimo medido 34.4 dB
#
# Medida(media, máximo, minimo)=35.47,36.9,34.4 dB	Time=2025-03-30 03:05:24
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.87 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.87,33.9,33.8 dB	Time=2025-03-30 03:05:25
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.94 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.94,34.4,33.5 dB	Time=2025-03-30 03:05:26
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.5 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.5,33.7,33.3 dB	Time=2025-03-30 03:05:27
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.91 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.91,34.4,33.3 dB	Time=2025-03-30 03:05:28
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.1dB
#
# Valor medio medido=33.45 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.45,34.1,33.1 dB	Time=2025-03-30 03:05:29
#
# RS232 read data:N:033.0dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.27 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.27,33.5,33.0 dB	Time=2025-03-30 03:05:30
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.55 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.55,33.7,33.4 dB	Time=2025-03-30 03:05:31
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=34.01 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.01,34.5,33.6 dB	Time=2025-03-30 03:05:32
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:032.7dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.21 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 32.7 dB
#
# Medida(media, máximo, minimo)=33.21,33.5,32.7 dB	Time=2025-03-30 03:05:33
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.54 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.54,33.8,33.3 dB	Time=2025-03-30 03:05:34
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:032.9dB
#
# Valor medio medido=33.26 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.26,33.6,32.9 dB	Time=2025-03-30 03:05:35
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.67,33.9,33.3 dB	Time=2025-03-30 03:05:36
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.83 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.83,34.0,33.7 dB	Time=2025-03-30 03:05:37
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:035.0dB
#
# Valor medio medido=34.48 dB
#
# Valor máximo medido 35.0 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.48,35.0,33.8 dB	Time=2025-03-30 03:05:38
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.45 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 34.4 dB
#
# Medida(media, máximo, minimo)=34.45,34.5,34.4 dB	Time=2025-03-30 03:05:39
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:035.2dB
#
# Valor medio medido=34.42 dB
#
# Valor máximo medido 35.2 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.42,35.2,33.9 dB	Time=2025-03-30 03:05:40
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=34.3 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.3,34.6,33.9 dB	Time=2025-03-30 03:05:41
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=34.0 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=34.0,34.0,34.0 dB	Time=2025-03-30 03:05:42
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=34.01 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.01,34.4,33.6 dB	Time=2025-03-30 03:05:43
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=34.08 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.08,34.8,33.6 dB	Time=2025-03-30 03:05:44
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.67,33.9,33.4 dB	Time=2025-03-30 03:05:45
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.33 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.33,33.4,33.3 dB	Time=2025-03-30 03:05:46
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.26 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.26,33.6,32.9 dB	Time=2025-03-30 03:05:47
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.47 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.47,33.7,33.2 dB	Time=2025-03-30 03:05:48
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.0dB
#
# RS232 read data:N:032.7dB
#
# Valor medio medido=33.11 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 32.7 dB
#
# Medida(media, máximo, minimo)=33.11,33.6,32.7 dB	Time=2025-03-30 03:05:49
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=34.07 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=34.07,34.2,34.0 dB	Time=2025-03-30 03:05:50
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=34.21 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.21,34.6,33.8 dB	Time=2025-03-30 03:05:51
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.54 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.54,33.8,33.2 dB	Time=2025-03-30 03:05:52
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.61 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.61,34.0,33.3 dB	Time=2025-03-30 03:05:53
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.0dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.27 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.27,33.7,33.0 dB	Time=2025-03-30 03:05:54
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:032.9dB
#
# Valor medio medido=33.15 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.15,33.4,32.9 dB	Time=2025-03-30 03:05:55
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.64 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.64,34.2,33.2 dB	Time=2025-03-30 03:05:56
#
# RS232 read data:N:032.8dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.62 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 32.8 dB
#
# Medida(media, máximo, minimo)=33.62,34.1,32.8 dB	Time=2025-03-30 03:05:57
#
# RS232 read data:N:033.0dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.2 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.2,33.4,33.0 dB	Time=2025-03-30 03:05:58
#
# RS232 read data:N:033.0dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.25 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.25,33.5,33.0 dB	Time=2025-03-30 03:05:59
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:032.6dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.29 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 32.6 dB
#
# Medida(media, máximo, minimo)=33.29,34.1,32.6 dB	Time=2025-03-30 03:06:00
#
# RS232 read data:N:032.8dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:032.9dB
#
# Valor medio medido=33.18 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 32.8 dB
#
# Medida(media, máximo, minimo)=33.18,33.8,32.8 dB	Time=2025-03-30 03:06:01
#
# RS232 read data:N:032.8dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.14 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 32.8 dB
#
# Medida(media, máximo, minimo)=33.14,33.4,32.8 dB	Time=2025-03-30 03:06:02
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.74 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.74,34.1,33.3 dB	Time=2025-03-30 03:06:03
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:032.7dB
#
# Valor medio medido=33.01 dB
#
# Valor máximo medido 33.3 dB
#
# Valor minimo medido 32.7 dB
#
# Medida(media, máximo, minimo)=33.01,33.3,32.7 dB	Time=2025-03-30 03:06:04
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.1dB
#
# Valor medio medido=33.13 dB
#
# Valor máximo medido 33.2 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.13,33.2,33.1 dB	Time=2025-03-30 03:06:05
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.61 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.61,34.0,33.2 dB	Time=2025-03-30 03:06:06
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:032.7dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.14 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 32.7 dB
#
# Medida(media, máximo, minimo)=33.14,33.4,32.7 dB	Time=2025-03-30 03:06:07
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.45 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.45,33.6,33.3 dB	Time=2025-03-30 03:06:08
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=33.64 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.64,34.0,33.4 dB	Time=2025-03-30 03:06:09
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.4 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.4,33.6,33.2 dB	Time=2025-03-30 03:06:10
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:032.9dB
#
# Valor medio medido=33.55 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.55,34.1,32.9 dB	Time=2025-03-30 03:06:11
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.35 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.35,33.5,33.2 dB	Time=2025-03-30 03:06:12
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.64 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.64,33.9,33.2 dB	Time=2025-03-30 03:06:13
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.37 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.37,33.7,33.2 dB	Time=2025-03-30 03:06:14
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.33 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.33,33.5,33.1 dB	Time=2025-03-30 03:06:15
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:032.8dB
#
# Valor medio medido=33.16 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 32.8 dB
#
# Medida(media, máximo, minimo)=33.16,33.5,32.8 dB	Time=2025-03-30 03:06:16
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.4 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.4,33.7,33.2 dB	Time=2025-03-30 03:06:17
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.48 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.48,34.0,32.9 dB	Time=2025-03-30 03:06:18
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:032.9dB
#
# Valor medio medido=33.04 dB
#
# Valor máximo medido 33.3 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.04,33.3,32.9 dB	Time=2025-03-30 03:06:19
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.57 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.57,33.9,33.3 dB	Time=2025-03-30 03:06:20
#
# RS232 read data:N:033.0dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.1 dB
#
# Valor máximo medido 33.2 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.1,33.2,33.0 dB	Time=2025-03-30 03:06:22
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:032.9dB
#
# Valor medio medido=33.17 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.17,33.4,32.9 dB	Time=2025-03-30 03:06:23
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.33 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.33,33.5,33.1 dB	Time=2025-03-30 03:06:24
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.4 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.4,33.6,33.2 dB	Time=2025-03-30 03:06:25
#
# RS232 read data:N:032.3dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=32.76 dB
#
# Valor máximo medido 33.2 dB
#
# Valor minimo medido 32.3 dB
#
# Medida(media, máximo, minimo)=32.76,33.2,32.3 dB	Time=2025-03-30 03:06:26
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.34 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.34,33.6,33.2 dB	Time=2025-03-30 03:06:27
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:032.6dB
#
# Valor medio medido=33.29 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 32.6 dB
#
# Medida(media, máximo, minimo)=33.29,34.0,32.6 dB	Time=2025-03-30 03:06:28
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.33 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.33,33.5,33.1 dB	Time=2025-03-30 03:06:29
#
# RS232 read data:N:033.0dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.1dB
#
# Valor medio medido=33.49 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.49,34.3,33.0 dB	Time=2025-03-30 03:06:30
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.1dB
#
# Valor medio medido=33.15 dB
#
# Valor máximo medido 33.2 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.15,33.2,33.1 dB	Time=2025-03-30 03:06:31
#
# RS232 read data:N:032.8dB
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:032.8dB
#
# Valor medio medido=32.9 dB
#
# Valor máximo medido 33.1 dB
#
# Valor minimo medido 32.8 dB
#
# Medida(media, máximo, minimo)=32.9,33.1,32.8 dB	Time=2025-03-30 03:06:32
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.1dB
#
# Valor medio medido=33.34 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.1 dB
#
# ...
#
# Medida(media, máximo, minimo)=33.5,33.6,33.4 dB	Time=2025-03-30 03:07:02
#
# RS232 read data:N:032.6dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.11 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 32.6 dB
#
# Medida(media, máximo, minimo)=33.11,33.4,32.6 dB	Time=2025-03-30 03:07:03
#
# RS232 read data:N:032.5dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:032.7dB
#
# Valor medio medido=32.81 dB
#
# Valor máximo medido 33.2 dB
#
# Valor minimo medido 32.5 dB
#
# Medida(media, máximo, minimo)=32.81,33.2,32.5 dB	Time=2025-03-30 03:07:04
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.77 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.77,34.2,33.5 dB	Time=2025-03-30 03:07:05
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:032.7dB
#
# Valor medio medido=33.2 dB
#
# Valor máximo medido 33.2 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.2,33.2,33.2 dB	Time=2025-03-30 03:07:06
#
# RS232 read data:N:037.7dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=34.87 dB
#
# Valor máximo medido 37.7 dB
#
# Valor minimo medido 32.7 dB
#
# Medida(media, máximo, minimo)=34.87,37.7,32.7 dB	Time=2025-03-30 03:07:07
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.7 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.7,33.8,33.5 dB	Time=2025-03-30 03:07:08
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.53 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.53,33.6,33.4 dB	Time=2025-03-30 03:07:09
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.6 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.6,33.8,33.4 dB	Time=2025-03-30 03:07:10
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.95 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.95,34.1,33.8 dB	Time=2025-03-30 03:07:11
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.6 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.6,33.8,33.4 dB	Time=2025-03-30 03:07:12
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=33.65 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.65,34.3,33.2 dB	Time=2025-03-30 03:07:13
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:032.8dB
#
# Valor medio medido=33.62 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 32.8 dB
#
# Medida(media, máximo, minimo)=33.62,34.3,32.8 dB	Time=2025-03-30 03:07:14
#
# RS232 read data:N:032.8dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.11 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 32.8 dB
#
# Medida(media, máximo, minimo)=33.11,33.4,32.8 dB	Time=2025-03-30 03:07:15
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.67,33.8,33.5 dB	Time=2025-03-30 03:07:16
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.77 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.77,34.1,33.6 dB	Time=2025-03-30 03:07:17
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.73 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.73,33.8,33.7 dB	Time=2025-03-30 03:07:18
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=33.85 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.85,34.0,33.7 dB	Time=2025-03-30 03:07:19
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.43 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.43,33.6,33.2 dB	Time=2025-03-30 03:07:20
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.44 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.44,33.8,33.2 dB	Time=2025-03-30 03:07:21
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.33 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.33,33.4,33.3 dB	Time=2025-03-30 03:07:22
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.7 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.7,33.8,33.6 dB	Time=2025-03-30 03:07:23
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.37 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.37,33.7,33.1 dB	Time=2025-03-30 03:07:24
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.5 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.5,33.8,33.1 dB	Time=2025-03-30 03:07:25
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=33.64 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.64,34.0,33.3 dB	Time=2025-03-30 03:07:26
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:032.9dB
#
# Valor medio medido=33.17 dB
#
# Valor máximo medido 33.3 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.17,33.3,32.9 dB	Time=2025-03-30 03:07:27
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.5 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.5,33.6,33.4 dB	Time=2025-03-30 03:07:28
#
# RS232 read data:N:033.0dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.44 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.44,33.7,33.0 dB	Time=2025-03-30 03:07:29
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.77 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.77,34.1,33.6 dB	Time=2025-03-30 03:07:30
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.7 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.7,33.9,33.6 dB	Time=2025-03-30 03:07:31
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:034.6dB
#
# Valor medio medido=34.8 dB
#
# Valor máximo medido 35.0 dB
#
# Valor minimo medido 34.6 dB
#
# Medida(media, máximo, minimo)=34.8,35.0,34.6 dB	Time=2025-03-30 03:07:32
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=34.49 dB
#
# Valor máximo medido 35.2 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.49,35.2,33.8 dB	Time=2025-03-30 03:07:33
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.84 dB
#
# Valor máximo medido 35.2 dB
#
# Valor minimo medido 34.5 dB
#
# Medida(media, máximo, minimo)=34.84,35.2,34.5 dB	Time=2025-03-30 03:07:34
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=34.36 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=34.36,34.7,34.0 dB	Time=2025-03-30 03:07:35
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.9 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.9,34.0,33.8 dB	Time=2025-03-30 03:07:36
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=34.15 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=34.15,34.6,33.5 dB	Time=2025-03-30 03:07:37
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=34.21 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.21,34.6,33.9 dB	Time=2025-03-30 03:07:38
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.4 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 34.3 dB
#
# Medida(media, máximo, minimo)=34.4,34.5,34.3 dB	Time=2025-03-30 03:07:39
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.81 dB
#
# Valor máximo medido 35.5 dB
#
# Valor minimo medido 34.4 dB
#
# Medida(media, máximo, minimo)=34.81,35.5,34.4 dB	Time=2025-03-30 03:07:40
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=34.6 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 34.4 dB
#
# Medida(media, máximo, minimo)=34.6,34.8,34.4 dB	Time=2025-03-30 03:07:41
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:035.4dB
#
# Valor medio medido=35.15 dB
#
# Valor máximo medido 35.4 dB
#
# Valor minimo medido 34.9 dB
#
# Medida(media, máximo, minimo)=35.15,35.4,34.9 dB	Time=2025-03-30 03:07:42
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:035.9dB
#
# RS232 read data:N:036.9dB
#
# Valor medio medido=36.06 dB
#
# Valor máximo medido 36.9 dB
#
# Valor minimo medido 35.3 dB
#
# Medida(media, máximo, minimo)=36.06,36.9,35.3 dB	Time=2025-03-30 03:07:43
#
# RS232 read data:N:037.5dB
#
# RS232 read data:N:036.5dB
#
# RS232 read data:N:035.7dB
#
# Valor medio medido=36.6 dB
#
# Valor máximo medido 37.5 dB
#
# Valor minimo medido 35.7 dB
#
# Medida(media, máximo, minimo)=36.6,37.5,35.7 dB	Time=2025-03-30 03:07:44
#
# RS232 read data:N:036.1dB
#
# RS232 read data:N:036.7dB
#
# Valor medio medido=36.41 dB
#
# Valor máximo medido 36.7 dB
#
# Valor minimo medido 36.1 dB
#
# Medida(media, máximo, minimo)=36.41,36.7,36.1 dB	Time=2025-03-30 03:07:45
#
# RS232 read data:N:035.7dB
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=34.92 dB
#
# Valor máximo medido 35.7 dB
#
# Valor minimo medido 34.2 dB
#
# Medida(media, máximo, minimo)=34.92,35.7,34.2 dB	Time=2025-03-30 03:07:46
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.37 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 34.3 dB
#
# Medida(media, máximo, minimo)=34.37,34.5,34.3 dB	Time=2025-03-30 03:07:47
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.55 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.55,33.6,33.5 dB	Time=2025-03-30 03:07:48
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.97 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.97,34.4,33.6 dB	Time=2025-03-30 03:07:49
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=34.07 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=34.07,34.2,34.0 dB	Time=2025-03-30 03:07:50
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:035.1dB
#
# Valor medio medido=34.58 dB
#
# Valor máximo medido 35.1 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.58,35.1,33.8 dB	Time=2025-03-30 03:07:51
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.61 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.61,33.9,33.3 dB	Time=2025-03-30 03:07:52
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.97 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.97,34.4,33.6 dB	Time=2025-03-30 03:07:53
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=34.37 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=34.37,34.8,34.0 dB	Time=2025-03-30 03:07:54
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.85 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.85,33.9,33.8 dB	Time=2025-03-30 03:07:55
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:032.8dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.31 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 32.8 dB
#
# Medida(media, máximo, minimo)=33.31,33.9,32.8 dB	Time=2025-03-30 03:07:56
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.47 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.47,33.7,33.3 dB	Time=2025-03-30 03:07:57
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.34 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.34,33.6,33.2 dB	Time=2025-03-30 03:07:58
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.0dB
#
# Valor medio medido=33.66 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.66,34.6,33.0 dB	Time=2025-03-30 03:07:59
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.5 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.5,33.5,33.5 dB	Time=2025-03-30 03:08:00
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:032.6dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.38 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 32.6 dB
#
# Medida(media, máximo, minimo)=33.38,33.8,32.6 dB	Time=2025-03-30 03:08:01
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:032.6dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.31 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 32.6 dB
#
# Medida(media, máximo, minimo)=33.31,33.7,32.6 dB	Time=2025-03-30 03:08:02
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.0dB
#
# Valor medio medido=33.54 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.54,34.1,33.0 dB	Time=2025-03-30 03:08:03
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.0dB
#
# Valor medio medido=33.51 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.51,34.0,33.0 dB	Time=2025-03-30 03:08:04
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.41 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.41,33.8,32.9 dB	Time=2025-03-30 03:08:05
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.84 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.84,34.1,33.4 dB	Time=2025-03-30 03:08:06
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.33 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.33,33.4,33.3 dB	Time=2025-03-30 03:08:07
#
# RS232 read data:N:033.0dB
#
# RS232 read data:N:032.7dB
#
# Valor medio medido=32.85 dB
#
# Valor máximo medido 33.0 dB
#
# Valor minimo medido 32.7 dB
#
# Medida(media, máximo, minimo)=32.85,33.0,32.7 dB	Time=2025-03-30 03:08:08
#
# RS232 read data:N:032.4dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.26 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 32.4 dB
#
# Medida(media, máximo, minimo)=33.26,34.1,32.4 dB	Time=2025-03-30 03:08:09
#
# RS232 read data:
#
# RS232 cerrando el puerto serie.
#
# Measurements saved to log_files/medida_2/type_2 Sun 2025-03-30 03h03m08s.json

# %%
import matplotlib.pyplot as plt

pic_path = 'Pics/medida_2/type_2 '+format_time(time.time(), True)

# Load the measurements from the JSON file.
with open(json_file, 'r') as f:
    measurements = json.load(f)

times = [m["time"] for m in measurements]
means = [m["mean"] for m in measurements]
maxs = [m["max"] for m in measurements]
mins = [m["min"] for m in measurements]

m_number = list(range(0,len(measurements)))

# Plot the measurements
plt.figure(figsize=(10, 6))
plt.plot(m_number, means, label="Mean", color="blue")
plt.plot(m_number, maxs, label="Max", color="red", linestyle="--")
plt.plot(m_number, mins, label="Min", color="green", linestyle="--")
plt.xlim(0, len(measurements)-1)
plt.ylim(30, 60)
plt.xlabel("Samples")
plt.ylabel("Sound Level (dB)")
plt.title("Sound Level Measurements Over Time")
plt.legend()
plt.grid(True)
plt.savefig(pic_path+'.png')
plt.show()

# %% [markdown]
# ## Ejemplo de lectura directa del Serial y almacenamiento en un vector.

# %%
import serial
import math

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'


# Sound level meter.
port_AZ8922 = SELECTED_PORT
ser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port


# Reset the arrays.
sound_level = []

#while(ser.connected):
for x in range(10):
    output = ser.readline().decode('utf-8', 'ignore')
    output = output.strip()
    #print("RS232 read data:"+str(output)+"\n")
    if output.startswith('N:') and output.endswith('dB'):
        salida_texto=float(output.split(':')[1].split('dB')[0])
        sound_level.append(salida_texto) # Para concatenar los valores y formar un Vector/Array
        print("RS232 db="+str(salida_texto)+"\n")     
    
ser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el 
#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia
#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.


# Round up.
#sound_level_mean = round(sound_level_mean,2)
#print("Sound Level(Media)="+str(sound_level_mean)+"\n") 

#Calculamos el máximo en dB
sound_level_max = max(sound_level) #Esto es el máximo de un vector
print(Green + "Sound Level(Max)="+str(sound_level_max)+" db\n") 

#Calculamos el mínomo en dB
sound_level_min = min(sound_level)
print(Magenta+"Sound Level(Min)="+str(sound_level_min)+" db\n") 

#Calculamos la suma de los valores sin decibelios
sound_level_linear = [math.pow(10,x/20) for x in sound_level] 
print(Blue +"Sound Level(linear)="+str(sound_level_linear)+"\n") 

#Pasamos la suma de lo medido en dB
sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
sound_level_mean = 20*math.log10(sound_level_mean)
print(Red + "Sound Level(Mean)="+str(sound_level_mean)+" db\n")
# Out:
# RS232 db=33.4
#
# RS232 db=33.4
#
# RS232 db=33.2
#
# RS232 db=33.0
#
# RS232 db=33.3
#
# RS232 db=33.5
#
# RS232 db=33.4
#
# RS232 db=32.9
#
# RS232 db=33.4
#
# RS232 db=33.9
#
# Sound Level(Max)=33.9 db
#
# Sound Level(Min)=32.9 db
#
# Sound Level(linear)=[46.77351412871981, 46.77351412871981, 45.708818961487516, 44.6683592150963, 46.23810213992601, 47.315125896148054, 46.77351412871981, 44.157044735331255, 46.77351412871981, 49.545019080479]
#
# Sound Level(Mean)=33.343949253433784 db
