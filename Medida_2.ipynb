# %% [markdown]
# # Medida 2
# ## Piso con ventana abierta
#
#  **Ubicacion**: Piso residencial (interior) con ventana abierta.
#
#  **Metodologia**:
#  * Medicion de los niveles de presion sonora en el interior del piso, con el fin de cuantificar la intrusion de ruido exterior (trafico, obras urbanas, vecindario etc.).
#  * Toma de mediciones en tres franjas horarias diurnas: mañana (10:00-13:00), siesta (14:00-17:00) y tarde (18:00-20:00).
#  * Toma de mediciones en dos franjas horarias nocturnas: tarde-noche (20:00-22:00) y noche (00:00-02:00).
#  * Toma de mediciones en diferentes dıas de la semana: fin de semana (sabado) y un dıa laboral.

# %%
import os

# initialize directory to store json files with sampled data. 
path = 'log_files/medida_2'
if not os.path.exists(path):
    os.makedirs(path)

# global port variable
SELECTED_PORT = 'COM3'

# %%
import threading
import time
import math
import serial  
import logging
import json

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'

def format_time(unix_epoch, isFileName=False):
    """format time in unix epoch to human-readable values"""
    if isFileName:
        day = time.ctime(unix_epoch)[:3]
        formatted_time = day+time.strftime(" %Y-%m-%d %Hh%Mm%Ss", time.localtime(unix_epoch))
        return formatted_time
    formatted_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(unix_epoch))
    return str(formatted_time)

#_____________________________________________________________________________________________________________________

class AZ8922:
    """class for sonometer object"""

    def __init__(self, port):
        self.port = port
        self.ser = None
        self.running = True
        self.connected = True
        self.sound_level = []
        print(Green+"AZ8922: Iniciando la clase.\n",flush=True)

    def get_sonometry(self):
        """returns mean and max value of the measurement"""
        if self.sound_level:
            sound_level_max = max(self.sound_level)
            sound_level_min = min(self.sound_level)
            sound_level_linear = [math.pow(10,x/20) for x in self.sound_level] 
            sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
            sound_level_mean = 20*math.log10(sound_level_mean) 
        else:
            sound_level_max = -1
            sound_level_min = -1
            sound_level_mean = -1
            
        # Check if the AZ8922 is off.
        # if self.connected and not self.sound_level: logging.warning('AZ8922 is off.')
        
        # Reset the arrays.
        self.sound_level = []
        
        # Round up.
        sound_level_mean = round(sound_level_mean,2)
        
        # logging.info(f'Sonometry AZ8922:{sound_level_mean}') 
        # logging.info('Sonometry AZ8922:%f' % sound_level_mean) 
        # if not self.connected: logging.warning('AZ8922 is disconnected.')
         
        return sound_level_mean, sound_level_max, sound_level_min

    def run_thread(self):
        """run thread to capture measurements from sonometer"""
        thread = threading.Thread(target=self.sonometro_thread, daemon=True)
        thread.start()

    def stop_thread(self):
        """stop sonometer thread"""
        self.running = False
        self.connected = False
        if self.ser is not None:
            self.ser.close()
            print(Red+"RS232 cerrando el puerto serie.\n",flush=True)
            

    def sonometro_thread(self):
        """reads values from serial port and updates sound level attribute"""
        while self.running:
            try:
                # If disconnected, check connection every 5 seconds.
                if not self.connected: time.sleep(5)
                self.ser = serial.Serial(self.port, 2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)
                self.connected = True
                print(Yellow+"RS232 abriendo el puerto serie.\n",flush=True)

                #Para sacar valores intermedios
                #print("Self.conected="+str(self.connected)+"\n")
                #print("self.ser.in_waiting="+str(self.ser.in_waiting)+"\n")
                #print("self.running="+str(self.running)+"\n")
                
                #while(self.connected and self.ser.in_waiting and self.running):
                while(self.connected and self.running):
                    output = self.ser.readline().decode('utf-8', 'ignore')
                    output = output.strip()
                    print(Yellow+"RS232 read data:"+str(output)+"\n",flush=True)
                    if output.startswith('N:') and output.endswith('dB'):
                        self.sound_level.append(float(output.split(':')[1].split('dB')[0]))

            except (serial.serialutil.SerialException, OSError):
                # Thread is not halted upon sensor disconnection.
                self.connected = False

# %% [markdown]
# ## Ejemplo toma de 10 medidas

# %%
# User Params.
MEASURE_PERIOD = 1  # How often (seconds) we poll for measurements.
log_file = 'log_files/log.txt'
json_file = path+'/type_1 '+format_time(time.time(), True)+'.json'

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  # Thread running condition.


#Llamada a la función y crea objeto de la clase AZ8922
port_AZ8922 = SELECTED_PORT
sound_level_meter = AZ8922(port_AZ8922)

print(Green+"Arrancamos el proceso para medir.\n")
sound_level_meter.run_thread()

# List to store measurements.
measurements = []

# Main thread.
for x in range(10):

        time.sleep(MEASURE_PERIOD)
        current_time = format_time(time.time())

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level_media, sound_level_maximo, sound_level_minimo = sound_level_meter.get_sonometry()
        print(Grey+"Valor medio medido="+ str(sound_level_media)+ " dB\n")
        print(Grey+"Valor máximo medido "+ str(sound_level_maximo)+ " dB\n")
        print(Grey+"Valor minimo medido "+ str(sound_level_minimo)+ " dB\n")
        #print(Magenta +"Medida(media, máximo)="+ str(sound_level)+ " dB\n" )
        print(Magenta +"Medida(media, máximo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+  " dB" +Cyan+"\tTime=" + current_time+"\n")
        logging.debug("Medida(media, maximo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+  " dB    Time=" + current_time+"\n")
        
        # Store the measurement in a dictionary
        measurement = {
            "time": current_time,
            "mean": sound_level_media,
            "max": sound_level_maximo,
            "min": sound_level_minimo
        }
        measurements.append(measurement)
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()

# Save measurements to a JSON file
with open(json_file, 'w') as f:
    json.dump(measurements, f, indent=4)
print(Green + f"Measurements saved to {json_file}\n")
# Out:
# AZ8922: Iniciando la clase.
#
# Arrancamos el proceso para medir.
#
# RS232 abriendo el puerto serie.
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.51 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo)=33.51,33.8 dB	Time=2025-03-27 03:51:35
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=33.7 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo)=33.7,34.0 dB	Time=2025-03-27 03:51:36
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=33.96 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo)=33.96,34.3 dB	Time=2025-03-27 03:51:37
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.1dB
#
# Valor medio medido=34.05 dB
#
# Valor máximo medido 35.2 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo)=34.05,35.2 dB	Time=2025-03-27 03:51:38
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:035.3dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=34.52 dB
#
# Valor máximo medido 35.3 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo)=34.52,35.3 dB	Time=2025-03-27 03:51:39
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=34.4 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 34.3 dB
#
# Medida(media, máximo)=34.4,34.5 dB	Time=2025-03-27 03:51:40
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.4 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo)=33.4,33.4 dB	Time=2025-03-27 03:51:41
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:032.9dB
#
# Valor medio medido=33.48 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo)=33.48,33.9 dB	Time=2025-03-27 03:51:42
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.7 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo)=33.7,34.0 dB	Time=2025-03-27 03:51:43
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.74 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo)=33.74,34.1 dB	Time=2025-03-27 03:51:44
#
# RS232 read data:
#
# RS232 cerrando el puerto serie.
#
# Measurements saved to log_files/medida_2/type_1 Thu 2025-03-27 03h51m34s.json

# %%
import matplotlib.pyplot as plt

pic_path = 'Pics/medida_2/type_1 '+format_time(time.time(), True)

# Load the measurements from the JSON file.
with open(json_file, 'r') as f:
    measurements = json.load(f)

times = [m["time"] for m in measurements]
means = [m["mean"] for m in measurements]
maxs = [m["max"] for m in measurements]
mins = [m["min"] for m in measurements]

m_number = list(range(0,len(measurements)))

# Plot the measurements
plt.figure(figsize=(10, 6))
plt.plot(m_number, means, label="Mean", color="blue")
plt.plot(m_number, maxs, label="Max", color="red", linestyle="--")
plt.plot(m_number, mins, label="Min", color="green", linestyle="--")
plt.xlim(0, len(measurements)-1)
plt.xlabel("Samples")
plt.ylabel("Sound Level (dB)")
plt.title("Sound Level Measurements Over Time")
plt.legend()
plt.grid(True)
plt.savefig(pic_path+'.png')
plt.show()

# %%
pic_path = 'Pics/medida_2/type_1_max '+format_time(time.time(), True)

plt.plot(maxs,'b',maxs,'ro') #Más opciones de plot aqui: https://matplotlib.org/tutorials/introductory/pyplot.html
plt.title('Max Sound Level sampled')
plt.ylabel('Sound Level [dB]')
plt.xlim(0, len(measurements)-1)
plt.xlabel('Samples')
plt.grid()
plt.savefig(pic_path+'.png')
plt.show()

# %% [markdown]
# ## Ejemplo toma de medidas para 5 minutos

# %%
# User Params.
MEASURE_PERIOD = 1  # How often (seconds) we poll for measurements.
log_file = 'log_files/log.txt'
json_file = path+'/type_2 '+format_time(time.time(), True)+'.json'
MEASUREMENT_DURATION = 5 * 60  # 5 minutes


# Get the start and stop time for the measurement.
start_time = time.time()
end_time = start_time + MEASUREMENT_DURATION

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  


#Llamada a la función y crea objeto de la clase AZ8922
port_AZ8922 = SELECTED_PORT
sound_level_meter = AZ8922(port_AZ8922)

print(Green+"Arrancamos el proceso para medir.\n")
sound_level_meter.run_thread()

measurements = []

# Main thread.
while time.time() < end_time:
        # Sleep for the measurement period
        time.sleep(MEASURE_PERIOD)
        current_time = format_time(time.time())

        # Store the measurement in a dictionary
        measurement = {
            "time": current_time,
            "mean": sound_level_media,
            "max": sound_level_maximo,
            "min": sound_level_minimo
        }
        measurements.append(measurement)

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level_media, sound_level_maximo, sound_level_minimo = sound_level_meter.get_sonometry()
        
        print(Grey+"Valor medio medido="+ str(sound_level_media)+ " dB\n")
        print(Grey+"Valor máximo medido "+ str(sound_level_maximo)+ " dB\n")
        print(Grey+"Valor minimo medido "+ str(sound_level_minimo)+ " dB\n")

        print(Magenta +"Medida(media, máximo, minimo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+","+ str(sound_level_minimo)+  " dB" +Cyan+"\tTime=" + current_time+"\n")
        logging.debug("Medida(media, maximo, minimo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+","+ str(sound_level_minimo)+  " dB    Time=" + current_time+"\n")
        
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()

# Save measurements to a JSON file
with open(json_file, 'w') as f:
    json.dump(measurements, f, indent=4)
print(Green + f"Measurements saved to {json_file}\n")
# Out:
# AZ8922: Iniciando la clase.
#
# Arrancamos el proceso para medir.
#
# RS232 abriendo el puerto serie.
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.61 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.61,34.0,33.2 dB	Time=2025-03-27 03:51:46
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.64 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.64,33.9,33.2 dB	Time=2025-03-27 03:51:47
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=34.3 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 34.1 dB
#
# Medida(media, máximo, minimo)=34.3,34.5,34.1 dB	Time=2025-03-27 03:51:48
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=34.08 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=34.08,34.5,33.5 dB	Time=2025-03-27 03:51:49
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=34.36 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.36,34.8,33.9 dB	Time=2025-03-27 03:51:50
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.1dB
#
# Valor medio medido=33.71 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.71,34.3,33.1 dB	Time=2025-03-27 03:51:51
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.64 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.64,33.8,33.3 dB	Time=2025-03-27 03:51:52
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.54 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.54,33.9,33.3 dB	Time=2025-03-27 03:51:53
#
# RS232 read data:N:032.8dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.26 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 32.8 dB
#
# Medida(media, máximo, minimo)=33.26,33.7,32.8 dB	Time=2025-03-27 03:51:54
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.1dB
#
# Valor medio medido=33.03 dB
#
# Valor máximo medido 33.1 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.03,33.1,32.9 dB	Time=2025-03-27 03:51:55
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.47 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.47,33.8,33.2 dB	Time=2025-03-27 03:51:56
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.67,33.8,33.6 dB	Time=2025-03-27 03:51:57
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.45 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.45,33.5,33.4 dB	Time=2025-03-27 03:51:58
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:032.9dB
#
# Valor medio medido=33.48 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.48,33.8,32.9 dB	Time=2025-03-27 03:51:59
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=33.64 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.64,34.2,33.2 dB	Time=2025-03-27 03:52:00
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.57 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.57,33.7,33.4 dB	Time=2025-03-27 03:52:01
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.36 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.36,33.8,32.9 dB	Time=2025-03-27 03:52:02
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.61 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.61,34.0,33.3 dB	Time=2025-03-27 03:52:03
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.93 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.93,34.1,33.7 dB	Time=2025-03-27 03:52:04
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.0dB
#
# Valor medio medido=33.89 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.89,34.4,33.0 dB	Time=2025-03-27 03:52:05
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.6 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.6,33.7,33.5 dB	Time=2025-03-27 03:52:06
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.1dB
#
# Valor medio medido=33.17 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.17,33.5,32.9 dB	Time=2025-03-27 03:52:07
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:032.9dB
#
# Valor medio medido=33.52 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.52,34.2,32.9 dB	Time=2025-03-27 03:52:08
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=33.51 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.51,34.0,32.9 dB	Time=2025-03-27 03:52:09
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.45 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.45,33.7,33.2 dB	Time=2025-03-27 03:52:10
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.6 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.6,33.8,33.5 dB	Time=2025-03-27 03:52:11
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.57 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.57,33.8,33.3 dB	Time=2025-03-27 03:52:12
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.91 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.91,34.6,33.5 dB	Time=2025-03-27 03:52:13
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.55 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.55,33.8,33.3 dB	Time=2025-03-27 03:52:14
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.77 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.77,34.0,33.4 dB	Time=2025-03-27 03:52:15
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.63 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.63,33.8,33.5 dB	Time=2025-03-27 03:52:16
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.77 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.77,33.9,33.7 dB	Time=2025-03-27 03:52:17
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.45 dB
# RS232 read data:N:033.8dB
#
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.45,33.7,33.2 dB	Time=2025-03-27 03:52:18
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=33.64 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.64,34.0,33.1 dB	Time=2025-03-27 03:52:19
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.43 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.43,33.6,33.3 dB	Time=2025-03-27 03:52:20
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.5 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.5,33.6,33.4 dB	Time=2025-03-27 03:52:21
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.37 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.37,33.6,33.1 dB	Time=2025-03-27 03:52:22
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.6 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.6,33.7,33.5 dB	Time=2025-03-27 03:52:23
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.0dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.34 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.34,33.5,33.0 dB	Time=2025-03-27 03:52:24
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.44 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.44,33.7,33.3 dB	Time=2025-03-27 03:52:25
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.4 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.4,33.4,33.4 dB	Time=2025-03-27 03:52:26
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.0dB
#
# Valor medio medido=33.47 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.47,33.8,33.0 dB	Time=2025-03-27 03:52:27
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.3 dB
#
# Valor máximo medido 33.3 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.3,33.3,33.3 dB	Time=2025-03-27 03:52:28
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.77 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.77,33.9,33.6 dB	Time=2025-03-27 03:52:29
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=33.97 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.97,34.1,33.8 dB	Time=2025-03-27 03:52:30
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.83 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.83,33.9,33.7 dB	Time=2025-03-27 03:52:31
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=33.68 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.68,34.4,32.9 dB	Time=2025-03-27 03:52:32
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.5 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.5,33.7,33.2 dB	Time=2025-03-27 03:52:33
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.67,33.8,33.6 dB	Time=2025-03-27 03:52:34
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.8 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.8,33.9,33.6 dB	Time=2025-03-27 03:52:35
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.7 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.7,33.8,33.6 dB	Time=2025-03-27 03:52:36
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=33.84 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.84,34.1,33.4 dB	Time=2025-03-27 03:52:37
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.73 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.73,33.8,33.6 dB	Time=2025-03-27 03:52:38
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=33.8 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.8,34.0,33.6 dB	Time=2025-03-27 03:52:39
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=34.21 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.21,34.6,33.8 dB	Time=2025-03-27 03:52:40
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=33.98 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.98,34.4,33.4 dB	Time=2025-03-27 03:52:41
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=34.14 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.14,34.5,33.8 dB	Time=2025-03-27 03:52:42
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.97 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.97,34.3,33.6 dB	Time=2025-03-27 03:52:43
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.35 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 34.3 dB
#
# Medida(media, máximo, minimo)=34.35,34.4,34.3 dB	Time=2025-03-27 03:52:44
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=34.47 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 34.1 dB
#
# Medida(media, máximo, minimo)=34.47,34.7,34.1 dB	Time=2025-03-27 03:52:45
#
# RS232 read data:N:035.2dB
#
# RS232 read data:N:035.5dB
#
# RS232 read data:N:034.7dB
#
# Valor medio medido=35.14 dB
#
# Valor máximo medido 35.5 dB
#
# Valor minimo medido 34.7 dB
#
# Medida(media, máximo, minimo)=35.14,35.5,34.7 dB	Time=2025-03-27 03:52:46
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.55 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 34.4 dB
#
# Medida(media, máximo, minimo)=34.55,34.7,34.4 dB	Time=2025-03-27 03:52:47
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=34.38 dB
#
# Valor máximo medido 34.9 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.38,34.9,33.8 dB	Time=2025-03-27 03:52:48
#
# RS232 read data:N:035.1dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=34.19 dB
#
# Valor máximo medido 35.1 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.19,35.1,33.6 dB	Time=2025-03-27 03:52:49
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.08 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=34.08,34.5,33.5 dB	Time=2025-03-27 03:52:50
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.86 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.86,34.2,33.5 dB	Time=2025-03-27 03:52:51
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=33.98 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.98,34.5,33.6 dB	Time=2025-03-27 03:52:52
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.9 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.9,34.2,33.6 dB	Time=2025-03-27 03:52:53
#
# RS232 read data:N:034.8dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=34.13 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=34.13,34.8,33.4 dB	Time=2025-03-27 03:52:54
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.37 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.37,33.5,33.2 dB	Time=2025-03-27 03:52:55
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:035.0dB
#
# Valor medio medido=34.06 dB
#
# Valor máximo medido 35.0 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=34.06,35.0,33.4 dB	Time=2025-03-27 03:52:56
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=34.17 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.17,34.5,33.8 dB	Time=2025-03-27 03:52:57
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.91 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.91,34.3,33.5 dB	Time=2025-03-27 03:52:58
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=34.11 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=34.11,34.6,33.5 dB	Time=2025-03-27 03:52:59
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.6dB
#
# Valor medio medido=34.21 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=34.21,34.6,33.7 dB	Time=2025-03-27 03:53:00
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.67,34.1,33.4 dB	Time=2025-03-27 03:53:01
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.45 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.45,33.7,33.2 dB	Time=2025-03-27 03:53:02
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=34.08 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.08,34.7,33.6 dB	Time=2025-03-27 03:53:03
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.64 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.64,34.0,33.3 dB	Time=2025-03-27 03:53:04
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.67,33.9,33.3 dB	Time=2025-03-27 03:53:05
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=34.15 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.15,34.4,33.9 dB	Time=2025-03-27 03:53:06
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.87 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.87,34.0,33.7 dB	Time=2025-03-27 03:53:07
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.92 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.92,34.7,33.5 dB	Time=2025-03-27 03:53:08
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=33.84 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.84,34.4,33.4 dB	Time=2025-03-27 03:53:09
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=34.0 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.0,34.1,33.9 dB	Time=2025-03-27 03:53:10
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.33 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.33,33.5,33.1 dB	Time=2025-03-27 03:53:11
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.77 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.77,34.1,33.4 dB	Time=2025-03-27 03:53:12
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.43 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.43,33.6,33.3 dB	Time=2025-03-27 03:53:13
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.66 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.66,34.1,33.2 dB	Time=2025-03-27 03:53:14
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.47 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.47,33.8,33.3 dB	Time=2025-03-27 03:53:15
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.57 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.57,33.7,33.3 dB	Time=2025-03-27 03:53:16
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.4 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.4,33.6,33.2 dB	Time=2025-03-27 03:53:17
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=33.85 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.85,34.0,33.7 dB	Time=2025-03-27 03:53:18
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.67,34.0,33.4 dB	Time=2025-03-27 03:53:19
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.74 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.74,34.2,33.3 dB	Time=2025-03-27 03:53:20
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.9 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.9,34.1,33.5 dB	Time=2025-03-27 03:53:21
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.4 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.4,33.6,33.2 dB	Time=2025-03-27 03:53:22
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.1dB
#
# Valor medio medido=33.74 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.74,34.1,33.1 dB	Time=2025-03-27 03:53:23
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.47 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.47,33.7,33.3 dB	Time=2025-03-27 03:53:24
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.5 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.5,33.5,33.5 dB	Time=2025-03-27 03:53:25
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.66 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.66,34.1,33.2 dB	Time=2025-03-27 03:53:26
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.7 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.7,33.9,33.6 dB	Time=2025-03-27 03:53:27
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.7dB
#
# Valor medio medido=34.37 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 34.2 dB
#
# Medida(media, máximo, minimo)=34.37,34.7,34.2 dB	Time=2025-03-27 03:53:28
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:033.1dB
#
# Valor medio medido=33.89 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.89,34.5,33.1 dB	Time=2025-03-27 03:53:29
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.5 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.5,33.6,33.4 dB	Time=2025-03-27 03:53:30
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=34.13 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.13,34.3,33.9 dB	Time=2025-03-27 03:53:31
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.7 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.7,34.1,33.5 dB	Time=2025-03-27 03:53:32
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.44 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.44,33.9,33.2 dB	Time=2025-03-27 03:53:33
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.7dB
#
# Valor medio medido=34.26 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.26,34.7,33.8 dB	Time=2025-03-27 03:53:34
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=34.04 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.04,34.3,33.8 dB	Time=2025-03-27 03:53:35
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=34.1 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.1,34.3,33.9 dB	Time=2025-03-27 03:53:36
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.7 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.7,34.1,33.5 dB	Time=2025-03-27 03:53:37
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.6 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.6,33.6,33.6 dB	Time=2025-03-27 03:53:38
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.07 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=34.07,34.5,33.7 dB	Time=2025-03-27 03:53:39
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.5 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.5,33.6,33.4 dB	Time=2025-03-27 03:53:40
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.55 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.55,34.1,32.9 dB	Time=2025-03-27 03:53:41
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.55 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.55,33.7,33.4 dB	Time=2025-03-27 03:53:42
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.87 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.87,34.2,33.5 dB	Time=2025-03-27 03:53:43
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.87 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.87,34.2,33.6 dB	Time=2025-03-27 03:53:44
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=34.1 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=34.1,34.2,34.0 dB	Time=2025-03-27 03:53:45
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.55 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.55,33.7,33.4 dB	Time=2025-03-27 03:53:46
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.6 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.6,33.7,33.5 dB	Time=2025-03-27 03:53:47
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.0dB
#
# Valor medio medido=33.48 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.48,34.1,33.0 dB	Time=2025-03-27 03:53:48
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.67,34.0,33.2 dB	Time=2025-03-27 03:53:49
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.06 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.06,34.5,33.6 dB	Time=2025-03-27 03:53:50
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=33.55 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.55,34.2,33.1 dB	Time=2025-03-27 03:53:51
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=34.04 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.04,34.5,33.6 dB	Time=2025-03-27 03:53:52
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=33.77 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.77,34.0,33.5 dB	Time=2025-03-27 03:53:53
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.9 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.9,34.1,33.7 dB	Time=2025-03-27 03:53:54
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.61 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.61,34.1,33.3 dB	Time=2025-03-27 03:53:55
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:032.9dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=33.82 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.82,34.3,32.9 dB	Time=2025-03-27 03:53:56
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.1dB
#
# Valor medio medido=33.27 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.27,33.4,33.1 dB	Time=2025-03-27 03:53:57
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:032.7dB
#
# Valor medio medido=33.43 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 32.7 dB
#
# Medida(media, máximo, minimo)=33.43,34.1,32.7 dB	Time=2025-03-27 03:53:58
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.67,33.9,33.3 dB	Time=2025-03-27 03:53:59
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.4 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.4,33.6,33.2 dB	Time=2025-03-27 03:54:00
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.44 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.44,33.8,33.2 dB	Time=2025-03-27 03:54:01
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.45 dB
#
# Valor máximo medido 33.5 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.45,33.5,33.4 dB	Time=2025-03-27 03:54:02
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.67,33.7,33.6 dB	Time=2025-03-27 03:54:03
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.0dB
#
# Valor medio medido=33.79 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.79,34.4,33.0 dB	Time=2025-03-27 03:54:04
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.74 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.74,34.1,33.3 dB	Time=2025-03-27 03:54:05
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.95 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.95,34.1,33.8 dB	Time=2025-03-27 03:54:06
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.5 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.5,33.7,33.3 dB	Time=2025-03-27 03:54:07
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.1dB
#
# Valor medio medido=33.61 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.61,34.0,33.1 dB	Time=2025-03-27 03:54:08
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.57 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.57,33.6,33.5 dB	Time=2025-03-27 03:54:09
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.85 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.85,34.0,33.7 dB	Time=2025-03-27 03:54:10
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.64 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.64,33.9,33.4 dB	Time=2025-03-27 03:54:11
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.67,33.9,33.4 dB	Time=2025-03-27 03:54:12
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=34.04 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=34.04,34.4,33.5 dB	Time=2025-03-27 03:54:13
#
# RS232 read data:N:033.0dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.41 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.41,33.8,33.0 dB	Time=2025-03-27 03:54:14
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.0dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.51 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.51,33.8,33.0 dB	Time=2025-03-27 03:54:15
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.53 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.53,33.6,33.4 dB	Time=2025-03-27 03:54:16
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.73 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.73,33.9,33.6 dB	Time=2025-03-27 03:54:17
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.85 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.85,33.9,33.8 dB	Time=2025-03-27 03:54:18
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.54 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.54,34.0,33.2 dB	Time=2025-03-27 03:54:19
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.75 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.75,34.5,33.2 dB	Time=2025-03-27 03:54:20
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.61 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.61,34.1,33.3 dB	Time=2025-03-27 03:54:21
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.9 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.9,34.0,33.8 dB	Time=2025-03-27 03:54:22
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.27 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.27,34.5,33.9 dB	Time=2025-03-27 03:54:23
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=34.01 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=34.01,34.5,33.7 dB	Time=2025-03-27 03:54:24
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.81 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.81,34.3,33.5 dB	Time=2025-03-27 03:54:25
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.35 dB
#
# Valor máximo medido 33.4 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.35,33.4,33.3 dB	Time=2025-03-27 03:54:26
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=34.03 dB
#
# Valor máximo medido 34.9 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=34.03,34.9,33.2 dB	Time=2025-03-27 03:54:27
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:034.9dB
#
# Valor medio medido=34.54 dB
#
# Valor máximo medido 34.9 dB
#
# Valor minimo medido 34.3 dB
#
# Medida(media, máximo, minimo)=34.54,34.9,34.3 dB	Time=2025-03-27 03:54:28
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.64 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.64,33.9,33.4 dB	Time=2025-03-27 03:54:29
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=34.15 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 34.1 dB
#
# Medida(media, máximo, minimo)=34.15,34.2,34.1 dB	Time=2025-03-27 03:54:30
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=34.1 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.1,34.3,33.8 dB	Time=2025-03-27 03:54:31
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.97 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.97,34.4,33.5 dB	Time=2025-03-27 03:54:32
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.9 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=33.9,33.9,33.9 dB	Time=2025-03-27 03:54:33
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.66 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.66,34.1,33.2 dB	Time=2025-03-27 03:54:34
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.4 dB
#
# Valor máximo medido 33.6 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.4,33.6,33.1 dB	Time=2025-03-27 03:54:35
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=34.0 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.0,34.1,33.8 dB	Time=2025-03-27 03:54:36
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=34.05 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.05,34.3,33.8 dB	Time=2025-03-27 03:54:37
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=33.94 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.94,34.3,33.5 dB	Time=2025-03-27 03:54:38
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.04 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.04,34.5,33.6 dB	Time=2025-03-27 03:54:39
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=34.2 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.2,34.4,33.9 dB	Time=2025-03-27 03:54:40
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.75 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.75,34.0,33.5 dB	Time=2025-03-27 03:54:41
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.2dB
#
# Valor medio medido=33.57 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.57,34.0,33.2 dB	Time=2025-03-27 03:54:42
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=34.01 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=34.01,34.4,33.7 dB	Time=2025-03-27 03:54:43
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.7dB
#
# Valor medio medido=34.24 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.24,34.7,33.8 dB	Time=2025-03-27 03:54:44
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.8 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.8,33.8,33.8 dB	Time=2025-03-27 03:54:45
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.9 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.9,34.1,33.7 dB	Time=2025-03-27 03:54:46
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.84 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.84,34.3,33.5 dB	Time=2025-03-27 03:54:47
#
# RS232 read data:N:035.0dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:035.1dB
#
# Valor medio medido=34.81 dB
#
# Valor máximo medido 35.1 dB
#
# Valor minimo medido 34.3 dB
#
# Medida(media, máximo, minimo)=34.81,35.1,34.3 dB	Time=2025-03-27 03:54:48
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.85 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.85,34.1,33.6 dB	Time=2025-03-27 03:54:49
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=33.97 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.97,34.2,33.8 dB	Time=2025-03-27 03:54:50
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=34.31 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.31,34.7,33.8 dB	Time=2025-03-27 03:54:51
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:032.9dB
#
# Valor medio medido=33.68 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.68,34.4,32.9 dB	Time=2025-03-27 03:54:52
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.81 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.81,34.3,33.5 dB	Time=2025-03-27 03:54:53
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.87 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.87,34.0,33.8 dB	Time=2025-03-27 03:54:54
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.86 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.86,34.7,33.3 dB	Time=2025-03-27 03:54:55
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=34.41 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=34.41,34.8,34.0 dB	Time=2025-03-27 03:54:56
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.27 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.27,34.5,33.8 dB	Time=2025-03-27 03:54:57
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=33.94 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.94,34.4,33.6 dB	Time=2025-03-27 03:54:58
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=34.2 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 34.1 dB
#
# Medida(media, máximo, minimo)=34.2,34.4,34.1 dB	Time=2025-03-27 03:54:59
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.7dB
#
# Valor medio medido=34.17 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.17,34.7,33.6 dB	Time=2025-03-27 03:55:00
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.0dB
#
# Valor medio medido=33.58 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.0 dB
#
# Medida(media, máximo, minimo)=33.58,34.3,33.0 dB	Time=2025-03-27 03:55:01
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=34.27 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 34.1 dB
#
# Medida(media, máximo, minimo)=34.27,34.4,34.1 dB	Time=2025-03-27 03:55:02
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.34 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.34,34.7,33.8 dB	Time=2025-03-27 03:55:03
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.15 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.15,34.4,33.9 dB	Time=2025-03-27 03:55:04
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:035.3dB
#
# Valor medio medido=34.59 dB
#
# Valor máximo medido 35.3 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.59,35.3,33.9 dB	Time=2025-03-27 03:55:05
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=34.17 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=34.17,34.3,34.0 dB	Time=2025-03-27 03:55:06
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.8 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.8,33.9,33.7 dB	Time=2025-03-27 03:55:07
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.94 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.94,34.3,33.4 dB	Time=2025-03-27 03:55:08
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.84 dB
#
# ...
#
# Medida(media, máximo, minimo)=33.5,33.5,33.5 dB	Time=2025-03-27 03:55:38
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.97 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.97,34.4,33.7 dB	Time=2025-03-27 03:55:39
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=34.01 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=34.01,34.5,33.4 dB	Time=2025-03-27 03:55:40
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:032.8dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=33.55 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 32.8 dB
#
# Medida(media, máximo, minimo)=33.55,34.3,32.8 dB	Time=2025-03-27 03:55:41
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.85 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.85,33.9,33.8 dB	Time=2025-03-27 03:55:42
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.84 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.84,34.1,33.5 dB	Time=2025-03-27 03:55:43
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.73 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.73,33.9,33.6 dB	Time=2025-03-27 03:55:44
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.77 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.77,34.0,33.4 dB	Time=2025-03-27 03:55:45
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:035.1dB
#
# Valor medio medido=34.47 dB
#
# Valor máximo medido 35.1 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.47,35.1,33.8 dB	Time=2025-03-27 03:55:46
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.14 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=34.14,34.4,34.0 dB	Time=2025-03-27 03:55:47
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.3 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 34.2 dB
#
# Medida(media, máximo, minimo)=34.3,34.4,34.2 dB	Time=2025-03-27 03:55:48
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.67,33.8,33.5 dB	Time=2025-03-27 03:55:49
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=34.16 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.16,34.5,33.8 dB	Time=2025-03-27 03:55:50
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.96 dB
#
# Valor máximo medido 34.9 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.96,34.9,33.2 dB	Time=2025-03-27 03:55:51
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.57 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.57,33.9,33.3 dB	Time=2025-03-27 03:55:52
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=34.1 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.1,34.3,33.9 dB	Time=2025-03-27 03:55:53
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.67,33.9,33.3 dB	Time=2025-03-27 03:55:54
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.74 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.74,34.1,33.3 dB	Time=2025-03-27 03:55:55
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.57 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.57,33.7,33.4 dB	Time=2025-03-27 03:55:56
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=34.0 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.0,34.2,33.8 dB	Time=2025-03-27 03:55:57
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=34.11 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=34.11,34.6,33.7 dB	Time=2025-03-27 03:55:58
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=35.71 dB
#
# Valor máximo medido 38.3 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=35.71,38.3,34.0 dB	Time=2025-03-27 03:55:59
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.84 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.84,34.3,33.4 dB	Time=2025-03-27 03:56:00
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.7 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.7,33.8,33.6 dB	Time=2025-03-27 03:56:01
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.94 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.94,34.4,33.6 dB	Time=2025-03-27 03:56:02
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=33.77 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.77,33.8,33.7 dB	Time=2025-03-27 03:56:03
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.61 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.61,34.2,33.3 dB	Time=2025-03-27 03:56:04
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.85 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.85,34.1,33.6 dB	Time=2025-03-27 03:56:05
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.4dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.74 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.74,34.0,33.4 dB	Time=2025-03-27 03:56:06
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=34.04 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.04,34.4,33.6 dB	Time=2025-03-27 03:56:07
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:032.9dB
#
# Valor medio medido=33.76 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 32.9 dB
#
# Medida(media, máximo, minimo)=33.76,34.5,32.9 dB	Time=2025-03-27 03:56:08
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.3 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 34.2 dB
#
# Medida(media, máximo, minimo)=34.3,34.4,34.2 dB	Time=2025-03-27 03:56:09
#
# RS232 read data:N:034.9dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=34.02 dB
#
# Valor máximo medido 34.9 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=34.02,34.9,33.5 dB	Time=2025-03-27 03:56:10
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=34.07 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=34.07,34.3,33.7 dB	Time=2025-03-27 03:56:11
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=33.8 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.8,34.0,33.5 dB	Time=2025-03-27 03:56:12
#
# RS232 read data:N:033.1dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=33.67 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.1 dB
#
# Medida(media, máximo, minimo)=33.67,34.2,33.1 dB	Time=2025-03-27 03:56:13
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=34.08 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=34.08,34.7,33.5 dB	Time=2025-03-27 03:56:14
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.1 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.1,34.4,33.8 dB	Time=2025-03-27 03:56:15
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.0dB
#
# Valor medio medido=34.0 dB
#
# Valor máximo medido 34.0 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=34.0,34.0,34.0 dB	Time=2025-03-27 03:56:16
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=34.07 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.07,34.3,33.8 dB	Time=2025-03-27 03:56:17
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:034.6dB
#
# Valor medio medido=34.14 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=34.14,34.6,33.7 dB	Time=2025-03-27 03:56:18
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=33.63 dB
#
# Valor máximo medido 33.7 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=33.63,33.7,33.6 dB	Time=2025-03-27 03:56:19
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.3 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 34.2 dB
#
# Medida(media, máximo, minimo)=34.3,34.4,34.2 dB	Time=2025-03-27 03:56:20
#
# RS232 read data:N:034.6dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.34 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 34.0 dB
#
# Medida(media, máximo, minimo)=34.34,34.6,34.0 dB	Time=2025-03-27 03:56:21
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.4dB
#
# Valor medio medido=33.88 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.4 dB
#
# Medida(media, máximo, minimo)=33.88,34.4,33.4 dB	Time=2025-03-27 03:56:22
#
# RS232 read data:N:034.5dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.6dB
#
# Valor medio medido=34.11 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.11,34.5,33.6 dB	Time=2025-03-27 03:56:23
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.2dB
#
# Valor medio medido=34.0 dB
#
# Valor máximo medido 34.2 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.0,34.2,33.8 dB	Time=2025-03-27 03:56:24
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=34.0 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=34.0,34.3,33.7 dB	Time=2025-03-27 03:56:25
#
# RS232 read data:N:033.2dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=33.81 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.2 dB
#
# Medida(media, máximo, minimo)=33.81,34.3,33.2 dB	Time=2025-03-27 03:56:26
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.6dB
#
# Valor medio medido=34.18 dB
#
# Valor máximo medido 34.6 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.18,34.6,33.6 dB	Time=2025-03-27 03:56:27
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.95 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=33.95,34.1,33.8 dB	Time=2025-03-27 03:56:28
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.63 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.63,33.8,33.5 dB	Time=2025-03-27 03:56:29
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=34.13 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.13,34.3,33.9 dB	Time=2025-03-27 03:56:30
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:035.2dB
#
# Valor medio medido=34.1 dB
#
# Valor máximo medido 35.2 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=34.1,35.2,33.5 dB	Time=2025-03-27 03:56:31
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=33.9 dB
#
# Valor máximo medido 34.1 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=33.9,34.1,33.7 dB	Time=2025-03-27 03:56:32
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.64 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.64,33.9,33.3 dB	Time=2025-03-27 03:56:33
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:034.4dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=34.07 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=34.07,34.4,33.7 dB	Time=2025-03-27 03:56:34
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:034.7dB
#
# RS232 read data:N:034.3dB
#
# Valor medio medido=34.37 dB
#
# Valor máximo medido 34.7 dB
#
# Valor minimo medido 34.1 dB
#
# Medida(media, máximo, minimo)=34.37,34.7,34.1 dB	Time=2025-03-27 03:56:35
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=33.65 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.65,33.8,33.5 dB	Time=2025-03-27 03:56:36
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.7dB
#
# Valor medio medido=34.0 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.7 dB
#
# Medida(media, máximo, minimo)=34.0,34.3,33.7 dB	Time=2025-03-27 03:56:37
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.0dB
#
# RS232 read data:N:033.8dB
#
# Valor medio medido=34.04 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.04,34.3,33.8 dB	Time=2025-03-27 03:56:38
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.5dB
#
# Valor medio medido=34.21 dB
#
# Valor máximo medido 34.5 dB
#
# Valor minimo medido 33.9 dB
#
# Medida(media, máximo, minimo)=34.21,34.5,33.9 dB	Time=2025-03-27 03:56:39
#
# RS232 read data:N:034.2dB
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:033.3dB
#
# Valor medio medido=33.94 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.94,34.3,33.3 dB	Time=2025-03-27 03:56:40
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.9dB
#
# RS232 read data:N:034.8dB
#
# Valor medio medido=34.18 dB
#
# Valor máximo medido 34.8 dB
#
# Valor minimo medido 33.8 dB
#
# Medida(media, máximo, minimo)=34.18,34.8,33.8 dB	Time=2025-03-27 03:56:41
#
# RS232 read data:N:034.3dB
#
# RS232 read data:N:034.1dB
#
# RS232 read data:N:034.1dB
#
# Valor medio medido=34.17 dB
#
# Valor máximo medido 34.3 dB
#
# Valor minimo medido 34.1 dB
#
# Medida(media, máximo, minimo)=34.17,34.3,34.1 dB	Time=2025-03-27 03:56:42
#
# RS232 read data:N:033.6dB
#
# RS232 read data:N:034.4dB
#
# Valor medio medido=34.01 dB
#
# Valor máximo medido 34.4 dB
#
# Valor minimo medido 33.6 dB
#
# Medida(media, máximo, minimo)=34.01,34.4,33.6 dB	Time=2025-03-27 03:56:43
#
# RS232 read data:N:033.8dB
#
# RS232 read data:N:033.5dB
#
# RS232 read data:N:033.5dB
#
# Valor medio medido=33.6 dB
#
# Valor máximo medido 33.8 dB
#
# Valor minimo medido 33.5 dB
#
# Medida(media, máximo, minimo)=33.6,33.8,33.5 dB	Time=2025-03-27 03:56:44
#
# RS232 read data:N:033.7dB
#
# RS232 read data:N:033.3dB
#
# RS232 read data:N:033.9dB
#
# Valor medio medido=33.64 dB
#
# Valor máximo medido 33.9 dB
#
# Valor minimo medido 33.3 dB
#
# Medida(media, máximo, minimo)=33.64,33.9,33.3 dB	Time=2025-03-27 03:56:45
#
# RS232 read data:
#
# RS232 cerrando el puerto serie.
#
# Measurements saved to log_files/medida_2/type_2 Thu 2025-03-27 03h51m45s.json

# %%
import matplotlib.pyplot as plt

pic_path = 'Pics/medida_2/type_2 '+format_time(time.time(), True)

# Load the measurements from the JSON file.
with open(json_file, 'r') as f:
    measurements = json.load(f)

times = [m["time"] for m in measurements]
means = [m["mean"] for m in measurements]
maxs = [m["max"] for m in measurements]
mins = [m["min"] for m in measurements]

m_number = list(range(0,len(measurements)))

# Plot the measurements
plt.figure(figsize=(10, 6))
plt.plot(m_number, means, label="Mean", color="blue")
plt.plot(m_number, maxs, label="Max", color="red", linestyle="--")
plt.plot(m_number, mins, label="Min", color="green", linestyle="--")
plt.xlim(0, len(measurements)-1)
plt.ylim(30, 60)
plt.xlabel("Samples")
plt.ylabel("Sound Level (dB)")
plt.title("Sound Level Measurements Over Time")
plt.legend()
plt.grid(True)
plt.savefig(pic_path+'.png')
plt.show()

# %% [markdown]
# ## Ejemplo de lectura directa del Serial y almacenamiento en un vector.

# %%
import serial
import math

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'


# Sound level meter.
port_AZ8922 = SELECTED_PORT
ser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port


# Reset the arrays.
sound_level = []

#while(ser.connected):
for x in range(10):
    output = ser.readline().decode('utf-8', 'ignore')
    output = output.strip()
    #print("RS232 read data:"+str(output)+"\n")
    if output.startswith('N:') and output.endswith('dB'):
        salida_texto=float(output.split(':')[1].split('dB')[0])
        sound_level.append(salida_texto) # Para concatenar los valores y formar un Vector/Array
        print("RS232 db="+str(salida_texto)+"\n")     
    
ser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el 
#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia
#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.


# Round up.
#sound_level_mean = round(sound_level_mean,2)
#print("Sound Level(Media)="+str(sound_level_mean)+"\n") 

#Calculamos el máximo en dB
sound_level_max = max(sound_level) #Esto es el máximo de un vector
print(Green + "Sound Level(Max)="+str(sound_level_max)+" db\n") 

#Calculamos el mínomo en dB
sound_level_min = min(sound_level)
print(Magenta+"Sound Level(Min)="+str(sound_level_min)+" db\n") 

#Calculamos la suma de los valores sin decibelios
sound_level_linear = [math.pow(10,x/20) for x in sound_level] 
print(Blue +"Sound Level(linear)="+str(sound_level_linear)+"\n") 

#Pasamos la suma de lo medido en dB
sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
sound_level_mean = 20*math.log10(sound_level_mean)
print(Red + "Sound Level(Mean)="+str(sound_level_mean)+" db\n")
# Out:
# RS232 db=33.1
#
# RS232 db=34.4
#
# RS232 db=34.1
#
# RS232 db=33.3
#
# RS232 db=34.8
#
# RS232 db=33.5
#
# RS232 db=33.4
#
# RS232 db=33.7
#
# RS232 db=34.4
#
# RS232 db=33.9
#
# Sound Level(Max)=34.8 db
#
# Sound Level(Min)=33.1 db
#
# Sound Level(linear)=[45.18559443749224, 52.48074602497726, 50.69907082747044, 46.23810213992601, 54.95408738576243, 47.315125896148054, 46.77351412871981, 48.41723675840994, 52.48074602497726, 49.545019080479]
#
# Sound Level(Mean)=33.87610797092767 db
