# %% [markdown]
# # Medida 2
# ## Piso con ventana abierta
#
#  **Ubicacion**: Piso residencial (interior) con ventana abierta.
#
#  **Metodologia**:
#  * Medicion de los niveles de presion sonora en el interior del piso, con el fin de cuantificar la intrusion de ruido exterior (trafico, obras urbanas, vecindario etc.).
#  * Toma de mediciones en tres franjas horarias diurnas: manana (10:00-13:00), siesta (14:00-17:00) y tarde (18:00-20:00).
#  * Toma de mediciones en dos franjas horarias nocturnas: tarde-noche (20:00-22:00) y noche (00:00-02:00).
#  * Toma de mediciones en diferentes dıas de la semana: fin de semana (sabado) y un dıa laboral.

# %%
import os

# initialize directory to store json files with sampled data. 
path = 'log_files/medida_2'
if not os.path.exists(path):
    os.makedirs(path)

# global port variable
SELECTED_PORT = 'COM3'

# %%
import threading
import time
import math
import serial  
import logging
import json

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'

def format_time(unix_epoch, isFileName=False):
    """format time in unix epoch to human-readable values"""
    if isFileName:
        day = time.ctime(unix_epoch)[:3]
        formatted_time = day+time.strftime(" %Y-%m-%d %Hh%Mm%Ss", time.localtime(unix_epoch))
        return formatted_time
    formatted_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(unix_epoch))
    return str(formatted_time)

#_____________________________________________________________________________________________________________________

class AZ8922:
    """class for sonometer object"""

    def __init__(self, port):
        self.port = port
        self.ser = None
        self.running = True
        self.connected = True
        self.sound_level = []
        print(Green+"AZ8922: Iniciando la clase.\n",flush=True)

    def get_sonometry(self):
        """returns mean and max value of the measurement"""
        if self.sound_level:
            sound_level_max = max(self.sound_level)
            sound_level_min = min(self.sound_level)
            sound_level_linear = [math.pow(10,x/20) for x in self.sound_level] 
            sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
            sound_level_mean = 20*math.log10(sound_level_mean) 
        else:
            sound_level_max = -1
            sound_level_min = -1
            sound_level_mean = -1
            
        # Check if the AZ8922 is off.
        # if self.connected and not self.sound_level: logging.warning('AZ8922 is off.')
        
        # Reset the arrays.
        self.sound_level = []
        
        # Round up.
        sound_level_mean = round(sound_level_mean,2)
        
        # logging.info(f'Sonometry AZ8922:{sound_level_mean}') 
        # logging.info('Sonometry AZ8922:%f' % sound_level_mean) 
        # if not self.connected: logging.warning('AZ8922 is disconnected.')
         
        return sound_level_mean, sound_level_max, sound_level_min

    def run_thread(self):
        """run thread to capture measurements from sonometer"""
        thread = threading.Thread(target=self.sonometro_thread, daemon=True)
        thread.start()

    def stop_thread(self):
        """stop sonometer thread"""
        self.running = False
        self.connected = False
        if self.ser is not None:
            self.ser.close()
            print(Red+"RS232 cerrando el puerto serie.\n",flush=True)
            

    def sonometro_thread(self):
        """reads values from serial port and updates sound level attribute"""
        while self.running:
            try:
                # If disconnected, check connection every 5 seconds.
                if not self.connected: time.sleep(5)
                self.ser = serial.Serial(self.port, 2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)
                self.connected = True
                print(Yellow+"RS232 abriendo el puerto serie.\n",flush=True)

                #Para sacar valores intermedios
                #print("Self.conected="+str(self.connected)+"\n")
                #print("self.ser.in_waiting="+str(self.ser.in_waiting)+"\n")
                #print("self.running="+str(self.running)+"\n")
                
                #while(self.connected and self.ser.in_waiting and self.running):
                while(self.connected and self.running):
                    output = self.ser.readline().decode('utf-8', 'ignore')
                    output = output.strip()
                    print(Yellow+"RS232 read data:"+str(output)+"\n",flush=True)
                    if output.startswith('N:') and output.endswith('dB'):
                        self.sound_level.append(float(output.split(':')[1].split('dB')[0]))

            except (serial.serialutil.SerialException, OSError):
                # Thread is not halted upon sensor disconnection.
                self.connected = False

# %% [markdown]
# ## Ejemplo toma de 10 medidas

# %%
# User Params.
MEASURE_PERIOD = 1  # How often (seconds) we poll for measurements.
log_file = 'log_files/log.txt'
json_file = path+'/type_1 '+format_time(time.time(), True)+'.json'

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  # Thread running condition.


#Llamada a la función y crea objeto de la clase AZ8922
port_AZ8922 = SELECTED_PORT
sound_level_meter = AZ8922(port_AZ8922)

print(Green+"Arrancamos el proceso para medir.\n")
sound_level_meter.run_thread()

# List to store measurements.
measurements = []

# Main thread.
for x in range(10):

        time.sleep(MEASURE_PERIOD)
        current_time = format_time(time.time())

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level_media, sound_level_maximo, sound_level_minimo = sound_level_meter.get_sonometry()
        print(Grey+"Valor medio medido="+ str(sound_level_media)+ " dB\n")
        print(Grey+"Valor máximo medido "+ str(sound_level_maximo)+ " dB\n")
        print(Grey+"Valor minimo medido "+ str(sound_level_minimo)+ " dB\n")
        #print(Magenta +"Medida(media, máximo)="+ str(sound_level)+ " dB\n" )
        print(Magenta +"Medida(media, máximo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+  " dB" +Cyan+"\tTime=" + current_time+"\n")
        logging.debug("Medida(media, maximo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+  " dB    Time=" + current_time+"\n")
        
        # Store the measurement in a dictionary
        measurement = {
            "time": current_time,
            "mean": sound_level_media,
            "max": sound_level_maximo,
            "min": sound_level_minimo
        }
        measurements.append(measurement)
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()

# Save measurements to a JSON file
with open(json_file, 'w') as f:
    json.dump(measurements, f, indent=4)
print(Green + f"Measurements saved to {json_file}\n")
# Out:
# AZ8922: Iniciando la clase.
#
# Arrancamos el proceso para medir.
#
# RS232 abriendo el puerto serie.
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:041.3dB
#
# Valor medio medido=40.86 dB
#
# Valor máximo medido 41.3 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo)=40.86,41.3 dB	Time=2025-03-26 21:30:40
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:041.3dB
#
# Valor medio medido=41.05 dB
#
# Valor máximo medido 41.3 dB
#
# Valor minimo medido 40.8 dB
#
# Medida(media, máximo)=41.05,41.3 dB	Time=2025-03-26 21:30:41
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:040.0dB
#
# Valor medio medido=40.35 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 40.0 dB
#
# Medida(media, máximo)=40.35,41.0 dB	Time=2025-03-26 21:30:42
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.86 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo)=39.86,40.3 dB	Time=2025-03-26 21:30:43
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=39.37 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 38.9 dB
#
# Medida(media, máximo)=39.37,39.6 dB	Time=2025-03-26 21:30:44
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:039.0dB
#
# Valor medio medido=39.67 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo)=39.67,40.3 dB	Time=2025-03-26 21:30:45
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.74 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo)=39.74,40.2 dB	Time=2025-03-26 21:30:46
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=39.65 dB
#
# Valor máximo medido 39.7 dB
#
# Valor minimo medido 39.6 dB
#
# Medida(media, máximo)=39.65,39.7 dB	Time=2025-03-26 21:30:47
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=40.28 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo)=40.28,41.0 dB	Time=2025-03-26 21:30:48
#
# RS232 read data:N:041.5dB
#
# RS232 read data:N:040.8dB
#
# Valor medio medido=41.16 dB
#
# Valor máximo medido 41.5 dB
#
# Valor minimo medido 40.8 dB
#
# Medida(media, máximo)=41.16,41.5 dB	Time=2025-03-26 21:30:49
#
# RS232 read data:
#
# RS232 cerrando el puerto serie.
#
# Measurements saved to log_files/medida_2/type_1 Wed 2025-03-26 21h30m39s.json

# %%
import matplotlib.pyplot as plt

pic_path = 'Pics/medida_2/type_1 '+format_time(time.time(), True)

# Load the measurements from the JSON file.
with open(json_file, 'r') as f:
    measurements = json.load(f)

times = [m["time"] for m in measurements]
means = [m["mean"] for m in measurements]
maxs = [m["max"] for m in measurements]
mins = [m["min"] for m in measurements]

m_number = list(range(0,len(measurements)))

# Plot the measurements
plt.figure(figsize=(10, 6))
plt.plot(m_number, means, label="Mean", color="blue")
plt.plot(m_number, maxs, label="Max", color="red", linestyle="--")
plt.plot(m_number, mins, label="Min", color="green", linestyle="--")
plt.xlim(0, len(measurements)-1)
plt.xlabel("Samples")
plt.ylabel("Sound Level (dB)")
plt.title("Sound Level Measurements Over Time")
plt.legend()
plt.grid(True)
plt.savefig(pic_path+'.png')
plt.show()

# %%
pic_path = 'Pics/medida_2/type_1_max '+format_time(time.time(), True)

plt.plot(maxs,'b',maxs,'ro') #Más opciones de plot aqui: https://matplotlib.org/tutorials/introductory/pyplot.html
plt.title('Max Sound Level sampled')
plt.ylabel('Sound Level [dB]')
plt.xlim(0, len(measurements)-1)
plt.xlabel('Samples')
plt.grid()
plt.savefig(pic_path+'.png')
plt.show()

# %% [markdown]
# ## Ejemplo toma de medidas para 5 minutos

# %%
# User Params.
MEASURE_PERIOD = 1  # How often (seconds) we poll for measurements.
log_file = 'log_files/log.txt'
json_file = path+'/type_2 '+format_time(time.time(), True)+'.json'
MEASUREMENT_DURATION = 5 * 60  # 5 minutes


# Get the start and stop time for the measurement.
start_time = time.time()
end_time = start_time + MEASUREMENT_DURATION

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  


#Llamada a la función y crea objeto de la clase AZ8922
port_AZ8922 = SELECTED_PORT
sound_level_meter = AZ8922(port_AZ8922)

print(Green+"Arrancamos el proceso para medir.\n")
sound_level_meter.run_thread()

measurements = []

# Main thread.
while time.time() < end_time:
        # Sleep for the measurement period
        time.sleep(MEASURE_PERIOD)
        current_time = format_time(time.time())

        # Store the measurement in a dictionary
        measurement = {
            "time": current_time,
            "mean": sound_level_media,
            "max": sound_level_maximo,
            "min": sound_level_minimo
        }
        measurements.append(measurement)

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level_media, sound_level_maximo, sound_level_minimo = sound_level_meter.get_sonometry()
        
        print(Grey+"Valor medio medido="+ str(sound_level_media)+ " dB\n")
        print(Grey+"Valor máximo medido "+ str(sound_level_maximo)+ " dB\n")
        print(Grey+"Valor minimo medido "+ str(sound_level_minimo)+ " dB\n")

        print(Magenta +"Medida(media, máximo, minimo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+","+ str(sound_level_minimo)+  " dB" +Cyan+"\tTime=" + current_time+"\n")
        logging.debug("Medida(media, maximo, minimo)="+ str(sound_level_media)+","+ str(sound_level_maximo)+","+ str(sound_level_minimo)+  " dB    Time=" + current_time+"\n")
        
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()

# Save measurements to a JSON file
with open(json_file, 'w') as f:
    json.dump(measurements, f, indent=4)
print(Green + f"Measurements saved to {json_file}\n")
# Out:
# AZ8922: Iniciando la clase.
#
# Arrancamos el proceso para medir.
#
# RS232 abriendo el puerto serie.
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:041.5dB
#
# Valor medio medido=41.16 dB
#
# Valor máximo medido 41.5 dB
#
# Valor minimo medido 40.8 dB
#
# Medida(media, máximo, minimo)=41.16,41.5,40.8 dB	Time=2025-03-26 21:59:16
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:041.5dB
#
# Valor medio medido=40.78 dB
#
# Valor máximo medido 41.5 dB
#
# Valor minimo medido 40.0 dB
#
# Medida(media, máximo, minimo)=40.78,41.5,40.0 dB	Time=2025-03-26 21:59:17
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:042.0dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=40.87 dB
#
# Valor máximo medido 42.0 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=40.87,42.0,40.1 dB	Time=2025-03-26 21:59:18
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=40.05 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.05,40.2,39.9 dB	Time=2025-03-26 21:59:19
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=40.42 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=40.42,41.0,39.8 dB	Time=2025-03-26 21:59:20
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=39.44 dB
#
# Valor máximo medido 39.8 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.44,39.8,39.2 dB	Time=2025-03-26 21:59:21
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=40.25 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=40.25,40.4,40.1 dB	Time=2025-03-26 21:59:22
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:046.4dB
#
# Valor medio medido=42.52 dB
#
# Valor máximo medido 46.4 dB
#
# Valor minimo medido 39.6 dB
#
# Medida(media, máximo, minimo)=42.52,46.4,39.6 dB	Time=2025-03-26 21:59:23
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:040.7dB
#
# Valor medio medido=40.36 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 40.0 dB
#
# Medida(media, máximo, minimo)=40.36,40.7,40.0 dB	Time=2025-03-26 21:59:24
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=39.73 dB
#
# Valor máximo medido 39.9 dB
#
# Valor minimo medido 39.6 dB
#
# Medida(media, máximo, minimo)=39.73,39.9,39.6 dB	Time=2025-03-26 21:59:25
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:039.1dB
#
# Valor medio medido=39.0 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 38.9 dB
#
# Medida(media, máximo, minimo)=39.0,39.1,38.9 dB	Time=2025-03-26 21:59:26
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=40.6 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo, minimo)=40.6,41.0,40.4 dB	Time=2025-03-26 21:59:27
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.01 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=39.01,39.4,38.6 dB	Time=2025-03-26 21:59:28
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:040.6dB
#
# Valor medio medido=40.11 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=40.11,40.6,39.7 dB	Time=2025-03-26 21:59:29
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:040.7dB
#
# Valor medio medido=40.36 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 40.0 dB
#
# Medida(media, máximo, minimo)=40.36,40.7,40.0 dB	Time=2025-03-26 21:59:30
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=40.11 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 39.6 dB
#
# Medida(media, máximo, minimo)=40.11,40.6,39.6 dB	Time=2025-03-26 21:59:31
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:040.6dB
#
# Valor medio medido=40.6 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo, minimo)=40.6,40.8,40.4 dB	Time=2025-03-26 21:59:32
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:041.3dB
#
# Valor medio medido=40.72 dB
#
# Valor máximo medido 41.3 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=40.72,41.3,40.1 dB	Time=2025-03-26 21:59:33
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=40.24 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=40.24,40.8,39.7 dB	Time=2025-03-26 21:59:34
#
# RS232 read data:N:041.5dB
#
# RS232 read data:N:043.0dB
#
# Valor medio medido=42.28 dB
#
# Valor máximo medido 43.0 dB
#
# Valor minimo medido 41.5 dB
#
# Medida(media, máximo, minimo)=42.28,43.0,41.5 dB	Time=2025-03-26 21:59:35
#
# RS232 read data:N:042.4dB
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:041.5dB
#
# Valor medio medido=41.56 dB
#
# Valor máximo medido 42.4 dB
#
# Valor minimo medido 40.7 dB
#
# Medida(media, máximo, minimo)=41.56,42.4,40.7 dB	Time=2025-03-26 21:59:36
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:040.7dB
#
# Valor medio medido=40.5 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 40.3 dB
#
# Medida(media, máximo, minimo)=40.5,40.7,40.3 dB	Time=2025-03-26 21:59:37
#
# RS232 read data:N:041.8dB
#
# RS232 read data:N:042.1dB
#
# Valor medio medido=41.95 dB
#
# Valor máximo medido 42.1 dB
#
# Valor minimo medido 41.8 dB
#
# Medida(media, máximo, minimo)=41.95,42.1,41.8 dB	Time=2025-03-26 21:59:38
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:042.4dB
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=41.34 dB
#
# Valor máximo medido 42.4 dB
#
# Valor minimo medido 40.5 dB
#
# Medida(media, máximo, minimo)=41.34,42.4,40.5 dB	Time=2025-03-26 21:59:39
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=40.0 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=40.0,40.2,39.8 dB	Time=2025-03-26 21:59:40
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:041.6dB
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=40.95 dB
#
# Valor máximo medido 41.6 dB
#
# Valor minimo medido 40.5 dB
#
# Medida(media, máximo, minimo)=40.95,41.6,40.5 dB	Time=2025-03-26 21:59:41
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=41.1 dB
#
# Valor máximo medido 41.2 dB
#
# Valor minimo medido 41.0 dB
#
# Medida(media, máximo, minimo)=41.1,41.2,41.0 dB	Time=2025-03-26 21:59:42
#
# RS232 read data:N:040.9dB
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:042.9dB
#
# Valor medio medido=41.68 dB
#
# Valor máximo medido 42.9 dB
#
# Valor minimo medido 40.9 dB
#
# Medida(media, máximo, minimo)=41.68,42.9,40.9 dB	Time=2025-03-26 21:59:43
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:041.2dB
#
# Valor medio medido=41.2 dB
#
# Valor máximo medido 41.2 dB
#
# Valor minimo medido 41.2 dB
#
# Medida(media, máximo, minimo)=41.2,41.2,41.2 dB	Time=2025-03-26 21:59:44
#
# RS232 read data:N:041.9dB
#
# RS232 read data:N:043.2dB
#
# Valor medio medido=42.57 dB
#
# Valor máximo medido 43.2 dB
#
# Valor minimo medido 41.9 dB
#
# Medida(media, máximo, minimo)=42.57,43.2,41.9 dB	Time=2025-03-26 21:59:45
#
# RS232 read data:N:041.6dB
#
# RS232 read data:N:043.4dB
#
# RS232 read data:N:041.2dB
#
# Valor medio medido=42.12 dB
#
# Valor máximo medido 43.4 dB
#
# Valor minimo medido 41.2 dB
#
# Medida(media, máximo, minimo)=42.12,43.4,41.2 dB	Time=2025-03-26 21:59:46
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:040.9dB
#
# Valor medio medido=41.0 dB
#
# Valor máximo medido 41.1 dB
#
# Valor minimo medido 40.9 dB
#
# Medida(media, máximo, minimo)=41.0,41.1,40.9 dB	Time=2025-03-26 21:59:47
#
# RS232 read data:N:041.7dB
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=41.12 dB
#
# Valor máximo medido 41.7 dB
#
# Valor minimo medido 40.5 dB
#
# Medida(media, máximo, minimo)=41.12,41.7,40.5 dB	Time=2025-03-26 21:59:48
#
# RS232 read data:N:041.8dB
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:040.9dB
#
# Valor medio medido=41.24 dB
#
# Valor máximo medido 41.8 dB
#
# Valor minimo medido 40.9 dB
#
# Medida(media, máximo, minimo)=41.24,41.8,40.9 dB	Time=2025-03-26 21:59:49
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=39.4 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=39.4,39.5,39.3 dB	Time=2025-03-26 21:59:50
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:039.1dB
#
# Valor medio medido=39.47 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 38.7 dB
#
# Medida(media, máximo, minimo)=39.47,40.5,38.7 dB	Time=2025-03-26 21:59:51
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=39.95 dB
#
# Valor máximo medido 40.0 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=39.95,40.0,39.9 dB	Time=2025-03-26 21:59:52
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=39.84 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=39.84,40.4,39.4 dB	Time=2025-03-26 21:59:53
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=39.4 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=39.4,39.5,39.3 dB	Time=2025-03-26 21:59:54
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=40.44 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=40.44,40.8,40.1 dB	Time=2025-03-26 21:59:55
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:038.1dB
#
# Valor medio medido=38.3 dB
#
# Valor máximo medido 38.5 dB
#
# Valor minimo medido 38.1 dB
#
# Medida(media, máximo, minimo)=38.3,38.5,38.1 dB	Time=2025-03-26 21:59:56
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=38.87 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=38.87,39.2,38.6 dB	Time=2025-03-26 21:59:57
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=40.01 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=40.01,40.3,39.7 dB	Time=2025-03-26 21:59:58
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=39.09 dB
#
# Valor máximo medido 39.9 dB
#
# Valor minimo medido 38.4 dB
#
# Medida(media, máximo, minimo)=39.09,39.9,38.4 dB	Time=2025-03-26 21:59:59
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=39.87 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.87,40.5,39.2 dB	Time=2025-03-26 22:00:00
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.51 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=39.51,40.1,39.0 dB	Time=2025-03-26 22:00:01
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:039.0dB
#
# Valor medio medido=38.61 dB
#
# Valor máximo medido 39.0 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=38.61,39.0,38.2 dB	Time=2025-03-26 22:00:02
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=39.38 dB
#
# Valor máximo medido 39.8 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=39.38,39.8,38.8 dB	Time=2025-03-26 22:00:03
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:038.0dB
#
# Valor medio medido=38.51 dB
#
# Valor máximo medido 39.0 dB
#
# Valor minimo medido 38.0 dB
#
# Medida(media, máximo, minimo)=38.51,39.0,38.0 dB	Time=2025-03-26 22:00:04
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=38.84 dB
#
# Valor máximo medido 39.3 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=38.84,39.3,38.3 dB	Time=2025-03-26 22:00:05
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=38.81 dB
#
# Valor máximo medido 39.3 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=38.81,39.3,38.3 dB	Time=2025-03-26 22:00:06
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:038.7dB
#
# Valor medio medido=39.0 dB
#
# Valor máximo medido 40.0 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=39.0,40.0,38.2 dB	Time=2025-03-26 22:00:07
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:038.8dB
#
# Valor medio medido=39.21 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=39.21,39.6,38.8 dB	Time=2025-03-26 22:00:08
#
# RS232 read data:N:038.2dB
#
# RS232 read data:N:038.4dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=38.61 dB
#
# Valor máximo medido 39.2 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=38.61,39.2,38.2 dB	Time=2025-03-26 22:00:09
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=40.21 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.21,40.5,39.9 dB	Time=2025-03-26 22:00:10
#
# RS232 read data:N:037.6dB
#
# RS232 read data:N:037.7dB
#
# Valor medio medido=37.65 dB
#
# Valor máximo medido 37.7 dB
#
# Valor minimo medido 37.6 dB
#
# Medida(media, máximo, minimo)=37.65,37.7,37.6 dB	Time=2025-03-26 22:00:11
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=39.23 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=39.23,39.4,39.0 dB	Time=2025-03-26 22:00:12
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:040.0dB
#
# Valor medio medido=39.85 dB
#
# Valor máximo medido 40.0 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=39.85,40.0,39.7 dB	Time=2025-03-26 22:00:13
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=39.54 dB
#
# Valor máximo medido 40.0 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=39.54,40.0,39.1 dB	Time=2025-03-26 22:00:14
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:039.1dB
#
# Valor medio medido=39.2 dB
#
# Valor máximo medido 39.3 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=39.2,39.3,39.1 dB	Time=2025-03-26 22:00:15
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:041.9dB
#
# Valor medio medido=40.59 dB
#
# Valor máximo medido 41.9 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.59,41.9,39.5 dB	Time=2025-03-26 22:00:16
#
# RS232 read data:N:042.0dB
#
# RS232 read data:N:039.0dB
#
# Valor medio medido=40.63 dB
#
# Valor máximo medido 42.0 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=40.63,42.0,39.0 dB	Time=2025-03-26 22:00:17
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:040.9dB
#
# Valor medio medido=39.9 dB
#
# Valor máximo medido 40.9 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=39.9,40.9,39.3 dB	Time=2025-03-26 22:00:18
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:038.9dB
#
# Valor medio medido=39.74 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 38.9 dB
#
# Medida(media, máximo, minimo)=39.74,40.5,38.9 dB	Time=2025-03-26 22:00:19
#
# RS232 read data:N:041.5dB
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=40.13 dB
#
# Valor máximo medido 41.5 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=40.13,41.5,39.2 dB	Time=2025-03-26 22:00:20
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:040.3dB
#
# Valor medio medido=39.77 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.77,40.3,39.2 dB	Time=2025-03-26 22:00:21
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=39.88 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=39.88,40.3,39.1 dB	Time=2025-03-26 22:00:22
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:038.2dB
#
# Valor medio medido=38.66 dB
#
# Valor máximo medido 39.1 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=38.66,39.1,38.2 dB	Time=2025-03-26 22:00:23
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=39.57 dB
#
# Valor máximo medido 39.9 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=39.57,39.9,39.4 dB	Time=2025-03-26 22:00:24
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.2 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=39.2,39.4,39.0 dB	Time=2025-03-26 22:00:25
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=39.77 dB
#
# Valor máximo medido 39.9 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=39.77,39.9,39.5 dB	Time=2025-03-26 22:00:26
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=39.81 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=39.81,40.2,39.4 dB	Time=2025-03-26 22:00:27
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=39.81 dB
#
# Valor máximo medido 41.1 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=39.81,41.1,38.3 dB	Time=2025-03-26 22:00:28
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:040.0dB
#
# Valor medio medido=40.28 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=40.28,41.0,39.8 dB	Time=2025-03-26 22:00:29
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=40.06 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 39.6 dB
#
# Medida(media, máximo, minimo)=40.06,40.5,39.6 dB	Time=2025-03-26 22:00:30
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=40.18 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=40.18,40.8,39.8 dB	Time=2025-03-26 22:00:31
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:042.4dB
#
# Valor medio medido=41.37 dB
#
# Valor máximo medido 42.4 dB
#
# Valor minimo medido 40.2 dB
#
# Medida(media, máximo, minimo)=41.37,42.4,40.2 dB	Time=2025-03-26 22:00:32
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:041.6dB
#
# Valor medio medido=41.08 dB
#
# Valor máximo medido 41.6 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo, minimo)=41.08,41.6,40.4 dB	Time=2025-03-26 22:00:33
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:040.0dB
#
# Valor medio medido=40.25 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 40.0 dB
#
# Medida(media, máximo, minimo)=40.25,40.5,40.0 dB	Time=2025-03-26 22:00:34
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=40.15 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.15,40.7,39.5 dB	Time=2025-03-26 22:00:35
#
# RS232 read data:N:042.4dB
#
# RS232 read data:N:041.9dB
#
# Valor medio medido=42.15 dB
#
# Valor máximo medido 42.4 dB
#
# Valor minimo medido 41.9 dB
#
# Medida(media, máximo, minimo)=42.15,42.4,41.9 dB	Time=2025-03-26 22:00:36
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:041.6dB
#
# Valor medio medido=41.11 dB
#
# Valor máximo medido 41.6 dB
#
# Valor minimo medido 40.6 dB
#
# Medida(media, máximo, minimo)=41.11,41.6,40.6 dB	Time=2025-03-26 22:00:37
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:042.9dB
#
# RS232 read data:N:042.0dB
#
# Valor medio medido=42.0 dB
#
# Valor máximo medido 42.9 dB
#
# Valor minimo medido 41.0 dB
#
# Medida(media, máximo, minimo)=42.0,42.9,41.0 dB	Time=2025-03-26 22:00:38
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:040.8dB
#
# Valor medio medido=40.8 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 40.8 dB
#
# Medida(media, máximo, minimo)=40.8,40.8,40.8 dB	Time=2025-03-26 22:00:39
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=40.25 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=40.25,41.0,39.7 dB	Time=2025-03-26 22:00:40
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=39.6 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=39.6,40.5,38.6 dB	Time=2025-03-26 22:00:41
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=39.88 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=39.88,40.4,39.1 dB	Time=2025-03-26 22:00:42
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=40.25 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 40.0 dB
#
# Medida(media, máximo, minimo)=40.25,40.5,40.0 dB	Time=2025-03-26 22:00:43
#
# RS232 read data:N:038.6dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=39.22 dB
#
# Valor máximo medido 39.8 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=39.22,39.8,38.6 dB	Time=2025-03-26 22:00:44
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=39.75 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 38.9 dB
#
# Medida(media, máximo, minimo)=39.75,40.2,38.9 dB	Time=2025-03-26 22:00:45
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:039.0dB
#
# Valor medio medido=39.57 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=39.57,40.1,39.0 dB	Time=2025-03-26 22:00:46
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:040.0dB
#
# Valor medio medido=39.8 dB
#
# Valor máximo medido 40.0 dB
#
# Valor minimo medido 39.6 dB
#
# Medida(media, máximo, minimo)=39.8,40.0,39.6 dB	Time=2025-03-26 22:00:47
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=39.45 dB
#
# Valor máximo medido 39.7 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.45,39.7,39.2 dB	Time=2025-03-26 22:00:48
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.17 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=39.17,39.4,39.0 dB	Time=2025-03-26 22:00:49
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:038.2dB
#
# Valor medio medido=38.98 dB
#
# Valor máximo medido 39.7 dB
#
# Valor minimo medido 38.2 dB
#
# Medida(media, máximo, minimo)=38.98,39.7,38.2 dB	Time=2025-03-26 22:00:50
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=40.15 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.15,40.8,39.5 dB	Time=2025-03-26 22:00:51
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=40.11 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 39.6 dB
#
# Medida(media, máximo, minimo)=40.11,40.6,39.6 dB	Time=2025-03-26 22:00:52
#
# RS232 read data:N:040.9dB
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:040.6dB
#
# Valor medio medido=40.26 dB
#
# Valor máximo medido 40.9 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=40.26,40.9,39.2 dB	Time=2025-03-26 22:00:53
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=39.81 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=39.81,40.2,39.4 dB	Time=2025-03-26 22:00:54
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:041.9dB
#
# Valor medio medido=41.41 dB
#
# Valor máximo medido 41.9 dB
#
# Valor minimo medido 41.0 dB
#
# Medida(media, máximo, minimo)=41.41,41.9,41.0 dB	Time=2025-03-26 22:00:55
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=40.15 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.15,40.4,39.9 dB	Time=2025-03-26 22:00:56
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:040.8dB
#
# Valor medio medido=40.75 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 40.7 dB
#
# Medida(media, máximo, minimo)=40.75,40.8,40.7 dB	Time=2025-03-26 22:00:57
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:040.8dB
#
# Valor medio medido=40.51 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.51,40.8,39.9 dB	Time=2025-03-26 22:00:58
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=39.78 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=39.78,40.5,39.0 dB	Time=2025-03-26 22:00:59
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:038.6dB
#
# Valor medio medido=39.07 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 38.6 dB
#
# Medida(media, máximo, minimo)=39.07,39.4,38.6 dB	Time=2025-03-26 22:01:00
#
# RS232 read data:N:040.9dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=40.23 dB
#
# Valor máximo medido 40.9 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.23,40.9,39.5 dB	Time=2025-03-26 22:01:01
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=40.61 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 40.3 dB
#
# Medida(media, máximo, minimo)=40.61,41.0,40.3 dB	Time=2025-03-26 22:01:02
#
# RS232 read data:N:040.0dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=40.1 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 40.0 dB
#
# Medida(media, máximo, minimo)=40.1,40.2,40.0 dB	Time=2025-03-26 22:01:03
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:041.3dB
#
# Valor medio medido=41.27 dB
#
# Valor máximo medido 41.3 dB
#
# Valor minimo medido 41.2 dB
#
# Medida(media, máximo, minimo)=41.27,41.3,41.2 dB	Time=2025-03-26 22:01:04
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=39.96 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=39.96,40.4,39.5 dB	Time=2025-03-26 22:01:05
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=39.61 dB
#
# Valor máximo medido 39.9 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=39.61,39.9,39.3 dB	Time=2025-03-26 22:01:06
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=39.92 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=39.92,40.7,39.1 dB	Time=2025-03-26 22:01:07
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=40.11 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=40.11,40.4,39.8 dB	Time=2025-03-26 22:01:08
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=39.57 dB
#
# Valor máximo medido 39.9 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.57,39.9,39.2 dB	Time=2025-03-26 22:01:09
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:040.6dB
#
# Valor medio medido=40.07 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.07,40.6,39.5 dB	Time=2025-03-26 22:01:10
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=40.18 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 39.6 dB
#
# Medida(media, máximo, minimo)=40.18,40.6,39.6 dB	Time=2025-03-26 22:01:11
#
# RS232 read data:N:038.3dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=39.25 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=39.25,40.1,38.3 dB	Time=2025-03-26 22:01:12
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=39.86 dB
#
# Valor máximo medido 41.2 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=39.86,41.2,39.0 dB	Time=2025-03-26 22:01:13
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=40.71 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo, minimo)=40.71,41.0,40.4 dB	Time=2025-03-26 22:01:14
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:041.7dB
#
# Valor medio medido=41.07 dB
#
# Valor máximo medido 41.7 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo, minimo)=41.07,41.7,40.4 dB	Time=2025-03-26 22:01:15
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.5 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=39.5,39.6,39.4 dB	Time=2025-03-26 22:01:16
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:038.4dB
#
# Valor medio medido=38.91 dB
#
# Valor máximo medido 39.4 dB
#
# Valor minimo medido 38.4 dB
#
# Medida(media, máximo, minimo)=38.91,39.4,38.4 dB	Time=2025-03-26 22:01:17
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:041.6dB
#
# Valor medio medido=41.01 dB
#
# Valor máximo medido 41.6 dB
#
# Valor minimo medido 40.6 dB
#
# Medida(media, máximo, minimo)=41.01,41.6,40.6 dB	Time=2025-03-26 22:01:18
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=40.66 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 40.3 dB
#
# Medida(media, máximo, minimo)=40.66,41.0,40.3 dB	Time=2025-03-26 22:01:19
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:041.3dB
#
# Valor medio medido=40.05 dB
#
# Valor máximo medido 41.3 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=40.05,41.3,39.3 dB	Time=2025-03-26 22:01:20
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=40.61 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 40.2 dB
#
# Medida(media, máximo, minimo)=40.61,41.0,40.2 dB	Time=2025-03-26 22:01:21
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:041.4dB
#
# Valor medio medido=40.6 dB
#
# Valor máximo medido 41.4 dB
#
# Valor minimo medido 39.6 dB
#
# Medida(media, máximo, minimo)=40.6,41.4,39.6 dB	Time=2025-03-26 22:01:22
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=40.25 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=40.25,40.4,40.1 dB	Time=2025-03-26 22:01:23
#
# RS232 read data:N:046.8dB
#
# RS232 read data:N:044.1dB
#
# Valor medio medido=45.55 dB
#
# Valor máximo medido 46.8 dB
#
# Valor minimo medido 44.1 dB
#
# Medida(media, máximo, minimo)=45.55,46.8,44.1 dB	Time=2025-03-26 22:01:24
#
# RS232 read data:N:041.4dB
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=40.86 dB
#
# Valor máximo medido 41.4 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.86,41.4,39.9 dB	Time=2025-03-26 22:01:25
#
# RS232 read data:N:042.4dB
#
# RS232 read data:N:041.3dB
#
# Valor medio medido=41.87 dB
#
# Valor máximo medido 42.4 dB
#
# Valor minimo medido 41.3 dB
#
# Medida(media, máximo, minimo)=41.87,42.4,41.3 dB	Time=2025-03-26 22:01:26
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=40.0 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.0,40.1,39.9 dB	Time=2025-03-26 22:01:27
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=39.9 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=39.9,40.2,39.7 dB	Time=2025-03-26 22:01:28
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:040.0dB
#
# Valor medio medido=39.9 dB
#
# Valor máximo medido 40.0 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=39.9,40.0,39.8 dB	Time=2025-03-26 22:01:29
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=39.75 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=39.75,40.4,39.0 dB	Time=2025-03-26 22:01:30
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=40.0 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.0,40.1,39.9 dB	Time=2025-03-26 22:01:31
#
# RS232 read data:N:038.5dB
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=39.39 dB
#
# Valor máximo medido 40.1 dB
#
# Valor minimo medido 38.5 dB
#
# Medida(media, máximo, minimo)=39.39,40.1,38.5 dB	Time=2025-03-26 22:01:32
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=39.73 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=39.73,40.4,39.0 dB	Time=2025-03-26 22:01:33
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=40.11 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=40.11,41.0,39.0 dB	Time=2025-03-26 22:01:34
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=39.45 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=39.45,39.5,39.4 dB	Time=2025-03-26 22:01:35
#
# RS232 read data:N:038.9dB
#
# RS232 read data:N:041.4dB
#
# RS232 read data:N:040.3dB
#
# Valor medio medido=40.26 dB
#
# Valor máximo medido 41.4 dB
#
# Valor minimo medido 38.9 dB
#
# Medida(media, máximo, minimo)=40.26,41.4,38.9 dB	Time=2025-03-26 22:01:36
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:041.6dB
#
# Valor medio medido=41.4 dB
#
# Valor máximo medido 41.6 dB
#
# Valor minimo medido 41.2 dB
#
# Medida(media, máximo, minimo)=41.4,41.6,41.2 dB	Time=2025-03-26 22:01:37
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=40.63 dB
#
# Valor máximo medido 41.3 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.63,41.3,39.9 dB	Time=2025-03-26 22:01:38
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=40.18 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 39.6 dB
#
# Medida(media, máximo, minimo)=40.18,40.5,39.6 dB	Time=2025-03-26 22:01:39
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:038.9dB
#
# Valor medio medido=39.41 dB
#
# Valor máximo medido 39.9 dB
#
# Valor minimo medido 38.9 dB
#
# Medida(media, máximo, minimo)=39.41,39.9,38.9 dB	Time=2025-03-26 22:01:40
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:041.8dB
#
# RS232 read data:N:040.6dB
#
# Valor medio medido=40.99 dB
#
# Valor máximo medido 41.8 dB
#
# Valor minimo medido 40.5 dB
#
# Medida(media, máximo, minimo)=40.99,41.8,40.5 dB	Time=2025-03-26 22:01:41
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:040.7dB
#
# Valor medio medido=40.12 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.12,40.7,39.5 dB	Time=2025-03-26 22:01:42
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:040.9dB
#
# Valor medio medido=40.39 dB
#
# Valor máximo medido 40.9 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=40.39,40.9,39.4 dB	Time=2025-03-26 22:01:43
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=40.1 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=40.1,41.0,39.1 dB	Time=2025-03-26 22:01:44
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=40.25 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=40.25,40.4,40.1 dB	Time=2025-03-26 22:01:45
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=40.24 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=40.24,40.8,39.7 dB	Time=2025-03-26 22:01:46
#
# RS232 read data:N:042.4dB
#
# RS232 read data:N:041.7dB
#
# Valor medio medido=42.06 dB
#
# Valor máximo medido 42.4 dB
#
# Valor minimo medido 41.7 dB
#
# Medida(media, máximo, minimo)=42.06,42.4,41.7 dB	Time=2025-03-26 22:01:47
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:042.6dB
#
# RS232 read data:N:042.1dB
#
# Valor medio medido=41.61 dB
#
# Valor máximo medido 42.6 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=41.61,42.6,39.9 dB	Time=2025-03-26 22:01:48
#
# RS232 read data:N:042.2dB
#
# RS232 read data:N:043.8dB
#
# Valor medio medido=43.04 dB
#
# Valor máximo medido 43.8 dB
#
# Valor minimo medido 42.2 dB
#
# Medida(media, máximo, minimo)=43.04,43.8,42.2 dB	Time=2025-03-26 22:01:49
#
# RS232 read data:N:043.0dB
#
# RS232 read data:N:042.4dB
#
# Valor medio medido=42.71 dB
#
# Valor máximo medido 43.0 dB
#
# Valor minimo medido 42.4 dB
#
# Medida(media, máximo, minimo)=42.71,43.0,42.4 dB	Time=2025-03-26 22:01:50
#
# RS232 read data:N:043.5dB
#
# RS232 read data:N:042.0dB
#
# RS232 read data:N:041.6dB
#
# Valor medio medido=42.41 dB
#
# Valor máximo medido 43.5 dB
#
# Valor minimo medido 41.6 dB
#
# Medida(media, máximo, minimo)=42.41,43.5,41.6 dB	Time=2025-03-26 22:01:51
#
# RS232 read data:N:045.6dB
#
# RS232 read data:N:043.5dB
#
# Valor medio medido=44.61 dB
#
# Valor máximo medido 45.6 dB
#
# Valor minimo medido 43.5 dB
#
# Medida(media, máximo, minimo)=44.61,45.6,43.5 dB	Time=2025-03-26 22:01:52
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:040.6dB
#
# Valor medio medido=40.65 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 40.6 dB
#
# Medida(media, máximo, minimo)=40.65,40.7,40.6 dB	Time=2025-03-26 22:01:53
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:041.4dB
#
# Valor medio medido=41.0 dB
#
# Valor máximo medido 41.4 dB
#
# Valor minimo medido 40.8 dB
#
# Medida(media, máximo, minimo)=41.0,41.4,40.8 dB	Time=2025-03-26 22:01:54
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:041.3dB
#
# Valor medio medido=41.05 dB
#
# Valor máximo medido 41.3 dB
#
# Valor minimo medido 40.8 dB
#
# Medida(media, máximo, minimo)=41.05,41.3,40.8 dB	Time=2025-03-26 22:01:55
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:043.2dB
#
# RS232 read data:N:042.1dB
#
# Valor medio medido=42.03 dB
#
# Valor máximo medido 43.2 dB
#
# Valor minimo medido 40.6 dB
#
# Medida(media, máximo, minimo)=42.03,43.2,40.6 dB	Time=2025-03-26 22:01:56
#
# RS232 read data:N:041.9dB
#
# RS232 read data:N:041.5dB
#
# Valor medio medido=41.7 dB
#
# Valor máximo medido 41.9 dB
#
# Valor minimo medido 41.5 dB
#
# Medida(media, máximo, minimo)=41.7,41.9,41.5 dB	Time=2025-03-26 22:01:57
#
# RS232 read data:N:041.4dB
#
# RS232 read data:N:040.6dB
#
# Valor medio medido=41.01 dB
#
# Valor máximo medido 41.4 dB
#
# Valor minimo medido 40.6 dB
#
# Medida(media, máximo, minimo)=41.01,41.4,40.6 dB	Time=2025-03-26 22:01:58
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:048.8dB
#
# Valor medio medido=44.39 dB
#
# Valor máximo medido 48.8 dB
#
# Valor minimo medido 40.5 dB
#
# Medida(media, máximo, minimo)=44.39,48.8,40.5 dB	Time=2025-03-26 22:01:59
#
# RS232 read data:N:047.5dB
#
# RS232 read data:N:042.8dB
#
# Valor medio medido=45.46 dB
#
# Valor máximo medido 47.5 dB
#
# Valor minimo medido 42.8 dB
#
# Medida(media, máximo, minimo)=45.46,47.5,42.8 dB	Time=2025-03-26 22:02:00
#
# RS232 read data:N:042.7dB
#
# RS232 read data:N:042.1dB
#
# Valor medio medido=42.41 dB
#
# Valor máximo medido 42.7 dB
#
# Valor minimo medido 42.1 dB
#
# Medida(media, máximo, minimo)=42.41,42.7,42.1 dB	Time=2025-03-26 22:02:01
#
# RS232 read data:N:041.6dB
#
# RS232 read data:N:040.9dB
#
# RS232 read data:N:041.1dB
#
# Valor medio medido=41.21 dB
#
# Valor máximo medido 41.6 dB
#
# Valor minimo medido 40.9 dB
#
# Medida(media, máximo, minimo)=41.21,41.6,40.9 dB	Time=2025-03-26 22:02:02
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=40.58 dB
#
# Valor máximo medido 41.3 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=40.58,41.3,39.8 dB	Time=2025-03-26 22:02:03
#
# RS232 read data:N:042.0dB
#
# RS232 read data:N:043.9dB
#
# RS232 read data:N:042.2dB
#
# Valor medio medido=42.74 dB
#
# Valor máximo medido 43.9 dB
#
# Valor minimo medido 42.0 dB
#
# Medida(media, máximo, minimo)=42.74,43.9,42.0 dB	Time=2025-03-26 22:02:04
#
# RS232 read data:N:042.3dB
#
# RS232 read data:N:043.2dB
#
# Valor medio medido=42.76 dB
#
# Valor máximo medido 43.2 dB
#
# Valor minimo medido 42.3 dB
#
# Medida(media, máximo, minimo)=42.76,43.2,42.3 dB	Time=2025-03-26 22:02:05
#
# RS232 read data:N:043.8dB
#
# RS232 read data:N:042.7dB
#
# Valor medio medido=43.27 dB
#
# Valor máximo medido 43.8 dB
#
# Valor minimo medido 42.7 dB
#
# Medida(media, máximo, minimo)=43.27,43.8,42.7 dB	Time=2025-03-26 22:02:06
#
# RS232 read data:N:044.5dB
#
# RS232 read data:N:050.9dB
#
# Valor medio medido=48.28 dB
#
# Valor máximo medido 50.9 dB
#
# Valor minimo medido 44.5 dB
#
# Medida(media, máximo, minimo)=48.28,50.9,44.5 dB	Time=2025-03-26 22:02:07
#
# RS232 read data:N:045.5dB
#
# RS232 read data:N:043.8dB
#
# RS232 read data:N:050.6dB
#
# Valor medio medido=47.13 dB
#
# Valor máximo medido 50.6 dB
#
# Valor minimo medido 43.8 dB
#
# Medida(media, máximo, minimo)=47.13,50.6,43.8 dB	Time=2025-03-26 22:02:08
#
# RS232 read data:N:044.0dB
#
# RS232 read data:N:045.6dB
#
# Valor medio medido=44.84 dB
#
# Valor máximo medido 45.6 dB
#
# Valor minimo medido 44.0 dB
#
# Medida(media, máximo, minimo)=44.84,45.6,44.0 dB	Time=2025-03-26 22:02:09
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=41.1 dB
#
# Valor máximo medido 41.2 dB
#
# Valor minimo medido 41.0 dB
#
# Medida(media, máximo, minimo)=41.1,41.2,41.0 dB	Time=2025-03-26 22:02:10
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:043.2dB
#
# RS232 read data:N:042.4dB
#
# Valor medio medido=42.33 dB
#
# Valor máximo medido 43.2 dB
#
# Valor minimo medido 41.3 dB
#
# Medida(media, máximo, minimo)=42.33,43.2,41.3 dB	Time=2025-03-26 22:02:11
#
# RS232 read data:N:043.2dB
#
# RS232 read data:N:041.7dB
#
# Valor medio medido=42.48 dB
#
# Valor máximo medido 43.2 dB
#
# Valor minimo medido 41.7 dB
#
# Medida(media, máximo, minimo)=42.48,43.2,41.7 dB	Time=2025-03-26 22:02:12
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:039.0dB
#
# Valor medio medido=40.06 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=40.06,40.6,39.0 dB	Time=2025-03-26 22:02:13
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=40.35 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=40.35,40.6,40.1 dB	Time=2025-03-26 22:02:14
#
# RS232 read data:N:042.6dB
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:041.4dB
#
# Valor medio medido=41.26 dB
#
# Valor máximo medido 42.6 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=41.26,42.6,39.5 dB	Time=2025-03-26 22:02:15
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=40.66 dB
#
# Valor máximo medido 41.1 dB
#
# Valor minimo medido 40.2 dB
#
# Medida(media, máximo, minimo)=40.66,41.1,40.2 dB	Time=2025-03-26 22:02:16
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=40.71 dB
#
# Valor máximo medido 41.2 dB
#
# Valor minimo medido 40.2 dB
#
# Medida(media, máximo, minimo)=40.71,41.2,40.2 dB	Time=2025-03-26 22:02:17
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=40.1 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=40.1,40.3,39.8 dB	Time=2025-03-26 22:02:18
#
# RS232 read data:N:041.5dB
#
# RS232 read data:N:041.8dB
#
# Valor medio medido=41.65 dB
#
# Valor máximo medido 41.8 dB
#
# Valor minimo medido 41.5 dB
#
# Medida(media, máximo, minimo)=41.65,41.8,41.5 dB	Time=2025-03-26 22:02:19
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=40.08 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=40.08,40.5,39.4 dB	Time=2025-03-26 22:02:20
#
# RS232 read data:N:042.7dB
#
# RS232 read data:N:045.0dB
#
# Valor medio medido=43.93 dB
#
# Valor máximo medido 45.0 dB
#
# Valor minimo medido 42.7 dB
#
# Medida(media, máximo, minimo)=43.93,45.0,42.7 dB	Time=2025-03-26 22:02:21
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:044.8dB
#
# Valor medio medido=42.8 dB
#
# Valor máximo medido 44.8 dB
#
# Valor minimo medido 40.2 dB
#
# Medida(media, máximo, minimo)=42.8,44.8,40.2 dB	Time=2025-03-26 22:02:22
#
# RS232 read data:N:044.8dB
#
# RS232 read data:N:040.9dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=41.96 dB
#
# Valor máximo medido 44.8 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=41.96,44.8,39.2 dB	Time=2025-03-26 22:02:23
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:040.3dB
#
# Valor medio medido=39.96 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 39.6 dB
#
# Medida(media, máximo, minimo)=39.96,40.3,39.6 dB	Time=2025-03-26 22:02:24
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:042.7dB
#
# Valor medio medido=41.33 dB
#
# Valor máximo medido 42.7 dB
#
# Valor minimo medido 40.5 dB
#
# Medida(media, máximo, minimo)=41.33,42.7,40.5 dB	Time=2025-03-26 22:02:25
#
# RS232 read data:N:041.5dB
#
# RS232 read data:N:042.3dB
#
# Valor medio medido=41.91 dB
#
# Valor máximo medido 42.3 dB
#
# Valor minimo medido 41.5 dB
#
# Medida(media, máximo, minimo)=41.91,42.3,41.5 dB	Time=2025-03-26 22:02:26
#
# RS232 read data:N:040.9dB
#
# RS232 read data:N:041.7dB
#
# Valor medio medido=41.31 dB
#
# Valor máximo medido 41.7 dB
#
# Valor minimo medido 40.9 dB
#
# Medida(media, máximo, minimo)=41.31,41.7,40.9 dB	Time=2025-03-26 22:02:27
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=40.48 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.48,41.0,39.9 dB	Time=2025-03-26 22:02:28
#
# RS232 read data:N:042.2dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=40.87 dB
#
# Valor máximo medido 42.2 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=40.87,42.2,39.3 dB	Time=2025-03-26 22:02:29
#
# RS232 read data:N:041.7dB
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:042.2dB
#
# Valor medio medido=41.47 dB
#
# Valor máximo medido 42.2 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo, minimo)=41.47,42.2,40.4 dB	Time=2025-03-26 22:02:30
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=39.91 dB
#
# Valor máximo medido 40.3 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=39.91,40.3,39.5 dB	Time=2025-03-26 22:02:31
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=40.45 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 40.2 dB
#
# Medida(media, máximo, minimo)=40.45,40.7,40.2 dB	Time=2025-03-26 22:02:32
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=40.91 dB
#
# Valor máximo medido 41.3 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo, minimo)=40.91,41.3,40.4 dB	Time=2025-03-26 22:02:33
#
# RS232 read data:N:048.1dB
#
# RS232 read data:N:041.6dB
#
# Valor medio medido=45.44 dB
#
# Valor máximo medido 48.1 dB
#
# Valor minimo medido 41.6 dB
#
# Medida(media, máximo, minimo)=45.44,48.1,41.6 dB	Time=2025-03-26 22:02:34
#
# RS232 read data:N:043.5dB
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:040.3dB
#
# Valor medio medido=41.44 dB
#
# Valor máximo medido 43.5 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=41.44,43.5,40.1 dB	Time=2025-03-26 22:02:35
#
# RS232 read data:N:044.3dB
#
# RS232 read data:N:040.7dB
#
# Valor medio medido=42.69 dB
#
# Valor máximo medido 44.3 dB
#
# Valor minimo medido 40.7 dB
#
# Medida(media, máximo, minimo)=42.69,44.3,40.7 dB	Time=2025-03-26 22:02:36
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=40.31 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=40.31,40.6,39.8 dB	Time=2025-03-26 22:02:37
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=40.4 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo, minimo)=40.4,40.4,40.4 dB	Time=2025-03-26 22:02:38
#
# RS232 read data:N:048.0dB
#
# RS232 read data:N:043.8dB
#
# Valor medio medido=46.15 dB
#
# Valor máximo medido 48.0 dB
#
# Valor minimo medido 43.8 dB
#
# Medida(media, máximo, minimo)=46.15,48.0,43.8 dB	Time=2025-03-26 22:02:39
#
# RS232 read data:N:043.9dB
#
# RS232 read data:N:043.0dB
#
# RS232 read data:N:043.9dB
#
# Valor medio medido=43.61 dB
#
# Valor máximo medido 43.9 dB
#
# Valor minimo medido 43.0 dB
#
# Medida(media, máximo, minimo)=43.61,43.9,43.0 dB	Time=2025-03-26 22:02:40
#
# RS232 read data:N:044.1dB
#
# RS232 read data:N:040.7dB
#
# Valor medio medido=42.57 dB
#
# Valor máximo medido 44.1 dB
#
# Valor minimo medido 40.7 dB
#
# Medida(media, máximo, minimo)=42.57,44.1,40.7 dB	Time=2025-03-26 22:02:41
#
# RS232 read data:N:040.9dB
#
# RS232 read data:N:041.7dB
#
# Valor medio medido=41.31 dB
#
# Valor máximo medido 41.7 dB
#
# Valor minimo medido 40.9 dB
#
# Medida(media, máximo, minimo)=41.31,41.7,40.9 dB	Time=2025-03-26 22:02:42
#
# RS232 read data:N:046.1dB
#
# RS232 read data:N:042.2dB
#
# RS232 read data:N:040.7dB
#
# Valor medio medido=43.31 dB
#
# Valor máximo medido 46.1 dB
#
# Valor minimo medido 40.7 dB
#
# Medida(media, máximo, minimo)=43.31,46.1,40.7 dB	Time=2025-03-26 22:02:43
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=40.21 dB
#
# Valor máximo medido 40.5 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.21,40.5,39.9 dB	Time=2025-03-26 22:02:44
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:041.7dB
#
# Valor medio medido=41.12 dB
#
# Valor máximo medido 41.7 dB
#
# Valor minimo medido 40.5 dB
#
# Medida(media, máximo, minimo)=41.12,41.7,40.5 dB	Time=2025-03-26 22:02:45
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:042.3dB
#
# Valor medio medido=41.06 dB
#
# Valor máximo medido 42.3 dB
#
# Valor minimo medido 39.9 dB
#
# ...
#
# RS232 read data:N:041.4dB
#
# RS232 read data:N:045.9dB
#
# Valor medio medido=43.94 dB
#
# Valor máximo medido 45.9 dB
#
# Valor minimo medido 41.4 dB
#
# Medida(media, máximo, minimo)=43.94,45.9,41.4 dB	Time=2025-03-26 22:03:06
#
# RS232 read data:N:041.2dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=40.81 dB
#
# Valor máximo medido 41.2 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo, minimo)=40.81,41.2,40.4 dB	Time=2025-03-26 22:03:07
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:041.1dB
#
# Valor medio medido=40.9 dB
#
# Valor máximo medido 41.1 dB
#
# Valor minimo medido 40.8 dB
#
# Medida(media, máximo, minimo)=40.9,41.1,40.8 dB	Time=2025-03-26 22:03:08
#
# RS232 read data:N:041.6dB
#
# RS232 read data:N:040.6dB
#
# Valor medio medido=41.11 dB
#
# Valor máximo medido 41.6 dB
#
# Valor minimo medido 40.6 dB
#
# Medida(media, máximo, minimo)=41.11,41.6,40.6 dB	Time=2025-03-26 22:03:09
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:041.8dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=40.92 dB
#
# Valor máximo medido 41.8 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.92,41.8,39.5 dB	Time=2025-03-26 22:03:10
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:044.9dB
#
# Valor medio medido=43.09 dB
#
# Valor máximo medido 44.9 dB
#
# Valor minimo medido 40.8 dB
#
# Medida(media, máximo, minimo)=43.09,44.9,40.8 dB	Time=2025-03-26 22:03:11
#
# RS232 read data:N:042.6dB
#
# RS232 read data:N:042.3dB
#
# Valor medio medido=42.45 dB
#
# Valor máximo medido 42.6 dB
#
# Valor minimo medido 42.3 dB
#
# Medida(media, máximo, minimo)=42.45,42.6,42.3 dB	Time=2025-03-26 22:03:12
#
# RS232 read data:N:042.0dB
#
# RS232 read data:N:042.0dB
#
# RS232 read data:N:043.8dB
#
# Valor medio medido=42.64 dB
#
# Valor máximo medido 43.8 dB
#
# Valor minimo medido 42.0 dB
#
# Medida(media, máximo, minimo)=42.64,43.8,42.0 dB	Time=2025-03-26 22:03:13
#
# RS232 read data:N:042.5dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=41.78 dB
#
# Valor máximo medido 42.5 dB
#
# Valor minimo medido 41.0 dB
#
# Medida(media, máximo, minimo)=41.78,42.5,41.0 dB	Time=2025-03-26 22:03:14
#
# RS232 read data:N:042.6dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=41.84 dB
#
# Valor máximo medido 42.6 dB
#
# Valor minimo medido 41.0 dB
#
# Medida(media, máximo, minimo)=41.84,42.6,41.0 dB	Time=2025-03-26 22:03:15
#
# RS232 read data:N:042.3dB
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=41.39 dB
#
# Valor máximo medido 42.3 dB
#
# Valor minimo medido 40.8 dB
#
# Medida(media, máximo, minimo)=41.39,42.3,40.8 dB	Time=2025-03-26 22:03:16
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:040.4dB
#
# Valor medio medido=40.86 dB
#
# Valor máximo medido 41.3 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo, minimo)=40.86,41.3,40.4 dB	Time=2025-03-26 22:03:17
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:042.1dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=40.64 dB
#
# Valor máximo medido 42.1 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.64,42.1,39.5 dB	Time=2025-03-26 22:03:18
#
# RS232 read data:N:046.4dB
#
# RS232 read data:N:042.8dB
#
# Valor medio medido=44.79 dB
#
# Valor máximo medido 46.4 dB
#
# Valor minimo medido 42.8 dB
#
# Medida(media, máximo, minimo)=44.79,46.4,42.8 dB	Time=2025-03-26 22:03:19
#
# RS232 read data:N:044.4dB
#
# RS232 read data:N:043.1dB
#
# Valor medio medido=43.77 dB
#
# Valor máximo medido 44.4 dB
#
# Valor minimo medido 43.1 dB
#
# Medida(media, máximo, minimo)=43.77,44.4,43.1 dB	Time=2025-03-26 22:03:20
#
# RS232 read data:N:040.3dB
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:041.5dB
#
# Valor medio medido=40.85 dB
#
# Valor máximo medido 41.5 dB
#
# Valor minimo medido 40.3 dB
#
# Medida(media, máximo, minimo)=40.85,41.5,40.3 dB	Time=2025-03-26 22:03:21
#
# RS232 read data:N:041.7dB
#
# RS232 read data:N:041.1dB
#
# Valor medio medido=41.41 dB
#
# Valor máximo medido 41.7 dB
#
# Valor minimo medido 41.1 dB
#
# Medida(media, máximo, minimo)=41.41,41.7,41.1 dB	Time=2025-03-26 22:03:22
#
# RS232 read data:N:043.5dB
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:040.1dB
#
# Valor medio medido=41.69 dB
#
# Valor máximo medido 43.5 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=41.69,43.5,40.1 dB	Time=2025-03-26 22:03:23
#
# RS232 read data:N:041.7dB
#
# RS232 read data:N:044.7dB
#
# Valor medio medido=43.33 dB
#
# Valor máximo medido 44.7 dB
#
# Valor minimo medido 41.7 dB
#
# Medida(media, máximo, minimo)=43.33,44.7,41.7 dB	Time=2025-03-26 22:03:24
#
# RS232 read data:N:040.2dB
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:042.2dB
#
# Valor medio medido=41.11 dB
#
# Valor máximo medido 42.2 dB
#
# Valor minimo medido 40.2 dB
#
# Medida(media, máximo, minimo)=41.11,42.2,40.2 dB	Time=2025-03-26 22:03:25
#
# RS232 read data:N:041.6dB
#
# RS232 read data:N:041.4dB
#
# Valor medio medido=41.5 dB
#
# Valor máximo medido 41.6 dB
#
# Valor minimo medido 41.4 dB
#
# Medida(media, máximo, minimo)=41.5,41.6,41.4 dB	Time=2025-03-26 22:03:26
#
# RS232 read data:N:044.4dB
#
# RS232 read data:N:041.4dB
#
# Valor medio medido=43.03 dB
#
# Valor máximo medido 44.4 dB
#
# Valor minimo medido 41.4 dB
#
# Medida(media, máximo, minimo)=43.03,44.4,41.4 dB	Time=2025-03-26 22:03:27
#
# RS232 read data:N:042.9dB
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=41.17 dB
#
# Valor máximo medido 42.9 dB
#
# Valor minimo medido 39.8 dB
#
# Medida(media, máximo, minimo)=41.17,42.9,39.8 dB	Time=2025-03-26 22:03:28
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:042.1dB
#
# Valor medio medido=41.34 dB
#
# Valor máximo medido 42.1 dB
#
# Valor minimo medido 40.5 dB
#
# Medida(media, máximo, minimo)=41.34,42.1,40.5 dB	Time=2025-03-26 22:03:29
#
# RS232 read data:N:041.5dB
#
# RS232 read data:N:041.3dB
#
# RS232 read data:N:041.9dB
# Valor medio medido=41.4 dB
#
# Valor máximo medido 41.5 dB
#
# Valor minimo medido 41.3 dB
#
# Medida(media, máximo, minimo)=41.4,41.5,41.3 dB	Time=2025-03-26 22:03:30
#
#
# RS232 read data:N:041.9dB
#
# RS232 read data:N:040.9dB
#
# Valor medio medido=41.58 dB
#
# Valor máximo medido 41.9 dB
#
# Valor minimo medido 40.9 dB
#
# Medida(media, máximo, minimo)=41.58,41.9,40.9 dB	Time=2025-03-26 22:03:31
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:042.3dB
#
# Valor medio medido=41.49 dB
#
# Valor máximo medido 42.3 dB
#
# Valor minimo medido 40.6 dB
#
# Medida(media, máximo, minimo)=41.49,42.3,40.6 dB	Time=2025-03-26 22:03:32
#
# RS232 read data:N:039.9dB
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:040.5dB
#
# Valor medio medido=40.51 dB
#
# Valor máximo medido 41.1 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.51,41.1,39.9 dB	Time=2025-03-26 22:03:33
#
# RS232 read data:N:041.4dB
#
# RS232 read data:N:041.3dB
#
# Valor medio medido=41.35 dB
#
# Valor máximo medido 41.4 dB
#
# Valor minimo medido 41.3 dB
#
# Medida(media, máximo, minimo)=41.35,41.4,41.3 dB	Time=2025-03-26 22:03:34
#
# RS232 read data:N:041.7dB
#
# RS232 read data:N:041.8dB
#
# Valor medio medido=41.75 dB
#
# Valor máximo medido 41.8 dB
#
# Valor minimo medido 41.7 dB
#
# Medida(media, máximo, minimo)=41.75,41.8,41.7 dB	Time=2025-03-26 22:03:35
#
# RS232 read data:N:046.9dB
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:046.2dB
#
# Valor medio medido=45.07 dB
#
# Valor máximo medido 46.9 dB
#
# Valor minimo medido 41.0 dB
#
# Medida(media, máximo, minimo)=45.07,46.9,41.0 dB	Time=2025-03-26 22:03:36
#
# RS232 read data:N:042.7dB
#
# RS232 read data:N:043.4dB
#
# Valor medio medido=43.06 dB
#
# Valor máximo medido 43.4 dB
#
# Valor minimo medido 42.7 dB
#
# Medida(media, máximo, minimo)=43.06,43.4,42.7 dB	Time=2025-03-26 22:03:37
#
# RS232 read data:N:041.5dB
#
# RS232 read data:N:043.9dB
#
# Valor medio medido=42.78 dB
#
# Valor máximo medido 43.9 dB
#
# Valor minimo medido 41.5 dB
#
# Medida(media, máximo, minimo)=42.78,43.9,41.5 dB	Time=2025-03-26 22:03:38
#
# RS232 read data:N:046.7dB
#
# RS232 read data:N:049.1dB
#
# RS232 read data:N:046.2dB
#
# Valor medio medido=47.43 dB
#
# Valor máximo medido 49.1 dB
#
# Valor minimo medido 46.2 dB
#
# Medida(media, máximo, minimo)=47.43,49.1,46.2 dB	Time=2025-03-26 22:03:39
#
# RS232 read data:N:044.7dB
#
# RS232 read data:N:042.5dB
#
# Valor medio medido=43.67 dB
#
# Valor máximo medido 44.7 dB
#
# Valor minimo medido 42.5 dB
#
# Medida(media, máximo, minimo)=43.67,44.7,42.5 dB	Time=2025-03-26 22:03:40
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:042.4dB
#
# Valor medio medido=41.73 dB
#
# Valor máximo medido 42.4 dB
#
# Valor minimo medido 41.0 dB
#
# Medida(media, máximo, minimo)=41.73,42.4,41.0 dB	Time=2025-03-26 22:03:41
#
# RS232 read data:N:046.9dB
#
# RS232 read data:N:043.3dB
#
# RS232 read data:N:040.6dB
#
# Valor medio medido=43.99 dB
#
# Valor máximo medido 46.9 dB
#
# Valor minimo medido 40.6 dB
#
# Medida(media, máximo, minimo)=43.99,46.9,40.6 dB	Time=2025-03-26 22:03:42
#
# RS232 read data:N:042.2dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=41.62 dB
#
# Valor máximo medido 42.2 dB
#
# Valor minimo medido 41.0 dB
#
# Medida(media, máximo, minimo)=41.62,42.2,41.0 dB	Time=2025-03-26 22:03:43
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:041.4dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=40.18 dB
#
# Valor máximo medido 41.4 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=40.18,41.4,39.4 dB	Time=2025-03-26 22:03:44
#
# RS232 read data:N:045.3dB
#
# RS232 read data:N:043.9dB
#
# Valor medio medido=44.63 dB
#
# Valor máximo medido 45.3 dB
#
# Valor minimo medido 43.9 dB
#
# Medida(media, máximo, minimo)=44.63,45.3,43.9 dB	Time=2025-03-26 22:03:45
#
# RS232 read data:N:043.0dB
#
# RS232 read data:N:042.5dB
#
# Valor medio medido=42.75 dB
#
# Valor máximo medido 43.0 dB
#
# Valor minimo medido 42.5 dB
#
# Medida(media, máximo, minimo)=42.75,43.0,42.5 dB	Time=2025-03-26 22:03:46
#
# RS232 read data:N:040.5dB
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=40.18 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=40.18,40.6,39.4 dB	Time=2025-03-26 22:03:47
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:039.7dB
#
# Valor medio medido=40.43 dB
#
# Valor máximo medido 41.1 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=40.43,41.1,39.7 dB	Time=2025-03-26 22:03:48
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=39.76 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=39.76,40.6,39.3 dB	Time=2025-03-26 22:03:49
#
# RS232 read data:N:039.1dB
#
# RS232 read data:N:039.6dB
#
# Valor medio medido=39.35 dB
#
# Valor máximo medido 39.6 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=39.35,39.6,39.1 dB	Time=2025-03-26 22:03:50
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:039.4dB
#
# Valor medio medido=39.84 dB
#
# Valor máximo medido 40.4 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=39.84,40.4,39.4 dB	Time=2025-03-26 22:03:51
#
# RS232 read data:N:039.3dB
#
# RS232 read data:N:040.6dB
#
# Valor medio medido=39.97 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 39.3 dB
#
# Medida(media, máximo, minimo)=39.97,40.6,39.3 dB	Time=2025-03-26 22:03:52
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:039.9dB
#
# Valor medio medido=40.31 dB
#
# Valor máximo medido 40.7 dB
#
# Valor minimo medido 39.9 dB
#
# Medida(media, máximo, minimo)=40.31,40.7,39.9 dB	Time=2025-03-26 22:03:53
#
# RS232 read data:N:039.8dB
#
# RS232 read data:N:039.0dB
#
# RS232 read data:N:039.0dB
#
# Valor medio medido=39.27 dB
#
# Valor máximo medido 39.8 dB
#
# Valor minimo medido 39.0 dB
#
# Medida(media, máximo, minimo)=39.27,39.8,39.0 dB	Time=2025-03-26 22:03:54
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:040.2dB
#
# Valor medio medido=40.15 dB
#
# Valor máximo medido 40.2 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=40.15,40.2,40.1 dB	Time=2025-03-26 22:03:55
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:038.8dB
#
# RS232 read data:N:039.8dB
#
# Valor medio medido=39.28 dB
#
# Valor máximo medido 39.8 dB
#
# Valor minimo medido 38.8 dB
#
# Medida(media, máximo, minimo)=39.28,39.8,38.8 dB	Time=2025-03-26 22:03:56
#
# RS232 read data:N:039.7dB
#
# RS232 read data:N:041.4dB
#
# Valor medio medido=40.59 dB
#
# Valor máximo medido 41.4 dB
#
# Valor minimo medido 39.7 dB
#
# Medida(media, máximo, minimo)=40.59,41.4,39.7 dB	Time=2025-03-26 22:03:57
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:040.8dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=40.06 dB
#
# Valor máximo medido 40.8 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=40.06,40.8,39.2 dB	Time=2025-03-26 22:03:58
#
# RS232 read data:N:039.2dB
#
# RS232 read data:N:039.3dB
#
# Valor medio medido=39.25 dB
#
# Valor máximo medido 39.3 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=39.25,39.3,39.2 dB	Time=2025-03-26 22:03:59
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:042.5dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=40.81 dB
#
# Valor máximo medido 42.5 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=40.81,42.5,39.2 dB	Time=2025-03-26 22:04:00
#
# RS232 read data:N:040.4dB
#
# RS232 read data:N:041.0dB
#
# Valor medio medido=40.71 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 40.4 dB
#
# Medida(media, máximo, minimo)=40.71,41.0,40.4 dB	Time=2025-03-26 22:04:01
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:044.3dB
#
# Valor medio medido=42.45 dB
#
# Valor máximo medido 44.3 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=42.45,44.3,40.1 dB	Time=2025-03-26 22:04:02
#
# RS232 read data:N:041.5dB
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:039.1dB
#
# Valor medio medido=40.49 dB
#
# Valor máximo medido 41.5 dB
#
# Valor minimo medido 39.1 dB
#
# Medida(media, máximo, minimo)=40.49,41.5,39.1 dB	Time=2025-03-26 22:04:03
#
# RS232 read data:N:042.5dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=41.13 dB
#
# Valor máximo medido 42.5 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=41.13,42.5,39.5 dB	Time=2025-03-26 22:04:04
#
# RS232 read data:N:038.7dB
#
# RS232 read data:N:041.0dB
#
# RS232 read data:N:040.3dB
#
# Valor medio medido=40.05 dB
#
# Valor máximo medido 41.0 dB
#
# Valor minimo medido 38.7 dB
#
# Medida(media, máximo, minimo)=40.05,41.0,38.7 dB	Time=2025-03-26 22:04:05
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:040.6dB
#
# Valor medio medido=40.07 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.07,40.6,39.5 dB	Time=2025-03-26 22:04:06
#
# RS232 read data:N:042.3dB
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:038.9dB
#
# Valor medio medido=40.71 dB
#
# Valor máximo medido 42.3 dB
#
# Valor minimo medido 38.9 dB
#
# Medida(media, máximo, minimo)=40.71,42.3,38.9 dB	Time=2025-03-26 22:04:07
#
# RS232 read data:N:041.1dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=40.34 dB
#
# Valor máximo medido 41.1 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=40.34,41.1,39.5 dB	Time=2025-03-26 22:04:08
#
# RS232 read data:N:041.7dB
#
# RS232 read data:N:039.2dB
#
# Valor medio medido=40.54 dB
#
# Valor máximo medido 41.7 dB
#
# Valor minimo medido 39.2 dB
#
# Medida(media, máximo, minimo)=40.54,41.7,39.2 dB	Time=2025-03-26 22:04:09
#
# RS232 read data:N:040.6dB
#
# RS232 read data:N:039.6dB
#
# RS232 read data:N:038.3dB
#
# Valor medio medido=39.55 dB
#
# Valor máximo medido 40.6 dB
#
# Valor minimo medido 38.3 dB
#
# Medida(media, máximo, minimo)=39.55,40.6,38.3 dB	Time=2025-03-26 22:04:10
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:042.0dB
#
# Valor medio medido=41.1 dB
#
# Valor máximo medido 42.0 dB
#
# Valor minimo medido 40.1 dB
#
# Medida(media, máximo, minimo)=41.1,42.0,40.1 dB	Time=2025-03-26 22:04:11
#
# RS232 read data:N:040.1dB
#
# RS232 read data:N:039.4dB
#
# RS232 read data:N:042.3dB
#
# Valor medio medido=40.69 dB
#
# Valor máximo medido 42.3 dB
#
# Valor minimo medido 39.4 dB
#
# Medida(media, máximo, minimo)=40.69,42.3,39.4 dB	Time=2025-03-26 22:04:12
#
# RS232 read data:N:041.4dB
#
# RS232 read data:N:041.1dB
#
# Valor medio medido=41.25 dB
#
# Valor máximo medido 41.4 dB
#
# Valor minimo medido 41.1 dB
#
# Medida(media, máximo, minimo)=41.25,41.4,41.1 dB	Time=2025-03-26 22:04:13
#
# RS232 read data:N:041.8dB
#
# RS232 read data:N:040.7dB
#
# RS232 read data:N:040.8dB
#
# Valor medio medido=41.11 dB
#
# Valor máximo medido 41.8 dB
#
# Valor minimo medido 40.7 dB
#
# Medida(media, máximo, minimo)=41.11,41.8,40.7 dB	Time=2025-03-26 22:04:14
#
# RS232 read data:N:039.5dB
#
# RS232 read data:N:039.5dB
#
# Valor medio medido=39.5 dB
#
# Valor máximo medido 39.5 dB
#
# Valor minimo medido 39.5 dB
#
# Medida(media, máximo, minimo)=39.5,39.5,39.5 dB	Time=2025-03-26 22:04:15
#
# RS232 read data:
#
# RS232 cerrando el puerto serie.
#
# Measurements saved to log_files/medida_2/type_2 Wed 2025-03-26 21h59m15s.json

# %%
import matplotlib.pyplot as plt

pic_path = 'Pics/medida_2/type_2 '+format_time(time.time(), True)

# Load the measurements from the JSON file.
with open(json_file, 'r') as f:
    measurements = json.load(f)

times = [m["time"] for m in measurements]
means = [m["mean"] for m in measurements]
maxs = [m["max"] for m in measurements]
mins = [m["min"] for m in measurements]

m_number = list(range(0,len(measurements)))

# Plot the measurements
plt.figure(figsize=(10, 6))
plt.plot(m_number, means, label="Mean", color="blue")
plt.plot(m_number, maxs, label="Max", color="red", linestyle="--")
plt.plot(m_number, mins, label="Min", color="green", linestyle="--")
plt.xlim(0, len(measurements)-1)
plt.ylim(30, 60)
plt.xlabel("Samples")
plt.ylabel("Sound Level (dB)")
plt.title("Sound Level Measurements Over Time")
plt.legend()
plt.grid(True)
plt.savefig(pic_path+'.png')
plt.show()

# %% [markdown]
# ## Ejemplo de lectura directa del Serial y almacenamiento en un vector.

# %%
import serial
import math

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'


# Sound level meter.
port_AZ8922 = SELECTED_PORT
ser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port


# Reset the arrays.
sound_level = []

#while(ser.connected):
for x in range(10):
    output = ser.readline().decode('utf-8', 'ignore')
    output = output.strip()
    #print("RS232 read data:"+str(output)+"\n")
    if output.startswith('N:') and output.endswith('dB'):
        salida_texto=float(output.split(':')[1].split('dB')[0])
        sound_level.append(salida_texto) # Para concatenar los valores y formar un Vector/Array
        print("RS232 db="+str(salida_texto)+"\n")     
    
ser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el 
#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia
#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.


# Round up.
#sound_level_mean = round(sound_level_mean,2)
#print("Sound Level(Media)="+str(sound_level_mean)+"\n") 

#Calculamos el máximo en dB
sound_level_max = max(sound_level) #Esto es el máximo de un vector
print(Green + "Sound Level(Max)="+str(sound_level_max)+" db\n") 

#Calculamos el mínomo en dB
sound_level_min = min(sound_level)
print(Magenta+"Sound Level(Min)="+str(sound_level_min)+" db\n") 

#Calculamos la suma de los valores sin decibelios
sound_level_linear = [math.pow(10,x/20) for x in sound_level] 
print(Blue +"Sound Level(linear)="+str(sound_level_linear)+"\n") 

#Pasamos la suma de lo medido en dB
sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
sound_level_mean = 20*math.log10(sound_level_mean)
print(Red + "Sound Level(Mean)="+str(sound_level_mean)+" db\n")
# Out:
# RS232 db=39.6
#
# RS232 db=39.8
#
# RS232 db=39.2
#
# RS232 db=39.0
#
# RS232 db=38.6
#
# RS232 db=41.0
#
# RS232 db=40.0
#
# RS232 db=39.7
#
# RS232 db=39.0
#
# RS232 db=41.0
#
# Sound Level(Max)=41.0 db
#
# Sound Level(Min)=38.6 db
#
# Sound Level(linear)=[95.49925860214358, 97.72372209558101, 91.20108393559102, 89.12509381337455, 85.11380382023768, 112.2018454301963, 100.0, 96.60508789898135, 89.12509381337455, 112.2018454301963]
#
# Sound Level(Mean)=39.72465422503872 db
